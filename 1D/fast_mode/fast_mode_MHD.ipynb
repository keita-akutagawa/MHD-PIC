# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import cv2


import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

from lib_MHDPIC1D.pic1d import *
from lib_MHDPIC1D.mhd1d import *
from lib_MHDPIC1D.interface import *
from lib_MHDPIC1D.remove_noise import *

# %% [markdown]
# fast modeの伝搬 MHDのみ

# %%
c = 1.0
mu_0 = 1.0
epsilon0 = 1.0 / (mu_0 * c**2)
m_electron = 1.0
r_m = 1 / 100
m_ion = m_electron / r_m
t_r = 1.0
ne0_pic = 100 #ここは手動で調整すること
ni0_pic = ne0_pic
B0_pic = np.sqrt(ne0_pic) / 1.0
Te_pic = 0.5 * m_electron * (0.1*c)**2
Ti_pic = Te_pic / t_r
q_electron = -1 * np.sqrt(epsilon0 * Te_pic / ne0_pic)
q_ion = -1 * q_electron
debye_length = np.sqrt(epsilon0 * Te_pic / ne0_pic / q_electron**2)
omega_pe = np.sqrt(ne0_pic * q_electron**2 / m_electron / epsilon0)
omega_pi = np.sqrt(ni0_pic * q_ion**2 / m_ion / epsilon0)
omega_ce = q_electron * B0_pic / m_electron
omega_ci = q_ion * B0_pic / m_ion
VA_pic = B0_pic / np.sqrt(ni0_pic * m_ion + ni0_pic * m_electron)
gamma_pic = 5.0 / 3.0
rho_pic = ni0_pic * m_ion + ne0_pic * m_electron
p_pic = ni0_pic * Ti_pic + ne0_pic * Te_pic
CS_pic = np.sqrt(gamma_pic * p_pic / rho_pic)
v_ion = np.array([0.0, 0.0, 0.0])
v_electron = np.array([0.0, 0.0, 0.0])
v_thermal_electron = np.sqrt(2.0 * Te_pic / m_electron)
v_thermal_ion = np.sqrt(2.0 * Ti_pic / m_ion)
ion_inertial_length = c / omega_pi

dx_pic = debye_length
nx_pic = 200
x_min_pic = 1e-10
x_max_pic = nx_pic * dx_pic - 1e-10
x_coordinate_pic = np.arange(0.0, x_max_pic, dx_pic)
dt_pic = 0.0
d_pic = 0.0

E_pic = np.zeros([3, nx_pic])
B_pic = np.zeros([3, nx_pic])
current_pic = np.zeros([3, nx_pic])
rho_pic = np.zeros(nx_pic)
B_pic[2, :] = B0_pic
beta_pic = (ne0_pic * Te_pic + ni0_pic * Ti_pic) / (B0_pic**2 / 2 / mu_0)

n_ion = int(ni0_pic * nx_pic)
n_electron = int(n_ion * abs(q_ion / q_electron))
x_pic_ion = np.zeros([3, n_ion])
x_pic_electron = np.zeros([3, n_electron])
v_pic_ion = np.zeros([3, n_ion])
v_pic_electron = np.zeros([3, n_electron])

rs_ion = np.random.RandomState(10)
rs_electron = np.random.RandomState(20)
for i in range(nx_pic):
    x_pic_ion[0, i * ni0_pic : (i+1) * ni0_pic] = (rs_ion.rand(ni0_pic) + i) * dx_pic
    x_pic_electron[0, i * ne0_pic : (i+1) * ne0_pic] = (rs_electron.rand(ne0_pic) + i) * dx_pic

v_pic_ion[0, :] = np.asarray(stats.norm.rvs(v_ion[0], v_thermal_ion, size=n_ion, random_state=30))
v_pic_ion[1, :] = np.asarray(stats.norm.rvs(v_ion[1], v_thermal_ion, size=n_ion, random_state=40))
v_pic_ion[2, :] = np.asarray(stats.norm.rvs(v_ion[2], v_thermal_ion, size=n_ion, random_state=50))
v_pic_electron[0, :] = np.asarray(stats.norm.rvs(v_electron[0], v_thermal_electron, size=n_electron, random_state=60))
v_pic_electron[1, :] = np.asarray(stats.norm.rvs(v_electron[1], v_thermal_electron, size=n_electron, random_state=70))
v_pic_electron[2, :] = np.asarray(stats.norm.rvs(v_electron[2], v_thermal_electron, size=n_electron, random_state=80))

print(f"total number of particles is {n_ion + n_electron}.")
print(f"Box size is {nx_pic}")
print(f"ion inertial length is {ion_inertial_length:.1f}")
# Out:
# total number of particles is 40000.
# Box size is 200
# ion inertial length is 141.4

# %% [markdown]
# MHD初期化 \
# U1は上半分、U2は下半分のつもり

# %%
gamma_mhd = 5.0 / 3.0
B0_mhd = B0_pic
rho0_mhd = ne0_pic * m_electron + ni0_pic * m_ion
p0_mhd = ne0_pic * Te_pic + ni0_pic * Ti_pic
VA_mhd = B0_mhd / np.sqrt(rho0_mhd)
CS_mhd = np.sqrt(gamma_mhd * p0_mhd / rho0_mhd)
Cf_mhd = np.sqrt(VA_mhd**2 + CS_mhd**2)
dx_mhd = dx_pic

nx_mhd = 5000
x_min_mhd = 1e-10
x_max_mhd = nx_mhd * dx_mhd - 1e-10
dt_mhd = 0.0
CFL = 0.7
x_coordinate_mhd = np.arange(x_min_mhd, x_max_mhd, dx_mhd)

startpoint = 10
lambda_mhd = 1000.0
kx_mhd = 2.0 * np.pi / lambda_mhd
x_coordinate_mhd_perturbation = np.arange(x_min_mhd, 2.0 * lambda_mhd * dx_mhd, dx_mhd)
perturbation_sin = np.zeros(x_coordinate_mhd.shape)
perturbation_sin[startpoint:startpoint+x_coordinate_mhd_perturbation.shape[0]] = -np.sin(kx_mhd * x_coordinate_mhd_perturbation)

U1 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd * (1.0 + 0.05 * perturbation_sin)
u_init = 0.05 * Cf_mhd * perturbation_sin
v_init = 0.0
w_init = 0.0
Bx_init = 0.0
By_init = 0.0
Bz_init = B0_mhd * (1.0 + 0.05 * perturbation_sin)
p_init = p0_mhd * (1.0 + gamma_mhd * 0.05 * perturbation_sin)
U1[0, :] = rho_init
U1[1, :] = rho_init * u_init
U1[2, :] = rho_init * v_init
U1[3, :] = rho_init * w_init
U1[4, :] = Bx_init
U1[5, :] = By_init
U1[6, :] = Bz_init
U1[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

U2 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd
u_init = 0.0
v_init = 0.0
w_init = 0.0
Bx_init = 0.0
By_init = 0.0
Bz_init = B0_mhd
p_init = p0_mhd
U2[0, :] = rho_init
U2[1, :] = rho_init * u_init
U2[2, :] = rho_init * v_init
U2[3, :] = rho_init * w_init
U2[4, :] = Bx_init
U2[5, :] = By_init
U2[6, :] = Bz_init
U2[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

flux1 = np.zeros(U1.shape)
flux1_bar = np.zeros(flux1.shape)
flux2 = np.zeros(U2.shape)
flux2_bar = np.zeros(flux2.shape)

print(f"U1 size = {U1.shape}, U2 size = {U2.shape}")
# Out:
# U1 size = (8, 5000), U2 size = (8, 5000)

# %%
window_size_convolution_pic = 10
window_size_smoothing_mhd = 5
interface_width = 50

index_interface_mhd_start_left = nx_mhd - interface_width
index_interface_mhd_end_left = nx_mhd
index_interface_mhd_start_right = 0
index_interface_mhd_end_right = interface_width
index_interface_pic_start_left = 0
index_interface_pic_end_left = interface_width
index_interface_pic_start_right = nx_pic - interface_width
index_interface_pic_end_right = nx_pic

x_interface_coordinate_left = np.arange(0, interface_width, 1)
x_interface_coordinate_half_left = np.arange(0.5, interface_width - 0.5, 1)
F_left = interlocking_function(x_interface_coordinate_left)
F_half_left = interlocking_function(x_interface_coordinate_half_left)
F_right = np.flip(F_left)
F_half_right = np.flip(F_half_left)

# %% [markdown]
# 時間発展

# %%
steps = 2000
time_mhd = 0.0

for step in range(steps+1):

    # save
    if (step % 10 == 0):
        print(f"{step} step done... : time_mhd = {time_mhd:.5f}, dt_mhd = {dt_mhd:.5f}")
        np.save(f"./results_MHD_fast_mode/U1_{step}.npy", U1)

    #MHD
    #----------------------------------------------------------- 

    U1_bar = U1.copy()

    rho_mhd = U1[0, :]
    u_mhd = U1[1, :] / rho_mhd
    v_mhd = U1[2, :] / rho_mhd
    w_mhd = U1[3, :] / rho_mhd
    Bx_mhd = U1[4, :]
    By_mhd = U1[5, :]
    Bz_mhd = U1[6, :]
    e_mhd = U1[7, :]
    p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
    flux1 = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, flux1, axis=0)

    cs_mhd = np.sqrt(gamma_mhd * p_mhd / rho_mhd)
    ca_mhd = np.sqrt((Bx_mhd**2 + By_mhd**2 + Bz_mhd**2) / rho_mhd)
    dt_mhd = CFL * np.min(1.0 / ((np.abs(u_mhd) + np.sqrt(cs_mhd**2 + ca_mhd**2)) / dx_mhd))
    if np.isnan(time_mhd):
        print(f"{step} steps (t = {time_mhd:.3f}) : Calculation is crashed!")
        break
    
    U1_bar += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
    U1_bar = boundary_symmetric_x(U1_bar)
    
    rho_mhd = U1_bar[0, :]
    u_mhd = U1_bar[1, :] / rho_mhd
    v_mhd = U1_bar[2, :] / rho_mhd
    w_mhd = U1_bar[3, :] / rho_mhd
    Bx_mhd = U1_bar[4, :]
    By_mhd = U1_bar[5, :]
    Bz_mhd = U1_bar[6, :]
    e_mhd = U1_bar[7, :]
    p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
    flux1_bar = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, flux1_bar, axis=0)
    flux1 = 0.5 * (flux1 + flux1_bar)

    U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
    U1 = boundary_symmetric_x(U1)
    
    time_mhd += dt_mhd
# Out:
# 0 step done... : time_mhd = 0.00000, dt_mhd = 0.00000
# 10 step done... : time_mhd = 64.92980, dt_mhd = 6.49299
# 20 step done... : time_mhd = 129.85989, dt_mhd = 6.49302
# 30 step done... : time_mhd = 194.79035, dt_mhd = 6.49307
# 40 step done... : time_mhd = 259.72128, dt_mhd = 6.49312
# 50 step done... : time_mhd = 324.65278, dt_mhd = 6.49318
# 60 step done... : time_mhd = 389.58495, dt_mhd = 6.49325
# 70 step done... : time_mhd = 454.51786, dt_mhd = 6.49333
# 80 step done... : time_mhd = 519.45157, dt_mhd = 6.49341
# 90 step done... : time_mhd = 584.38612, dt_mhd = 6.49349
# 100 step done... : time_mhd = 649.32154, dt_mhd = 6.49358
# 110 step done... : time_mhd = 714.25782, dt_mhd = 6.49367
# 120 step done... : time_mhd = 779.19495, dt_mhd = 6.49375
# 130 step done... : time_mhd = 844.13288, dt_mhd = 6.49383
# 140 step done... : time_mhd = 909.07155, dt_mhd = 6.49390
# 150 step done... : time_mhd = 974.01089, dt_mhd = 6.49396
# 160 step done... : time_mhd = 1038.95079, dt_mhd = 6.49401
# 170 step done... : time_mhd = 1103.89113, dt_mhd = 6.49405
# 180 step done... : time_mhd = 1168.83181, dt_mhd = 6.49408
# 190 step done... : time_mhd = 1233.77268, dt_mhd = 6.49409
# 200 step done... : time_mhd = 1298.71360, dt_mhd = 6.49409
# 210 step done... : time_mhd = 1363.65441, dt_mhd = 6.49407
# 220 step done... : time_mhd = 1428.59497, dt_mhd = 6.49404
# 230 step done... : time_mhd = 1493.53514, dt_mhd = 6.49400
# 240 step done... : time_mhd = 1558.47479, dt_mhd = 6.49394
# 250 step done... : time_mhd = 1623.41382, dt_mhd = 6.49387
# 260 step done... : time_mhd = 1688.35214, dt_mhd = 6.49380
# 270 step done... : time_mhd = 1753.28970, dt_mhd = 6.49372
# 280 step done... : time_mhd = 1818.22646, dt_mhd = 6.49364
# 290 step done... : time_mhd = 1883.16240, dt_mhd = 6.49356
# 300 step done... : time_mhd = 1948.09754, dt_mhd = 6.49348
# 310 step done... : time_mhd = 2013.03193, dt_mhd = 6.49341
# 320 step done... : time_mhd = 2077.96564, dt_mhd = 6.49334
# 330 step done... : time_mhd = 2142.89874, dt_mhd = 6.49329
# 340 step done... : time_mhd = 2207.83136, dt_mhd = 6.49324
# 350 step done... : time_mhd = 2272.76361, dt_mhd = 6.49321
# 360 step done... : time_mhd = 2337.69564, dt_mhd = 6.49320
# 370 step done... : time_mhd = 2402.62759, dt_mhd = 6.49319
# 380 step done... : time_mhd = 2467.55959, dt_mhd = 6.49321
# 390 step done... : time_mhd = 2532.49178, dt_mhd = 6.49323
# 400 step done... : time_mhd = 2597.42429, dt_mhd = 6.49327
# 410 step done... : time_mhd = 2662.35725, dt_mhd = 6.49332
# 420 step done... : time_mhd = 2727.29079, dt_mhd = 6.49338
# 430 step done... : time_mhd = 2792.22502, dt_mhd = 6.49346
# 440 step done... : time_mhd = 2857.16002, dt_mhd = 6.49354
# 450 step done... : time_mhd = 2922.09587, dt_mhd = 6.49362
# 460 step done... : time_mhd = 2987.03261, dt_mhd = 6.49371
# 470 step done... : time_mhd = 3051.97026, dt_mhd = 6.49381
# 480 step done... : time_mhd = 3116.90882, dt_mhd = 6.49390
# 490 step done... : time_mhd = 3181.84827, dt_mhd = 6.49398
# 500 step done... : time_mhd = 3246.78855, dt_mhd = 6.49406
# 510 step done... : time_mhd = 3311.72959, dt_mhd = 6.49414
# 520 step done... : time_mhd = 3376.67130, dt_mhd = 6.49420
# 530 step done... : time_mhd = 3441.61357, dt_mhd = 6.49425
# 540 step done... : time_mhd = 3506.55627, dt_mhd = 6.49429
# 550 step done... : time_mhd = 3571.49928, dt_mhd = 6.49431
# 560 step done... : time_mhd = 3636.44246, dt_mhd = 6.49432
# 570 step done... : time_mhd = 3701.38566, dt_mhd = 6.49432
# 580 step done... : time_mhd = 3766.32873, dt_mhd = 6.49430
# 590 step done... : time_mhd = 3831.27154, dt_mhd = 6.49426
# 600 step done... : time_mhd = 3896.21395, dt_mhd = 6.49422
# 610 step done... : time_mhd = 3961.15585, dt_mhd = 6.49416
# 620 step done... : time_mhd = 4026.09715, dt_mhd = 6.49410
# 630 step done... : time_mhd = 4091.03778, dt_mhd = 6.49403
# 640 step done... : time_mhd = 4155.97769, dt_mhd = 6.49396
# 650 step done... : time_mhd = 4220.91685, dt_mhd = 6.49388
# 660 step done... : time_mhd = 4285.85527, dt_mhd = 6.49381
# 670 step done... : time_mhd = 4350.79296, dt_mhd = 6.49374
# 680 step done... : time_mhd = 4415.72996, dt_mhd = 6.49367
# 690 step done... : time_mhd = 4480.66635, dt_mhd = 6.49361
# 700 step done... : time_mhd = 4545.60220, dt_mhd = 6.49356
# 710 step done... : time_mhd = 4610.53760, dt_mhd = 6.49352
# 720 step done... : time_mhd = 4675.47268, dt_mhd = 6.49350
# 730 step done... : time_mhd = 4740.40755, dt_mhd = 6.49348
# 740 step done... : time_mhd = 4805.34233, dt_mhd = 6.49348
# 750 step done... : time_mhd = 4870.27715, dt_mhd = 6.49349
# 760 step done... : time_mhd = 4935.21212, dt_mhd = 6.49351
# 770 step done... : time_mhd = 5000.14735, dt_mhd = 6.49354
# 780 step done... : time_mhd = 5065.08297, dt_mhd = 6.49358
# 790 step done... : time_mhd = 5130.01907, dt_mhd = 6.49364
# 800 step done... : time_mhd = 5194.95577, dt_mhd = 6.49370
# 810 step done... : time_mhd = 5259.89313, dt_mhd = 6.49377
# 820 step done... : time_mhd = 5324.83124, dt_mhd = 6.49385
# 830 step done... : time_mhd = 5389.77014, dt_mhd = 6.49393
# 840 step done... : time_mhd = 5454.70985, dt_mhd = 6.49401
# 850 step done... : time_mhd = 5519.65039, dt_mhd = 6.49409
# 860 step done... : time_mhd = 5584.59174, dt_mhd = 6.49417
# 870 step done... : time_mhd = 5649.53386, dt_mhd = 6.49425
# 880 step done... : time_mhd = 5714.47670, dt_mhd = 6.49431
# 890 step done... : time_mhd = 5779.42018, dt_mhd = 6.49437
# 900 step done... : time_mhd = 5844.36420, dt_mhd = 6.49442
# 910 step done... : time_mhd = 5909.30865, dt_mhd = 6.49446
# 920 step done... : time_mhd = 5974.25342, dt_mhd = 6.49449
# 930 step done... : time_mhd = 6039.19835, dt_mhd = 6.49450
# 940 step done... : time_mhd = 6104.14337, dt_mhd = 6.49450
# 950 step done... : time_mhd = 6169.08845, dt_mhd = 6.49451
# 960 step done... : time_mhd = 6234.03357, dt_mhd = 6.49451
# 970 step done... : time_mhd = 6298.97874, dt_mhd = 6.49452
# 980 step done... : time_mhd = 6363.92395, dt_mhd = 6.49452
# 990 step done... : time_mhd = 6428.86922, dt_mhd = 6.49453
# 1000 step done... : time_mhd = 6493.81453, dt_mhd = 6.49453
# 1010 step done... : time_mhd = 6558.75989, dt_mhd = 6.49454
# 1020 step done... : time_mhd = 6623.70530, dt_mhd = 6.49454
# 1030 step done... : time_mhd = 6688.65076, dt_mhd = 6.49455
# 1040 step done... : time_mhd = 6753.59626, dt_mhd = 6.49455
# 1050 step done... : time_mhd = 6818.54182, dt_mhd = 6.49456
# 1060 step done... : time_mhd = 6883.48743, dt_mhd = 6.49456
# 1070 step done... : time_mhd = 6948.43309, dt_mhd = 6.49457
# 1080 step done... : time_mhd = 7013.37880, dt_mhd = 6.49457
# 1090 step done... : time_mhd = 7078.32457, dt_mhd = 6.49458
# 1100 step done... : time_mhd = 7143.27039, dt_mhd = 6.49458
# 1110 step done... : time_mhd = 7208.21627, dt_mhd = 6.49459
# 1120 step done... : time_mhd = 7273.16220, dt_mhd = 6.49460
# 1130 step done... : time_mhd = 7338.10818, dt_mhd = 6.49460
# 1140 step done... : time_mhd = 7403.05422, dt_mhd = 6.49461
# 1150 step done... : time_mhd = 7468.00032, dt_mhd = 6.49461
# 1160 step done... : time_mhd = 7532.94647, dt_mhd = 6.49462
# 1170 step done... : time_mhd = 7597.89268, dt_mhd = 6.49462
# 1180 step done... : time_mhd = 7662.83895, dt_mhd = 6.49463
# 1190 step done... : time_mhd = 7727.78528, dt_mhd = 6.49464
# 1200 step done... : time_mhd = 7792.73166, dt_mhd = 6.49464
# 1210 step done... : time_mhd = 7857.67811, dt_mhd = 6.49465
# 1220 step done... : time_mhd = 7922.62461, dt_mhd = 6.49465
# 1230 step done... : time_mhd = 7987.57116, dt_mhd = 6.49466
# 1240 step done... : time_mhd = 8052.51778, dt_mhd = 6.49466
# 1250 step done... : time_mhd = 8117.46446, dt_mhd = 6.49467
# 1260 step done... : time_mhd = 8182.41119, dt_mhd = 6.49468
# 1270 step done... : time_mhd = 8247.35798, dt_mhd = 6.49468
# 1280 step done... : time_mhd = 8312.30483, dt_mhd = 6.49469
# 1290 step done... : time_mhd = 8377.25173, dt_mhd = 6.49469
# 1300 step done... : time_mhd = 8442.19869, dt_mhd = 6.49470
# 1310 step done... : time_mhd = 8507.14571, dt_mhd = 6.49470
# 1320 step done... : time_mhd = 8572.09277, dt_mhd = 6.49471
# 1330 step done... : time_mhd = 8637.03987, dt_mhd = 6.49471
# 1340 step done... : time_mhd = 8701.98703, dt_mhd = 6.49472
# 1350 step done... : time_mhd = 8766.93422, dt_mhd = 6.49472
# 1360 step done... : time_mhd = 8831.88146, dt_mhd = 6.49473
# 1370 step done... : time_mhd = 8896.82874, dt_mhd = 6.49473
# 1380 step done... : time_mhd = 8961.77607, dt_mhd = 6.49473
# 1390 step done... : time_mhd = 9026.72343, dt_mhd = 6.49474
# 1400 step done... : time_mhd = 9091.67085, dt_mhd = 6.49474
# 1410 step done... : time_mhd = 9156.61830, dt_mhd = 6.49475
# 1420 step done... : time_mhd = 9221.56580, dt_mhd = 6.49475
# 1430 step done... : time_mhd = 9286.51335, dt_mhd = 6.49476
# 1440 step done... : time_mhd = 9351.46093, dt_mhd = 6.49476
# 1450 step done... : time_mhd = 9416.40856, dt_mhd = 6.49476
# 1460 step done... : time_mhd = 9481.35623, dt_mhd = 6.49477
# 1470 step done... : time_mhd = 9546.30395, dt_mhd = 6.49477
# 1480 step done... : time_mhd = 9611.25170, dt_mhd = 6.49478
# 1490 step done... : time_mhd = 9676.19950, dt_mhd = 6.49478
# 1500 step done... : time_mhd = 9741.14735, dt_mhd = 6.49479
# 1510 step done... : time_mhd = 9806.09523, dt_mhd = 6.49479
# 1520 step done... : time_mhd = 9871.04316, dt_mhd = 6.49479
# 1530 step done... : time_mhd = 9935.99113, dt_mhd = 6.49480
# 1540 step done... : time_mhd = 10000.93914, dt_mhd = 6.49480
# 1550 step done... : time_mhd = 10065.88720, dt_mhd = 6.49481
# 1560 step done... : time_mhd = 10130.83529, dt_mhd = 6.49481
# 1570 step done... : time_mhd = 10195.78343, dt_mhd = 6.49482
# 1580 step done... : time_mhd = 10260.73161, dt_mhd = 6.49482
# 1590 step done... : time_mhd = 10325.67983, dt_mhd = 6.49482
# 1600 step done... : time_mhd = 10390.62810, dt_mhd = 6.49483
# 1610 step done... : time_mhd = 10455.57640, dt_mhd = 6.49483
# 1620 step done... : time_mhd = 10520.52473, dt_mhd = 6.49484
# 1630 step done... : time_mhd = 10585.47310, dt_mhd = 6.49484
# 1640 step done... : time_mhd = 10650.42150, dt_mhd = 6.49484
# 1650 step done... : time_mhd = 10715.36993, dt_mhd = 6.49484
# 1660 step done... : time_mhd = 10780.31839, dt_mhd = 6.49485
# 1670 step done... : time_mhd = 10845.26688, dt_mhd = 6.49485
# 1680 step done... : time_mhd = 10910.21540, dt_mhd = 6.49485
# 1690 step done... : time_mhd = 10975.16395, dt_mhd = 6.49486
# 1700 step done... : time_mhd = 11040.11254, dt_mhd = 6.49486
# 1710 step done... : time_mhd = 11105.06116, dt_mhd = 6.49486
# 1720 step done... : time_mhd = 11170.00981, dt_mhd = 6.49487
# 1730 step done... : time_mhd = 11234.95850, dt_mhd = 6.49487
# 1740 step done... : time_mhd = 11299.90722, dt_mhd = 6.49487
# 1750 step done... : time_mhd = 11364.85598, dt_mhd = 6.49488
# 1760 step done... : time_mhd = 11429.80477, dt_mhd = 6.49488
# 1770 step done... : time_mhd = 11494.75360, dt_mhd = 6.49488
# 1780 step done... : time_mhd = 11559.70247, dt_mhd = 6.49489
# 1790 step done... : time_mhd = 11624.65137, dt_mhd = 6.49489
# 1800 step done... : time_mhd = 11689.60032, dt_mhd = 6.49490
# 1810 step done... : time_mhd = 11754.54930, dt_mhd = 6.49490
# 1820 step done... : time_mhd = 11819.49833, dt_mhd = 6.49490
# 1830 step done... : time_mhd = 11884.44739, dt_mhd = 6.49491
# 1840 step done... : time_mhd = 11949.39650, dt_mhd = 6.49491
# 1850 step done... : time_mhd = 12014.34565, dt_mhd = 6.49492
# 1860 step done... : time_mhd = 12079.29484, dt_mhd = 6.49492
# 1870 step done... : time_mhd = 12144.24407, dt_mhd = 6.49492
# 1880 step done... : time_mhd = 12209.19334, dt_mhd = 6.49493
# 1890 step done... : time_mhd = 12274.14265, dt_mhd = 6.49493
# 1900 step done... : time_mhd = 12339.09200, dt_mhd = 6.49494
# 1910 step done... : time_mhd = 12404.04140, dt_mhd = 6.49494
# 1920 step done... : time_mhd = 12468.99083, dt_mhd = 6.49495
# 1930 step done... : time_mhd = 12533.94030, dt_mhd = 6.49495
# 1940 step done... : time_mhd = 12598.88982, dt_mhd = 6.49495
# 1950 step done... : time_mhd = 12663.83937, dt_mhd = 6.49496
# 1960 step done... : time_mhd = 12728.78897, dt_mhd = 6.49496
# 1970 step done... : time_mhd = 12793.73860, dt_mhd = 6.49497
# 1980 step done... : time_mhd = 12858.68828, dt_mhd = 6.49497
# 1990 step done... : time_mhd = 12923.63799, dt_mhd = 6.49497
# 2000 step done... : time_mhd = 12988.58775, dt_mhd = 6.49498

# %% [markdown]
# プロット

# %%
k = 500

U = np.load(f"results_MHD_fast_mode/U1_{k}.npy")
rho_mhd = U[0, :]
u_mhd = U[1, :] / rho_mhd
v_mhd = U[2, :] / rho_mhd
w_mhd = U[3, :] / rho_mhd
Bx_mhd = U[4, :]
By_mhd = U[5, :]
Bz_mhd = U[6, :]
e_mhd = U[7, :]
p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
Ex_mhd = -(v_mhd * Bz_mhd - w_mhd * By_mhd)
Ey_mhd = -(w_mhd * Bx_mhd - u_mhd * Bz_mhd)
Ez_mhd = -(u_mhd * By_mhd - v_mhd * Bx_mhd)
current_x_mhd = np.zeros(Bx_mhd.shape)
current_y_mhd = -(np.roll(Bz_mhd, -1, axis=0) - np.roll(Bz_mhd, 1, axis=0)) / (2*dx_mhd)
current_z_mhd = (np.roll(By_mhd, -1, axis=0) - np.roll(By_mhd, 1, axis=0)) / (2*dx_mhd)
current_y_mhd[0] = current_y_mhd[1] 
current_y_mhd[-1] = current_y_mhd[-2] 
current_z_mhd[0] = current_z_mhd[1] 
current_z_mhd[-1] = current_z_mhd[-2]

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

rho = U[0, :]
u = U[1, :] / rho 
v = U[2, :] / rho 
w = U[3, :] / rho 
Bx = U[4, :]
By = U[5, :]
Bz = U[6, :]
e = U[7, :]
p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)

ax1.plot(x_coordinate_mhd, rho, marker='o')
ax2.plot(x_coordinate_mhd, p, marker='o')
ax3.plot(x_coordinate_mhd, u, marker='o')
ax4.plot(x_coordinate_mhd, v, marker='o')
ax5.plot(x_coordinate_mhd, By, marker='o')
ax6.plot(x_coordinate_mhd, Bz, marker='o')

ax1.set_title(r"$\rho$", fontsize=24)
ax2.set_title(r"$p$", fontsize=24)
ax3.set_title(r"$u$", fontsize=24)
ax4.set_title(r"$v$", fontsize=24)
ax5.set_title(r"$B_y$", fontsize=24)
ax6.set_title(r"$B_z$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax5.tick_params(labelsize=16)
ax6.tick_params(labelsize=16)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

plt.suptitle(f"t = {k}", y=0.95, fontsize=32)

plt.show()

# %% [markdown]
# 動画作成

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

filename = "fast_mode_MHD.mp4"

interval = 10
plot_steps = steps
for i in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()
    ax5.clear()
    ax6.clear()

    U = np.load(f"results_MHD_fast_mode/U1_{i}.npy")
    rho = U[0, :]
    u = U[1, :] / rho 
    v = U[2, :] / rho 
    w = U[3, :] / rho 
    Bx = U[4, :]
    By = U[5, :]
    Bz = U[6, :]
    e = U[7, :]
    p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)
    Ex = -(v * Bz - w * Bx)
    Ey = -(w * Bx - u * Bz)
    Ez = -(u * By - v - Bx)

    ax1.plot(x_coordinate_mhd, rho / rho0_mhd, marker='o')
    ax2.plot(x_coordinate_mhd, By / B0_mhd, marker='o')
    ax3.plot(x_coordinate_mhd, Bz / B0_mhd, marker='o')
    ax4.plot(x_coordinate_mhd, p / p0_mhd, marker='o')
    ax5.plot(x_coordinate_mhd, Ey, marker='o')
    ax6.plot(x_coordinate_mhd, Ez, marker='o')
    

    ax1.set_ylim(0.5, 1.5)
    ax2.set_ylim(-0.2, 0.2)
    ax3.set_ylim(0.8, 1.2)
    ax4.set_ylim(0.5, 2.0)
    ax5.set_ylim(-0.2, 0.2)
    ax6.set_ylim(-0.2, 0.2)
    

    ax1.set_title(r"$\rho$", fontsize=24)
    ax2.set_title(r"$B_y$", fontsize=24)
    ax3.set_title(r"$B_z$", fontsize=24)
    ax4.set_title(r"$p$", fontsize=24)
    ax5.set_title(r"$E_y$", fontsize=24)
    ax6.set_title(r"$E_z$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax5.tick_params(labelsize=16)
    ax6.tick_params(labelsize=16)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()
    ax5.grid()
    ax6.grid()
    #ax1.set_xlim(nx_mhd * dx_mhd - nx_pic * dx_pic, nx_mhd * dx_mhd)
    #ax2.set_xlim(nx_mhd * dx_mhd - nx_pic * dx_pic, nx_mhd * dx_mhd)
    #ax3.set_xlim(nx_mhd * dx_mhd - nx_pic * dx_pic, nx_mhd * dx_mhd)
    #ax4.set_xlim(nx_mhd * dx_mhd - nx_pic * dx_pic, nx_mhd * dx_mhd)
    #ax5.set_xlim(nx_mhd * dx_mhd - nx_pic * dx_pic, nx_mhd * dx_mhd)
    #ax6.set_xlim(nx_mhd * dx_mhd - nx_pic * dx_pic, nx_mhd * dx_mhd)

    plt.suptitle(f"t = {i}", y=0.95, fontsize=32)

    fig.savefig(f'./pictures/{i}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for i in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{i}.png')
    video.write(img)
video.release()

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

filename = "fast_mode_MHD_rhoB.mp4"

interval = 10
plot_steps = steps
for i in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()

    U = np.load(f"results_MHD_fast_mode/U1_{i}.npy")
    rho = U[0, :]
    u = U[1, :] / rho 
    v = U[2, :] / rho 
    w = U[3, :] / rho 
    Bx = U[4, :]
    By = U[5, :]
    Bz = U[6, :]
    e = U[7, :]
    p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)

    ax1.plot(x_coordinate_mhd, rho / rho0_mhd, lw=5)
    ax2.plot(x_coordinate_mhd, Bz / B0_mhd, lw=5)

    ax1.set_xlim(x_min_mhd, x_max_mhd)
    ax2.set_xlim(x_min_mhd, x_max_mhd)
    ax1.set_ylim(0.9, 1.1)
    ax2.set_ylim(0.9, 1.1)

    ax1.set_title(r"$\rho / \rho_0$", fontsize=24)
    ax2.set_title(r"$B_z / B_0$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax1.grid()
    ax2.grid()

    plt.suptitle(f"t = {i}", y=0.95, fontsize=32)

    fig.savefig(f'./pictures/{i}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for i in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{i}.png')
    video.write(img)
video.release()
