# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import cv2


import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

from lib_MHDPIC1D.pic1d import *
from lib_MHDPIC1D.mhd1d import *
from lib_MHDPIC1D.interface import *
from lib_MHDPIC1D.remove_noise import *

# %% [markdown]
# カレントシート with Poynting flux

# %%
def boundary_Poynting_flux(speed_ratio, VA, B0, rho_init, p_init, gamma, U1, U2):
    U1[0, 0] = rho_init[0] * (1.0 + speed_ratio)
    U1[1, 0] = rho_init[0] * speed_ratio * VA
    U1[2, 0] = 0.0
    U1[3, 0] = 0.0
    U1[4, 0] = 0.1 * B0
    U1[5, 0] = -B0 * (1.0 + speed_ratio)
    U1[6, 0] = 0.0
    p = p_init[0] * (1.0 + gamma * speed_ratio)
    U1[7, 0] = p / (gamma - 1.0) \
            + 0.5 * rho_init[0] * (1.0 + speed_ratio) * (speed_ratio * VA)**2 \
            + 0.5 * (B0 * (1.0 + speed_ratio))**2
    
    U1[:, -1] = U1[:, -2]
    
    
    U2[:, 0] = U2[:, 1]
    
    U2[0, -1] = rho_init[-1] * (1.0 + speed_ratio)
    U2[1, -1] = -rho_init[-1] * speed_ratio * VA
    U2[2, -1] = 0.0
    U2[3, -1] = 0.0
    U2[4, -1] = 0.1 * B0
    U2[5, -1] = B0 * (1.0 + speed_ratio)
    U2[6, -1] = 0.0
    p = p_init[0] * (1.0 + gamma * speed_ratio)
    U2[7, -1] = p / (gamma - 1.0) \
            + 0.5 * rho_init[-1] * (1.0 + speed_ratio) * (speed_ratio * VA)**2 \
            + 0.5 * (B0 * (1.0 + speed_ratio))**2 

    return U1, U2

# %% [markdown]
# PIC初期化

# %%
c = 1.0
mu_0 = 1.0
epsilon0 = 1.0 / (mu_0 * c**2)
m_electron = 1.0
r_m = 1 / 100
m_ion = m_electron / r_m
t_r = 1.0
ne0_pic = 100 #ここは手動で調整すること
ni0_pic = ne0_pic
B0_pic = np.sqrt(ne0_pic) / 1.0 / np.sqrt(2/(1+t_r))
Ti_pic  = (B0_pic**2 / 2.0 / mu_0) / (ni0_pic + ne0_pic * t_r)
Te_pic = Ti_pic * t_r
q_electron = -1 * np.sqrt(epsilon0 * Te_pic / ne0_pic)
q_ion = -1 * q_electron
debye_length = np.sqrt(epsilon0 * Te_pic / ne0_pic / q_electron**2)
omega_pe = np.sqrt(ne0_pic * q_electron**2 / m_electron / epsilon0)
omega_pi = np.sqrt(ni0_pic * q_ion**2 / m_ion / epsilon0)
omega_ce = q_electron * B0_pic / m_electron
omega_ci = q_ion * B0_pic / m_ion
VA_pic = B0_pic / np.sqrt(ni0_pic * m_ion + ni0_pic * m_electron)
gamma_pic = 5.0 / 3.0
rho_pic = ni0_pic * m_ion + ne0_pic * m_electron
p_pic = ni0_pic * Ti_pic + ne0_pic * Te_pic
CS_pic = np.sqrt(gamma_pic * p_pic / rho_pic)
ion_inertial_length = c / omega_pi
sheat_thickness_pic = 1.5 * ion_inertial_length
v_electron = np.array([0.0, 0.0, -c * debye_length / sheat_thickness_pic * np.sqrt(2 / (1.0 + 1/t_r))])
v_ion = -v_electron / t_r
v_thermal_electron = np.sqrt(2.0 * Te_pic / m_electron)
v_thermal_ion = np.sqrt(2.0 * Ti_pic / m_ion)
v_thermal_electron_background = np.sqrt(2.0 * 0.2 * Te_pic / m_electron)
v_thermal_ion_background = np.sqrt(2.0 * 0.2 * Ti_pic / m_ion)

dx_pic = debye_length
nx_pic = int(40 * ion_inertial_length)
x_min_pic = 1e-10
x_max_pic = nx_pic * dx_pic - 1e-10
x_coordinate_pic = np.arange(0.0, x_max_pic, dx_pic)
dt_pic = 0.0
d_pic = 0.0

E_pic = np.zeros([3, nx_pic])
B_pic = np.zeros([3, nx_pic])
current_pic = np.zeros([3, nx_pic])
rho_pic = np.zeros(nx_pic)
B_pic[0, :] = 0.1 * B0_pic
B_pic[1, :] = B0_pic * np.tanh((x_coordinate_pic - nx_pic/2.0) / sheat_thickness_pic)
beta_pic = (ne0_pic * Te_pic + ni0_pic * Ti_pic) / (B0_pic**2 / 2 / mu_0)

n_ion = int(ni0_pic * 2.0 * sheat_thickness_pic)
n_electron = int(n_ion * abs(q_ion / q_electron))
n_ion_background = int(0.2 * ni0_pic * x_max_pic)
n_electron_background = int(0.2 * ne0_pic * x_max_pic)
x_pic_ion = np.zeros([3, n_ion + n_ion_background])
x_pic_electron = np.zeros([3, n_electron + n_electron_background])
v_pic_ion = np.zeros([3, n_ion + n_ion_background])
v_pic_electron = np.zeros([3, n_electron + n_electron_background])

rs_ion = np.random.RandomState(10)
rs_electron = np.random.RandomState(20)
x_start_ion = np.array(x_max_pic/2.0 + sheat_thickness_pic * np.arctanh(2.0 * rs_ion.rand(n_ion) - 1.0))
x_start_ion[x_start_ion >= x_max_pic] = x_max_pic / 2.0
x_start_ion[x_start_ion <= x_min_pic] = x_max_pic / 2.0
x_start_ion_background = np.random.rand(n_ion_background) * (x_max_pic - x_min_pic)
x_start_electron = np.array(x_max_pic/2.0 + sheat_thickness_pic * np.arctanh(2.0 * rs_electron.rand(n_electron) - 1.0))
x_start_electron[x_start_electron >= x_max_pic] = x_max_pic / 2.0
x_start_electron[x_start_electron <= x_min_pic] = x_max_pic / 2.0
x_start_electron_background = np.random.rand(n_electron_background) * (x_max_pic - x_min_pic)
x_pic_ion[0, :] = np.concatenate([x_start_ion, x_start_ion_background])
x_pic_electron[0, :] = np.concatenate([x_start_electron, x_start_electron_background])
v_pic_ion[0, :n_ion] = stats.norm.rvs(v_ion[0], v_thermal_ion, size=n_ion)
v_pic_ion[0, n_ion:] = stats.norm.rvs(0.0, v_thermal_ion_background, size=n_ion_background)
v_pic_ion[1, :n_ion] = stats.norm.rvs(v_ion[1], v_thermal_ion, size=n_ion)
v_pic_ion[1, n_ion:] = stats.norm.rvs(0.0, v_thermal_ion_background, size=n_ion_background)
v_pic_ion[2, :n_ion] = stats.norm.rvs(v_ion[2], v_thermal_ion, size=n_ion)
v_pic_ion[2, n_ion:] = stats.norm.rvs(0.0, v_thermal_ion_background, size=n_ion_background)
v_pic_electron[0, :n_electron] = stats.norm.rvs(v_electron[0], v_thermal_electron, size=n_electron)
v_pic_electron[0, n_electron:] = stats.norm.rvs(0.0, v_thermal_electron_background, size=n_electron_background)
v_pic_electron[1, :n_electron] = stats.norm.rvs(v_electron[1], v_thermal_electron, size=n_electron)
v_pic_electron[1, n_electron:] = stats.norm.rvs(0.0, v_thermal_electron_background, size=n_electron_background)
v_pic_electron[2, :n_electron] = stats.norm.rvs(v_electron[2], v_thermal_electron, size=n_electron)
v_pic_electron[2, n_electron:] = stats.norm.rvs(0.0, v_thermal_electron_background, size=n_electron_background)

print(f"total number of particles is {n_ion + n_ion_background + n_electron + n_electron_background}.")
print(f"Box size is {nx_pic}")
print(f"ion inertial length is {ion_inertial_length:.1f}")
print(r"$\omega_{ci}^{-1}$" + f" is {1.0/omega_ci:.1f}")
# Out:
# total number of particles is 43998.
# Box size is 800
# ion inertial length is 20.0
# $\omega_{ci}^{-1}$ is 200.0

# %% [markdown]
# MHD初期化

# %%
gamma_mhd = 5.0 / 3.0
B0_mhd = B0_pic
rho0_mhd = 0.2 * ne0_pic * m_electron + 0.2 * ni0_pic * m_ion
p0_mhd = 0.2 * ne0_pic * (0.5 * m_electron * v_thermal_electron_background**2) \
       + 0.2 * ni0_pic * (0.5 * m_ion * v_thermal_ion_background**2)
VA_mhd = B0_mhd / np.sqrt(rho0_mhd)
CS_mhd = np.sqrt(gamma_mhd * p0_mhd / rho0_mhd)
Cf_mhd = np.sqrt(VA_mhd**2 + CS_mhd**2)
dx_mhd = dx_pic

nx_mhd = 500
x_min_mhd = 1e-10
x_max_mhd = nx_mhd * dx_mhd - 1e-10
dt_mhd = 0.0
CFL = 0.7
x_coordinate_mhd = np.arange(x_min_mhd, x_max_mhd, dx_mhd)

sheat_thickness_mhd = sheat_thickness_pic / dx_pic * dx_mhd
speed_ratio = 0.2

U1 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd * np.ones(nx_mhd)
u_init = 0.0
v_init = 0.0
w_init = 0.0
Bx_init = 0.1 * B0_mhd
By_init = -B0_mhd * np.ones(nx_mhd)
Bz_init = 0.0
p_init = p0_mhd * np.ones(nx_mhd)
U1[0, :] = rho_init
U1[1, :] = rho_init * u_init
U1[2, :] = rho_init * v_init
U1[3, :] = rho_init * w_init
U1[4, :] = Bx_init
U1[5, :] = By_init
U1[6, :] = Bz_init
U1[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

U2 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd * np.ones(nx_mhd)
u_init = 0.0
v_init = 0.0
w_init = 0.0
Bx_init = 0.1 * B0_mhd
By_init = B0_mhd * np.ones(nx_mhd)
Bz_init = 0.0
p_init = p0_mhd * np.ones(nx_mhd)
U2[0, :] = rho_init
U2[1, :] = rho_init * u_init
U2[2, :] = rho_init * v_init
U2[3, :] = rho_init * w_init
U2[4, :] = Bx_init
U2[5, :] = By_init
U2[6, :] = Bz_init
U2[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

flux1 = np.zeros(U1.shape)
flux1_bar = np.zeros(flux1.shape)
flux2 = np.zeros(U2.shape)
flux2_bar = np.zeros(flux2.shape)

print(f"U1 size = {U1.shape}, U2 size = {U2.shape}")
# Out:
# U1 size = (8, 500), U2 size = (8, 500)

# %% [markdown]
# interface用の変数

# %%
window_size_convolution_pic = 10
window_size_smoothing_mhd = 5
interface_width = 50

index_interface_mhd_start_left = nx_mhd - interface_width
index_interface_mhd_end_left = nx_mhd
index_interface_mhd_start_right = 0
index_interface_mhd_end_right = interface_width
index_interface_pic_start_left = 0
index_interface_pic_end_left = interface_width
index_interface_pic_start_right = nx_pic - interface_width
index_interface_pic_end_right = nx_pic

x_interface_coordinate_left = np.arange(0, interface_width, 1)
x_interface_coordinate_half_left = np.arange(0.5, interface_width - 0.5, 1)
F_left = interlocking_function(x_interface_coordinate_left)
F_half_left = interlocking_function(x_interface_coordinate_half_left)
F_right = np.flip(F_left)
F_half_right = np.flip(F_half_left)

# %% [markdown]
# 時間発展

# %%
#STEP1:PICとMHDの時間を合わせる
#以下、t1からt2に時間発展させるとする
#ただし、t2 = t1 + dt_mhdとする
B_pic_time_ave = np.zeros(B_pic.shape)
zeroth_moment_ion_time_ave = np.zeros(nx_pic)
zeroth_moment_electron_time_ave = np.zeros(nx_pic)
first_moment_ion_time_ave = np.zeros([3, nx_pic])
first_moment_electron_time_ave = np.zeros([3, nx_pic])
second_moment_ion_time_ave = np.zeros([9, nx_pic])
second_moment_electron_time_ave = np.zeros([9, nx_pic])

total_substeps = 10

dirname = "results_MS_current_sheet_By"
steps = 3000
time_mhd = 0.0
time_pic = 0.0
for step in range(steps+1):

    # save
    if (step % 10 == 0):
        print(f"{step} step done... : time_mhd = {time_mhd:.5f}, time_pic = {time_pic:.5f}, dt_mhd = {dt_mhd:.5f}, dt_pic = {dt_pic:.5f}")

        np.save(f'./{dirname}/x_ion_{step}.npy', x_pic_ion)
        np.save(f'./{dirname}/x_electron_{step}.npy', x_pic_electron)
        np.save(f'./{dirname}/v_ion_{step}.npy', v_pic_ion)
        np.save(f'./{dirname}/v_electron_{step}.npy', v_pic_electron)
        np.save(f'./{dirname}/E_{step}.npy', E_pic)
        np.save(f'./{dirname}/B_{step}.npy', B_pic)
        np.save(f'./{dirname}/current_{step}.npy', current_pic)
        np.save(f"./{dirname}/U1_{step}.npy", U1)
        np.save(f"./{dirname}/U2_{step}.npy", U2)

        zeroth_moment_ion = np.zeros(nx_pic)
        zeroth_moment_electron = np.zeros(nx_pic)
        zeroth_moment_ion = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion)
        zeroth_moment_electron = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron)
        first_moment_ion = np.zeros([3, nx_pic])
        first_moment_electron = np.zeros([3, nx_pic])
        first_moment_ion = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion)
        first_moment_electron = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron)
        second_moment_ion = np.zeros([9, nx_pic])
        second_moment_electron = np.zeros([9, nx_pic])
        second_moment_ion = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion)
        second_moment_electron = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron)

        np.save(f'./{dirname}/zeroth_moment_ion_{step}.npy', zeroth_moment_ion)
        np.save(f'./{dirname}/zeroth_moment_electron_{step}.npy', zeroth_moment_electron)
        np.save(f'./{dirname}/first_moment_ion_{step}.npy', first_moment_ion)
        np.save(f'./{dirname}/first_moment_electron_{step}.npy', first_moment_electron)
        np.save(f'./{dirname}/second_moment_ion_{step}.npy', second_moment_ion)
        np.save(f'./{dirname}/second_moment_electron_{step}.npy', second_moment_electron)

        np.save(f'./{dirname}/B_time_ave_{step}.npy', B_pic_time_ave)
        np.save(f'./{dirname}/zeroth_moment_ion_time_ave_{step}.npy', zeroth_moment_ion_time_ave)
        np.save(f'./{dirname}/zeroth_moment_electron_time_ave_{step}.npy', zeroth_moment_electron_time_ave)
        np.save(f'./{dirname}/first_moment_ion_time_ave_{step}.npy', first_moment_ion_time_ave)
        np.save(f'./{dirname}/first_moment_electron_time_ave_{step}.npy', first_moment_electron_time_ave)
        np.save(f'./{dirname}/second_moment_ion_time_ave_{step}.npy', second_moment_ion_time_ave)
        np.save(f'./{dirname}/second_moment_electron_time_ave_{step}.npy', second_moment_electron_time_ave)

    #STEP1:MHD-Predictor
    U1_past = U1.copy()
    U2_past = U2.copy()
    #MHD
    #----------------------------------------------------------- 
    if True:
        U1_bar = U1.copy()
        U2_bar = U2.copy()

        dt_mhd_left = get_time_step(U1, gamma_mhd, dx_mhd, CFL)
        dt_mhd_right = get_time_step(U2, gamma_mhd, dx_mhd, CFL)
        dt_mhd = np.min([dt_mhd_left, dt_mhd_right])
        if np.isnan(dt_mhd):
            print(f"{step} steps (t = {time_mhd:.3f}) : Calculation is crashed!")
            break

        flux1 = get_flux_mhd(U1, gamma_mhd, flux1)
        flux2 = get_flux_mhd(U2, gamma_mhd, flux2)
        U1_bar += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2_bar += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1_bar, U2_bar = boundary_Poynting_flux(speed_ratio, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1_bar, U2_bar)

        flux1_bar = get_flux_mhd(U1_bar, gamma_mhd, flux1_bar)
        flux2_bar = get_flux_mhd(U2_bar, gamma_mhd, flux2_bar)
        flux1 = 0.5 * (flux1 + flux1_bar)
        flux2 = 0.5 * (flux2 + flux2_bar)
        U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2 += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1, U2 = boundary_Poynting_flux(speed_ratio, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1, U2)


    #STEP2:PIC
    B_pic_time_ave = np.zeros(B_pic.shape)
    zeroth_moment_ion_time_ave = np.zeros(zeroth_moment_ion_time_ave.shape)
    zeroth_moment_electron_time_ave = np.zeros(zeroth_moment_electron_time_ave.shape)
    first_moment_ion_time_ave = np.zeros(first_moment_ion_time_ave.shape)
    first_moment_electron_time_ave = np.zeros(first_moment_electron_time_ave.shape)
    second_moment_ion_time_ave = np.zeros(second_moment_ion_time_ave.shape)
    second_moment_electron_time_ave = np.zeros(second_moment_electron_time_ave.shape)
    
    dt_pic = dt_mhd / total_substeps
    for substep in range(total_substeps):

        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic) 
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U1 * (substep + 0.5) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, B_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U2 * (substep + 0.5) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, B_pic
        )
        
        v_pic_ion = time_evolution_v(c, E_pic, B_pic, x_pic_ion, q_ion, m_ion, nx_pic, dx_pic, dt_pic, v_pic_ion)
        v_pic_electron = time_evolution_v(c, E_pic, B_pic, x_pic_electron, q_electron, m_electron, nx_pic, dx_pic, dt_pic, v_pic_electron)
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)

        current_pic = np.zeros(current_pic.shape)
        current_pic = get_current_density(c, q_ion, v_pic_ion, x_pic_ion, nx_pic, dx_pic, current_pic)
        current_pic = get_current_density(c, q_electron, v_pic_electron, x_pic_electron, nx_pic, dx_pic, current_pic)
        current_pic[:, 0] = current_pic[:, 1]
        current_pic[:, -1] = current_pic[:, -2]
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U1 * (substep + 0.5) / total_substeps
        current_pic = send_MHD_to_PICinterface_current(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, dx_mhd, window_size_convolution_pic, current_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U2 * (substep + 0.5) / total_substeps
        current_pic = send_MHD_to_PICinterface_current(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, dx_mhd, window_size_convolution_pic, current_pic
        )
        
        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic)
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, B_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, B_pic
        )
        
        E_pic = time_evolution_E(B_pic, current_pic, c, epsilon0, dx_pic, dt_pic, E_pic)
        E_pic = boundary_E(E_pic)
        rho_pic = np.zeros(rho_pic.shape)
        rho_pic = get_rho(q_ion, x_pic_ion, nx_pic, dx_pic, rho_pic)
        rho_pic = get_rho(q_electron, x_pic_electron, nx_pic, dx_pic, rho_pic)
        rho_pic[0] = rho_pic[1]
        rho_pic[-1] = rho_pic[-2]
        E_pic = filter_E(rho_pic, dx_pic, dt_pic, d_pic, epsilon0, E_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        E_pic = send_MHD_to_PICinterface_E(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, E_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        E_pic = send_MHD_to_PICinterface_E(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, E_pic
        )
        
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, x_min_pic,  
            U1_send, dx_mhd, gamma_mhd, q_electron, 
            m_electron, m_ion, nx_pic, c, window_size_convolution_pic, 
            v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, x_min_pic,  
            U2_send, dx_mhd, gamma_mhd, q_electron, 
            m_electron, m_ion, nx_pic, c, window_size_convolution_pic, 
            v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        )

        time_pic += dt_pic


        # 時間平均のため
        if True:
            B_pic_time_ave += B_pic

            zeroth_moment_ion_tmp = np.zeros(zeroth_moment_ion_time_ave.shape)
            zeroth_moment_electron_tmp = np.zeros(zeroth_moment_electron_time_ave.shape)
            zeroth_moment_ion_tmp = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion_tmp)
            zeroth_moment_electron_tmp = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron_tmp)
            zeroth_moment_ion_time_ave += zeroth_moment_ion_tmp
            zeroth_moment_electron_time_ave += zeroth_moment_electron_tmp

            first_moment_ion_tmp = np.zeros(first_moment_ion_time_ave.shape)
            first_moment_electron_tmp = np.zeros(first_moment_electron_time_ave.shape)
            first_moment_ion_tmp = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion_tmp)
            first_moment_electron_tmp = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron_tmp)
            first_moment_ion_time_ave += first_moment_ion_tmp
            first_moment_electron_time_ave += first_moment_electron_tmp

            second_moment_ion_tmp = np.zeros(second_moment_ion_time_ave.shape)
            second_moment_electron_tmp = np.zeros(second_moment_electron_time_ave.shape)
            second_moment_ion_tmp = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion_tmp)
            second_moment_electron_tmp = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron_tmp)
            second_moment_ion_time_ave += second_moment_ion_tmp
            second_moment_electron_time_ave += second_moment_electron_tmp
            
    B_pic_time_ave /= total_substeps
    zeroth_moment_ion_time_ave /= total_substeps
    zeroth_moment_electron_time_ave /= total_substeps
    first_moment_ion_time_ave /= total_substeps
    first_moment_electron_time_ave /= total_substeps
    second_moment_ion_time_ave /= total_substeps
    second_moment_electron_time_ave /= total_substeps


    #STEP3:MHD-Correcter
    U1_PIC = np.zeros(U1.shape)
    U2_PIC = np.zeros(U2.shape)
    #n+1/2にする
    U1_PIC[:, :] = 0.5 * (U1_past[:, :] + U1[:, :])
    U2_PIC[:, :] = 0.5 * (U2_past[:, :] + U2[:, :])
    U1_PIC = send_PIC_to_MHDinterface(
        index_interface_mhd_start_left, index_interface_mhd_end_left, 
        index_interface_pic_start_left, index_interface_pic_end_left, 
        F_left, 
        gamma_mhd, m_electron, m_ion, nx_pic, B_pic_time_ave, 
        zeroth_moment_ion_time_ave, zeroth_moment_electron_time_ave, 
        first_moment_ion_time_ave, first_moment_electron_time_ave, 
        second_moment_ion_time_ave, second_moment_electron_time_ave, 
        window_size_convolution_pic, U1_PIC
    )
    U2_PIC = send_PIC_to_MHDinterface(
        index_interface_mhd_start_right, index_interface_mhd_end_right, 
        index_interface_pic_start_right, index_interface_pic_end_right, 
        F_right, 
        gamma_mhd, m_electron, m_ion, nx_pic, B_pic_time_ave, 
        zeroth_moment_ion_time_ave, zeroth_moment_electron_time_ave, 
        first_moment_ion_time_ave, first_moment_electron_time_ave, 
        second_moment_ion_time_ave, second_moment_electron_time_ave, 
        window_size_convolution_pic, U2_PIC
    )

    if True:
        U1 = U1_past.copy()
        U2 = U2_past.copy()
    
        flux1 = get_flux_mhd(U1_PIC, gamma_mhd, flux1)
        flux2 = get_flux_mhd(U2_PIC, gamma_mhd, flux2)
        U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2 += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1, U2 = boundary_Poynting_flux(speed_ratio, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1, U2)
        
        time_mhd += dt_mhd


    #interface領域のスムージング処理
    U1 = smoothing_U_left(
        U1, index_interface_mhd_start_left, index_interface_mhd_end_left, 
        window_size_smoothing_mhd
    )
    U2 = smoothing_U_right(
        U2, index_interface_mhd_start_right, index_interface_mhd_end_right, 
        window_size_smoothing_mhd
    )
# Out:
# 0 step done... : time_mhd = 0.00000, time_pic = 0.00000, dt_mhd = 0.00000, dt_pic = 0.00000
# 10 step done... : time_mhd = 24.94948, time_pic = 24.94948, dt_mhd = 2.41930, dt_pic = 0.24193
# 20 step done... : time_mhd = 49.14864, time_pic = 49.14864, dt_mhd = 2.42111, dt_pic = 0.24211
# 30 step done... : time_mhd = 73.36823, time_pic = 73.36823, dt_mhd = 2.42245, dt_pic = 0.24225
# 40 step done... : time_mhd = 97.59646, time_pic = 97.59646, dt_mhd = 2.42309, dt_pic = 0.24231
# 50 step done... : time_mhd = 121.82854, time_pic = 121.82854, dt_mhd = 2.42337, dt_pic = 0.24234
# 60 step done... : time_mhd = 146.06331, time_pic = 146.06331, dt_mhd = 2.42354, dt_pic = 0.24235
# 70 step done... : time_mhd = 170.29939, time_pic = 170.29939, dt_mhd = 2.42367, dt_pic = 0.24237
# 80 step done... : time_mhd = 194.53642, time_pic = 194.53642, dt_mhd = 2.42375, dt_pic = 0.24237
# 90 step done... : time_mhd = 218.77407, time_pic = 218.77407, dt_mhd = 2.42379, dt_pic = 0.24238
# 100 step done... : time_mhd = 243.01206, time_pic = 243.01206, dt_mhd = 2.42381, dt_pic = 0.24238
# 110 step done... : time_mhd = 267.25013, time_pic = 267.25013, dt_mhd = 2.42381, dt_pic = 0.24238
# 120 step done... : time_mhd = 291.48805, time_pic = 291.48805, dt_mhd = 2.42380, dt_pic = 0.24238
# 130 step done... : time_mhd = 315.72558, time_pic = 315.72558, dt_mhd = 2.42372, dt_pic = 0.24237
# 140 step done... : time_mhd = 339.96262, time_pic = 339.96262, dt_mhd = 2.42369, dt_pic = 0.24237
# 150 step done... : time_mhd = 364.19910, time_pic = 364.19910, dt_mhd = 2.42362, dt_pic = 0.24236
# 160 step done... : time_mhd = 388.43497, time_pic = 388.43497, dt_mhd = 2.42355, dt_pic = 0.24236
# 170 step done... : time_mhd = 412.67029, time_pic = 412.67029, dt_mhd = 2.42352, dt_pic = 0.24235
# 180 step done... : time_mhd = 436.90522, time_pic = 436.90522, dt_mhd = 2.42346, dt_pic = 0.24235
# 190 step done... : time_mhd = 461.13956, time_pic = 461.13956, dt_mhd = 2.42343, dt_pic = 0.24234
# 200 step done... : time_mhd = 485.37356, time_pic = 485.37356, dt_mhd = 2.42338, dt_pic = 0.24234
# 210 step done... : time_mhd = 509.60717, time_pic = 509.60717, dt_mhd = 2.42335, dt_pic = 0.24233
# 220 step done... : time_mhd = 533.84077, time_pic = 533.84077, dt_mhd = 2.42338, dt_pic = 0.24234
# 230 step done... : time_mhd = 558.07445, time_pic = 558.07445, dt_mhd = 2.42335, dt_pic = 0.24233
# 240 step done... : time_mhd = 582.30781, time_pic = 582.30781, dt_mhd = 2.42332, dt_pic = 0.24233
# 250 step done... : time_mhd = 606.54097, time_pic = 606.54097, dt_mhd = 2.42330, dt_pic = 0.24233
# 260 step done... : time_mhd = 630.77361, time_pic = 630.77361, dt_mhd = 2.42323, dt_pic = 0.24232
# 270 step done... : time_mhd = 655.00577, time_pic = 655.00577, dt_mhd = 2.42321, dt_pic = 0.24232
# 280 step done... : time_mhd = 679.23776, time_pic = 679.23776, dt_mhd = 2.42319, dt_pic = 0.24232
# 290 step done... : time_mhd = 703.46956, time_pic = 703.46956, dt_mhd = 2.42317, dt_pic = 0.24232
# 300 step done... : time_mhd = 727.70121, time_pic = 727.70121, dt_mhd = 2.42315, dt_pic = 0.24232
# 310 step done... : time_mhd = 751.93234, time_pic = 751.93234, dt_mhd = 2.42280, dt_pic = 0.24228
# 320 step done... : time_mhd = 776.14147, time_pic = 776.14147, dt_mhd = 2.41965, dt_pic = 0.24196
# 330 step done... : time_mhd = 800.32601, time_pic = 800.32601, dt_mhd = 2.41764, dt_pic = 0.24176
# 340 step done... : time_mhd = 824.49536, time_pic = 824.49536, dt_mhd = 2.41643, dt_pic = 0.24164
# 350 step done... : time_mhd = 848.66283, time_pic = 848.66283, dt_mhd = 2.41734, dt_pic = 0.24173
# 360 step done... : time_mhd = 872.84029, time_pic = 872.84029, dt_mhd = 2.41794, dt_pic = 0.24179
# 370 step done... : time_mhd = 897.02182, time_pic = 897.02182, dt_mhd = 2.41826, dt_pic = 0.24183
# 380 step done... : time_mhd = 921.20600, time_pic = 921.20600, dt_mhd = 2.41852, dt_pic = 0.24185
# 390 step done... : time_mhd = 945.39193, time_pic = 945.39193, dt_mhd = 2.41829, dt_pic = 0.24183
# 400 step done... : time_mhd = 969.56619, time_pic = 969.56619, dt_mhd = 2.41683, dt_pic = 0.24168
# 410 step done... : time_mhd = 993.72925, time_pic = 993.72925, dt_mhd = 2.41601, dt_pic = 0.24160
# 420 step done... : time_mhd = 1017.88729, time_pic = 1017.88729, dt_mhd = 2.41554, dt_pic = 0.24155
# 430 step done... : time_mhd = 1042.04034, time_pic = 1042.04034, dt_mhd = 2.41514, dt_pic = 0.24151
# 440 step done... : time_mhd = 1066.19035, time_pic = 1066.19035, dt_mhd = 2.41490, dt_pic = 0.24149
# 450 step done... : time_mhd = 1090.33852, time_pic = 1090.33852, dt_mhd = 2.41476, dt_pic = 0.24148
# 460 step done... : time_mhd = 1114.48579, time_pic = 1114.48579, dt_mhd = 2.41485, dt_pic = 0.24149
# 470 step done... : time_mhd = 1138.63920, time_pic = 1138.63920, dt_mhd = 2.41543, dt_pic = 0.24154
# 480 step done... : time_mhd = 1162.79357, time_pic = 1162.79357, dt_mhd = 2.41547, dt_pic = 0.24155
# 490 step done... : time_mhd = 1186.94853, time_pic = 1186.94853, dt_mhd = 2.41553, dt_pic = 0.24155
# 500 step done... : time_mhd = 1211.10234, time_pic = 1211.10234, dt_mhd = 2.41521, dt_pic = 0.24152
# 510 step done... : time_mhd = 1235.24655, time_pic = 1235.24655, dt_mhd = 2.41400, dt_pic = 0.24140
# 520 step done... : time_mhd = 1259.38784, time_pic = 1259.38784, dt_mhd = 2.41422, dt_pic = 0.24142
# 530 step done... : time_mhd = 1283.53024, time_pic = 1283.53024, dt_mhd = 2.41423, dt_pic = 0.24142
# 540 step done... : time_mhd = 1307.67205, time_pic = 1307.67205, dt_mhd = 2.41414, dt_pic = 0.24141
# 550 step done... : time_mhd = 1331.81320, time_pic = 1331.81320, dt_mhd = 2.41412, dt_pic = 0.24141
# 560 step done... : time_mhd = 1355.95490, time_pic = 1355.95490, dt_mhd = 2.41417, dt_pic = 0.24142
# 570 step done... : time_mhd = 1380.09608, time_pic = 1380.09608, dt_mhd = 2.41407, dt_pic = 0.24141
# 580 step done... : time_mhd = 1404.23207, time_pic = 1404.23207, dt_mhd = 2.41336, dt_pic = 0.24134
# 590 step done... : time_mhd = 1428.36707, time_pic = 1428.36707, dt_mhd = 2.41354, dt_pic = 0.24135
# 600 step done... : time_mhd = 1452.50237, time_pic = 1452.50237, dt_mhd = 2.41352, dt_pic = 0.24135
# 610 step done... : time_mhd = 1476.63718, time_pic = 1476.63718, dt_mhd = 2.41344, dt_pic = 0.24134
# 620 step done... : time_mhd = 1500.77126, time_pic = 1500.77126, dt_mhd = 2.41340, dt_pic = 0.24134
# 630 step done... : time_mhd = 1524.90560, time_pic = 1524.90560, dt_mhd = 2.41347, dt_pic = 0.24135
# 640 step done... : time_mhd = 1549.04122, time_pic = 1549.04122, dt_mhd = 2.41363, dt_pic = 0.24136
# 650 step done... : time_mhd = 1573.17822, time_pic = 1573.17822, dt_mhd = 2.41375, dt_pic = 0.24138
# 660 step done... : time_mhd = 1597.31564, time_pic = 1597.31564, dt_mhd = 2.41368, dt_pic = 0.24137
# 670 step done... : time_mhd = 1621.45106, time_pic = 1621.45106, dt_mhd = 2.41345, dt_pic = 0.24135
# 680 step done... : time_mhd = 1645.58544, time_pic = 1645.58544, dt_mhd = 2.41347, dt_pic = 0.24135
# 690 step done... : time_mhd = 1669.72082, time_pic = 1669.72082, dt_mhd = 2.41349, dt_pic = 0.24135
# 700 step done... : time_mhd = 1693.85500, time_pic = 1693.85500, dt_mhd = 2.41336, dt_pic = 0.24134
# 710 step done... : time_mhd = 1717.98849, time_pic = 1717.98849, dt_mhd = 2.41337, dt_pic = 0.24134
# 720 step done... : time_mhd = 1742.12372, time_pic = 1742.12372, dt_mhd = 2.41361, dt_pic = 0.24136
# 730 step done... : time_mhd = 1766.25965, time_pic = 1766.25965, dt_mhd = 2.41356, dt_pic = 0.24136
# 740 step done... : time_mhd = 1790.39494, time_pic = 1790.39494, dt_mhd = 2.41353, dt_pic = 0.24135
# 750 step done... : time_mhd = 1814.53074, time_pic = 1814.53074, dt_mhd = 2.41361, dt_pic = 0.24136
# 760 step done... : time_mhd = 1838.66642, time_pic = 1838.66642, dt_mhd = 2.41355, dt_pic = 0.24135
# 770 step done... : time_mhd = 1862.80207, time_pic = 1862.80207, dt_mhd = 2.41357, dt_pic = 0.24136
# 780 step done... : time_mhd = 1886.93757, time_pic = 1886.93757, dt_mhd = 2.41355, dt_pic = 0.24136
# 790 step done... : time_mhd = 1911.07321, time_pic = 1911.07321, dt_mhd = 2.41356, dt_pic = 0.24136
# 800 step done... : time_mhd = 1935.08894, time_pic = 1935.08894, dt_mhd = 2.37726, dt_pic = 0.23773
# 810 step done... : time_mhd = 1958.48833, time_pic = 1958.48833, dt_mhd = 2.31077, dt_pic = 0.23108
# 820 step done... : time_mhd = 1981.24025, time_pic = 1981.24025, dt_mhd = 2.24342, dt_pic = 0.22434
# 830 step done... : time_mhd = 2003.36018, time_pic = 2003.36018, dt_mhd = 2.19435, dt_pic = 0.21944
# 840 step done... : time_mhd = 2025.13091, time_pic = 2025.13091, dt_mhd = 2.16095, dt_pic = 0.21609
# 850 step done... : time_mhd = 2046.73222, time_pic = 2046.73222, dt_mhd = 2.16361, dt_pic = 0.21636
# 860 step done... : time_mhd = 2068.42033, time_pic = 2068.42033, dt_mhd = 2.17695, dt_pic = 0.21769
# 870 step done... : time_mhd = 2090.39846, time_pic = 2090.39846, dt_mhd = 2.22226, dt_pic = 0.22223
# 880 step done... : time_mhd = 2113.02363, time_pic = 2113.02363, dt_mhd = 2.29659, dt_pic = 0.22966
# 890 step done... : time_mhd = 2136.45998, time_pic = 2136.45998, dt_mhd = 2.38836, dt_pic = 0.23884
# 900 step done... : time_mhd = 2160.57652, time_pic = 2160.57652, dt_mhd = 2.41369, dt_pic = 0.24137
# 910 step done... : time_mhd = 2184.71331, time_pic = 2184.71331, dt_mhd = 2.41367, dt_pic = 0.24137
# 920 step done... : time_mhd = 2208.84715, time_pic = 2208.84715, dt_mhd = 2.41069, dt_pic = 0.24107
# 930 step done... : time_mhd = 2232.82431, time_pic = 2232.82431, dt_mhd = 2.39160, dt_pic = 0.23916
# 940 step done... : time_mhd = 2256.72529, time_pic = 2256.72529, dt_mhd = 2.39003, dt_pic = 0.23900
# 950 step done... : time_mhd = 2280.63196, time_pic = 2280.63196, dt_mhd = 2.37871, dt_pic = 0.23787
# 960 step done... : time_mhd = 2304.32263, time_pic = 2304.32263, dt_mhd = 2.36122, dt_pic = 0.23612
# 970 step done... : time_mhd = 2327.79655, time_pic = 2327.79655, dt_mhd = 2.33569, dt_pic = 0.23357
# 980 step done... : time_mhd = 2351.01733, time_pic = 2351.01733, dt_mhd = 2.31107, dt_pic = 0.23111
# 990 step done... : time_mhd = 2373.90072, time_pic = 2373.90072, dt_mhd = 2.27541, dt_pic = 0.22754
# 1000 step done... : time_mhd = 2396.52374, time_pic = 2396.52374, dt_mhd = 2.25248, dt_pic = 0.22525
# 1010 step done... : time_mhd = 2419.05743, time_pic = 2419.05743, dt_mhd = 2.25472, dt_pic = 0.22547
# 1020 step done... : time_mhd = 2441.62191, time_pic = 2441.62191, dt_mhd = 2.25548, dt_pic = 0.22555
# 1030 step done... : time_mhd = 2464.20700, time_pic = 2464.20700, dt_mhd = 2.25276, dt_pic = 0.22528
# 1040 step done... : time_mhd = 2486.73389, time_pic = 2486.73389, dt_mhd = 2.25144, dt_pic = 0.22514
# 1050 step done... : time_mhd = 2509.13843, time_pic = 2509.13843, dt_mhd = 2.24109, dt_pic = 0.22411
# 1060 step done... : time_mhd = 2531.54493, time_pic = 2531.54493, dt_mhd = 2.24648, dt_pic = 0.22465
# 1070 step done... : time_mhd = 2554.04410, time_pic = 2554.04410, dt_mhd = 2.25613, dt_pic = 0.22561
# 1080 step done... : time_mhd = 2576.86979, time_pic = 2576.86979, dt_mhd = 2.30568, dt_pic = 0.23057
# 1090 step done... : time_mhd = 2600.17289, time_pic = 2600.17289, dt_mhd = 2.35456, dt_pic = 0.23546
# 1100 step done... : time_mhd = 2623.83504, time_pic = 2623.83504, dt_mhd = 2.37301, dt_pic = 0.23730
# 1110 step done... : time_mhd = 2647.56089, time_pic = 2647.56089, dt_mhd = 2.37494, dt_pic = 0.23749
# 1120 step done... : time_mhd = 2671.34639, time_pic = 2671.34639, dt_mhd = 2.39197, dt_pic = 0.23920
# 1130 step done... : time_mhd = 2695.42180, time_pic = 2695.42180, dt_mhd = 2.41140, dt_pic = 0.24114
# 1140 step done... : time_mhd = 2719.53513, time_pic = 2719.53513, dt_mhd = 2.41137, dt_pic = 0.24114
# 1150 step done... : time_mhd = 2743.65255, time_pic = 2743.65255, dt_mhd = 2.41209, dt_pic = 0.24121
# 1160 step done... : time_mhd = 2767.66908, time_pic = 2767.66908, dt_mhd = 2.39246, dt_pic = 0.23925
# 1170 step done... : time_mhd = 2791.44357, time_pic = 2791.44357, dt_mhd = 2.36701, dt_pic = 0.23670
# 1180 step done... : time_mhd = 2815.07560, time_pic = 2815.07560, dt_mhd = 2.35523, dt_pic = 0.23552
# 1190 step done... : time_mhd = 2838.54222, time_pic = 2838.54222, dt_mhd = 2.34775, dt_pic = 0.23477
# 1200 step done... : time_mhd = 2862.03377, time_pic = 2862.03377, dt_mhd = 2.34487, dt_pic = 0.23449
# 1210 step done... : time_mhd = 2885.35878, time_pic = 2885.35878, dt_mhd = 2.32020, dt_pic = 0.23202
# 1220 step done... : time_mhd = 2908.38816, time_pic = 2908.38816, dt_mhd = 2.28920, dt_pic = 0.22892
# 1230 step done... : time_mhd = 2931.19683, time_pic = 2931.19683, dt_mhd = 2.28218, dt_pic = 0.22822
# 1240 step done... : time_mhd = 2954.05385, time_pic = 2954.05385, dt_mhd = 2.29065, dt_pic = 0.22906
# 1250 step done... : time_mhd = 2976.98106, time_pic = 2976.98106, dt_mhd = 2.29605, dt_pic = 0.22960
# 1260 step done... : time_mhd = 3000.10073, time_pic = 3000.10073, dt_mhd = 2.32275, dt_pic = 0.23227
# 1270 step done... : time_mhd = 3023.55171, time_pic = 3023.55171, dt_mhd = 2.35916, dt_pic = 0.23592
# 1280 step done... : time_mhd = 3047.28058, time_pic = 3047.28058, dt_mhd = 2.38650, dt_pic = 0.23865
# 1290 step done... : time_mhd = 3071.23372, time_pic = 3071.23372, dt_mhd = 2.40802, dt_pic = 0.24080
# 1300 step done... : time_mhd = 3095.29563, time_pic = 3095.29563, dt_mhd = 2.40187, dt_pic = 0.24019
# 1310 step done... : time_mhd = 3119.29536, time_pic = 3119.29536, dt_mhd = 2.40189, dt_pic = 0.24019
# 1320 step done... : time_mhd = 3143.29212, time_pic = 3143.29212, dt_mhd = 2.39566, dt_pic = 0.23957
# 1330 step done... : time_mhd = 3167.08975, time_pic = 3167.08975, dt_mhd = 2.35921, dt_pic = 0.23592
# 1340 step done... : time_mhd = 3190.67759, time_pic = 3190.67759, dt_mhd = 2.35695, dt_pic = 0.23569
# 1350 step done... : time_mhd = 3214.30382, time_pic = 3214.30382, dt_mhd = 2.36815, dt_pic = 0.23682
# 1360 step done... : time_mhd = 3238.00551, time_pic = 3238.00551, dt_mhd = 2.36336, dt_pic = 0.23634
# 1370 step done... : time_mhd = 3261.46340, time_pic = 3261.46340, dt_mhd = 2.33571, dt_pic = 0.23357
# 1380 step done... : time_mhd = 3284.73457, time_pic = 3284.73457, dt_mhd = 2.31544, dt_pic = 0.23154
# 1390 step done... : time_mhd = 3307.60772, time_pic = 3307.60772, dt_mhd = 2.26584, dt_pic = 0.22658
# 1400 step done... : time_mhd = 3330.10353, time_pic = 3330.10353, dt_mhd = 2.23478, dt_pic = 0.22348
# 1410 step done... : time_mhd = 3352.35122, time_pic = 3352.35122, dt_mhd = 2.21536, dt_pic = 0.22154
# 1420 step done... : time_mhd = 3374.44826, time_pic = 3374.44826, dt_mhd = 2.20628, dt_pic = 0.22063
# 1430 step done... : time_mhd = 3396.51722, time_pic = 3396.51722, dt_mhd = 2.21365, dt_pic = 0.22137
# 1440 step done... : time_mhd = 3418.82113, time_pic = 3418.82113, dt_mhd = 2.25001, dt_pic = 0.22500
# 1450 step done... : time_mhd = 3441.62385, time_pic = 3441.62385, dt_mhd = 2.30866, dt_pic = 0.23087
# 1460 step done... : time_mhd = 3464.97948, time_pic = 3464.97948, dt_mhd = 2.35603, dt_pic = 0.23560
# 1470 step done... : time_mhd = 3488.75056, time_pic = 3488.75056, dt_mhd = 2.40741, dt_pic = 0.24074
# 1480 step done... : time_mhd = 3512.93281, time_pic = 3512.93281, dt_mhd = 2.41883, dt_pic = 0.24188
# 1490 step done... : time_mhd = 3537.12507, time_pic = 3537.12507, dt_mhd = 2.41949, dt_pic = 0.24195
# 1500 step done... : time_mhd = 3561.31913, time_pic = 3561.31913, dt_mhd = 2.41895, dt_pic = 0.24189
# 1510 step done... : time_mhd = 3585.49976, time_pic = 3585.49976, dt_mhd = 2.41791, dt_pic = 0.24179
# 1520 step done... : time_mhd = 3609.69253, time_pic = 3609.69253, dt_mhd = 2.42010, dt_pic = 0.24201
# 1530 step done... : time_mhd = 3633.83996, time_pic = 3633.83996, dt_mhd = 2.41130, dt_pic = 0.24113
# 1540 step done... : time_mhd = 3657.93832, time_pic = 3657.93832, dt_mhd = 2.40963, dt_pic = 0.24096
# 1550 step done... : time_mhd = 3682.05610, time_pic = 3682.05610, dt_mhd = 2.41465, dt_pic = 0.24146
# 1560 step done... : time_mhd = 3706.13428, time_pic = 3706.13428, dt_mhd = 2.40450, dt_pic = 0.24045
# 1570 step done... : time_mhd = 3730.07122, time_pic = 3730.07122, dt_mhd = 2.38579, dt_pic = 0.23858
# 1580 step done... : time_mhd = 3753.75694, time_pic = 3753.75694, dt_mhd = 2.35500, dt_pic = 0.23550
# 1590 step done... : time_mhd = 3777.36325, time_pic = 3777.36325, dt_mhd = 2.36577, dt_pic = 0.23658
# 1600 step done... : time_mhd = 3801.10008, time_pic = 3801.10008, dt_mhd = 2.37776, dt_pic = 0.23778
# 1610 step done... : time_mhd = 3824.91843, time_pic = 3824.91843, dt_mhd = 2.39318, dt_pic = 0.23932
# 1620 step done... : time_mhd = 3848.96781, time_pic = 3848.96781, dt_mhd = 2.40233, dt_pic = 0.24023
# 1630 step done... : time_mhd = 3872.90255, time_pic = 3872.90255, dt_mhd = 2.39293, dt_pic = 0.23929
# 1640 step done... : time_mhd = 3896.65869, time_pic = 3896.65869, dt_mhd = 2.35987, dt_pic = 0.23599
# 1650 step done... : time_mhd = 3920.06925, time_pic = 3920.06925, dt_mhd = 2.32663, dt_pic = 0.23266
# 1660 step done... : time_mhd = 3943.28939, time_pic = 3943.28939, dt_mhd = 2.32145, dt_pic = 0.23214
# 1670 step done... : time_mhd = 3966.49172, time_pic = 3966.49172, dt_mhd = 2.31960, dt_pic = 0.23196
# 1680 step done... : time_mhd = 3989.70659, time_pic = 3989.70659, dt_mhd = 2.33034, dt_pic = 0.23303
# 1690 step done... : time_mhd = 4013.07290, time_pic = 4013.07290, dt_mhd = 2.34805, dt_pic = 0.23481
# 1700 step done... : time_mhd = 4036.58292, time_pic = 4036.58292, dt_mhd = 2.35117, dt_pic = 0.23512
# 1710 step done... : time_mhd = 4059.95540, time_pic = 4059.95540, dt_mhd = 2.32623, dt_pic = 0.23262
# 1720 step done... : time_mhd = 4083.08793, time_pic = 4083.08793, dt_mhd = 2.30057, dt_pic = 0.23006
# 1730 step done... : time_mhd = 4106.00189, time_pic = 4106.00189, dt_mhd = 2.29429, dt_pic = 0.22943
# 1740 step done... : time_mhd = 4128.94071, time_pic = 4128.94071, dt_mhd = 2.28744, dt_pic = 0.22874
# 1750 step done... : time_mhd = 4151.89842, time_pic = 4151.89842, dt_mhd = 2.30302, dt_pic = 0.23030
# 1760 step done... : time_mhd = 4175.04572, time_pic = 4175.04572, dt_mhd = 2.33039, dt_pic = 0.23304
# 1770 step done... : time_mhd = 4198.47802, time_pic = 4198.47802, dt_mhd = 2.35197, dt_pic = 0.23520
# 1780 step done... : time_mhd = 4222.15637, time_pic = 4222.15637, dt_mhd = 2.38556, dt_pic = 0.23856
# 1790 step done... : time_mhd = 4246.04406, time_pic = 4246.04406, dt_mhd = 2.38946, dt_pic = 0.23895
# 1800 step done... : time_mhd = 4269.99818, time_pic = 4269.99818, dt_mhd = 2.40288, dt_pic = 0.24029
# 1810 step done... : time_mhd = 4293.95657, time_pic = 4293.95657, dt_mhd = 2.40840, dt_pic = 0.24084
# 1820 step done... : time_mhd = 4318.04590, time_pic = 4318.04590, dt_mhd = 2.41648, dt_pic = 0.24165
# 1830 step done... : time_mhd = 4342.19539, time_pic = 4342.19539, dt_mhd = 2.41095, dt_pic = 0.24109
# 1840 step done... : time_mhd = 4366.32285, time_pic = 4366.32285, dt_mhd = 2.40822, dt_pic = 0.24082
# 1850 step done... : time_mhd = 4390.20827, time_pic = 4390.20827, dt_mhd = 2.36870, dt_pic = 0.23687
# 1860 step done... : time_mhd = 4413.74909, time_pic = 4413.74909, dt_mhd = 2.34341, dt_pic = 0.23434
# 1870 step done... : time_mhd = 4437.24366, time_pic = 4437.24366, dt_mhd = 2.35705, dt_pic = 0.23571
# 1880 step done... : time_mhd = 4460.78797, time_pic = 4460.78797, dt_mhd = 2.33986, dt_pic = 0.23399
# 1890 step done... : time_mhd = 4484.14681, time_pic = 4484.14681, dt_mhd = 2.33217, dt_pic = 0.23322
# 1900 step done... : time_mhd = 4507.52437, time_pic = 4507.52437, dt_mhd = 2.34109, dt_pic = 0.23411
# 1910 step done... : time_mhd = 4530.98028, time_pic = 4530.98028, dt_mhd = 2.34395, dt_pic = 0.23439
# 1920 step done... : time_mhd = 4554.47673, time_pic = 4554.47673, dt_mhd = 2.35432, dt_pic = 0.23543
# 1930 step done... : time_mhd = 4577.98525, time_pic = 4577.98525, dt_mhd = 2.35398, dt_pic = 0.23540
# 1940 step done... : time_mhd = 4601.53928, time_pic = 4601.53928, dt_mhd = 2.36682, dt_pic = 0.23668
# 1950 step done... : time_mhd = 4625.35736, time_pic = 4625.35736, dt_mhd = 2.39776, dt_pic = 0.23978
# 1960 step done... : time_mhd = 4649.41725, time_pic = 4649.41725, dt_mhd = 2.40545, dt_pic = 0.24054
# 1970 step done... : time_mhd = 4673.45911, time_pic = 4673.45911, dt_mhd = 2.40269, dt_pic = 0.24027
# 1980 step done... : time_mhd = 4697.50218, time_pic = 4697.50218, dt_mhd = 2.40533, dt_pic = 0.24053
# 1990 step done... : time_mhd = 4721.58010, time_pic = 4721.58010, dt_mhd = 2.40960, dt_pic = 0.24096
# 2000 step done... : time_mhd = 4745.68013, time_pic = 4745.68013, dt_mhd = 2.41146, dt_pic = 0.24115
# 2010 step done... : time_mhd = 4769.79489, time_pic = 4769.79489, dt_mhd = 2.41200, dt_pic = 0.24120
# 2020 step done... : time_mhd = 4793.91375, time_pic = 4793.91375, dt_mhd = 2.41050, dt_pic = 0.24105
# 2030 step done... : time_mhd = 4818.01341, time_pic = 4818.01341, dt_mhd = 2.41013, dt_pic = 0.24101
# 2040 step done... : time_mhd = 4842.12288, time_pic = 4842.12288, dt_mhd = 2.41142, dt_pic = 0.24114
# 2050 step done... : time_mhd = 4866.24091, time_pic = 4866.24091, dt_mhd = 2.41171, dt_pic = 0.24117
# 2060 step done... : time_mhd = 4890.36189, time_pic = 4890.36189, dt_mhd = 2.41275, dt_pic = 0.24128
# 2070 step done... : time_mhd = 4914.50102, time_pic = 4914.50102, dt_mhd = 2.41574, dt_pic = 0.24157
# 2080 step done... : time_mhd = 4938.66831, time_pic = 4938.66831, dt_mhd = 2.41588, dt_pic = 0.24159
# 2090 step done... : time_mhd = 4962.81585, time_pic = 4962.81585, dt_mhd = 2.41479, dt_pic = 0.24148
# 2100 step done... : time_mhd = 4986.98304, time_pic = 4986.98304, dt_mhd = 2.41847, dt_pic = 0.24185
# 2110 step done... : time_mhd = 5011.14537, time_pic = 5011.14537, dt_mhd = 2.41357, dt_pic = 0.24136
# 2120 step done... : time_mhd = 5035.26532, time_pic = 5035.26532, dt_mhd = 2.41137, dt_pic = 0.24114
# 2130 step done... : time_mhd = 5059.38027, time_pic = 5059.38027, dt_mhd = 2.41176, dt_pic = 0.24118
# 2140 step done... : time_mhd = 5083.46498, time_pic = 5083.46498, dt_mhd = 2.41051, dt_pic = 0.24105
# 2150 step done... : time_mhd = 5107.57848, time_pic = 5107.57848, dt_mhd = 2.41060, dt_pic = 0.24106
# 2160 step done... : time_mhd = 5131.67267, time_pic = 5131.67267, dt_mhd = 2.40869, dt_pic = 0.24087
# 2170 step done... : time_mhd = 5155.75633, time_pic = 5155.75633, dt_mhd = 2.40832, dt_pic = 0.24083
# 2180 step done... : time_mhd = 5179.84420, time_pic = 5179.84420, dt_mhd = 2.40956, dt_pic = 0.24096
# 2190 step done... : time_mhd = 5203.96783, time_pic = 5203.96783, dt_mhd = 2.41390, dt_pic = 0.24139
# 2200 step done... : time_mhd = 5228.08504, time_pic = 5228.08504, dt_mhd = 2.41045, dt_pic = 0.24104
# 2210 step done... : time_mhd = 5252.18528, time_pic = 5252.18528, dt_mhd = 2.41003, dt_pic = 0.24100
# 2220 step done... : time_mhd = 5276.28530, time_pic = 5276.28530, dt_mhd = 2.40907, dt_pic = 0.24091
# 2230 step done... : time_mhd = 5300.36235, time_pic = 5300.36235, dt_mhd = 2.40688, dt_pic = 0.24069
# 2240 step done... : time_mhd = 5324.42747, time_pic = 5324.42747, dt_mhd = 2.40641, dt_pic = 0.24064
# 2250 step done... : time_mhd = 5348.49774, time_pic = 5348.49774, dt_mhd = 2.40805, dt_pic = 0.24080
# 2260 step done... : time_mhd = 5372.60645, time_pic = 5372.60645, dt_mhd = 2.41189, dt_pic = 0.24119
# 2270 step done... : time_mhd = 5396.72806, time_pic = 5396.72806, dt_mhd = 2.41260, dt_pic = 0.24126
# 2280 step done... : time_mhd = 5420.84812, time_pic = 5420.84812, dt_mhd = 2.41122, dt_pic = 0.24112
# 2290 step done... : time_mhd = 5444.95419, time_pic = 5444.95419, dt_mhd = 2.41026, dt_pic = 0.24103
# 2300 step done... : time_mhd = 5469.05570, time_pic = 5469.05570, dt_mhd = 2.41015, dt_pic = 0.24101
# 2310 step done... : time_mhd = 5493.15905, time_pic = 5493.15905, dt_mhd = 2.41068, dt_pic = 0.24107
# 2320 step done... : time_mhd = 5517.25887, time_pic = 5517.25887, dt_mhd = 2.40911, dt_pic = 0.24091
# 2330 step done... : time_mhd = 5541.34221, time_pic = 5541.34221, dt_mhd = 2.40783, dt_pic = 0.24078
# 2340 step done... : time_mhd = 5565.41789, time_pic = 5565.41789, dt_mhd = 2.40746, dt_pic = 0.24075
# 2350 step done... : time_mhd = 5589.49352, time_pic = 5589.49352, dt_mhd = 2.40779, dt_pic = 0.24078
# 2360 step done... : time_mhd = 5613.58013, time_pic = 5613.58013, dt_mhd = 2.40969, dt_pic = 0.24097
# 2370 step done... : time_mhd = 5637.69671, time_pic = 5637.69671, dt_mhd = 2.41212, dt_pic = 0.24121
# 2380 step done... : time_mhd = 5661.80143, time_pic = 5661.80143, dt_mhd = 2.40916, dt_pic = 0.24092
# 2390 step done... : time_mhd = 5685.87890, time_pic = 5685.87890, dt_mhd = 2.40668, dt_pic = 0.24067
# 2400 step done... : time_mhd = 5709.93647, time_pic = 5709.93647, dt_mhd = 2.40521, dt_pic = 0.24052
# 2410 step done... : time_mhd = 5733.98542, time_pic = 5733.98542, dt_mhd = 2.40477, dt_pic = 0.24048
# 2420 step done... : time_mhd = 5758.03348, time_pic = 5758.03348, dt_mhd = 2.40491, dt_pic = 0.24049
# 2430 step done... : time_mhd = 5782.09041, time_pic = 5782.09041, dt_mhd = 2.40674, dt_pic = 0.24067
# 2440 step done... : time_mhd = 5806.18416, time_pic = 5806.18416, dt_mhd = 2.41227, dt_pic = 0.24123
# 2450 step done... : time_mhd = 5830.32681, time_pic = 5830.32681, dt_mhd = 2.41509, dt_pic = 0.24151
# 2460 step done... : time_mhd = 5854.49313, time_pic = 5854.49313, dt_mhd = 2.41738, dt_pic = 0.24174
# 2470 step done... : time_mhd = 5878.66595, time_pic = 5878.66595, dt_mhd = 2.41728, dt_pic = 0.24173
# 2480 step done... : time_mhd = 5902.84081, time_pic = 5902.84081, dt_mhd = 2.41779, dt_pic = 0.24178
# 2490 step done... : time_mhd = 5927.02287, time_pic = 5927.02287, dt_mhd = 2.41810, dt_pic = 0.24181
# 2500 step done... : time_mhd = 5951.19846, time_pic = 5951.19846, dt_mhd = 2.41727, dt_pic = 0.24173
# 2510 step done... : time_mhd = 5975.36968, time_pic = 5975.36968, dt_mhd = 2.41706, dt_pic = 0.24171
# 2520 step done... : time_mhd = 5999.54355, time_pic = 5999.54355, dt_mhd = 2.41783, dt_pic = 0.24178
# 2530 step done... : time_mhd = 6023.73118, time_pic = 6023.73118, dt_mhd = 2.41930, dt_pic = 0.24193
# 2540 step done... : time_mhd = 6047.93423, time_pic = 6047.93423, dt_mhd = 2.42160, dt_pic = 0.24216
# 2550 step done... : time_mhd = 6072.17720, time_pic = 6072.17720, dt_mhd = 2.42720, dt_pic = 0.24272
# 2560 step done... : time_mhd = 6096.47800, time_pic = 6096.47800, dt_mhd = 2.43290, dt_pic = 0.24329
# 2570 step done... : time_mhd = 6120.81867, time_pic = 6120.81867, dt_mhd = 2.43327, dt_pic = 0.24333
# 2580 step done... : time_mhd = 6145.13888, time_pic = 6145.13888, dt_mhd = 2.43099, dt_pic = 0.24310
# 2590 step done... : time_mhd = 6169.43873, time_pic = 6169.43873, dt_mhd = 2.42932, dt_pic = 0.24293
# 2600 step done... : time_mhd = 6193.72740, time_pic = 6193.72740, dt_mhd = 2.42864, dt_pic = 0.24286
# 2610 step done... : time_mhd = 6218.01468, time_pic = 6218.01468, dt_mhd = 2.42896, dt_pic = 0.24290
# 2620 step done... : time_mhd = 6242.31321, time_pic = 6242.31321, dt_mhd = 2.43110, dt_pic = 0.24311
# 2630 step done... : time_mhd = 6266.65786, time_pic = 6266.65786, dt_mhd = 2.43700, dt_pic = 0.24370
# 2640 step done... : time_mhd = 6291.03605, time_pic = 6291.03605, dt_mhd = 2.43902, dt_pic = 0.24390
# 2650 step done... : time_mhd = 6315.44448, time_pic = 6315.44448, dt_mhd = 2.44111, dt_pic = 0.24411
# 2660 step done... : time_mhd = 6339.85321, time_pic = 6339.85321, dt_mhd = 2.44077, dt_pic = 0.24408
# 2670 step done... : time_mhd = 6364.26269, time_pic = 6364.26269, dt_mhd = 2.44129, dt_pic = 0.24413
# 2680 step done... : time_mhd = 6388.67639, time_pic = 6388.67639, dt_mhd = 2.44085, dt_pic = 0.24408
# 2690 step done... : time_mhd = 6413.07950, time_pic = 6413.07950, dt_mhd = 2.44004, dt_pic = 0.24400
# 2700 step done... : time_mhd = 6437.47991, time_pic = 6437.47991, dt_mhd = 2.44014, dt_pic = 0.24401
# 2710 step done... : time_mhd = 6461.88752, time_pic = 6461.88752, dt_mhd = 2.44169, dt_pic = 0.24417
# 2720 step done... : time_mhd = 6486.32166, time_pic = 6486.32166, dt_mhd = 2.44431, dt_pic = 0.24443
# 2730 step done... : time_mhd = 6510.75329, time_pic = 6510.75329, dt_mhd = 2.44234, dt_pic = 0.24423
# 2740 step done... : time_mhd = 6535.17022, time_pic = 6535.17022, dt_mhd = 2.44133, dt_pic = 0.24413
# 2750 step done... : time_mhd = 6559.58273, time_pic = 6559.58273, dt_mhd = 2.44126, dt_pic = 0.24413
# 2760 step done... : time_mhd = 6583.99653, time_pic = 6583.99653, dt_mhd = 2.44147, dt_pic = 0.24415
# 2770 step done... : time_mhd = 6608.41519, time_pic = 6608.41519, dt_mhd = 2.44228, dt_pic = 0.24423
# 2780 step done... : time_mhd = 6632.85624, time_pic = 6632.85624, dt_mhd = 2.44665, dt_pic = 0.24467
# 2790 step done... : time_mhd = 6657.35120, time_pic = 6657.35120, dt_mhd = 2.45013, dt_pic = 0.24501
# 2800 step done... : time_mhd = 6681.85885, time_pic = 6681.85885, dt_mhd = 2.45101, dt_pic = 0.24510
# 2810 step done... : time_mhd = 6706.36896, time_pic = 6706.36896, dt_mhd = 2.45101, dt_pic = 0.24510
# 2820 step done... : time_mhd = 6730.87908, time_pic = 6730.87908, dt_mhd = 2.45101, dt_pic = 0.24510
# 2830 step done... : time_mhd = 6755.38920, time_pic = 6755.38920, dt_mhd = 2.45101, dt_pic = 0.24510
# 2840 step done... : time_mhd = 6779.89932, time_pic = 6779.89932, dt_mhd = 2.45101, dt_pic = 0.24510
# 2850 step done... : time_mhd = 6804.40944, time_pic = 6804.40944, dt_mhd = 2.45101, dt_pic = 0.24510
# 2860 step done... : time_mhd = 6828.91956, time_pic = 6828.91956, dt_mhd = 2.45101, dt_pic = 0.24510
# 2870 step done... : time_mhd = 6853.42968, time_pic = 6853.42968, dt_mhd = 2.45101, dt_pic = 0.24510
# 2880 step done... : time_mhd = 6877.93979, time_pic = 6877.93979, dt_mhd = 2.45101, dt_pic = 0.24510
# 2890 step done... : time_mhd = 6902.44991, time_pic = 6902.44991, dt_mhd = 2.45101, dt_pic = 0.24510
# 2900 step done... : time_mhd = 6926.96003, time_pic = 6926.96003, dt_mhd = 2.45101, dt_pic = 0.24510
# 2910 step done... : time_mhd = 6951.47015, time_pic = 6951.47015, dt_mhd = 2.45101, dt_pic = 0.24510
# 2920 step done... : time_mhd = 6975.98027, time_pic = 6975.98027, dt_mhd = 2.45101, dt_pic = 0.24510
# 2930 step done... : time_mhd = 7000.49039, time_pic = 7000.49039, dt_mhd = 2.45101, dt_pic = 0.24510
# 2940 step done... : time_mhd = 7025.00051, time_pic = 7025.00051, dt_mhd = 2.45101, dt_pic = 0.24510
# 2950 step done... : time_mhd = 7049.51062, time_pic = 7049.51062, dt_mhd = 2.45101, dt_pic = 0.24510
# 2960 step done... : time_mhd = 7074.02074, time_pic = 7074.02074, dt_mhd = 2.45101, dt_pic = 0.24510
# 2970 step done... : time_mhd = 7098.53086, time_pic = 7098.53086, dt_mhd = 2.45101, dt_pic = 0.24510
# 2980 step done... : time_mhd = 7123.04098, time_pic = 7123.04098, dt_mhd = 2.45101, dt_pic = 0.24510
# 2990 step done... : time_mhd = 7147.55110, time_pic = 7147.55110, dt_mhd = 2.45101, dt_pic = 0.24510
# 3000 step done... : time_mhd = 7172.06122, time_pic = 7172.06122, dt_mhd = 2.45101, dt_pic = 0.24510

# %% [markdown]
# プロット

# %%
dirname = "results_MS_current_sheet"
step = 3000

B = np.load(f"{dirname}/B_{step}.npy")
E = np.load(f"{dirname}/E_{step}.npy")
current = np.load(f"{dirname}/current_{step}.npy")
x_pic_ion = np.load(f"{dirname}/x_ion_{step}.npy")
x_pic_electron = np.load(f"{dirname}/x_electron_{step}.npy")
v_pic_ion = np.load(f"{dirname}/v_ion_{step}.npy")
v_pic_electron = np.load(f"{dirname}/v_electron_{step}.npy")
zeroth_moment_ion = np.load(f"{dirname}/zeroth_moment_ion_{step}.npy")
zeroth_moment_electron = np.load(f"{dirname}/zeroth_moment_electron_{step}.npy")
first_moment_ion = np.load(f"{dirname}/first_moment_ion_{step}.npy")
first_moment_electron = np.load(f"{dirname}/first_moment_electron_{step}.npy")
second_moment_ion = np.load(f"{dirname}/second_moment_ion_{step}.npy")
second_moment_electron = np.load(f"{dirname}/second_moment_electron_{step}.npy")

B_time_ave = np.load(f"{dirname}/B_time_ave_{step}.npy")
zeroth_moment_ion_time_ave = np.load(f"{dirname}/zeroth_moment_ion_time_ave_{step}.npy")
zeroth_moment_electron_time_ave = np.load(f"{dirname}/zeroth_moment_electron_time_ave_{step}.npy")
first_moment_ion_time_ave = np.load(f"{dirname}/first_moment_ion_time_ave_{step}.npy")
first_moment_electron_time_ave = np.load(f"{dirname}/first_moment_electron_time_ave_{step}.npy")
second_moment_ion_time_ave = np.load(f"{dirname}/second_moment_ion_time_ave_{step}.npy")
second_moment_electron_time_ave = np.load(f"{dirname}/second_moment_electron_time_ave_{step}.npy")

U1 = np.load(f"{dirname}/U1_{step}.npy")
rho1_mhd = U1[0, :]
u1_mhd = U1[1, :] / rho1_mhd
v1_mhd = U1[2, :] / rho1_mhd
w1_mhd = U1[3, :] / rho1_mhd
Bx1_mhd = U1[4, :]
By1_mhd = U1[5, :]
Bz1_mhd = U1[6, :]
e1_mhd = U1[7, :]
p1_mhd = (gamma_mhd - 1.0) \
        * (e1_mhd - 0.5 * rho1_mhd * (u1_mhd**2+v1_mhd**2+w1_mhd**2)
            - 0.5 * (Bx1_mhd**2+By1_mhd**2+Bz1_mhd**2))
Ex1_mhd = -(v1_mhd * Bz1_mhd - w1_mhd * By1_mhd)
Ey1_mhd = -(w1_mhd * Bx1_mhd - u1_mhd * Bz1_mhd)
Ez1_mhd = -(u1_mhd * By1_mhd - v1_mhd * Bx1_mhd)
current1_x_mhd = np.zeros(Bx1_mhd.shape)
current1_y_mhd = -(np.roll(Bz1_mhd, -1, axis=0) - np.roll(Bz1_mhd, 1, axis=0)) / (2*dx_mhd)
current1_z_mhd = (np.roll(By1_mhd, -1, axis=0) - np.roll(By1_mhd, 1, axis=0)) / (2*dx_mhd)
current1_y_mhd[0] = current1_y_mhd[1] 
current1_y_mhd[-1] = current1_y_mhd[-2] 
current1_z_mhd[0] = current1_z_mhd[1] 
current1_z_mhd[-1] = current1_z_mhd[-2] 

U2 = np.load(f"{dirname}/U2_{step}.npy")
rho2_mhd = U2[0, :]
u2_mhd = U2[1, :] / rho2_mhd
v2_mhd = U2[2, :] / rho2_mhd
w2_mhd = U2[3, :] / rho2_mhd
Bx2_mhd = U2[4, :]
By2_mhd = U2[5, :]
Bz2_mhd = U2[6, :]
e2_mhd = U2[7, :]
p2_mhd = (gamma_mhd - 1.0) \
        * (e2_mhd - 0.5 * rho2_mhd * (u2_mhd**2+v2_mhd**2+w2_mhd**2)
            - 0.5 * (Bx2_mhd**2+By2_mhd**2+Bz2_mhd**2))
Ex2_mhd = -(v2_mhd * Bz2_mhd - w2_mhd * By2_mhd)
Ey2_mhd = -(w2_mhd * Bx2_mhd - u2_mhd * Bz2_mhd)
Ez2_mhd = -(u2_mhd * By2_mhd - v2_mhd * Bx2_mhd)
current2_x_mhd = np.zeros(Bx2_mhd.shape)
current2_y_mhd = -(np.roll(Bz2_mhd, -1, axis=0) - np.roll(Bz2_mhd, 1, axis=0)) / (2*dx_mhd)
current2_z_mhd = (np.roll(By2_mhd, -1, axis=0) - np.roll(By2_mhd, 1, axis=0)) / (2*dx_mhd)
current2_y_mhd[0] = current2_y_mhd[1] 
current2_y_mhd[-1] = current2_y_mhd[-2] 
current2_z_mhd[0] = current2_z_mhd[1] 
current2_z_mhd[-1] = current2_z_mhd[-2]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 4
#       1 dirname = "results_MS_current_sheet"
#       2 step = 3000
# ----> 4 B = np.load(f"{dirname}/B_{step}.npy")
#       5 E = np.load(f"{dirname}/E_{step}.npy")
#       6 current = np.load(f"{dirname}/current_{step}.npy")
#
# File c:\Users\keita\Anaconda3\lib\site-packages\numpy\lib\npyio.py:417, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415     own_fid = False
#     416 else:
# --> 417     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418     own_fid = True
#     420 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results_MS_current_sheet/B_3000.npy'

# %%
fig = plt.figure(figsize=(24, 16))
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412)
ax3 = fig.add_subplot(413)
ax4 = fig.add_subplot(414)

rho_pic = m_ion * zeroth_moment_ion + m_electron * zeroth_moment_electron

ax1.plot(x_coordinate_mhd/ion_inertial_length, rho1_mhd / rho0_mhd, color='black', lw=3)
ax2.plot(x_coordinate_mhd/ion_inertial_length, current1_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
ax3.plot(x_coordinate_mhd/ion_inertial_length, By1_mhd / B0_mhd, color='black', lw=3)
ax4.plot(x_coordinate_mhd/ion_inertial_length, Ez1_mhd / VA_mhd / B0_mhd, color='black', lw=3)
ax1.plot((x_coordinate_mhd + 1200)/ion_inertial_length, rho2_mhd / rho0_mhd, color='black', lw=3)
ax2.plot((x_coordinate_mhd + 1200)/ion_inertial_length, current2_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
ax3.plot((x_coordinate_mhd + 1200)/ion_inertial_length, By2_mhd / B0_mhd, color='black', lw=3)
ax4.plot((x_coordinate_mhd + 1200)/ion_inertial_length, Ez2_mhd / VA_mhd / B0_mhd, color='black', lw=3)
ax1.plot((x_coordinate_pic + 450) / ion_inertial_length, rho_pic / rho0_mhd, color='green', lw=3)
ax2.plot((x_coordinate_pic + 450) / ion_inertial_length, np.convolve(current[2, :], np.ones(5)/5, mode="same") / B0_pic / ion_inertial_length, color='green', lw=3)
ax3.plot((x_coordinate_pic + 450) / ion_inertial_length, B[1, :] / B0_pic, color='green', lw=3)
ax4.plot((x_coordinate_pic + 450) / ion_inertial_length, E[2, :] / VA_pic / B0_pic, color='green', lw=3)

ax1.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax2.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax3.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax4.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax1.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax2.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax3.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax4.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax1.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
ax2.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
ax3.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
ax4.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)

ax4.set_xlabel(r"$x / \lambda_i$", fontsize=24)
ax1.set_ylabel(r"$\rho / \rho_0$", fontsize=24)
ax2.set_ylabel(r"$j_z / B_0 / \lambda_i$", fontsize=24)
ax3.set_ylabel(r"$B_y / B_0$", fontsize=24)
ax4.set_ylabel(r"$E_z / V_A / B_0$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax1.set_xlim(0, 1700/ion_inertial_length)
ax2.set_xlim(0, 1700/ion_inertial_length)
ax3.set_xlim(0, 1700/ion_inertial_length)
ax4.set_xlim(0, 1700/ion_inertial_length)
ax1.set_ylim(0.0, 8.0)
ax2.set_ylim(-0.005, 0.005)
ax3.set_ylim(-2.0, 2.0)
ax4.set_ylim(-1.0, 2.0)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.suptitle(f"t = {step}", y=0.95, fontsize=32)

plt.show()

# %% [markdown]
# 動画作成

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412)
ax3 = fig.add_subplot(413)
ax4 = fig.add_subplot(414)

dirname = "results_MS_current_sheet_By"
filename = "current_sheet_MHD-PIC_By.mp4"
log = np.loadtxt('log_By.txt', dtype=str)

interval = 10
plot_steps = 3000
for step in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()

    B = np.load(f"{dirname}/B_{step}.npy")
    E = np.load(f"{dirname}/E_{step}.npy")
    current = np.load(f"{dirname}/current_{step}.npy")
    zeroth_moment_ion = np.load(f"{dirname}/zeroth_moment_ion_{step}.npy")
    zeroth_moment_electron = np.load(f"{dirname}/zeroth_moment_electron_{step}.npy")
    first_moment_ion = np.load(f"{dirname}/first_moment_ion_{step}.npy")
    first_moment_electron = np.load(f"{dirname}/first_moment_electron_{step}.npy")

    U1 = np.load(f"{dirname}/U1_{step}.npy")
    rho1_mhd = U1[0, :]
    u1_mhd = U1[1, :] / rho1_mhd
    v1_mhd = U1[2, :] / rho1_mhd
    w1_mhd = U1[3, :] / rho1_mhd
    Bx1_mhd = U1[4, :]
    By1_mhd = U1[5, :]
    Bz1_mhd = U1[6, :]
    e1_mhd = U1[7, :]
    p1_mhd = (gamma_mhd - 1.0) \
            * (e1_mhd - 0.5 * rho1_mhd * (u1_mhd**2+v1_mhd**2+w1_mhd**2)
                - 0.5 * (Bx1_mhd**2+By1_mhd**2+Bz1_mhd**2))
    Ex1_mhd = -(v1_mhd * Bz1_mhd - w1_mhd * By1_mhd)
    Ey1_mhd = -(w1_mhd * Bx1_mhd - u1_mhd * Bz1_mhd)
    Ez1_mhd = -(u1_mhd * By1_mhd - v1_mhd * Bx1_mhd)
    current1_x_mhd = np.zeros(Bx1_mhd.shape)
    current1_y_mhd = -(np.roll(Bz1_mhd, -1, axis=0) - np.roll(Bz1_mhd, 1, axis=0)) / (2*dx_mhd)
    current1_z_mhd = (np.roll(By1_mhd, -1, axis=0) - np.roll(By1_mhd, 1, axis=0)) / (2*dx_mhd)
    current1_y_mhd[0] = current1_y_mhd[1] 
    current1_y_mhd[-1] = current1_y_mhd[-2] 
    current1_z_mhd[0] = current1_z_mhd[1] 
    current1_z_mhd[-1] = current1_z_mhd[-2] 

    U2 = np.load(f"{dirname}/U2_{step}.npy")
    rho2_mhd = U2[0, :]
    u2_mhd = U2[1, :] / rho2_mhd
    v2_mhd = U2[2, :] / rho2_mhd
    w2_mhd = U2[3, :] / rho2_mhd
    Bx2_mhd = U2[4, :]
    By2_mhd = U2[5, :]
    Bz2_mhd = U2[6, :]
    e2_mhd = U2[7, :]
    p2_mhd = (gamma_mhd - 1.0) \
            * (e2_mhd - 0.5 * rho2_mhd * (u2_mhd**2+v2_mhd**2+w2_mhd**2)
                - 0.5 * (Bx2_mhd**2+By2_mhd**2+Bz2_mhd**2))
    Ex2_mhd = -(v2_mhd * Bz2_mhd - w2_mhd * By2_mhd)
    Ey2_mhd = -(w2_mhd * Bx2_mhd - u2_mhd * Bz2_mhd)
    Ez2_mhd = -(u2_mhd * By2_mhd - v2_mhd * Bx2_mhd)
    current2_x_mhd = np.zeros(Bx2_mhd.shape)
    current2_y_mhd = -(np.roll(Bz2_mhd, -1, axis=0) - np.roll(Bz2_mhd, 1, axis=0)) / (2*dx_mhd)
    current2_z_mhd = (np.roll(By2_mhd, -1, axis=0) - np.roll(By2_mhd, 1, axis=0)) / (2*dx_mhd)
    current2_y_mhd[0] = current2_y_mhd[1] 
    current2_y_mhd[-1] = current2_y_mhd[-2] 
    current2_z_mhd[0] = current2_z_mhd[1] 
    current2_z_mhd[-1] = current2_z_mhd[-2] 


    rho_pic = m_ion * zeroth_moment_ion + m_electron * zeroth_moment_electron

    ax1.plot(x_coordinate_mhd/ion_inertial_length, rho1_mhd / rho0_mhd, color='black', lw=3)
    ax2.plot(x_coordinate_mhd/ion_inertial_length, current1_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
    ax3.plot(x_coordinate_mhd/ion_inertial_length, By1_mhd / B0_mhd, color='black', lw=3)
    ax4.plot(x_coordinate_mhd/ion_inertial_length, Ez1_mhd / VA_mhd / B0_mhd, color='black', lw=3)
    ax1.plot((x_coordinate_mhd + 1200)/ion_inertial_length, rho2_mhd / rho0_mhd, color='black', lw=3)
    ax2.plot((x_coordinate_mhd + 1200)/ion_inertial_length, current2_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
    ax3.plot((x_coordinate_mhd + 1200)/ion_inertial_length, By2_mhd / B0_mhd, color='black', lw=3)
    ax4.plot((x_coordinate_mhd + 1200)/ion_inertial_length, Ez2_mhd / VA_mhd / B0_mhd, color='black', lw=3)
    ax1.plot((x_coordinate_pic + 450) / ion_inertial_length, rho_pic / rho0_mhd, color='green', lw=3)
    ax2.plot((x_coordinate_pic + 450) / ion_inertial_length, np.convolve(current[2, :], np.ones(5)/5, mode="same") / B0_pic / ion_inertial_length, color='green', lw=3)
    ax3.plot((x_coordinate_pic + 450) / ion_inertial_length, B[1, :] / B0_pic, color='green', lw=3)
    ax4.plot((x_coordinate_pic + 450) / ion_inertial_length, E[2, :] / VA_pic / B0_pic, color='green', lw=3)

    ax1.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax2.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax3.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax4.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax1.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax2.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax3.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax4.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax1.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
    ax2.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
    ax3.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
    ax4.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)

    ax4.set_xlabel(r"$x / \lambda_i$", fontsize=24)
    ax1.set_ylabel(r"$\rho / \rho_0$", fontsize=24)
    ax2.set_ylabel(r"$j_z / B_0 / \lambda_i$", fontsize=24)
    ax3.set_ylabel(r"$B_y / B_0$", fontsize=24)
    ax4.set_ylabel(r"$E_z / V_A / B_0$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax1.set_xlim(0, 1700/ion_inertial_length)
    ax2.set_xlim(0, 1700/ion_inertial_length)
    ax3.set_xlim(0, 1700/ion_inertial_length)
    ax4.set_xlim(0, 1700/ion_inertial_length)
    ax1.set_ylim(0.0, 8.0)
    ax2.set_ylim(-0.005, 0.005)
    ax3.set_ylim(-2.0, 2.0)
    ax4.set_ylim(-1.0, 2.0)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()

    time = float(log[int(step/interval), 6].replace(',', ''))
    plt.suptitle(f"t = {time / (1.0 / omega_ci):.2f}" + r"$\Omega_{ci}^{-1}$", y=0.93, fontsize=32)

    fig.savefig(f'./pictures/{step}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for step in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{step}.png')
    video.write(img)
video.release()
