# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import cv2


import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

from lib_MHDPIC1D.pic1d import *
from lib_MHDPIC1D.mhd1d import *
from lib_MHDPIC1D.interface import *
from lib_MHDPIC1D.remove_noise import *

# %% [markdown]
# カレントシート with Poynting flux

# %%
def boundary_Poynting_flux(speed_ratio, VA, B0, rho_init, p_init, gamma, U1, U2):
    U1[0, 0] = rho_init[0] * (1.0 + speed_ratio)
    U1[1, 0] = rho_init[0] * speed_ratio * VA
    U1[2, 0] = 0.0
    U1[3, 0] = 0.0
    U1[4, 0] = 0.1 * B0
    U1[5, 0] = -B0 * (1.0 + speed_ratio)
    U1[6, 0] = 0.0
    p = p_init[0] * (1.0 + gamma * speed_ratio)
    U1[7, 0] = p / (gamma - 1.0) \
            + 0.5 * rho_init[0] * (1.0 + speed_ratio) * (speed_ratio * VA)**2 \
            + 0.5 * (B0 * (1.0 + speed_ratio))**2
    
    U1[:, -1] = U1[:, -2]
    
    
    U2[:, 0] = U2[:, 1]
    
    U2[0, -1] = rho_init[-1] * (1.0 + speed_ratio)
    U2[1, -1] = -rho_init[-1] * speed_ratio * VA
    U2[2, -1] = 0.0
    U2[3, -1] = 0.0
    U2[4, -1] = 0.1 * B0
    U2[5, -1] = B0 * (1.0 + speed_ratio)
    U2[6, -1] = 0.0
    p = p_init[0] * (1.0 + gamma * speed_ratio)
    U2[7, -1] = p / (gamma - 1.0) \
            + 0.5 * rho_init[-1] * (1.0 + speed_ratio) * (speed_ratio * VA)**2 \
            + 0.5 * (B0 * (1.0 + speed_ratio))**2 

    return U1, U2

# %% [markdown]
# PIC初期化

# %%
c = 1.0
mu_0 = 1.0
epsilon0 = 1.0 / (mu_0 * c**2)
m_electron = 1.0
r_m = 1 / 100
m_ion = m_electron / r_m
t_r = 1.0
ne0_pic = 100 #ここは手動で調整すること
ni0_pic = ne0_pic
B0_pic = np.sqrt(ne0_pic) / 1.0 / np.sqrt(2/(1+t_r))
Ti_pic  = (B0_pic**2 / 2.0 / mu_0) / (ni0_pic + ne0_pic * t_r)
Te_pic = Ti_pic * t_r
q_electron = -1 * np.sqrt(epsilon0 * Te_pic / ne0_pic)
q_ion = -1 * q_electron
debye_length = np.sqrt(epsilon0 * Te_pic / ne0_pic / q_electron**2)
omega_pe = np.sqrt(ne0_pic * q_electron**2 / m_electron / epsilon0)
omega_pi = np.sqrt(ni0_pic * q_ion**2 / m_ion / epsilon0)
omega_ce = q_electron * B0_pic / m_electron
omega_ci = q_ion * B0_pic / m_ion
VA_pic = B0_pic / np.sqrt(ni0_pic * m_ion + ni0_pic * m_electron)
gamma_pic = 5.0 / 3.0
rho_pic = ni0_pic * m_ion + ne0_pic * m_electron
p_pic = ni0_pic * Ti_pic + ne0_pic * Te_pic
CS_pic = np.sqrt(gamma_pic * p_pic / rho_pic)
ion_inertial_length = c / omega_pi
sheat_thickness_pic = 3.0 * ion_inertial_length
v_electron = np.array([0.0, 0.0, -c * debye_length / sheat_thickness_pic * np.sqrt(2 / (1.0 + 1/t_r))])
v_ion = -v_electron / t_r
v_thermal_electron = np.sqrt(2.0 * Te_pic / m_electron)
v_thermal_ion = np.sqrt(2.0 * Ti_pic / m_ion)
v_thermal_electron_background = np.sqrt(2.0 * 0.2 * Te_pic / m_electron)
v_thermal_ion_background = np.sqrt(2.0 * 0.2 * Ti_pic / m_ion)

dx_pic = debye_length
nx_pic = int(40 * ion_inertial_length)
x_min_pic = 1e-10
x_max_pic = nx_pic * dx_pic - 1e-10
x_coordinate_pic = np.arange(0.0, x_max_pic, dx_pic)
dt_pic = 0.0
d_pic = 0.0

E_pic = np.zeros([3, nx_pic])
B_pic = np.zeros([3, nx_pic])
current_pic = np.zeros([3, nx_pic])
rho_pic = np.zeros(nx_pic)
B_pic[0, :] = 0.1 * B0_pic
B_pic[1, :] = B0_pic * np.tanh((x_coordinate_pic - nx_pic/2.0) / sheat_thickness_pic)
beta_pic = (ne0_pic * Te_pic + ni0_pic * Ti_pic) / (B0_pic**2 / 2 / mu_0)

n_ion = int(ni0_pic * 2.0 * sheat_thickness_pic)
n_electron = int(n_ion * abs(q_ion / q_electron))
n_ion_background = int(0.2 * ni0_pic * x_max_pic)
n_electron_background = int(0.2 * ne0_pic * x_max_pic)
x_pic_ion = np.zeros([3, n_ion + n_ion_background])
x_pic_electron = np.zeros([3, n_electron + n_electron_background])
v_pic_ion = np.zeros([3, n_ion + n_ion_background])
v_pic_electron = np.zeros([3, n_electron + n_electron_background])

rs_ion = np.random.RandomState(10)
rs_electron = np.random.RandomState(20)
x_start_ion = np.array(x_max_pic/2.0 + sheat_thickness_pic * np.arctanh(2.0 * rs_ion.rand(n_ion) - 1.0))
x_start_ion[x_start_ion >= x_max_pic] = x_max_pic / 2.0
x_start_ion[x_start_ion <= x_min_pic] = x_max_pic / 2.0
x_start_ion_background = np.random.rand(n_ion_background) * (x_max_pic - x_min_pic)
x_start_electron = np.array(x_max_pic/2.0 + sheat_thickness_pic * np.arctanh(2.0 * rs_electron.rand(n_electron) - 1.0))
x_start_electron[x_start_electron >= x_max_pic] = x_max_pic / 2.0
x_start_electron[x_start_electron <= x_min_pic] = x_max_pic / 2.0
x_start_electron_background = np.random.rand(n_electron_background) * (x_max_pic - x_min_pic)
x_pic_ion[0, :] = np.concatenate([x_start_ion, x_start_ion_background])
x_pic_electron[0, :] = np.concatenate([x_start_electron, x_start_electron_background])
v_pic_ion[0, :n_ion] = stats.norm.rvs(v_ion[0], v_thermal_ion, size=n_ion)
v_pic_ion[0, n_ion:] = stats.norm.rvs(0.0, v_thermal_ion_background, size=n_ion_background)
v_pic_ion[1, :n_ion] = stats.norm.rvs(v_ion[1], v_thermal_ion, size=n_ion)
v_pic_ion[1, n_ion:] = stats.norm.rvs(0.0, v_thermal_ion_background, size=n_ion_background)
v_pic_ion[2, :n_ion] = stats.norm.rvs(v_ion[2], v_thermal_ion, size=n_ion)
v_pic_ion[2, n_ion:] = stats.norm.rvs(0.0, v_thermal_ion_background, size=n_ion_background)
v_pic_electron[0, :n_electron] = stats.norm.rvs(v_electron[0], v_thermal_electron, size=n_electron)
v_pic_electron[0, n_electron:] = stats.norm.rvs(0.0, v_thermal_electron_background, size=n_electron_background)
v_pic_electron[1, :n_electron] = stats.norm.rvs(v_electron[1], v_thermal_electron, size=n_electron)
v_pic_electron[1, n_electron:] = stats.norm.rvs(0.0, v_thermal_electron_background, size=n_electron_background)
v_pic_electron[2, :n_electron] = stats.norm.rvs(v_electron[2], v_thermal_electron, size=n_electron)
v_pic_electron[2, n_electron:] = stats.norm.rvs(0.0, v_thermal_electron_background, size=n_electron_background)

print(f"total number of particles is {n_ion + n_ion_background + n_electron + n_electron_background}.")
print(f"Box size is {nx_pic}")
print(f"ion inertial length is {ion_inertial_length:.1f}")
print(r"$\omega_{ci}^{-1}$" + f" is {1.0/omega_ci:.1f}")
# Out:
# total number of particles is 55998.
# Box size is 800
# ion inertial length is 20.0
# $\omega_{ci}^{-1}$ is 200.0

# %% [markdown]
# MHD初期化

# %%
gamma_mhd = 5.0 / 3.0
B0_mhd = B0_pic
rho0_mhd = 0.2 * ne0_pic * m_electron + 0.2 * ni0_pic * m_ion
p0_mhd = 0.2 * ne0_pic * (0.5 * m_electron * v_thermal_electron_background**2) \
       + 0.2 * ni0_pic * (0.5 * m_ion * v_thermal_ion_background**2)
VA_mhd = B0_mhd / np.sqrt(rho0_mhd)
CS_mhd = np.sqrt(gamma_mhd * p0_mhd / rho0_mhd)
Cf_mhd = np.sqrt(VA_mhd**2 + CS_mhd**2)
dx_mhd = dx_pic

nx_mhd = 500
x_min_mhd = 1e-10
x_max_mhd = nx_mhd * dx_mhd - 1e-10
dt_mhd = 0.0
CFL = 0.7
x_coordinate_mhd = np.arange(x_min_mhd, x_max_mhd, dx_mhd)

sheat_thickness_mhd = sheat_thickness_pic / dx_pic * dx_mhd
speed_ratio = 0.1

U1 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd * np.ones(nx_mhd)
u_init = 0.0
v_init = 0.0
w_init = 0.0
Bx_init = 0.1 * B0_mhd
By_init = -B0_mhd * np.ones(nx_mhd)
Bz_init = 0.0
p_init = p0_mhd * np.ones(nx_mhd)
U1[0, :] = rho_init
U1[1, :] = rho_init * u_init
U1[2, :] = rho_init * v_init
U1[3, :] = rho_init * w_init
U1[4, :] = Bx_init
U1[5, :] = By_init
U1[6, :] = Bz_init
U1[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

U2 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd * np.ones(nx_mhd)
u_init = 0.0
v_init = 0.0
w_init = 0.0
Bx_init = 0.1 * B0_mhd
By_init = B0_mhd * np.ones(nx_mhd)
Bz_init = 0.0
p_init = p0_mhd * np.ones(nx_mhd)
U2[0, :] = rho_init
U2[1, :] = rho_init * u_init
U2[2, :] = rho_init * v_init
U2[3, :] = rho_init * w_init
U2[4, :] = Bx_init
U2[5, :] = By_init
U2[6, :] = Bz_init
U2[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

flux1 = np.zeros(U1.shape)
flux1_bar = np.zeros(flux1.shape)
flux2 = np.zeros(U2.shape)
flux2_bar = np.zeros(flux2.shape)

print(f"U1 size = {U1.shape}, U2 size = {U2.shape}")
# Out:
# U1 size = (8, 500), U2 size = (8, 500)

# %% [markdown]
# interface用の変数

# %%
window_size_convolution_pic = 10
window_size_smoothing_mhd = 5
interface_width = 50

index_interface_mhd_start_left = nx_mhd - interface_width
index_interface_mhd_end_left = nx_mhd
index_interface_mhd_start_right = 0
index_interface_mhd_end_right = interface_width
index_interface_pic_start_left = 0
index_interface_pic_end_left = interface_width
index_interface_pic_start_right = nx_pic - interface_width
index_interface_pic_end_right = nx_pic

x_interface_coordinate_left = np.arange(0, interface_width, 1)
x_interface_coordinate_half_left = np.arange(0.5, interface_width - 0.5, 1)
F_left = interlocking_function(x_interface_coordinate_left)
F_half_left = interlocking_function(x_interface_coordinate_half_left)
F_right = np.flip(F_left)
F_half_right = np.flip(F_half_left)

# %% [markdown]
# 時間発展

# %%
#STEP1:PICとMHDの時間を合わせる
#以下、t1からt2に時間発展させるとする
#ただし、t2 = t1 + dt_mhdとする
B_pic_time_ave = np.zeros(B_pic.shape)
zeroth_moment_ion_time_ave = np.zeros(nx_pic)
zeroth_moment_electron_time_ave = np.zeros(nx_pic)
first_moment_ion_time_ave = np.zeros([3, nx_pic])
first_moment_electron_time_ave = np.zeros([3, nx_pic])
second_moment_ion_time_ave = np.zeros([9, nx_pic])
second_moment_electron_time_ave = np.zeros([9, nx_pic])

total_substeps = 10

dirname = "results_MS_current_sheet_Bx"
steps = 3000
time_mhd = 0.0
time_pic = 0.0
for step in range(steps+1):

    # save
    if (step % 10 == 0):
        print(f"{step} step done... : time_mhd = {time_mhd:.5f}, time_pic = {time_pic:.5f}, dt_mhd = {dt_mhd:.5f}, dt_pic = {dt_pic:.5f}")

        #np.save(f'./{dirname}/x_ion_{step}.npy', x_pic_ion)
        #np.save(f'./{dirname}/x_electron_{step}.npy', x_pic_electron)
        #np.save(f'./{dirname}/v_ion_{step}.npy', v_pic_ion)
        #np.save(f'./{dirname}/v_electron_{step}.npy', v_pic_electron)
        np.save(f'./{dirname}/E_{step}.npy', E_pic)
        np.save(f'./{dirname}/B_{step}.npy', B_pic)
        np.save(f'./{dirname}/current_{step}.npy', current_pic)
        np.save(f"./{dirname}/U1_{step}.npy", U1)
        np.save(f"./{dirname}/U2_{step}.npy", U2)

        zeroth_moment_ion = np.zeros(nx_pic)
        zeroth_moment_electron = np.zeros(nx_pic)
        zeroth_moment_ion = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion)
        zeroth_moment_electron = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron)
        first_moment_ion = np.zeros([3, nx_pic])
        first_moment_electron = np.zeros([3, nx_pic])
        first_moment_ion = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion)
        first_moment_electron = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron)
        second_moment_ion = np.zeros([9, nx_pic])
        second_moment_electron = np.zeros([9, nx_pic])
        second_moment_ion = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion)
        second_moment_electron = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron)

        np.save(f'./{dirname}/zeroth_moment_ion_{step}.npy', zeroth_moment_ion)
        np.save(f'./{dirname}/zeroth_moment_electron_{step}.npy', zeroth_moment_electron)
        np.save(f'./{dirname}/first_moment_ion_{step}.npy', first_moment_ion)
        np.save(f'./{dirname}/first_moment_electron_{step}.npy', first_moment_electron)
        np.save(f'./{dirname}/second_moment_ion_{step}.npy', second_moment_ion)
        np.save(f'./{dirname}/second_moment_electron_{step}.npy', second_moment_electron)

        #np.save(f'./{dirname}/B_time_ave_{step}.npy', B_pic_time_ave)
        #np.save(f'./{dirname}/zeroth_moment_ion_time_ave_{step}.npy', zeroth_moment_ion_time_ave)
        #np.save(f'./{dirname}/zeroth_moment_electron_time_ave_{step}.npy', zeroth_moment_electron_time_ave)
        #np.save(f'./{dirname}/first_moment_ion_time_ave_{step}.npy', first_moment_ion_time_ave)
        #np.save(f'./{dirname}/first_moment_electron_time_ave_{step}.npy', first_moment_electron_time_ave)
        #np.save(f'./{dirname}/second_moment_ion_time_ave_{step}.npy', second_moment_ion_time_ave)
        #np.save(f'./{dirname}/second_moment_electron_time_ave_{step}.npy', second_moment_electron_time_ave)

    #STEP1:MHD-Predictor
    U1_past = U1.copy()
    U2_past = U2.copy()
    #MHD
    #----------------------------------------------------------- 
    if True:
        U1_bar = U1.copy()
        U2_bar = U2.copy()

        dt_mhd_left = get_time_step(U1, gamma_mhd, dx_mhd, CFL)
        dt_mhd_right = get_time_step(U2, gamma_mhd, dx_mhd, CFL)
        dt_mhd = np.min([dt_mhd_left, dt_mhd_right])
        if np.isnan(dt_mhd):
            print(f"{step} steps (t = {time_mhd:.3f}) : Calculation is crashed!")
            break

        flux1 = get_flux_mhd(U1, gamma_mhd, flux1)
        flux2 = get_flux_mhd(U2, gamma_mhd, flux2)
        U1_bar += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2_bar += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1_bar, U2_bar = boundary_Poynting_flux(speed_ratio * (1.0 + np.tanh(((step-200)/50)))/2.0, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1_bar, U2_bar)

        flux1_bar = get_flux_mhd(U1_bar, gamma_mhd, flux1_bar)
        flux2_bar = get_flux_mhd(U2_bar, gamma_mhd, flux2_bar)
        flux1 = 0.5 * (flux1 + flux1_bar)
        flux2 = 0.5 * (flux2 + flux2_bar)
        U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2 += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1, U2 = boundary_Poynting_flux(speed_ratio * (1.0 + np.tanh(((step-200)/50)))/2.0, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1, U2)


    #STEP2:PIC
    B_pic_time_ave = np.zeros(B_pic.shape)
    zeroth_moment_ion_time_ave = np.zeros(zeroth_moment_ion_time_ave.shape)
    zeroth_moment_electron_time_ave = np.zeros(zeroth_moment_electron_time_ave.shape)
    first_moment_ion_time_ave = np.zeros(first_moment_ion_time_ave.shape)
    first_moment_electron_time_ave = np.zeros(first_moment_electron_time_ave.shape)
    second_moment_ion_time_ave = np.zeros(second_moment_ion_time_ave.shape)
    second_moment_electron_time_ave = np.zeros(second_moment_electron_time_ave.shape)
    
    dt_pic = dt_mhd / total_substeps
    for substep in range(total_substeps):

        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic) 
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U1 * (substep + 0.5) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, B_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U2 * (substep + 0.5) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, B_pic
        )
        
        v_pic_ion = time_evolution_v(c, E_pic, B_pic, x_pic_ion, q_ion, m_ion, nx_pic, dx_pic, dt_pic, v_pic_ion)
        v_pic_electron = time_evolution_v(c, E_pic, B_pic, x_pic_electron, q_electron, m_electron, nx_pic, dx_pic, dt_pic, v_pic_electron)
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)

        current_pic = np.zeros(current_pic.shape)
        current_pic = get_current_density(c, q_ion, v_pic_ion, x_pic_ion, nx_pic, dx_pic, current_pic)
        current_pic = get_current_density(c, q_electron, v_pic_electron, x_pic_electron, nx_pic, dx_pic, current_pic)
        current_pic[:, 0] = current_pic[:, 1]
        current_pic[:, -1] = current_pic[:, -2]
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U1 * (substep + 0.5) / total_substeps
        current_pic = send_MHD_to_PICinterface_current(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, dx_mhd, window_size_convolution_pic, current_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U2 * (substep + 0.5) / total_substeps
        current_pic = send_MHD_to_PICinterface_current(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, dx_mhd, window_size_convolution_pic, current_pic
        )
        
        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic)
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, B_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, B_pic
        )
        
        E_pic = time_evolution_E(B_pic, current_pic, c, epsilon0, dx_pic, dt_pic, E_pic)
        E_pic = boundary_E(E_pic)
        rho_pic = np.zeros(rho_pic.shape)
        rho_pic = get_rho(q_ion, x_pic_ion, nx_pic, dx_pic, rho_pic)
        rho_pic = get_rho(q_electron, x_pic_electron, nx_pic, dx_pic, rho_pic)
        rho_pic[0] = rho_pic[1]
        rho_pic[-1] = rho_pic[-2]
        E_pic = filter_E(rho_pic, dx_pic, dt_pic, d_pic, epsilon0, E_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        E_pic = send_MHD_to_PICinterface_E(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, E_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        E_pic = send_MHD_to_PICinterface_E(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, E_pic
        )
        
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, x_min_pic,  
            U1_send, dx_mhd, gamma_mhd, q_electron, 
            m_electron, m_ion, nx_pic, c, window_size_convolution_pic, 
            v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, x_min_pic,  
            U2_send, dx_mhd, gamma_mhd, q_electron, 
            m_electron, m_ion, nx_pic, c, window_size_convolution_pic, 
            v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        )

        time_pic += dt_pic


        # 時間平均のため
        if True:
            B_pic_time_ave += B_pic

            zeroth_moment_ion_tmp = np.zeros(zeroth_moment_ion_time_ave.shape)
            zeroth_moment_electron_tmp = np.zeros(zeroth_moment_electron_time_ave.shape)
            zeroth_moment_ion_tmp = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion_tmp)
            zeroth_moment_electron_tmp = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron_tmp)
            zeroth_moment_ion_time_ave += zeroth_moment_ion_tmp
            zeroth_moment_electron_time_ave += zeroth_moment_electron_tmp

            first_moment_ion_tmp = np.zeros(first_moment_ion_time_ave.shape)
            first_moment_electron_tmp = np.zeros(first_moment_electron_time_ave.shape)
            first_moment_ion_tmp = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion_tmp)
            first_moment_electron_tmp = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron_tmp)
            first_moment_ion_time_ave += first_moment_ion_tmp
            first_moment_electron_time_ave += first_moment_electron_tmp

            second_moment_ion_tmp = np.zeros(second_moment_ion_time_ave.shape)
            second_moment_electron_tmp = np.zeros(second_moment_electron_time_ave.shape)
            second_moment_ion_tmp = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion_tmp)
            second_moment_electron_tmp = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron_tmp)
            second_moment_ion_time_ave += second_moment_ion_tmp
            second_moment_electron_time_ave += second_moment_electron_tmp
            
    B_pic_time_ave /= total_substeps
    zeroth_moment_ion_time_ave /= total_substeps
    zeroth_moment_electron_time_ave /= total_substeps
    first_moment_ion_time_ave /= total_substeps
    first_moment_electron_time_ave /= total_substeps
    second_moment_ion_time_ave /= total_substeps
    second_moment_electron_time_ave /= total_substeps


    #STEP3:MHD-Correcter
    U1_PIC = np.zeros(U1.shape)
    U2_PIC = np.zeros(U2.shape)
    #n+1/2にする
    U1_PIC[:, :] = 0.5 * (U1_past[:, :] + U1[:, :])
    U2_PIC[:, :] = 0.5 * (U2_past[:, :] + U2[:, :])
    U1_PIC = send_PIC_to_MHDinterface(
        index_interface_mhd_start_left, index_interface_mhd_end_left, 
        index_interface_pic_start_left, index_interface_pic_end_left, 
        F_left, 
        gamma_mhd, m_electron, m_ion, nx_pic, B_pic_time_ave, 
        zeroth_moment_ion_time_ave, zeroth_moment_electron_time_ave, 
        first_moment_ion_time_ave, first_moment_electron_time_ave, 
        second_moment_ion_time_ave, second_moment_electron_time_ave, 
        window_size_convolution_pic, U1_PIC
    )
    U2_PIC = send_PIC_to_MHDinterface(
        index_interface_mhd_start_right, index_interface_mhd_end_right, 
        index_interface_pic_start_right, index_interface_pic_end_right, 
        F_right, 
        gamma_mhd, m_electron, m_ion, nx_pic, B_pic_time_ave, 
        zeroth_moment_ion_time_ave, zeroth_moment_electron_time_ave, 
        first_moment_ion_time_ave, first_moment_electron_time_ave, 
        second_moment_ion_time_ave, second_moment_electron_time_ave, 
        window_size_convolution_pic, U2_PIC
    )

    if True:
        U1 = U1_past.copy()
        U2 = U2_past.copy()
    
        flux1 = get_flux_mhd(U1_PIC, gamma_mhd, flux1)
        flux2 = get_flux_mhd(U2_PIC, gamma_mhd, flux2)
        U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2 += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1, U2 = boundary_Poynting_flux(speed_ratio * (1.0 + np.tanh(((step-200)/50)))/2.0, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1, U2)
        
        time_mhd += dt_mhd


    #interface領域のスムージング処理
    U1 = smoothing_U_left(
        U1, index_interface_mhd_start_left, index_interface_mhd_end_left, 
        window_size_smoothing_mhd
    )
    U2 = smoothing_U_right(
        U2, index_interface_mhd_start_right, index_interface_mhd_end_right, 
        window_size_smoothing_mhd
    )
# Out:
# 0 step done... : time_mhd = 0.00000, time_pic = 0.00000, dt_mhd = 0.00000, dt_pic = 0.00000
# 10 step done... : time_mhd = 30.68775, time_pic = 30.68775, dt_mhd = 3.06215, dt_pic = 0.30622
# 20 step done... : time_mhd = 61.24927, time_pic = 61.24927, dt_mhd = 3.04743, dt_pic = 0.30474
# 30 step done... : time_mhd = 91.50512, time_pic = 91.50512, dt_mhd = 3.01677, dt_pic = 0.30168
# 40 step done... : time_mhd = 121.62153, time_pic = 121.62153, dt_mhd = 3.00872, dt_pic = 0.30087
# 50 step done... : time_mhd = 151.76056, time_pic = 151.76056, dt_mhd = 3.01828, dt_pic = 0.30183
# 60 step done... : time_mhd = 181.97025, time_pic = 181.97025, dt_mhd = 3.01847, dt_pic = 0.30185
# 70 step done... : time_mhd = 212.11633, time_pic = 212.11633, dt_mhd = 3.00950, dt_pic = 0.30095
# 80 step done... : time_mhd = 242.16811, time_pic = 242.16811, dt_mhd = 2.99624, dt_pic = 0.29962
# 90 step done... : time_mhd = 272.17894, time_pic = 272.17894, dt_mhd = 3.01170, dt_pic = 0.30117
# 100 step done... : time_mhd = 302.40911, time_pic = 302.40911, dt_mhd = 3.02502, dt_pic = 0.30250
# 110 step done... : time_mhd = 332.58857, time_pic = 332.58857, dt_mhd = 3.01828, dt_pic = 0.30183
# 120 step done... : time_mhd = 362.91045, time_pic = 362.91045, dt_mhd = 3.03547, dt_pic = 0.30355
# 130 step done... : time_mhd = 393.25039, time_pic = 393.25039, dt_mhd = 3.03683, dt_pic = 0.30368
# 140 step done... : time_mhd = 423.52665, time_pic = 423.52665, dt_mhd = 3.02092, dt_pic = 0.30209
# 150 step done... : time_mhd = 453.64237, time_pic = 453.64237, dt_mhd = 3.00651, dt_pic = 0.30065
# 160 step done... : time_mhd = 483.51686, time_pic = 483.51686, dt_mhd = 2.98127, dt_pic = 0.29813
# 170 step done... : time_mhd = 513.31690, time_pic = 513.31690, dt_mhd = 2.97460, dt_pic = 0.29746
# 180 step done... : time_mhd = 542.99902, time_pic = 542.99902, dt_mhd = 2.95708, dt_pic = 0.29571
# 190 step done... : time_mhd = 572.39748, time_pic = 572.39748, dt_mhd = 2.92528, dt_pic = 0.29253
# 200 step done... : time_mhd = 601.46464, time_pic = 601.46464, dt_mhd = 2.89097, dt_pic = 0.28910
# 210 step done... : time_mhd = 630.17297, time_pic = 630.17297, dt_mhd = 2.85470, dt_pic = 0.28547
# 220 step done... : time_mhd = 658.53561, time_pic = 658.53561, dt_mhd = 2.82185, dt_pic = 0.28219
# 230 step done... : time_mhd = 686.59698, time_pic = 686.59698, dt_mhd = 2.79411, dt_pic = 0.27941
# 240 step done... : time_mhd = 714.41203, time_pic = 714.41203, dt_mhd = 2.77203, dt_pic = 0.27720
# 250 step done... : time_mhd = 742.02339, time_pic = 742.02339, dt_mhd = 2.75295, dt_pic = 0.27530
# 260 step done... : time_mhd = 769.47223, time_pic = 769.47223, dt_mhd = 2.73840, dt_pic = 0.27384
# 270 step done... : time_mhd = 796.79513, time_pic = 796.79513, dt_mhd = 2.72783, dt_pic = 0.27278
# 280 step done... : time_mhd = 824.02418, time_pic = 824.02418, dt_mhd = 2.71956, dt_pic = 0.27196
# 290 step done... : time_mhd = 851.18615, time_pic = 851.18615, dt_mhd = 2.71354, dt_pic = 0.27135
# 300 step done... : time_mhd = 878.29856, time_pic = 878.29856, dt_mhd = 2.70939, dt_pic = 0.27094
# 310 step done... : time_mhd = 905.37457, time_pic = 905.37457, dt_mhd = 2.70647, dt_pic = 0.27065
# 320 step done... : time_mhd = 932.42466, time_pic = 932.42466, dt_mhd = 2.70406, dt_pic = 0.27041
# 330 step done... : time_mhd = 959.45660, time_pic = 959.45660, dt_mhd = 2.70242, dt_pic = 0.27024
# 340 step done... : time_mhd = 986.47466, time_pic = 986.47466, dt_mhd = 2.70137, dt_pic = 0.27014
# 350 step done... : time_mhd = 1013.48234, time_pic = 1013.48234, dt_mhd = 2.70039, dt_pic = 0.27004
# 360 step done... : time_mhd = 1040.48291, time_pic = 1040.48291, dt_mhd = 2.69971, dt_pic = 0.26997
# 370 step done... : time_mhd = 1067.47777, time_pic = 1067.47777, dt_mhd = 2.69931, dt_pic = 0.26993
# 380 step done... : time_mhd = 1094.46768, time_pic = 1094.46768, dt_mhd = 2.69883, dt_pic = 0.26988
# 390 step done... : time_mhd = 1121.45460, time_pic = 1121.45460, dt_mhd = 2.69848, dt_pic = 0.26985
# 400 step done... : time_mhd = 1148.43814, time_pic = 1148.43814, dt_mhd = 2.69832, dt_pic = 0.26983
# 410 step done... : time_mhd = 1175.41891, time_pic = 1175.41891, dt_mhd = 2.69795, dt_pic = 0.26979
# 420 step done... : time_mhd = 1202.39774, time_pic = 1202.39774, dt_mhd = 2.69774, dt_pic = 0.26977
# 430 step done... : time_mhd = 1229.37395, time_pic = 1229.37395, dt_mhd = 2.69760, dt_pic = 0.26976
# 440 step done... : time_mhd = 1256.34834, time_pic = 1256.34834, dt_mhd = 2.69730, dt_pic = 0.26973
# 450 step done... : time_mhd = 1283.32090, time_pic = 1283.32090, dt_mhd = 2.69717, dt_pic = 0.26972
# 460 step done... : time_mhd = 1310.29110, time_pic = 1310.29110, dt_mhd = 2.69696, dt_pic = 0.26970
# 470 step done... : time_mhd = 1337.25987, time_pic = 1337.25987, dt_mhd = 2.69674, dt_pic = 0.26967
# 480 step done... : time_mhd = 1364.22669, time_pic = 1364.22669, dt_mhd = 2.69666, dt_pic = 0.26967
# 490 step done... : time_mhd = 1391.19145, time_pic = 1391.19145, dt_mhd = 2.69638, dt_pic = 0.26964
# 500 step done... : time_mhd = 1418.15481, time_pic = 1418.15481, dt_mhd = 2.69622, dt_pic = 0.26962
# 510 step done... : time_mhd = 1445.11602, time_pic = 1445.11602, dt_mhd = 2.69610, dt_pic = 0.26961
# 520 step done... : time_mhd = 1472.07565, time_pic = 1472.07565, dt_mhd = 2.69584, dt_pic = 0.26958
# 530 step done... : time_mhd = 1499.03366, time_pic = 1499.03366, dt_mhd = 2.69572, dt_pic = 0.26957
# 540 step done... : time_mhd = 1525.98954, time_pic = 1525.98954, dt_mhd = 2.69553, dt_pic = 0.26955
# 550 step done... : time_mhd = 1552.94412, time_pic = 1552.94412, dt_mhd = 2.69533, dt_pic = 0.26953
# 560 step done... : time_mhd = 1579.89681, time_pic = 1579.89681, dt_mhd = 2.69526, dt_pic = 0.26953
# 570 step done... : time_mhd = 1606.84768, time_pic = 1606.84768, dt_mhd = 2.69499, dt_pic = 0.26950
# 580 step done... : time_mhd = 1633.79719, time_pic = 1633.79719, dt_mhd = 2.69485, dt_pic = 0.26949
# 590 step done... : time_mhd = 1660.74468, time_pic = 1660.74468, dt_mhd = 2.69471, dt_pic = 0.26947
# 600 step done... : time_mhd = 1687.69079, time_pic = 1687.69079, dt_mhd = 2.69450, dt_pic = 0.26945
# 610 step done... : time_mhd = 1714.63533, time_pic = 1714.63533, dt_mhd = 2.69440, dt_pic = 0.26944
# 620 step done... : time_mhd = 1741.57798, time_pic = 1741.57798, dt_mhd = 2.69420, dt_pic = 0.26942
# 630 step done... : time_mhd = 1768.51944, time_pic = 1768.51944, dt_mhd = 2.69404, dt_pic = 0.26940
# 640 step done... : time_mhd = 1795.45917, time_pic = 1795.45917, dt_mhd = 2.69398, dt_pic = 0.26940
# 650 step done... : time_mhd = 1822.39734, time_pic = 1822.39734, dt_mhd = 2.69370, dt_pic = 0.26937
# 660 step done... : time_mhd = 1849.33389, time_pic = 1849.33389, dt_mhd = 2.69356, dt_pic = 0.26936
# 670 step done... : time_mhd = 1876.26803, time_pic = 1876.26803, dt_mhd = 2.69334, dt_pic = 0.26933
# 680 step done... : time_mhd = 1903.20069, time_pic = 1903.20069, dt_mhd = 2.69317, dt_pic = 0.26932
# 690 step done... : time_mhd = 1930.13245, time_pic = 1930.13245, dt_mhd = 2.69325, dt_pic = 0.26933
# 700 step done... : time_mhd = 1957.06544, time_pic = 1957.06544, dt_mhd = 2.69337, dt_pic = 0.26934
# 710 step done... : time_mhd = 1984.00045, time_pic = 1984.00045, dt_mhd = 2.69357, dt_pic = 0.26936
# 720 step done... : time_mhd = 2010.93731, time_pic = 2010.93731, dt_mhd = 2.69387, dt_pic = 0.26939
# 730 step done... : time_mhd = 2037.88119, time_pic = 2037.88119, dt_mhd = 2.69494, dt_pic = 0.26949
# 740 step done... : time_mhd = 2064.83906, time_pic = 2064.83906, dt_mhd = 2.69605, dt_pic = 0.26960
# 750 step done... : time_mhd = 2091.79966, time_pic = 2091.79966, dt_mhd = 2.69608, dt_pic = 0.26961
# 760 step done... : time_mhd = 2118.76055, time_pic = 2118.76055, dt_mhd = 2.69611, dt_pic = 0.26961
# 770 step done... : time_mhd = 2145.72222, time_pic = 2145.72222, dt_mhd = 2.69622, dt_pic = 0.26962
# 780 step done... : time_mhd = 2172.68098, time_pic = 2172.68098, dt_mhd = 2.69537, dt_pic = 0.26954
# 790 step done... : time_mhd = 2199.63258, time_pic = 2199.63258, dt_mhd = 2.69512, dt_pic = 0.26951
# 800 step done... : time_mhd = 2226.58034, time_pic = 2226.58034, dt_mhd = 2.69418, dt_pic = 0.26942
# 810 step done... : time_mhd = 2253.51103, time_pic = 2253.51103, dt_mhd = 2.69196, dt_pic = 0.26920
# 820 step done... : time_mhd = 2280.41105, time_pic = 2280.41105, dt_mhd = 2.68812, dt_pic = 0.26881
# 830 step done... : time_mhd = 2307.27342, time_pic = 2307.27342, dt_mhd = 2.68530, dt_pic = 0.26853
# 840 step done... : time_mhd = 2334.12778, time_pic = 2334.12778, dt_mhd = 2.68545, dt_pic = 0.26855
# 850 step done... : time_mhd = 2360.97132, time_pic = 2360.97132, dt_mhd = 2.68386, dt_pic = 0.26839
# 860 step done... : time_mhd = 2387.85410, time_pic = 2387.85410, dt_mhd = 2.69506, dt_pic = 0.26951
# 870 step done... : time_mhd = 2414.79038, time_pic = 2414.79038, dt_mhd = 2.69230, dt_pic = 0.26923
# 880 step done... : time_mhd = 2441.70749, time_pic = 2441.70749, dt_mhd = 2.69148, dt_pic = 0.26915
# 890 step done... : time_mhd = 2468.62435, time_pic = 2468.62435, dt_mhd = 2.69221, dt_pic = 0.26922
# 900 step done... : time_mhd = 2495.55113, time_pic = 2495.55113, dt_mhd = 2.69115, dt_pic = 0.26912
# 910 step done... : time_mhd = 2522.44474, time_pic = 2522.44474, dt_mhd = 2.68848, dt_pic = 0.26885
# 920 step done... : time_mhd = 2549.33320, time_pic = 2549.33320, dt_mhd = 2.68985, dt_pic = 0.26898
# 930 step done... : time_mhd = 2576.29024, time_pic = 2576.29024, dt_mhd = 2.70101, dt_pic = 0.27010
# 940 step done... : time_mhd = 2603.28315, time_pic = 2603.28315, dt_mhd = 2.69739, dt_pic = 0.26974
# 950 step done... : time_mhd = 2630.23054, time_pic = 2630.23054, dt_mhd = 2.69239, dt_pic = 0.26924
# 960 step done... : time_mhd = 2657.11611, time_pic = 2657.11611, dt_mhd = 2.68081, dt_pic = 0.26808
# 970 step done... : time_mhd = 2683.78277, time_pic = 2683.78277, dt_mhd = 2.66043, dt_pic = 0.26604
# 980 step done... : time_mhd = 2710.23313, time_pic = 2710.23313, dt_mhd = 2.63081, dt_pic = 0.26308
# 990 step done... : time_mhd = 2736.29705, time_pic = 2736.29705, dt_mhd = 2.57916, dt_pic = 0.25792
# 1000 step done... : time_mhd = 2761.78838, time_pic = 2761.78838, dt_mhd = 2.53080, dt_pic = 0.25308
# 1010 step done... : time_mhd = 2786.87314, time_pic = 2786.87314, dt_mhd = 2.48948, dt_pic = 0.24895
# 1020 step done... : time_mhd = 2811.70411, time_pic = 2811.70411, dt_mhd = 2.48001, dt_pic = 0.24800
# 1030 step done... : time_mhd = 2836.56241, time_pic = 2836.56241, dt_mhd = 2.49510, dt_pic = 0.24951
# 1040 step done... : time_mhd = 2861.80596, time_pic = 2861.80596, dt_mhd = 2.54874, dt_pic = 0.25487
# 1050 step done... : time_mhd = 2887.47772, time_pic = 2887.47772, dt_mhd = 2.58697, dt_pic = 0.25870
# 1060 step done... : time_mhd = 2913.48551, time_pic = 2913.48551, dt_mhd = 2.60638, dt_pic = 0.26064
# 1070 step done... : time_mhd = 2939.67696, time_pic = 2939.67696, dt_mhd = 2.62278, dt_pic = 0.26228
# 1080 step done... : time_mhd = 2965.85189, time_pic = 2965.85189, dt_mhd = 2.61600, dt_pic = 0.26160
# 1090 step done... : time_mhd = 2992.08819, time_pic = 2992.08819, dt_mhd = 2.63004, dt_pic = 0.26300
# 1100 step done... : time_mhd = 3018.49400, time_pic = 3018.49400, dt_mhd = 2.64640, dt_pic = 0.26464
# 1110 step done... : time_mhd = 3044.86739, time_pic = 3044.86739, dt_mhd = 2.62958, dt_pic = 0.26296
# 1120 step done... : time_mhd = 3071.16055, time_pic = 3071.16055, dt_mhd = 2.62854, dt_pic = 0.26285
# 1130 step done... : time_mhd = 3097.49569, time_pic = 3097.49569, dt_mhd = 2.63615, dt_pic = 0.26362
# 1140 step done... : time_mhd = 3123.93702, time_pic = 3123.93702, dt_mhd = 2.64842, dt_pic = 0.26484
# 1150 step done... : time_mhd = 3150.35579, time_pic = 3150.35579, dt_mhd = 2.63859, dt_pic = 0.26386
# 1160 step done... : time_mhd = 3176.69968, time_pic = 3176.69968, dt_mhd = 2.63364, dt_pic = 0.26336
# 1170 step done... : time_mhd = 3203.10039, time_pic = 3203.10039, dt_mhd = 2.64257, dt_pic = 0.26426
# 1180 step done... : time_mhd = 3229.65900, time_pic = 3229.65900, dt_mhd = 2.66678, dt_pic = 0.26668
# 1190 step done... : time_mhd = 3256.24660, time_pic = 3256.24660, dt_mhd = 2.65516, dt_pic = 0.26552
# 1200 step done... : time_mhd = 3282.72753, time_pic = 3282.72753, dt_mhd = 2.63813, dt_pic = 0.26381
# 1210 step done... : time_mhd = 3309.02102, time_pic = 3309.02102, dt_mhd = 2.62312, dt_pic = 0.26231
# 1220 step done... : time_mhd = 3335.21746, time_pic = 3335.21746, dt_mhd = 2.61814, dt_pic = 0.26181
# 1230 step done... : time_mhd = 3361.38416, time_pic = 3361.38416, dt_mhd = 2.61414, dt_pic = 0.26141
# 1240 step done... : time_mhd = 3387.50486, time_pic = 3387.50486, dt_mhd = 2.61224, dt_pic = 0.26122
# 1250 step done... : time_mhd = 3413.64166, time_pic = 3413.64166, dt_mhd = 2.61486, dt_pic = 0.26149
# 1260 step done... : time_mhd = 3439.79230, time_pic = 3439.79230, dt_mhd = 2.61930, dt_pic = 0.26193
# 1270 step done... : time_mhd = 3466.08908, time_pic = 3466.08908, dt_mhd = 2.63322, dt_pic = 0.26332
# 1280 step done... : time_mhd = 3492.37796, time_pic = 3492.37796, dt_mhd = 2.62542, dt_pic = 0.26254
# 1290 step done... : time_mhd = 3518.72313, time_pic = 3518.72313, dt_mhd = 2.64030, dt_pic = 0.26403
# 1300 step done... : time_mhd = 3545.07967, time_pic = 3545.07967, dt_mhd = 2.63404, dt_pic = 0.26340
# 1310 step done... : time_mhd = 3571.41876, time_pic = 3571.41876, dt_mhd = 2.62775, dt_pic = 0.26277
# 1320 step done... : time_mhd = 3597.69676, time_pic = 3597.69676, dt_mhd = 2.63218, dt_pic = 0.26322
# 1330 step done... : time_mhd = 3624.05858, time_pic = 3624.05858, dt_mhd = 2.63784, dt_pic = 0.26378
# 1340 step done... : time_mhd = 3650.48669, time_pic = 3650.48669, dt_mhd = 2.64386, dt_pic = 0.26439
# 1350 step done... : time_mhd = 3676.98229, time_pic = 3676.98229, dt_mhd = 2.65088, dt_pic = 0.26509
# 1360 step done... : time_mhd = 3703.51874, time_pic = 3703.51874, dt_mhd = 2.65683, dt_pic = 0.26568
# 1370 step done... : time_mhd = 3730.10696, time_pic = 3730.10696, dt_mhd = 2.65925, dt_pic = 0.26593
# 1380 step done... : time_mhd = 3756.70050, time_pic = 3756.70050, dt_mhd = 2.65946, dt_pic = 0.26595
# 1390 step done... : time_mhd = 3783.29546, time_pic = 3783.29546, dt_mhd = 2.65960, dt_pic = 0.26596
# 1400 step done... : time_mhd = 3809.88483, time_pic = 3809.88483, dt_mhd = 2.66037, dt_pic = 0.26604
# 1410 step done... : time_mhd = 3836.49260, time_pic = 3836.49260, dt_mhd = 2.66033, dt_pic = 0.26603
# 1420 step done... : time_mhd = 3863.08944, time_pic = 3863.08944, dt_mhd = 2.65948, dt_pic = 0.26595
# 1430 step done... : time_mhd = 3889.68966, time_pic = 3889.68966, dt_mhd = 2.66079, dt_pic = 0.26608
# 1440 step done... : time_mhd = 3916.26868, time_pic = 3916.26868, dt_mhd = 2.65588, dt_pic = 0.26559
# 1450 step done... : time_mhd = 3942.75039, time_pic = 3942.75039, dt_mhd = 2.64693, dt_pic = 0.26469
# 1460 step done... : time_mhd = 3969.19566, time_pic = 3969.19566, dt_mhd = 2.63988, dt_pic = 0.26399
# 1470 step done... : time_mhd = 3995.59491, time_pic = 3995.59491, dt_mhd = 2.64305, dt_pic = 0.26431
# 1480 step done... : time_mhd = 4022.04288, time_pic = 4022.04288, dt_mhd = 2.64502, dt_pic = 0.26450
# 1490 step done... : time_mhd = 4048.52986, time_pic = 4048.52986, dt_mhd = 2.65807, dt_pic = 0.26581
# 1500 step done... : time_mhd = 4075.12063, time_pic = 4075.12063, dt_mhd = 2.65881, dt_pic = 0.26588
# 1510 step done... : time_mhd = 4101.71010, time_pic = 4101.71010, dt_mhd = 2.65963, dt_pic = 0.26596
# 1520 step done... : time_mhd = 4128.29672, time_pic = 4128.29672, dt_mhd = 2.65731, dt_pic = 0.26573
# 1530 step done... : time_mhd = 4154.85996, time_pic = 4154.85996, dt_mhd = 2.65592, dt_pic = 0.26559
# 1540 step done... : time_mhd = 4181.42434, time_pic = 4181.42434, dt_mhd = 2.65726, dt_pic = 0.26573
# 1550 step done... : time_mhd = 4208.01322, time_pic = 4208.01322, dt_mhd = 2.66031, dt_pic = 0.26603
# 1560 step done... : time_mhd = 4234.63277, time_pic = 4234.63277, dt_mhd = 2.66253, dt_pic = 0.26625
# 1570 step done... : time_mhd = 4261.23614, time_pic = 4261.23614, dt_mhd = 2.65836, dt_pic = 0.26584
# 1580 step done... : time_mhd = 4287.81040, time_pic = 4287.81040, dt_mhd = 2.65718, dt_pic = 0.26572
# 1590 step done... : time_mhd = 4314.39337, time_pic = 4314.39337, dt_mhd = 2.65995, dt_pic = 0.26600
# 1600 step done... : time_mhd = 4340.96302, time_pic = 4340.96302, dt_mhd = 2.64812, dt_pic = 0.26481
# 1610 step done... : time_mhd = 4367.36976, time_pic = 4367.36976, dt_mhd = 2.63195, dt_pic = 0.26319
# 1620 step done... : time_mhd = 4393.57989, time_pic = 4393.57989, dt_mhd = 2.61599, dt_pic = 0.26160
# 1630 step done... : time_mhd = 4419.67801, time_pic = 4419.67801, dt_mhd = 2.60663, dt_pic = 0.26066
# 1640 step done... : time_mhd = 4445.75726, time_pic = 4445.75726, dt_mhd = 2.61055, dt_pic = 0.26106
# 1650 step done... : time_mhd = 4471.97993, time_pic = 4471.97993, dt_mhd = 2.63157, dt_pic = 0.26316
# 1660 step done... : time_mhd = 4498.44254, time_pic = 4498.44254, dt_mhd = 2.65442, dt_pic = 0.26544
# 1670 step done... : time_mhd = 4524.93760, time_pic = 4524.93760, dt_mhd = 2.64584, dt_pic = 0.26458
# 1680 step done... : time_mhd = 4551.37065, time_pic = 4551.37065, dt_mhd = 2.64215, dt_pic = 0.26421
# 1690 step done... : time_mhd = 4577.79825, time_pic = 4577.79825, dt_mhd = 2.64420, dt_pic = 0.26442
# 1700 step done... : time_mhd = 4604.28394, time_pic = 4604.28394, dt_mhd = 2.65078, dt_pic = 0.26508
# 1710 step done... : time_mhd = 4630.77327, time_pic = 4630.77327, dt_mhd = 2.64525, dt_pic = 0.26453
# 1720 step done... : time_mhd = 4657.14174, time_pic = 4657.14174, dt_mhd = 2.63007, dt_pic = 0.26301
# 1730 step done... : time_mhd = 4683.25923, time_pic = 4683.25923, dt_mhd = 2.59462, dt_pic = 0.25946
# 1740 step done... : time_mhd = 4709.10019, time_pic = 4709.10019, dt_mhd = 2.57615, dt_pic = 0.25761
# 1750 step done... : time_mhd = 4734.85513, time_pic = 4734.85513, dt_mhd = 2.57380, dt_pic = 0.25738
# 1760 step done... : time_mhd = 4760.57040, time_pic = 4760.57040, dt_mhd = 2.56580, dt_pic = 0.25658
# 1770 step done... : time_mhd = 4786.04592, time_pic = 4786.04592, dt_mhd = 2.53613, dt_pic = 0.25361
# 1780 step done... : time_mhd = 4811.36763, time_pic = 4811.36763, dt_mhd = 2.53244, dt_pic = 0.25324
# 1790 step done... : time_mhd = 4836.91215, time_pic = 4836.91215, dt_mhd = 2.56941, dt_pic = 0.25694
# 1800 step done... : time_mhd = 4862.77226, time_pic = 4862.77226, dt_mhd = 2.59832, dt_pic = 0.25983
# 1810 step done... : time_mhd = 4888.84282, time_pic = 4888.84282, dt_mhd = 2.61067, dt_pic = 0.26107
# 1820 step done... : time_mhd = 4915.04434, time_pic = 4915.04434, dt_mhd = 2.63268, dt_pic = 0.26327
# 1830 step done... : time_mhd = 4941.52883, time_pic = 4941.52883, dt_mhd = 2.65275, dt_pic = 0.26528
# 1840 step done... : time_mhd = 4968.05721, time_pic = 4968.05721, dt_mhd = 2.64994, dt_pic = 0.26499
# 1850 step done... : time_mhd = 4994.54077, time_pic = 4994.54077, dt_mhd = 2.64692, dt_pic = 0.26469
# 1860 step done... : time_mhd = 5020.87825, time_pic = 5020.87825, dt_mhd = 2.62014, dt_pic = 0.26201
# 1870 step done... : time_mhd = 5047.01711, time_pic = 5047.01711, dt_mhd = 2.62378, dt_pic = 0.26238
# 1880 step done... : time_mhd = 5073.26284, time_pic = 5073.26284, dt_mhd = 2.61953, dt_pic = 0.26195
# 1890 step done... : time_mhd = 5099.34884, time_pic = 5099.34884, dt_mhd = 2.60419, dt_pic = 0.26042
# 1900 step done... : time_mhd = 5125.39878, time_pic = 5125.39878, dt_mhd = 2.60033, dt_pic = 0.26003
# 1910 step done... : time_mhd = 5151.32668, time_pic = 5151.32668, dt_mhd = 2.58283, dt_pic = 0.25828
# 1920 step done... : time_mhd = 5177.03911, time_pic = 5177.03911, dt_mhd = 2.57243, dt_pic = 0.25724
# 1930 step done... : time_mhd = 5202.71240, time_pic = 5202.71240, dt_mhd = 2.56220, dt_pic = 0.25622
# 1940 step done... : time_mhd = 5228.32012, time_pic = 5228.32012, dt_mhd = 2.56058, dt_pic = 0.25606
# 1950 step done... : time_mhd = 5254.00037, time_pic = 5254.00037, dt_mhd = 2.57069, dt_pic = 0.25707
# 1960 step done... : time_mhd = 5279.87944, time_pic = 5279.87944, dt_mhd = 2.60018, dt_pic = 0.26002
# 1970 step done... : time_mhd = 5306.16447, time_pic = 5306.16447, dt_mhd = 2.64632, dt_pic = 0.26463
# 1980 step done... : time_mhd = 5332.63231, time_pic = 5332.63231, dt_mhd = 2.64650, dt_pic = 0.26465
# 1990 step done... : time_mhd = 5359.00206, time_pic = 5359.00206, dt_mhd = 2.63069, dt_pic = 0.26307
# 2000 step done... : time_mhd = 5385.31126, time_pic = 5385.31126, dt_mhd = 2.63186, dt_pic = 0.26319
# 2010 step done... : time_mhd = 5411.62645, time_pic = 5411.62645, dt_mhd = 2.62000, dt_pic = 0.26200
# 2020 step done... : time_mhd = 5437.72016, time_pic = 5437.72016, dt_mhd = 2.60762, dt_pic = 0.26076
# 2030 step done... : time_mhd = 5463.80423, time_pic = 5463.80423, dt_mhd = 2.61164, dt_pic = 0.26116
# 2040 step done... : time_mhd = 5489.97198, time_pic = 5489.97198, dt_mhd = 2.61726, dt_pic = 0.26173
# 2050 step done... : time_mhd = 5516.14087, time_pic = 5516.14087, dt_mhd = 2.61638, dt_pic = 0.26164
# 2060 step done... : time_mhd = 5542.32848, time_pic = 5542.32848, dt_mhd = 2.61799, dt_pic = 0.26180
# 2070 step done... : time_mhd = 5568.55935, time_pic = 5568.55935, dt_mhd = 2.62494, dt_pic = 0.26249
# 2080 step done... : time_mhd = 5594.65744, time_pic = 5594.65744, dt_mhd = 2.59981, dt_pic = 0.25998
# 2090 step done... : time_mhd = 5620.81982, time_pic = 5620.81982, dt_mhd = 2.61658, dt_pic = 0.26166
# 2100 step done... : time_mhd = 5646.95149, time_pic = 5646.95149, dt_mhd = 2.60731, dt_pic = 0.26073
# 2110 step done... : time_mhd = 5673.03254, time_pic = 5673.03254, dt_mhd = 2.60371, dt_pic = 0.26037
# 2120 step done... : time_mhd = 5699.02110, time_pic = 5699.02110, dt_mhd = 2.59944, dt_pic = 0.25994
# 2130 step done... : time_mhd = 5725.05078, time_pic = 5725.05078, dt_mhd = 2.60529, dt_pic = 0.26053
# 2140 step done... : time_mhd = 5751.09892, time_pic = 5751.09892, dt_mhd = 2.60232, dt_pic = 0.26023
# 2150 step done... : time_mhd = 5777.10494, time_pic = 5777.10494, dt_mhd = 2.59857, dt_pic = 0.25986
# 2160 step done... : time_mhd = 5803.11262, time_pic = 5803.11262, dt_mhd = 2.60615, dt_pic = 0.26061
# 2170 step done... : time_mhd = 5829.21245, time_pic = 5829.21245, dt_mhd = 2.61582, dt_pic = 0.26158
# 2180 step done... : time_mhd = 5855.35574, time_pic = 5855.35574, dt_mhd = 2.60872, dt_pic = 0.26087
# 2190 step done... : time_mhd = 5881.43921, time_pic = 5881.43921, dt_mhd = 2.60871, dt_pic = 0.26087
# 2200 step done... : time_mhd = 5907.57027, time_pic = 5907.57027, dt_mhd = 2.61302, dt_pic = 0.26130
# 2210 step done... : time_mhd = 5933.66557, time_pic = 5933.66557, dt_mhd = 2.61574, dt_pic = 0.26157
# 2220 step done... : time_mhd = 5959.88789, time_pic = 5959.88789, dt_mhd = 2.62973, dt_pic = 0.26297
# 2230 step done... : time_mhd = 5986.13595, time_pic = 5986.13595, dt_mhd = 2.61723, dt_pic = 0.26172
# 2240 step done... : time_mhd = 6012.27894, time_pic = 6012.27894, dt_mhd = 2.61457, dt_pic = 0.26146
# 2250 step done... : time_mhd = 6038.45903, time_pic = 6038.45903, dt_mhd = 2.62006, dt_pic = 0.26201
# 2260 step done... : time_mhd = 6064.62412, time_pic = 6064.62412, dt_mhd = 2.60577, dt_pic = 0.26058
# 2270 step done... : time_mhd = 6090.55528, time_pic = 6090.55528, dt_mhd = 2.58678, dt_pic = 0.25868
# 2280 step done... : time_mhd = 6116.33528, time_pic = 6116.33528, dt_mhd = 2.56901, dt_pic = 0.25690
# 2290 step done... : time_mhd = 6141.92059, time_pic = 6141.92059, dt_mhd = 2.54490, dt_pic = 0.25449
# 2300 step done... : time_mhd = 6167.32058, time_pic = 6167.32058, dt_mhd = 2.54106, dt_pic = 0.25411
# 2310 step done... : time_mhd = 6192.73850, time_pic = 6192.73850, dt_mhd = 2.53700, dt_pic = 0.25370
# 2320 step done... : time_mhd = 6217.99008, time_pic = 6217.99008, dt_mhd = 2.51211, dt_pic = 0.25121
# 2330 step done... : time_mhd = 6243.08898, time_pic = 6243.08898, dt_mhd = 2.50985, dt_pic = 0.25099
# 2340 step done... : time_mhd = 6268.17064, time_pic = 6268.17064, dt_mhd = 2.51334, dt_pic = 0.25133
# 2350 step done... : time_mhd = 6293.43270, time_pic = 6293.43270, dt_mhd = 2.53798, dt_pic = 0.25380
# 2360 step done... : time_mhd = 6319.01687, time_pic = 6319.01687, dt_mhd = 2.57118, dt_pic = 0.25712
# 2370 step done... : time_mhd = 6344.84775, time_pic = 6344.84775, dt_mhd = 2.59682, dt_pic = 0.25968
# 2380 step done... : time_mhd = 6370.93530, time_pic = 6370.93530, dt_mhd = 2.61763, dt_pic = 0.26176
# 2390 step done... : time_mhd = 6397.21638, time_pic = 6397.21638, dt_mhd = 2.63639, dt_pic = 0.26364
# 2400 step done... : time_mhd = 6423.74506, time_pic = 6423.74506, dt_mhd = 2.65891, dt_pic = 0.26589
# 2410 step done... : time_mhd = 6450.22692, time_pic = 6450.22692, dt_mhd = 2.64262, dt_pic = 0.26426
# 2420 step done... : time_mhd = 6476.63686, time_pic = 6476.63686, dt_mhd = 2.64442, dt_pic = 0.26444
# 2430 step done... : time_mhd = 6503.11953, time_pic = 6503.11953, dt_mhd = 2.63984, dt_pic = 0.26398
# 2440 step done... : time_mhd = 6529.46229, time_pic = 6529.46229, dt_mhd = 2.63510, dt_pic = 0.26351
# 2450 step done... : time_mhd = 6555.71771, time_pic = 6555.71771, dt_mhd = 2.62441, dt_pic = 0.26244
# 2460 step done... : time_mhd = 6582.01211, time_pic = 6582.01211, dt_mhd = 2.64065, dt_pic = 0.26407
# 2470 step done... : time_mhd = 6608.47284, time_pic = 6608.47284, dt_mhd = 2.64260, dt_pic = 0.26426
# 2480 step done... : time_mhd = 6634.76206, time_pic = 6634.76206, dt_mhd = 2.61843, dt_pic = 0.26184
# 2490 step done... : time_mhd = 6660.81842, time_pic = 6660.81842, dt_mhd = 2.59839, dt_pic = 0.25984
# 2500 step done... : time_mhd = 6686.74014, time_pic = 6686.74014, dt_mhd = 2.59356, dt_pic = 0.25936
# 2510 step done... : time_mhd = 6712.82674, time_pic = 6712.82674, dt_mhd = 2.62108, dt_pic = 0.26211
# 2520 step done... : time_mhd = 6739.01179, time_pic = 6739.01179, dt_mhd = 2.61945, dt_pic = 0.26194
# 2530 step done... : time_mhd = 6765.28295, time_pic = 6765.28295, dt_mhd = 2.62632, dt_pic = 0.26263
# 2540 step done... : time_mhd = 6791.50484, time_pic = 6791.50484, dt_mhd = 2.62350, dt_pic = 0.26235
# 2550 step done... : time_mhd = 6817.83755, time_pic = 6817.83755, dt_mhd = 2.64398, dt_pic = 0.26440
# 2560 step done... : time_mhd = 6844.35632, time_pic = 6844.35632, dt_mhd = 2.65632, dt_pic = 0.26563
# 2570 step done... : time_mhd = 6870.98537, time_pic = 6870.98537, dt_mhd = 2.66005, dt_pic = 0.26600
# 2580 step done... : time_mhd = 6897.42075, time_pic = 6897.42075, dt_mhd = 2.63104, dt_pic = 0.26310
# 2590 step done... : time_mhd = 6923.60990, time_pic = 6923.60990, dt_mhd = 2.61226, dt_pic = 0.26123
# 2600 step done... : time_mhd = 6949.66261, time_pic = 6949.66261, dt_mhd = 2.59787, dt_pic = 0.25979
# 2610 step done... : time_mhd = 6975.52147, time_pic = 6975.52147, dt_mhd = 2.57746, dt_pic = 0.25775
# 2620 step done... : time_mhd = 7001.19989, time_pic = 7001.19989, dt_mhd = 2.56029, dt_pic = 0.25603
# 2630 step done... : time_mhd = 7026.75861, time_pic = 7026.75861, dt_mhd = 2.55177, dt_pic = 0.25518
# 2640 step done... : time_mhd = 7052.24392, time_pic = 7052.24392, dt_mhd = 2.54287, dt_pic = 0.25429
# 2650 step done... : time_mhd = 7077.56465, time_pic = 7077.56465, dt_mhd = 2.52605, dt_pic = 0.25260
# 2660 step done... : time_mhd = 7102.81415, time_pic = 7102.81415, dt_mhd = 2.52573, dt_pic = 0.25257
# 2670 step done... : time_mhd = 7128.13437, time_pic = 7128.13437, dt_mhd = 2.53208, dt_pic = 0.25321
# 2680 step done... : time_mhd = 7153.55251, time_pic = 7153.55251, dt_mhd = 2.55193, dt_pic = 0.25519
# 2690 step done... : time_mhd = 7179.20163, time_pic = 7179.20163, dt_mhd = 2.57420, dt_pic = 0.25742
# 2700 step done... : time_mhd = 7204.98570, time_pic = 7204.98570, dt_mhd = 2.58440, dt_pic = 0.25844
# 2710 step done... : time_mhd = 7230.91240, time_pic = 7230.91240, dt_mhd = 2.59921, dt_pic = 0.25992
# 2720 step done... : time_mhd = 7256.99949, time_pic = 7256.99949, dt_mhd = 2.61328, dt_pic = 0.26133
# 2730 step done... : time_mhd = 7283.31670, time_pic = 7283.31670, dt_mhd = 2.64478, dt_pic = 0.26448
# 2740 step done... : time_mhd = 7309.83111, time_pic = 7309.83111, dt_mhd = 2.65832, dt_pic = 0.26583
# 2750 step done... : time_mhd = 7336.48022, time_pic = 7336.48022, dt_mhd = 2.67112, dt_pic = 0.26711
# 2760 step done... : time_mhd = 7363.29828, time_pic = 7363.29828, dt_mhd = 2.68859, dt_pic = 0.26886
# 2770 step done... : time_mhd = 7390.17870, time_pic = 7390.17870, dt_mhd = 2.68754, dt_pic = 0.26875
# 2780 step done... : time_mhd = 7417.04970, time_pic = 7417.04970, dt_mhd = 2.68682, dt_pic = 0.26868
# 2790 step done... : time_mhd = 7443.91604, time_pic = 7443.91604, dt_mhd = 2.68655, dt_pic = 0.26865
# 2800 step done... : time_mhd = 7470.78219, time_pic = 7470.78219, dt_mhd = 2.68678, dt_pic = 0.26868
# 2810 step done... : time_mhd = 7497.65705, time_pic = 7497.65705, dt_mhd = 2.68833, dt_pic = 0.26883
# 2820 step done... : time_mhd = 7524.42447, time_pic = 7524.42447, dt_mhd = 2.66030, dt_pic = 0.26603
# 2830 step done... : time_mhd = 7551.12555, time_pic = 7551.12555, dt_mhd = 2.67053, dt_pic = 0.26705
# 2840 step done... : time_mhd = 7577.71287, time_pic = 7577.71287, dt_mhd = 2.65302, dt_pic = 0.26530
# 2850 step done... : time_mhd = 7604.33479, time_pic = 7604.33479, dt_mhd = 2.66822, dt_pic = 0.26682
# 2860 step done... : time_mhd = 7630.98178, time_pic = 7630.98178, dt_mhd = 2.66827, dt_pic = 0.26683
# 2870 step done... : time_mhd = 7657.62422, time_pic = 7657.62422, dt_mhd = 2.65855, dt_pic = 0.26585
# 2880 step done... : time_mhd = 7684.19822, time_pic = 7684.19822, dt_mhd = 2.66196, dt_pic = 0.26620
# 2890 step done... : time_mhd = 7710.90979, time_pic = 7710.90979, dt_mhd = 2.67389, dt_pic = 0.26739
# 2900 step done... : time_mhd = 7737.68252, time_pic = 7737.68252, dt_mhd = 2.67357, dt_pic = 0.26736
# 2910 step done... : time_mhd = 7764.48403, time_pic = 7764.48403, dt_mhd = 2.68381, dt_pic = 0.26838
# 2920 step done... : time_mhd = 7791.33760, time_pic = 7791.33760, dt_mhd = 2.68745, dt_pic = 0.26875
# 2930 step done... : time_mhd = 7818.26570, time_pic = 7818.26570, dt_mhd = 2.69802, dt_pic = 0.26980
# 2940 step done... : time_mhd = 7845.23386, time_pic = 7845.23386, dt_mhd = 2.69607, dt_pic = 0.26961
# 2950 step done... : time_mhd = 7872.19047, time_pic = 7872.19047, dt_mhd = 2.69548, dt_pic = 0.26955
# 2960 step done... : time_mhd = 7899.14590, time_pic = 7899.14590, dt_mhd = 2.69570, dt_pic = 0.26957
# 2970 step done... : time_mhd = 7926.10425, time_pic = 7926.10425, dt_mhd = 2.69584, dt_pic = 0.26958
# 2980 step done... : time_mhd = 7953.03518, time_pic = 7953.03518, dt_mhd = 2.68801, dt_pic = 0.26880
# 2990 step done... : time_mhd = 7979.94937, time_pic = 7979.94937, dt_mhd = 2.69270, dt_pic = 0.26927
# 3000 step done... : time_mhd = 8006.80536, time_pic = 8006.80536, dt_mhd = 2.68877, dt_pic = 0.26888

# %% [markdown]
# プロット

# %%
dirname = "results_MS_current_sheet_Bx"
step = 3000

B = np.load(f"{dirname}/B_{step}.npy")
E = np.load(f"{dirname}/E_{step}.npy")
current = np.load(f"{dirname}/current_{step}.npy")
zeroth_moment_ion = np.load(f"{dirname}/zeroth_moment_ion_{step}.npy")
zeroth_moment_electron = np.load(f"{dirname}/zeroth_moment_electron_{step}.npy")
first_moment_ion = np.load(f"{dirname}/first_moment_ion_{step}.npy")
first_moment_electron = np.load(f"{dirname}/first_moment_electron_{step}.npy")
second_moment_ion = np.load(f"{dirname}/second_moment_ion_{step}.npy")
second_moment_electron = np.load(f"{dirname}/second_moment_electron_{step}.npy")

U1 = np.load(f"{dirname}/U1_{step}.npy")
rho1_mhd = U1[0, :]
u1_mhd = U1[1, :] / rho1_mhd
v1_mhd = U1[2, :] / rho1_mhd
w1_mhd = U1[3, :] / rho1_mhd
Bx1_mhd = U1[4, :]
By1_mhd = U1[5, :]
Bz1_mhd = U1[6, :]
e1_mhd = U1[7, :]
p1_mhd = (gamma_mhd - 1.0) \
        * (e1_mhd - 0.5 * rho1_mhd * (u1_mhd**2+v1_mhd**2+w1_mhd**2)
            - 0.5 * (Bx1_mhd**2+By1_mhd**2+Bz1_mhd**2))
Ex1_mhd = -(v1_mhd * Bz1_mhd - w1_mhd * By1_mhd)
Ey1_mhd = -(w1_mhd * Bx1_mhd - u1_mhd * Bz1_mhd)
Ez1_mhd = -(u1_mhd * By1_mhd - v1_mhd * Bx1_mhd)
current1_x_mhd = np.zeros(Bx1_mhd.shape)
current1_y_mhd = -(np.roll(Bz1_mhd, -1, axis=0) - np.roll(Bz1_mhd, 1, axis=0)) / (2*dx_mhd)
current1_z_mhd = (np.roll(By1_mhd, -1, axis=0) - np.roll(By1_mhd, 1, axis=0)) / (2*dx_mhd)
current1_y_mhd[0] = current1_y_mhd[1] 
current1_y_mhd[-1] = current1_y_mhd[-2] 
current1_z_mhd[0] = current1_z_mhd[1] 
current1_z_mhd[-1] = current1_z_mhd[-2] 

U2 = np.load(f"{dirname}/U2_{step}.npy")
rho2_mhd = U2[0, :]
u2_mhd = U2[1, :] / rho2_mhd
v2_mhd = U2[2, :] / rho2_mhd
w2_mhd = U2[3, :] / rho2_mhd
Bx2_mhd = U2[4, :]
By2_mhd = U2[5, :]
Bz2_mhd = U2[6, :]
e2_mhd = U2[7, :]
p2_mhd = (gamma_mhd - 1.0) \
        * (e2_mhd - 0.5 * rho2_mhd * (u2_mhd**2+v2_mhd**2+w2_mhd**2)
            - 0.5 * (Bx2_mhd**2+By2_mhd**2+Bz2_mhd**2))
Ex2_mhd = -(v2_mhd * Bz2_mhd - w2_mhd * By2_mhd)
Ey2_mhd = -(w2_mhd * Bx2_mhd - u2_mhd * Bz2_mhd)
Ez2_mhd = -(u2_mhd * By2_mhd - v2_mhd * Bx2_mhd)
current2_x_mhd = np.zeros(Bx2_mhd.shape)
current2_y_mhd = -(np.roll(Bz2_mhd, -1, axis=0) - np.roll(Bz2_mhd, 1, axis=0)) / (2*dx_mhd)
current2_z_mhd = (np.roll(By2_mhd, -1, axis=0) - np.roll(By2_mhd, 1, axis=0)) / (2*dx_mhd)
current2_y_mhd[0] = current2_y_mhd[1] 
current2_y_mhd[-1] = current2_y_mhd[-2] 
current2_z_mhd[0] = current2_z_mhd[1] 
current2_z_mhd[-1] = current2_z_mhd[-2]

# %%
fig = plt.figure(figsize=(24, 16))
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412)
ax3 = fig.add_subplot(413)
ax4 = fig.add_subplot(414)

rho_pic = m_ion * zeroth_moment_ion + m_electron * zeroth_moment_electron

ax1.plot(x_coordinate_mhd/ion_inertial_length, rho1_mhd / rho0_mhd, color='black', lw=3)
ax2.plot(x_coordinate_mhd/ion_inertial_length, current1_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
ax3.plot(x_coordinate_mhd/ion_inertial_length, By1_mhd / B0_mhd, color='black', lw=3)
ax4.plot(x_coordinate_mhd/ion_inertial_length, Ez1_mhd / VA_mhd / B0_mhd, color='black', lw=3)
ax1.plot((x_coordinate_mhd + 1200)/ion_inertial_length, rho2_mhd / rho0_mhd, color='black', lw=3)
ax2.plot((x_coordinate_mhd + 1200)/ion_inertial_length, current2_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
ax3.plot((x_coordinate_mhd + 1200)/ion_inertial_length, By2_mhd / B0_mhd, color='black', lw=3)
ax4.plot((x_coordinate_mhd + 1200)/ion_inertial_length, Ez2_mhd / VA_mhd / B0_mhd, color='black', lw=3)
ax1.plot((x_coordinate_pic + 450) / ion_inertial_length, rho_pic / rho0_mhd, color='green', lw=3)
ax2.plot((x_coordinate_pic + 450) / ion_inertial_length, np.convolve(current[2, :], np.ones(5)/5, mode="same") / B0_pic / ion_inertial_length, color='green', lw=3)
ax3.plot((x_coordinate_pic + 450) / ion_inertial_length, B[1, :] / B0_pic, color='green', lw=3)
ax4.plot((x_coordinate_pic + 450) / ion_inertial_length, E[2, :] / VA_pic / B0_pic, color='green', lw=3)

ax1.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax2.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax3.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax4.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
ax1.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax2.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax3.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax4.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
ax1.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
ax2.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
ax3.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
ax4.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)

ax4.set_xlabel(r"$x / \lambda_i$", fontsize=24)
ax1.set_ylabel(r"$\rho / \rho_0$", fontsize=24)
ax2.set_ylabel(r"$j_z / B_0 / \lambda_i$", fontsize=24)
ax3.set_ylabel(r"$B_y / B_0$", fontsize=24)
ax4.set_ylabel(r"$E_z / V_A / B_0$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax1.set_xlim(0, 1700/ion_inertial_length)
ax2.set_xlim(0, 1700/ion_inertial_length)
ax3.set_xlim(0, 1700/ion_inertial_length)
ax4.set_xlim(0, 1700/ion_inertial_length)
ax1.set_ylim(0.0, 8.0)
ax2.set_ylim(-0.005, 0.005)
ax3.set_ylim(-2.0, 2.0)
ax4.set_ylim(-1.0, 2.0)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.suptitle(f"t = {step}", y=0.95, fontsize=32)

plt.show()

# %% [markdown]
# 動画作成

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412)
ax3 = fig.add_subplot(413)
ax4 = fig.add_subplot(414)

dirname = "results_MS_current_sheet_Bx"
filename = "current_sheet_MHD-PIC_Bx.mp4"
log = np.loadtxt('log_Bx.txt', dtype=str)

interval = 10
plot_steps = 3000
for step in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()

    B = np.load(f"{dirname}/B_{step}.npy")
    E = np.load(f"{dirname}/E_{step}.npy")
    current = np.load(f"{dirname}/current_{step}.npy")
    zeroth_moment_ion = np.load(f"{dirname}/zeroth_moment_ion_{step}.npy")
    zeroth_moment_electron = np.load(f"{dirname}/zeroth_moment_electron_{step}.npy")
    first_moment_ion = np.load(f"{dirname}/first_moment_ion_{step}.npy")
    first_moment_electron = np.load(f"{dirname}/first_moment_electron_{step}.npy")

    U1 = np.load(f"{dirname}/U1_{step}.npy")
    rho1_mhd = U1[0, :]
    u1_mhd = U1[1, :] / rho1_mhd
    v1_mhd = U1[2, :] / rho1_mhd
    w1_mhd = U1[3, :] / rho1_mhd
    Bx1_mhd = U1[4, :]
    By1_mhd = U1[5, :]
    Bz1_mhd = U1[6, :]
    e1_mhd = U1[7, :]
    p1_mhd = (gamma_mhd - 1.0) \
            * (e1_mhd - 0.5 * rho1_mhd * (u1_mhd**2+v1_mhd**2+w1_mhd**2)
                - 0.5 * (Bx1_mhd**2+By1_mhd**2+Bz1_mhd**2))
    Ex1_mhd = -(v1_mhd * Bz1_mhd - w1_mhd * By1_mhd)
    Ey1_mhd = -(w1_mhd * Bx1_mhd - u1_mhd * Bz1_mhd)
    Ez1_mhd = -(u1_mhd * By1_mhd - v1_mhd * Bx1_mhd)
    current1_x_mhd = np.zeros(Bx1_mhd.shape)
    current1_y_mhd = -(np.roll(Bz1_mhd, -1, axis=0) - np.roll(Bz1_mhd, 1, axis=0)) / (2*dx_mhd)
    current1_z_mhd = (np.roll(By1_mhd, -1, axis=0) - np.roll(By1_mhd, 1, axis=0)) / (2*dx_mhd)
    current1_y_mhd[0] = current1_y_mhd[1] 
    current1_y_mhd[-1] = current1_y_mhd[-2] 
    current1_z_mhd[0] = current1_z_mhd[1] 
    current1_z_mhd[-1] = current1_z_mhd[-2] 

    U2 = np.load(f"{dirname}/U2_{step}.npy")
    rho2_mhd = U2[0, :]
    u2_mhd = U2[1, :] / rho2_mhd
    v2_mhd = U2[2, :] / rho2_mhd
    w2_mhd = U2[3, :] / rho2_mhd
    Bx2_mhd = U2[4, :]
    By2_mhd = U2[5, :]
    Bz2_mhd = U2[6, :]
    e2_mhd = U2[7, :]
    p2_mhd = (gamma_mhd - 1.0) \
            * (e2_mhd - 0.5 * rho2_mhd * (u2_mhd**2+v2_mhd**2+w2_mhd**2)
                - 0.5 * (Bx2_mhd**2+By2_mhd**2+Bz2_mhd**2))
    Ex2_mhd = -(v2_mhd * Bz2_mhd - w2_mhd * By2_mhd)
    Ey2_mhd = -(w2_mhd * Bx2_mhd - u2_mhd * Bz2_mhd)
    Ez2_mhd = -(u2_mhd * By2_mhd - v2_mhd * Bx2_mhd)
    current2_x_mhd = np.zeros(Bx2_mhd.shape)
    current2_y_mhd = -(np.roll(Bz2_mhd, -1, axis=0) - np.roll(Bz2_mhd, 1, axis=0)) / (2*dx_mhd)
    current2_z_mhd = (np.roll(By2_mhd, -1, axis=0) - np.roll(By2_mhd, 1, axis=0)) / (2*dx_mhd)
    current2_y_mhd[0] = current2_y_mhd[1] 
    current2_y_mhd[-1] = current2_y_mhd[-2] 
    current2_z_mhd[0] = current2_z_mhd[1] 
    current2_z_mhd[-1] = current2_z_mhd[-2] 


    rho_pic = m_ion * zeroth_moment_ion + m_electron * zeroth_moment_electron

    ax1.plot(x_coordinate_mhd/ion_inertial_length, rho1_mhd / rho0_mhd, color='black', lw=3)
    ax2.plot(x_coordinate_mhd/ion_inertial_length, current1_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
    ax3.plot(x_coordinate_mhd/ion_inertial_length, By1_mhd / B0_mhd, color='black', lw=3)
    ax4.plot(x_coordinate_mhd/ion_inertial_length, Ez1_mhd / VA_mhd / B0_mhd, color='black', lw=3)
    ax1.plot((x_coordinate_mhd + 1200)/ion_inertial_length, rho2_mhd / rho0_mhd, color='black', lw=3)
    ax2.plot((x_coordinate_mhd + 1200)/ion_inertial_length, current2_z_mhd / B0_mhd / ion_inertial_length, color='black', lw=3)
    ax3.plot((x_coordinate_mhd + 1200)/ion_inertial_length, By2_mhd / B0_mhd, color='black', lw=3)
    ax4.plot((x_coordinate_mhd + 1200)/ion_inertial_length, Ez2_mhd / VA_mhd / B0_mhd, color='black', lw=3)
    ax1.plot((x_coordinate_pic + 450) / ion_inertial_length, rho_pic / rho0_mhd, color='green', lw=3)
    ax2.plot((x_coordinate_pic + 450) / ion_inertial_length, np.convolve(current[2, :], np.ones(5)/5, mode="same") / B0_pic / ion_inertial_length, color='green', lw=3)
    ax3.plot((x_coordinate_pic + 450) / ion_inertial_length, B[1, :] / B0_pic, color='green', lw=3)
    ax4.plot((x_coordinate_pic + 450) / ion_inertial_length, E[2, :] / VA_pic / B0_pic, color='green', lw=3)

    ax1.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax2.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax3.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax4.axvspan(0, 500/ion_inertial_length, color='blue', alpha=0.7)
    ax1.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax2.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax3.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax4.axvspan(1200/ion_inertial_length, 1700/ion_inertial_length, color='blue', alpha=0.7)
    ax1.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
    ax2.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
    ax3.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)
    ax4.axvspan(450/ion_inertial_length, 1250/ion_inertial_length, color='orange', alpha=0.7)

    ax4.set_xlabel(r"$x / \lambda_i$", fontsize=24)
    ax1.set_ylabel(r"$\rho / \rho_0$", fontsize=24)
    ax2.set_ylabel(r"$j_z / B_0 / \lambda_i$", fontsize=24)
    ax3.set_ylabel(r"$B_y / B_0$", fontsize=24)
    ax4.set_ylabel(r"$E_z / V_A / B_0$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax1.set_xlim(0, 1700/ion_inertial_length)
    ax2.set_xlim(0, 1700/ion_inertial_length)
    ax3.set_xlim(0, 1700/ion_inertial_length)
    ax4.set_xlim(0, 1700/ion_inertial_length)
    ax1.set_ylim(0.0, 8.0)
    ax2.set_ylim(-0.005, 0.005)
    ax3.set_ylim(-2.0, 2.0)
    ax4.set_ylim(-1.0, 2.0)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()

    time = float(log[int(step/interval), 6].replace(',', ''))
    plt.suptitle(f"t = {time / (1.0 / omega_ci):.2f}" + r"$\Omega_{ci}^{-1}$", y=0.93, fontsize=32)

    fig.savefig(f'./pictures/{step}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for step in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{step}.png')
    video.write(img)
video.release()
