# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import cv2


import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

from lib_MHDPIC1D.pic1d import *
from lib_MHDPIC1D.mhd1d import *
from lib_MHDPIC1D.interface import *
from lib_MHDPIC1D.remove_noise import *

# %%
def boundary_Poynting_flux(speed_ratio, VA, B0, rho_init, p_init, gamma, U):
    U[0, :2] = rho_init[:2] * (1.0 + speed_ratio)
    U[1, :2] = rho_init[:2] * speed_ratio * VA
    U[2, :2] = 0.0
    U[3, :2] = 0.0
    U[4, :2] = 0.1 * B0
    U[5, :2] = -B0 * (1.0 + speed_ratio)
    U[6, :2] = 0.0
    p = p_init[:2] * (1.0 + gamma * speed_ratio)
    U[7, :2] = p / (gamma - 1.0) \
            + 0.5 * rho_init[:2] * (1.0 + speed_ratio) * (speed_ratio * VA)**2 \
            + 0.5 * (B0 * (1.0 + speed_ratio))**2
    
    U[0, -2:] = rho_init[-2:] * (1.0 + speed_ratio)
    U[1, -2:] = -rho_init[-2:] * speed_ratio * VA
    U[2, -2:] = 0.0
    U[3, -2:] = 0.0
    U[4, -2:] = 0.1 * B0
    U[5, -2:] = B0 * (1.0 + speed_ratio)
    U[6, -2:] = 0.0
    p = p_init[0] * (1.0 + gamma * speed_ratio)
    U[7, -2:] = p / (gamma - 1.0) \
            + 0.5 * rho_init[-2:] * (1.0 + speed_ratio) * (speed_ratio * VA)**2 \
            + 0.5 * (B0 * (1.0 + speed_ratio))**2

    return U

# %% [markdown]
# カレントシート with Poynting flux MHDのみ

# %%
c = 1.0
mu_0 = 1.0
epsilon0 = 1.0 / (mu_0 * c**2)
m_electron = 1.0
r_m = 1 / 100
m_ion = m_electron / r_m
t_r = 1.0
ne0_pic = 100 #ここは手動で調整すること
ni0_pic = ne0_pic
B0_pic = np.sqrt(ne0_pic) / 1.0 / np.sqrt(2/(1+t_r))
Ti_pic  = (B0_pic**2 / 2.0 / mu_0) / (ni0_pic + ne0_pic * t_r)
Te_pic = Ti_pic * t_r
q_electron = -1 * np.sqrt(epsilon0 * Te_pic / ne0_pic)
q_ion = -1 * q_electron
debye_length = np.sqrt(epsilon0 * Te_pic / ne0_pic / q_electron**2)
omega_pe = np.sqrt(ne0_pic * q_electron**2 / m_electron / epsilon0)
omega_pi = np.sqrt(ni0_pic * q_ion**2 / m_ion / epsilon0)
omega_ce = q_electron * B0_pic / m_electron
omega_ci = q_ion * B0_pic / m_ion
VA_pic = B0_pic / np.sqrt(ni0_pic * m_ion + ni0_pic * m_electron)
gamma_pic = 5.0 / 3.0
rho_pic = ni0_pic * m_ion + ne0_pic * m_electron
p_pic = ni0_pic * Ti_pic + ne0_pic * Te_pic
CS_pic = np.sqrt(gamma_pic * p_pic / rho_pic)
ion_inertial_length = c / omega_pi
sheat_thickness_pic = 3.0 * ion_inertial_length
v_electron = np.array([0.0, 0.0, -c * debye_length / sheat_thickness_pic * np.sqrt(2 / (1.0 + 1/t_r))])
v_ion = -v_electron / t_r
v_thermal_electron = np.sqrt(2.0 * Te_pic / m_electron)
v_thermal_ion = np.sqrt(2.0 * Ti_pic / m_ion)
v_thermal_electron_background = np.sqrt(2.0 * 0.2 * Te_pic / m_electron)
v_thermal_ion_background = np.sqrt(2.0 * 0.2 * Ti_pic / m_ion)

dx_pic = debye_length
nx_pic = int(40 * ion_inertial_length)
x_min_pic = 1e-10
x_max_pic = nx_pic * dx_pic - 1e-10
x_coordinate_pic = np.arange(0.0, x_max_pic, dx_pic)
dt_pic = 0.0
d_pic = 0.0

E_pic = np.zeros([3, nx_pic])
B_pic = np.zeros([3, nx_pic])
current_pic = np.zeros([3, nx_pic])
rho_pic = np.zeros(nx_pic)
B_pic[1, :] = B0_pic * np.tanh((x_coordinate_pic - nx_pic/2.0) / sheat_thickness_pic)
beta_pic = (ne0_pic * Te_pic + ni0_pic * Ti_pic) / (B0_pic**2 / 2 / mu_0)

n_ion = int(ni0_pic * 2.0 * sheat_thickness_pic)
n_electron = int(n_ion * abs(q_ion / q_electron))
n_ion_background = int(0.2 * ni0_pic * x_max_pic)
n_electron_background = int(0.2 * ne0_pic * x_max_pic)

# %% [markdown]
# MHD初期化 \
# U1は上半分、U2は下半分のつもり

# %%
gamma_mhd = 5.0 / 3.0
B0_mhd = B0_pic
rho0_mhd = ne0_pic * m_electron + ni0_pic * m_ion
p0_mhd = ne0_pic * Te_pic + ni0_pic * Ti_pic
VA_mhd = B0_mhd / np.sqrt(rho0_mhd)
CS_mhd = np.sqrt(gamma_mhd * p0_mhd / rho0_mhd)
Cf_mhd = np.sqrt(VA_mhd**2 + CS_mhd**2)
dx_mhd = dx_pic

nx_mhd = 1700
x_min_mhd = 1e-10
x_max_mhd = nx_mhd * dx_mhd - 1e-10
dt_mhd = 0.0
CFL = 0.7
x_coordinate_mhd = np.arange(x_min_mhd, x_max_mhd, dx_mhd)

sheat_thickness_mhd = sheat_thickness_pic / dx_pic * dx_mhd
speed_ratio = 0.05

U1 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd * (0.2 + 1.0 / np.cosh((x_coordinate_mhd - nx_mhd/2.0) / sheat_thickness_mhd)**2)
u_init = 0.0
v_init = 0.0
w_init = 0.0
Bx_init = 0.1 * B0_mhd
By_init = B0_mhd * np.tanh((x_coordinate_mhd - nx_mhd/2.0) / sheat_thickness_mhd)
Bz_init = 0.0
p_init = p0_mhd * (0.2**2 + 1.0 / np.cosh((x_coordinate_mhd - nx_mhd/2.0) / sheat_thickness_mhd)**2)
U1[0, :] = rho_init
U1[1, :] = rho_init * u_init
U1[2, :] = rho_init * v_init
U1[3, :] = rho_init * w_init
U1[4, :] = Bx_init
U1[5, :] = By_init
U1[6, :] = Bz_init
U1[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

flux1 = np.zeros(U1.shape)
flux1_bar = np.zeros(flux1.shape)

print(f"U1 size = {U1.shape}")
# Out:
# U1 size = (8, 1700)

# %% [markdown]
# 時間発展

# %%
steps = 3000
time_mhd = 0.0

for step in range(steps+1):

    # save
    if (step % 10 == 0):
        print(f"{step} step done... : time_mhd = {time_mhd:.5f}, dt_mhd = {dt_mhd:.5f}")
        np.save(f"./results_MHD_current_sheet_Bx/U1_{step}.npy", U1)

    #MHD
    #----------------------------------------------------------- 

    U1_bar = U1.copy()

    rho_mhd = U1[0, :]
    u_mhd = U1[1, :] / rho_mhd
    v_mhd = U1[2, :] / rho_mhd
    w_mhd = U1[3, :] / rho_mhd
    Bx_mhd = U1[4, :]
    By_mhd = U1[5, :]
    Bz_mhd = U1[6, :]
    e_mhd = U1[7, :]
    p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
    flux1 = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, flux1, axis=0)

    cs_mhd = np.sqrt(gamma_mhd * p_mhd / rho_mhd)
    ca_mhd = np.sqrt((Bx_mhd**2 + By_mhd**2 + Bz_mhd**2) / rho_mhd)
    dt_mhd = CFL * np.min(1.0 / ((np.abs(u_mhd) + np.sqrt(cs_mhd**2 + ca_mhd**2)) / dx_mhd))
    if np.isnan(time_mhd):
        print(f"{step} steps (t = {time_mhd:.3f}) : Calculation is crashed!")
        break
    
    U1_bar += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
    U1_bar = boundary_Poynting_flux(speed_ratio * (1.0 + np.tanh(((step-200)/50)))/2.0, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1_bar)
    
    rho_mhd = U1_bar[0, :]
    u_mhd = U1_bar[1, :] / rho_mhd
    v_mhd = U1_bar[2, :] / rho_mhd
    w_mhd = U1_bar[3, :] / rho_mhd
    Bx_mhd = U1_bar[4, :]
    By_mhd = U1_bar[5, :]
    Bz_mhd = U1_bar[6, :]
    e_mhd = U1_bar[7, :]
    p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
    flux1_bar = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, flux1_bar, axis=0)
    flux1 = 0.5 * (flux1 + flux1_bar)

    U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
    U1 = boundary_Poynting_flux(speed_ratio * (1.0 + np.tanh(((step-200)/50)))/2.0, VA_mhd, B0_mhd, rho_init, p_init, gamma_mhd, U1)
    
    time_mhd += dt_mhd
# Out:
# 0 step done... : time_mhd = 0.00000, dt_mhd = 0.00000
# 10 step done... : time_mhd = 30.77395, dt_mhd = 3.07605
# 20 step done... : time_mhd = 61.52633, dt_mhd = 3.07459
# 30 step done... : time_mhd = 92.26480, dt_mhd = 3.07328
# 40 step done... : time_mhd = 122.99140, dt_mhd = 3.07218
# 50 step done... : time_mhd = 153.70786, dt_mhd = 3.07123
# 60 step done... : time_mhd = 184.41575, dt_mhd = 3.07044
# 70 step done... : time_mhd = 215.11645, dt_mhd = 3.06979
# 80 step done... : time_mhd = 245.81129, dt_mhd = 3.06926
# 90 step done... : time_mhd = 276.50157, dt_mhd = 3.06886
# 100 step done... : time_mhd = 307.18857, dt_mhd = 3.06852
# 110 step done... : time_mhd = 337.86973, dt_mhd = 3.06782
# 120 step done... : time_mhd = 368.54522, dt_mhd = 3.06737
# 130 step done... : time_mhd = 399.21776, dt_mhd = 3.06683
# 140 step done... : time_mhd = 429.86268, dt_mhd = 3.06240
# 150 step done... : time_mhd = 460.45611, dt_mhd = 3.05660
# 160 step done... : time_mhd = 490.98258, dt_mhd = 3.04919
# 170 step done... : time_mhd = 521.42419, dt_mhd = 3.03972
# 180 step done... : time_mhd = 551.75844, dt_mhd = 3.02795
# 190 step done... : time_mhd = 581.96434, dt_mhd = 3.01436
# 200 step done... : time_mhd = 612.02827, dt_mhd = 2.99979
# 210 step done... : time_mhd = 641.94552, dt_mhd = 2.98522
# 220 step done... : time_mhd = 671.72293, dt_mhd = 2.97190
# 230 step done... : time_mhd = 701.37747, dt_mhd = 2.96012
# 240 step done... : time_mhd = 730.91848, dt_mhd = 2.94953
# 250 step done... : time_mhd = 760.36735, dt_mhd = 2.94147
# 260 step done... : time_mhd = 789.74938, dt_mhd = 2.93586
# 270 step done... : time_mhd = 819.07799, dt_mhd = 2.93067
# 280 step done... : time_mhd = 848.36337, dt_mhd = 2.92702
# 290 step done... : time_mhd = 877.62038, dt_mhd = 2.92477
# 300 step done... : time_mhd = 906.85599, dt_mhd = 2.92253
# 310 step done... : time_mhd = 936.07081, dt_mhd = 2.92072
# 320 step done... : time_mhd = 965.27089, dt_mhd = 2.91952
# 330 step done... : time_mhd = 994.46204, dt_mhd = 2.91877
# 340 step done... : time_mhd = 1023.64224, dt_mhd = 2.91744
# 350 step done... : time_mhd = 1052.81078, dt_mhd = 2.91642
# 360 step done... : time_mhd = 1081.97112, dt_mhd = 2.91577
# 370 step done... : time_mhd = 1111.12666, dt_mhd = 2.91524
# 380 step done... : time_mhd = 1140.27291, dt_mhd = 2.91415
# 390 step done... : time_mhd = 1169.40951, dt_mhd = 2.91330
# 400 step done... : time_mhd = 1198.53927, dt_mhd = 2.91277
# 410 step done... : time_mhd = 1227.66477, dt_mhd = 2.91218
# 420 step done... : time_mhd = 1256.78074, dt_mhd = 2.91115
# 430 step done... : time_mhd = 1285.88773, dt_mhd = 2.91037
# 440 step done... : time_mhd = 1314.98862, dt_mhd = 2.90991
# 450 step done... : time_mhd = 1344.08506, dt_mhd = 2.90923
# 460 step done... : time_mhd = 1373.17183, dt_mhd = 2.90826
# 470 step done... : time_mhd = 1402.25024, dt_mhd = 2.90754
# 480 step done... : time_mhd = 1431.32312, dt_mhd = 2.90713
# 490 step done... : time_mhd = 1460.39118, dt_mhd = 2.90637
# 500 step done... : time_mhd = 1489.44973, dt_mhd = 2.90547
# 510 step done... : time_mhd = 1518.50065, dt_mhd = 2.90482
# 520 step done... : time_mhd = 1547.54658, dt_mhd = 2.90445
# 530 step done... : time_mhd = 1576.58730, dt_mhd = 2.90365
# 540 step done... : time_mhd = 1605.61917, dt_mhd = 2.90284
# 550 step done... : time_mhd = 1634.64413, dt_mhd = 2.90225
# 560 step done... : time_mhd = 1663.66461, dt_mhd = 2.90192
# 570 step done... : time_mhd = 1692.67972, dt_mhd = 2.90112
# 580 step done... : time_mhd = 1721.68666, dt_mhd = 2.90038
# 590 step done... : time_mhd = 1750.68733, dt_mhd = 2.89985
# 600 step done... : time_mhd = 1779.68398, dt_mhd = 2.89956
# 610 step done... : time_mhd = 1808.67524, dt_mhd = 2.89877
# 620 step done... : time_mhd = 1837.65908, dt_mhd = 2.89810
# 630 step done... : time_mhd = 1866.63722, dt_mhd = 2.89762
# 640 step done... : time_mhd = 1895.61177, dt_mhd = 2.89735
# 650 step done... : time_mhd = 1924.58100, dt_mhd = 2.89660
# 660 step done... : time_mhd = 1953.54348, dt_mhd = 2.89599
# 670 step done... : time_mhd = 1982.50086, dt_mhd = 2.89556
# 680 step done... : time_mhd = 2011.45499, dt_mhd = 2.89529
# 690 step done... : time_mhd = 2040.40397, dt_mhd = 2.89460
# 700 step done... : time_mhd = 2069.34686, dt_mhd = 2.89406
# 710 step done... : time_mhd = 2098.28517, dt_mhd = 2.89367
# 720 step done... : time_mhd = 2127.22057, dt_mhd = 2.89340
# 730 step done... : time_mhd = 2156.15106, dt_mhd = 2.89278
# 740 step done... : time_mhd = 2185.07607, dt_mhd = 2.89229
# 750 step done... : time_mhd = 2213.99700, dt_mhd = 2.89195
# 760 step done... : time_mhd = 2242.91532, dt_mhd = 2.89168
# 770 step done... : time_mhd = 2271.82898, dt_mhd = 2.89113
# 780 step done... : time_mhd = 2300.73775, dt_mhd = 2.89069
# 790 step done... : time_mhd = 2329.64291, dt_mhd = 2.89039
# 800 step done... : time_mhd = 2358.54568, dt_mhd = 2.89012
# 810 step done... : time_mhd = 2387.44409, dt_mhd = 2.88963
# 820 step done... : time_mhd = 2416.33813, dt_mhd = 2.88924
# 830 step done... : time_mhd = 2445.22901, dt_mhd = 2.88898
# 840 step done... : time_mhd = 2474.11771, dt_mhd = 2.88871
# 850 step done... : time_mhd = 2503.00232, dt_mhd = 2.88827
# 860 step done... : time_mhd = 2531.88307, dt_mhd = 2.88793
# 870 step done... : time_mhd = 2560.76105, dt_mhd = 2.88771
# 880 step done... : time_mhd = 2589.63701, dt_mhd = 2.88743
# 890 step done... : time_mhd = 2618.50915, dt_mhd = 2.88705
# 900 step done... : time_mhd = 2647.37792, dt_mhd = 2.88675
# 910 step done... : time_mhd = 2676.24432, dt_mhd = 2.88657
# 920 step done... : time_mhd = 2705.10879, dt_mhd = 2.88629
# 930 step done... : time_mhd = 2733.96969, dt_mhd = 2.88594
# 940 step done... : time_mhd = 2762.82764, dt_mhd = 2.88569
# 950 step done... : time_mhd = 2791.68358, dt_mhd = 2.88553
# 960 step done... : time_mhd = 2820.53755, dt_mhd = 2.88524
# 970 step done... : time_mhd = 2849.38824, dt_mhd = 2.88494
# 980 step done... : time_mhd = 2878.23637, dt_mhd = 2.88472
# 990 step done... : time_mhd = 2907.08282, dt_mhd = 2.88460
# 1000 step done... : time_mhd = 2935.92711, dt_mhd = 2.88428
# 1010 step done... : time_mhd = 2964.76844, dt_mhd = 2.88402
# 1020 step done... : time_mhd = 2993.60751, dt_mhd = 2.88383
# 1030 step done... : time_mhd = 3022.44508, dt_mhd = 2.88368
# 1040 step done... : time_mhd = 3051.28018, dt_mhd = 2.88338
# 1050 step done... : time_mhd = 3080.11263, dt_mhd = 2.88314
# 1060 step done... : time_mhd = 3108.94309, dt_mhd = 2.88298
# 1070 step done... : time_mhd = 3137.77202, dt_mhd = 2.88278
# 1080 step done... : time_mhd = 3166.59822, dt_mhd = 2.88250
# 1090 step done... : time_mhd = 3195.42194, dt_mhd = 2.88228
# 1100 step done... : time_mhd = 3224.24383, dt_mhd = 2.88212
# 1110 step done... : time_mhd = 3253.06381, dt_mhd = 2.88186
# 1120 step done... : time_mhd = 3281.88097, dt_mhd = 2.88160
# 1130 step done... : time_mhd = 3310.69582, dt_mhd = 2.88140
# 1140 step done... : time_mhd = 3339.50893, dt_mhd = 2.88123
# 1150 step done... : time_mhd = 3368.31953, dt_mhd = 2.88093
# 1160 step done... : time_mhd = 3397.12741, dt_mhd = 2.88068
# 1170 step done... : time_mhd = 3425.93314, dt_mhd = 2.88049
# 1180 step done... : time_mhd = 3454.73698, dt_mhd = 2.88026
# 1190 step done... : time_mhd = 3483.53794, dt_mhd = 2.87997
# 1200 step done... : time_mhd = 3512.33635, dt_mhd = 2.87974
# 1210 step done... : time_mhd = 3541.13279, dt_mhd = 2.87957
# 1220 step done... : time_mhd = 3569.92688, dt_mhd = 2.87927
# 1230 step done... : time_mhd = 3598.71817, dt_mhd = 2.87902
# 1240 step done... : time_mhd = 3627.50714, dt_mhd = 2.87881
# 1250 step done... : time_mhd = 3656.29416, dt_mhd = 2.87859
# 1260 step done... : time_mhd = 3685.07841, dt_mhd = 2.87830
# 1270 step done... : time_mhd = 3713.86011, dt_mhd = 2.87807
# 1280 step done... : time_mhd = 3742.63980, dt_mhd = 2.87790
# 1290 step done... : time_mhd = 3771.41730, dt_mhd = 2.87762
# 1300 step done... : time_mhd = 3800.19207, dt_mhd = 2.87737
# 1310 step done... : time_mhd = 3828.96458, dt_mhd = 2.87716
# 1320 step done... : time_mhd = 3857.73525, dt_mhd = 2.87696
# 1330 step done... : time_mhd = 3886.50331, dt_mhd = 2.87669
# 1340 step done... : time_mhd = 3915.26893, dt_mhd = 2.87646
# 1350 step done... : time_mhd = 3944.03257, dt_mhd = 2.87629
# 1360 step done... : time_mhd = 3972.79406, dt_mhd = 2.87602
# 1370 step done... : time_mhd = 4001.55298, dt_mhd = 2.87579
# 1380 step done... : time_mhd = 4030.30979, dt_mhd = 2.87560
# 1390 step done... : time_mhd = 4059.06476, dt_mhd = 2.87539
# 1400 step done... : time_mhd = 4087.81709, dt_mhd = 2.87511
# 1410 step done... : time_mhd = 4116.56688, dt_mhd = 2.87488
# 1420 step done... : time_mhd = 4145.31464, dt_mhd = 2.87470
# 1430 step done... : time_mhd = 4174.06023, dt_mhd = 2.87444
# 1440 step done... : time_mhd = 4202.80339, dt_mhd = 2.87422
# 1450 step done... : time_mhd = 4231.54453, dt_mhd = 2.87403
# 1460 step done... : time_mhd = 4260.28387, dt_mhd = 2.87383
# 1470 step done... : time_mhd = 4289.02083, dt_mhd = 2.87360
# 1480 step done... : time_mhd = 4317.75569, dt_mhd = 2.87340
# 1490 step done... : time_mhd = 4346.48882, dt_mhd = 2.87324
# 1500 step done... : time_mhd = 4375.21986, dt_mhd = 2.87300
# 1510 step done... : time_mhd = 4403.94869, dt_mhd = 2.87279
# 1520 step done... : time_mhd = 4432.67571, dt_mhd = 2.87263
# 1530 step done... : time_mhd = 4461.40101, dt_mhd = 2.87243
# 1540 step done... : time_mhd = 4490.12404, dt_mhd = 2.87221
# 1550 step done... : time_mhd = 4518.84511, dt_mhd = 2.87203
# 1560 step done... : time_mhd = 4547.56454, dt_mhd = 2.87186
# 1570 step done... : time_mhd = 4576.28184, dt_mhd = 2.87163
# 1580 step done... : time_mhd = 4604.99704, dt_mhd = 2.87143
# 1590 step done... : time_mhd = 4633.71044, dt_mhd = 2.87126
# 1600 step done... : time_mhd = 4662.42197, dt_mhd = 2.87105
# 1610 step done... : time_mhd = 4691.13130, dt_mhd = 2.87084
# 1620 step done... : time_mhd = 4719.83870, dt_mhd = 2.87066
# 1630 step done... : time_mhd = 4748.54438, dt_mhd = 2.87047
# 1640 step done... : time_mhd = 4777.24785, dt_mhd = 2.87025
# 1650 step done... : time_mhd = 4805.94927, dt_mhd = 2.87006
# 1660 step done... : time_mhd = 4834.64887, dt_mhd = 2.86988
# 1670 step done... : time_mhd = 4863.34635, dt_mhd = 2.86964
# 1680 step done... : time_mhd = 4892.04164, dt_mhd = 2.86944
# 1690 step done... : time_mhd = 4920.73503, dt_mhd = 2.86926
# 1700 step done... : time_mhd = 4949.42644, dt_mhd = 2.86904
# 1710 step done... : time_mhd = 4978.11549, dt_mhd = 2.86881
# 1720 step done... : time_mhd = 5006.80240, dt_mhd = 2.86860
# 1730 step done... : time_mhd = 5035.48730, dt_mhd = 2.86838
# 1740 step done... : time_mhd = 5064.16983, dt_mhd = 2.86814
# 1750 step done... : time_mhd = 5092.85006, dt_mhd = 2.86793
# 1760 step done... : time_mhd = 5121.52823, dt_mhd = 2.86772
# 1770 step done... : time_mhd = 5150.20407, dt_mhd = 2.86748
# 1780 step done... : time_mhd = 5178.87756, dt_mhd = 2.86725
# 1790 step done... : time_mhd = 5207.54881, dt_mhd = 2.86703
# 1800 step done... : time_mhd = 5236.21772, dt_mhd = 2.86677
# 1810 step done... : time_mhd = 5264.88416, dt_mhd = 2.86654
# 1820 step done... : time_mhd = 5293.54837, dt_mhd = 2.86632
# 1830 step done... : time_mhd = 5322.21039, dt_mhd = 2.86609
# 1840 step done... : time_mhd = 5350.86993, dt_mhd = 2.86585
# 1850 step done... : time_mhd = 5379.52713, dt_mhd = 2.86562
# 1860 step done... : time_mhd = 5408.18215, dt_mhd = 2.86539
# 1870 step done... : time_mhd = 5436.83472, dt_mhd = 2.86515
# 1880 step done... : time_mhd = 5465.48495, dt_mhd = 2.86492
# 1890 step done... : time_mhd = 5494.13303, dt_mhd = 2.86471
# 1900 step done... : time_mhd = 5522.77880, dt_mhd = 2.86447
# 1910 step done... : time_mhd = 5551.42230, dt_mhd = 2.86425
# 1920 step done... : time_mhd = 5580.06370, dt_mhd = 2.86405
# 1930 step done... : time_mhd = 5608.70280, dt_mhd = 2.86381
# 1940 step done... : time_mhd = 5637.33964, dt_mhd = 2.86359
# 1950 step done... : time_mhd = 5665.97441, dt_mhd = 2.86339
# 1960 step done... : time_mhd = 5694.60702, dt_mhd = 2.86316
# 1970 step done... : time_mhd = 5723.23742, dt_mhd = 2.86294
# 1980 step done... : time_mhd = 5751.86578, dt_mhd = 2.86275
# 1990 step done... : time_mhd = 5780.49205, dt_mhd = 2.86253
# 2000 step done... : time_mhd = 5809.11619, dt_mhd = 2.86232
# 2010 step done... : time_mhd = 5837.73834, dt_mhd = 2.86213
# 2020 step done... : time_mhd = 5866.35850, dt_mhd = 2.86192
# 2030 step done... : time_mhd = 5894.97658, dt_mhd = 2.86172
# 2040 step done... : time_mhd = 5923.59273, dt_mhd = 2.86153
# 2050 step done... : time_mhd = 5952.20698, dt_mhd = 2.86133
# 2060 step done... : time_mhd = 5980.81924, dt_mhd = 2.86114
# 2070 step done... : time_mhd = 6009.42967, dt_mhd = 2.86096
# 2080 step done... : time_mhd = 6038.03829, dt_mhd = 2.86078
# 2090 step done... : time_mhd = 6066.64502, dt_mhd = 2.86059
# 2100 step done... : time_mhd = 6095.25000, dt_mhd = 2.86042
# 2110 step done... : time_mhd = 6123.85330, dt_mhd = 2.86025
# 2120 step done... : time_mhd = 6152.45484, dt_mhd = 2.86008
# 2130 step done... : time_mhd = 6181.05477, dt_mhd = 2.85992
# 2140 step done... : time_mhd = 6209.65315, dt_mhd = 2.85977
# 2150 step done... : time_mhd = 6238.24994, dt_mhd = 2.85961
# 2160 step done... : time_mhd = 6266.84528, dt_mhd = 2.85947
# 2170 step done... : time_mhd = 6295.43927, dt_mhd = 2.85933
# 2180 step done... : time_mhd = 6324.03186, dt_mhd = 2.85920
# 2190 step done... : time_mhd = 6352.62321, dt_mhd = 2.85908
# 2200 step done... : time_mhd = 6381.21343, dt_mhd = 2.85897
# 2210 step done... : time_mhd = 6409.80252, dt_mhd = 2.85886
# 2220 step done... : time_mhd = 6438.39063, dt_mhd = 2.85877
# 2230 step done... : time_mhd = 6466.97788, dt_mhd = 2.85869
# 2240 step done... : time_mhd = 6495.56428, dt_mhd = 2.85861
# 2250 step done... : time_mhd = 6524.14999, dt_mhd = 2.85855
# 2260 step done... : time_mhd = 6552.73517, dt_mhd = 2.85849
# 2270 step done... : time_mhd = 6581.31987, dt_mhd = 2.85845
# 2280 step done... : time_mhd = 6609.90426, dt_mhd = 2.85843
# 2290 step done... : time_mhd = 6638.48857, dt_mhd = 2.85843
# 2300 step done... : time_mhd = 6667.07285, dt_mhd = 2.85843
# 2310 step done... : time_mhd = 6695.65719, dt_mhd = 2.85844
# 2320 step done... : time_mhd = 6724.24175, dt_mhd = 2.85847
# 2330 step done... : time_mhd = 6752.82673, dt_mhd = 2.85852
# 2340 step done... : time_mhd = 6781.41224, dt_mhd = 2.85858
# 2350 step done... : time_mhd = 6809.99847, dt_mhd = 2.85866
# 2360 step done... : time_mhd = 6838.58555, dt_mhd = 2.85875
# 2370 step done... : time_mhd = 6867.17357, dt_mhd = 2.85885
# 2380 step done... : time_mhd = 6895.76271, dt_mhd = 2.85897
# 2390 step done... : time_mhd = 6924.35312, dt_mhd = 2.85910
# 2400 step done... : time_mhd = 6952.94483, dt_mhd = 2.85923
# 2410 step done... : time_mhd = 6981.53799, dt_mhd = 2.85938
# 2420 step done... : time_mhd = 7010.13271, dt_mhd = 2.85954
# 2430 step done... : time_mhd = 7038.72903, dt_mhd = 2.85971
# 2440 step done... : time_mhd = 7067.32702, dt_mhd = 2.85988
# 2450 step done... : time_mhd = 7095.92678, dt_mhd = 2.86006
# 2460 step done... : time_mhd = 7124.52828, dt_mhd = 2.86023
# 2470 step done... : time_mhd = 7153.13157, dt_mhd = 2.86041
# 2480 step done... : time_mhd = 7181.73670, dt_mhd = 2.86060
# 2490 step done... : time_mhd = 7210.34365, dt_mhd = 2.86077
# 2500 step done... : time_mhd = 7238.95237, dt_mhd = 2.86095
# 2510 step done... : time_mhd = 7267.56290, dt_mhd = 2.86114
# 2520 step done... : time_mhd = 7296.17519, dt_mhd = 2.86131
# 2530 step done... : time_mhd = 7324.78917, dt_mhd = 2.86147
# 2540 step done... : time_mhd = 7353.40483, dt_mhd = 2.86164
# 2550 step done... : time_mhd = 7382.02211, dt_mhd = 2.86180
# 2560 step done... : time_mhd = 7410.64090, dt_mhd = 2.86195
# 2570 step done... : time_mhd = 7439.26120, dt_mhd = 2.86210
# 2580 step done... : time_mhd = 7467.88292, dt_mhd = 2.86223
# 2590 step done... : time_mhd = 7496.50597, dt_mhd = 2.86236
# 2600 step done... : time_mhd = 7525.13027, dt_mhd = 2.86248
# 2610 step done... : time_mhd = 7553.75574, dt_mhd = 2.86260
# 2620 step done... : time_mhd = 7582.38225, dt_mhd = 2.86270
# 2630 step done... : time_mhd = 7611.00975, dt_mhd = 2.86279
# 2640 step done... : time_mhd = 7639.63816, dt_mhd = 2.86288
# 2650 step done... : time_mhd = 7668.26733, dt_mhd = 2.86295
# 2660 step done... : time_mhd = 7696.89721, dt_mhd = 2.86302
# 2670 step done... : time_mhd = 7725.52770, dt_mhd = 2.86307
# 2680 step done... : time_mhd = 7754.15868, dt_mhd = 2.86312
# 2690 step done... : time_mhd = 7782.79008, dt_mhd = 2.86316
# 2700 step done... : time_mhd = 7811.42183, dt_mhd = 2.86319
# 2710 step done... : time_mhd = 7840.05378, dt_mhd = 2.86320
# 2720 step done... : time_mhd = 7868.68586, dt_mhd = 2.86321
# 2730 step done... : time_mhd = 7897.31798, dt_mhd = 2.86321
# 2740 step done... : time_mhd = 7925.95006, dt_mhd = 2.86320
# 2750 step done... : time_mhd = 7954.58203, dt_mhd = 2.86319
# 2760 step done... : time_mhd = 7983.21383, dt_mhd = 2.86317
# 2770 step done... : time_mhd = 8011.84532, dt_mhd = 2.86313
# 2780 step done... : time_mhd = 8040.47633, dt_mhd = 2.86308
# 2790 step done... : time_mhd = 8069.10692, dt_mhd = 2.86304
# 2800 step done... : time_mhd = 8097.73723, dt_mhd = 2.86302
# 2810 step done... : time_mhd = 8126.36725, dt_mhd = 2.86299
# 2820 step done... : time_mhd = 8154.99686, dt_mhd = 2.86293
# 2830 step done... : time_mhd = 8183.62521, dt_mhd = 2.86273
# 2840 step done... : time_mhd = 8212.25008, dt_mhd = 2.86226
# 2850 step done... : time_mhd = 8240.86956, dt_mhd = 2.86170
# 2860 step done... : time_mhd = 8269.48387, dt_mhd = 2.86122
# 2870 step done... : time_mhd = 8298.09390, dt_mhd = 2.86084
# 2880 step done... : time_mhd = 8326.70071, dt_mhd = 2.86057
# 2890 step done... : time_mhd = 8355.30525, dt_mhd = 2.86037
# 2900 step done... : time_mhd = 8383.90821, dt_mhd = 2.86024
# 2910 step done... : time_mhd = 8412.51004, dt_mhd = 2.86014
# 2920 step done... : time_mhd = 8441.11112, dt_mhd = 2.86008
# 2930 step done... : time_mhd = 8469.71177, dt_mhd = 2.86006
# 2940 step done... : time_mhd = 8498.31231, dt_mhd = 2.86005
# 2950 step done... : time_mhd = 8526.91290, dt_mhd = 2.86007
# 2960 step done... : time_mhd = 8555.51404, dt_mhd = 2.86017
# 2970 step done... : time_mhd = 8584.11728, dt_mhd = 2.86049
# 2980 step done... : time_mhd = 8612.72759, dt_mhd = 2.86176
# 2990 step done... : time_mhd = 8641.37282, dt_mhd = 2.86841
# 3000 step done... : time_mhd = 8670.16944, dt_mhd = 2.89078

# %% [markdown]
# プロット

# %%
k = 1000

U = np.load(f"results_MHD_current_sheet_Bx/U1_{k}.npy")
rho_mhd = U[0, :]
u_mhd = U[1, :] / rho_mhd
v_mhd = U[2, :] / rho_mhd
w_mhd = U[3, :] / rho_mhd
Bx_mhd = U[4, :]
By_mhd = U[5, :]
Bz_mhd = U[6, :]
e_mhd = U[7, :]
p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
Ex_mhd = -(v_mhd * Bz_mhd - w_mhd * By_mhd)
Ey_mhd = -(w_mhd * Bx_mhd - u_mhd * Bz_mhd)
Ez_mhd = -(u_mhd * By_mhd - v_mhd * Bx_mhd)
current_x_mhd = np.zeros(Bx_mhd.shape)
current_y_mhd = -(np.roll(Bz_mhd, -1, axis=0) - np.roll(Bz_mhd, 1, axis=0)) / (2*dx_mhd)
current_z_mhd = (np.roll(By_mhd, -1, axis=0) - np.roll(By_mhd, 1, axis=0)) / (2*dx_mhd)
current_y_mhd[0] = current_y_mhd[1] 
current_y_mhd[-1] = current_y_mhd[-2] 
current_z_mhd[0] = current_z_mhd[1] 
current_z_mhd[-1] = current_z_mhd[-2]

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

rho = U[0, :]
u = U[1, :] / rho 
v = U[2, :] / rho 
w = U[3, :] / rho 
Bx = U[4, :]
By = U[5, :]
Bz = U[6, :]
e = U[7, :]
p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)

ax1.plot(x_coordinate_mhd/ion_inertial_length, rho / rho0_mhd, marker='o', markersize=5)
ax2.plot(x_coordinate_mhd/ion_inertial_length, p / p0_mhd, marker='o', markersize=5)
ax3.plot(x_coordinate_mhd/ion_inertial_length, u, marker='o', markersize=5)
ax4.plot(x_coordinate_mhd/ion_inertial_length, v, marker='o', markersize=5)
ax5.plot(x_coordinate_mhd/ion_inertial_length, By / B0_mhd, marker='o', markersize=5)
ax6.plot(x_coordinate_mhd/ion_inertial_length, Bz / B0_mhd, marker='o', markersize=5)

ax1.set_title(r"$\rho$", fontsize=24)
ax2.set_title(r"$p$", fontsize=24)
ax3.set_title(r"$u$", fontsize=24)
ax4.set_title(r"$v$", fontsize=24)
ax5.set_title(r"$B_y$", fontsize=24)
ax6.set_title(r"$B_z$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax5.tick_params(labelsize=16)
ax6.tick_params(labelsize=16)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

plt.suptitle(f"t = {k}", y=0.95, fontsize=32)

plt.show()

# %% [markdown]
# 動画作成

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412)
ax3 = fig.add_subplot(413)
ax4 = fig.add_subplot(414)

filename = "current_sheet_Bx_MHD.mp4"

interval = 10
plot_steps = steps
for i in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()

    U = np.load(f"results_MHD_current_sheet_Bx/U1_{i}.npy")
    rho = U[0, :]
    u = U[1, :] / rho 
    v = U[2, :] / rho 
    w = U[3, :] / rho 
    Bx = U[4, :]
    By = U[5, :]
    Bz = U[6, :]
    e = U[7, :]
    p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)
    Ex = -(v * Bz - w * Bx)
    Ey = -(w * Bx - u * Bz)
    Ez = -(u * By - v * Bx)
    current_x = np.zeros(Bx.shape)
    current_y = -(np.roll(Bz, -1, axis=0) - np.roll(Bz, 1, axis=0)) / (2*dx_mhd)
    current_z = (np.roll(By, -1, axis=0) - np.roll(By, 1, axis=0)) / (2*dx_mhd)
    current_y[0] = current_y[1] 
    current_y[-1] = current_y[-2] 
    current_z[0] = current_z[1] 
    current_z[-1] = current_z[-2] 

    ax1.plot(x_coordinate_mhd/ion_inertial_length, rho / 0.2 / rho0_mhd, lw=3)
    ax2.plot(x_coordinate_mhd/ion_inertial_length, current_z / B0_mhd / ion_inertial_length, lw=3)
    ax3.plot(x_coordinate_mhd/ion_inertial_length, By / B0_mhd, lw=3)
    ax4.plot(x_coordinate_mhd/ion_inertial_length, Ez / VA_mhd / B0_mhd, lw=3)
    
    ax1.set_xlim(0, nx_mhd*dx_mhd/ion_inertial_length)
    ax2.set_xlim(0, nx_mhd*dx_mhd/ion_inertial_length)
    ax3.set_xlim(0, nx_mhd*dx_mhd/ion_inertial_length)
    ax4.set_xlim(0, nx_mhd*dx_mhd/ion_inertial_length)
    ax1.set_ylim(0.0, 8.0)
    ax2.set_ylim(-0.005, 0.005)
    ax3.set_ylim(-2.0, 2.0)
    ax4.set_ylim(-1.0, 2.0)

    ax4.set_xlabel(r"$x / \lambda_i$", fontsize=24)
    ax1.set_ylabel(r"$\rho / \rho_0$", fontsize=24)
    ax2.set_ylabel(r"$j_z / B_0 / \lambda_i$", fontsize=24)
    ax3.set_ylabel(r"$B_y / B_0$", fontsize=24)
    ax4.set_ylabel(r"$E_z / V_A / B_0$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()

    plt.suptitle(f"t = {i}", y=0.95, fontsize=32)

    fig.savefig(f'./pictures/{i}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for i in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{i}.png')
    video.write(img)
video.release()
