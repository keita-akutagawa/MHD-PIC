# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import cv2

from lib_MHDPIC1D.interface import *

# %%
x_interface_coordinate = np.arange(0.0, 10.0, 0.1)

F = interlocking_function(x_interface_coordinate)

plt.figure(figsize=(8, 4))
plt.plot(x_interface_coordinate, F)
plt.ylabel("F", fontsize=18)
plt.savefig("interlocking_function.png", dpi=200)
