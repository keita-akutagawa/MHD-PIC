# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import cv2


import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

from lib_MHDPIC1D.pic1d import *
from lib_MHDPIC1D.mhd1d import *
from lib_MHDPIC1D.interface import *
from lib_MHDPIC1D.remove_noise import *

# %% [markdown]
# Alfven波の伝搬 MHDのみ

# %%
c = 1.0
mu_0 = 1.0
epsilon0 = 1.0 / (mu_0 * c**2)
m_electron = 1.0
r_m = 1 / 100
m_ion = m_electron / r_m
t_r = 1.0
ne0_pic = 100 #ここは手動で調整すること
ni0_pic = ne0_pic
B0_pic = np.sqrt(ne0_pic) / 1.0
Te_pic = 0.5 * m_electron * (0.1*c)**2
Ti_pic = Te_pic / t_r
q_electron = -1 * np.sqrt(epsilon0 * Te_pic / ne0_pic)
q_ion = -1 * q_electron
debye_length = np.sqrt(epsilon0 * Te_pic / ne0_pic / q_electron**2)
omega_pe = np.sqrt(ne0_pic * q_electron**2 / m_electron / epsilon0)
omega_pi = np.sqrt(ni0_pic * q_ion**2 / m_ion / epsilon0)
omega_ce = q_electron * B0_pic / m_electron
omega_ci = q_ion * B0_pic / m_ion
VA_pic = B0_pic / np.sqrt(ni0_pic * m_ion + ni0_pic * m_electron)
gamma_pic = 5.0 / 3.0
rho_pic = ni0_pic * m_ion + ne0_pic * m_electron
p_pic = ni0_pic * Ti_pic + ne0_pic * Te_pic
CS_pic = np.sqrt(gamma_pic * p_pic / rho_pic)
v_ion = np.array([0.0, 0.0, 0.0])
v_electron = np.array([0.0, 0.0, 0.0])
v_thermal_electron = np.sqrt(2.0 * Te_pic / m_electron)
v_thermal_ion = np.sqrt(2.0 * Ti_pic / m_ion)
ion_inertial_length = c / omega_pi

dx_pic = debye_length
nx_pic = 200
x_min_pic = 1e-10
x_max_pic = nx_pic * dx_pic - 1e-10
x_coordinate_pic = np.arange(0.0, x_max_pic, dx_pic)
dt_pic = 0.0
d_pic = 0.0

# %% [markdown]
# MHD初期化 \
# U1は上半分、U2は下半分のつもり

# %%
gamma_mhd = 5.0 / 3.0
B0_mhd = B0_pic
rho0_mhd = ne0_pic * m_electron + ni0_pic * m_ion
p0_mhd = ne0_pic * Te_pic + ni0_pic * Ti_pic
VA_mhd = B0_mhd / np.sqrt(rho0_mhd)
CS_mhd = np.sqrt(gamma_mhd * p0_mhd / rho0_mhd)
Cf_mhd = np.sqrt(VA_mhd**2 + CS_mhd**2)
dx_mhd = dx_pic

nx_mhd = 5000
x_min_mhd = 1e-10
x_max_mhd = nx_mhd * dx_mhd - 1e-10
dt_mhd = 0.0
CFL = 0.7
x_coordinate_mhd = np.arange(x_min_mhd, x_max_mhd, dx_mhd)

lambda_mhd = 1000.0
kx_mhd = 2.0 * np.pi / lambda_mhd

U1 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd
u_init = 0.0
v_init = -0.1 * VA_mhd * np.cos(kx_mhd * x_coordinate_mhd)
w_init = 0.1 * VA_mhd * np.sin(kx_mhd * x_coordinate_mhd)
Bx_init = B0_mhd
By_init = 0.1 * B0_mhd * np.cos(kx_mhd * x_coordinate_mhd)
Bz_init = -0.1 * B0_mhd * np.sin(kx_mhd * x_coordinate_mhd)
p_init = p0_mhd
U1[0, :] = rho_init
U1[1, :] = rho_init * u_init
U1[2, :] = rho_init * v_init
U1[3, :] = rho_init * w_init
U1[4, :] = Bx_init
U1[5, :] = By_init
U1[6, :] = Bz_init
U1[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

flux1 = np.zeros(U1.shape)
flux1_bar = np.zeros(flux1.shape)

print(f"U1 size = {U1.shape}")
# Out:
# U1 size = (8, 5000)

# %% [markdown]
# 時間発展

# %%
steps = 2000
time_mhd = 0.0

for step in range(steps+1):

    # save
    if (step % 10 == 0):
        print(f"{step} step done... : time_mhd = {time_mhd:.5f}, dt_mhd = {dt_mhd:.5f}")
        np.save(f"./results_MHD_alfven/U1_{step}.npy", U1)

    #MHD
    #----------------------------------------------------------- 

    U1_bar = U1.copy()

    rho_mhd = U1[0, :]
    u_mhd = U1[1, :] / rho_mhd
    v_mhd = U1[2, :] / rho_mhd
    w_mhd = U1[3, :] / rho_mhd
    Bx_mhd = U1[4, :]
    By_mhd = U1[5, :]
    Bz_mhd = U1[6, :]
    e_mhd = U1[7, :]
    p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
    flux1 = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, flux1, axis=0)

    cs_mhd = np.sqrt(gamma_mhd * p_mhd / rho_mhd)
    ca_mhd = np.sqrt((Bx_mhd**2 + By_mhd**2 + Bz_mhd**2) / rho_mhd)
    dt_mhd = CFL * np.min(1.0 / ((np.abs(u_mhd) + np.sqrt(cs_mhd**2 + ca_mhd**2)) / dx_mhd))
    if np.isnan(time_mhd):
        print(f"{step} steps (t = {time_mhd:.3f}) : Calculation is crashed!")
        break
    
    U1_bar += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
    
    rho_mhd = U1_bar[0, :]
    u_mhd = U1_bar[1, :] / rho_mhd
    v_mhd = U1_bar[2, :] / rho_mhd
    w_mhd = U1_bar[3, :] / rho_mhd
    Bx_mhd = U1_bar[4, :]
    By_mhd = U1_bar[5, :]
    Bz_mhd = U1_bar[6, :]
    e_mhd = U1_bar[7, :]
    p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
    flux1_bar = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, flux1_bar, axis=0)
    flux1 = 0.5 * (flux1 + flux1_bar)

    U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
    
    time_mhd += dt_mhd
# Out:
# 0 step done... : time_mhd = 0.00000, dt_mhd = 0.00000
# 10 step done... : time_mhd = 69.42948, dt_mhd = 6.94295
# 20 step done... : time_mhd = 138.85893, dt_mhd = 6.94294
# 30 step done... : time_mhd = 208.28837, dt_mhd = 6.94294
# 40 step done... : time_mhd = 277.71781, dt_mhd = 6.94294
# 50 step done... : time_mhd = 347.14723, dt_mhd = 6.94294
# 60 step done... : time_mhd = 416.57665, dt_mhd = 6.94294
# 70 step done... : time_mhd = 486.00605, dt_mhd = 6.94294
# 80 step done... : time_mhd = 555.43545, dt_mhd = 6.94294
# 90 step done... : time_mhd = 624.86484, dt_mhd = 6.94294
# 100 step done... : time_mhd = 694.29422, dt_mhd = 6.94294
# 110 step done... : time_mhd = 763.72359, dt_mhd = 6.94294
# 120 step done... : time_mhd = 833.15295, dt_mhd = 6.94294
# 130 step done... : time_mhd = 902.58231, dt_mhd = 6.94294
# 140 step done... : time_mhd = 972.01166, dt_mhd = 6.94293
# 150 step done... : time_mhd = 1041.44100, dt_mhd = 6.94293
# 160 step done... : time_mhd = 1110.87033, dt_mhd = 6.94293
# 170 step done... : time_mhd = 1180.29966, dt_mhd = 6.94293
# 180 step done... : time_mhd = 1249.72898, dt_mhd = 6.94293
# 190 step done... : time_mhd = 1319.15830, dt_mhd = 6.94293
# 200 step done... : time_mhd = 1388.58761, dt_mhd = 6.94293
# 210 step done... : time_mhd = 1458.01692, dt_mhd = 6.94293
# 220 step done... : time_mhd = 1527.44621, dt_mhd = 6.94293
# 230 step done... : time_mhd = 1596.87551, dt_mhd = 6.94293
# 240 step done... : time_mhd = 1666.30479, dt_mhd = 6.94293
# 250 step done... : time_mhd = 1735.73408, dt_mhd = 6.94293
# 260 step done... : time_mhd = 1805.16335, dt_mhd = 6.94293
# 270 step done... : time_mhd = 1874.59261, dt_mhd = 6.94293
# 280 step done... : time_mhd = 1944.02186, dt_mhd = 6.94293
# 290 step done... : time_mhd = 2013.45111, dt_mhd = 6.94292
# 300 step done... : time_mhd = 2082.88035, dt_mhd = 6.94292
# 310 step done... : time_mhd = 2152.30957, dt_mhd = 6.94292
# 320 step done... : time_mhd = 2221.73878, dt_mhd = 6.94292
# 330 step done... : time_mhd = 2291.16797, dt_mhd = 6.94292
# 340 step done... : time_mhd = 2360.59714, dt_mhd = 6.94292
# 350 step done... : time_mhd = 2430.02628, dt_mhd = 6.94291
# 360 step done... : time_mhd = 2499.45541, dt_mhd = 6.94291
# 370 step done... : time_mhd = 2568.88454, dt_mhd = 6.94291
# 380 step done... : time_mhd = 2638.31366, dt_mhd = 6.94291
# 390 step done... : time_mhd = 2707.74279, dt_mhd = 6.94291
# 400 step done... : time_mhd = 2777.17193, dt_mhd = 6.94291
# 410 step done... : time_mhd = 2846.60107, dt_mhd = 6.94291
# 420 step done... : time_mhd = 2916.03022, dt_mhd = 6.94291
# 430 step done... : time_mhd = 2985.45937, dt_mhd = 6.94292
# 440 step done... : time_mhd = 3054.88853, dt_mhd = 6.94292
# 450 step done... : time_mhd = 3124.31770, dt_mhd = 6.94292
# 460 step done... : time_mhd = 3193.74687, dt_mhd = 6.94292
# 470 step done... : time_mhd = 3263.17604, dt_mhd = 6.94292
# 480 step done... : time_mhd = 3332.60521, dt_mhd = 6.94292
# 490 step done... : time_mhd = 3402.03438, dt_mhd = 6.94292
# 500 step done... : time_mhd = 3471.46355, dt_mhd = 6.94292
# 510 step done... : time_mhd = 3540.89272, dt_mhd = 6.94292
# 520 step done... : time_mhd = 3610.32188, dt_mhd = 6.94292
# 530 step done... : time_mhd = 3679.75104, dt_mhd = 6.94292
# 540 step done... : time_mhd = 3749.18019, dt_mhd = 6.94292
# 550 step done... : time_mhd = 3818.60934, dt_mhd = 6.94291
# 560 step done... : time_mhd = 3888.03848, dt_mhd = 6.94291
# 570 step done... : time_mhd = 3957.46761, dt_mhd = 6.94291
# 580 step done... : time_mhd = 4026.89674, dt_mhd = 6.94291
# 590 step done... : time_mhd = 4096.32586, dt_mhd = 6.94291
# 600 step done... : time_mhd = 4165.75497, dt_mhd = 6.94291
# 610 step done... : time_mhd = 4235.18406, dt_mhd = 6.94291
# 620 step done... : time_mhd = 4304.61315, dt_mhd = 6.94291
# 630 step done... : time_mhd = 4374.04222, dt_mhd = 6.94291
# 640 step done... : time_mhd = 4443.47127, dt_mhd = 6.94290
# 650 step done... : time_mhd = 4512.90030, dt_mhd = 6.94290
# 660 step done... : time_mhd = 4582.32930, dt_mhd = 6.94290
# 670 step done... : time_mhd = 4651.75827, dt_mhd = 6.94290
# 680 step done... : time_mhd = 4721.18722, dt_mhd = 6.94289
# 690 step done... : time_mhd = 4790.61616, dt_mhd = 6.94289
# 700 step done... : time_mhd = 4860.04509, dt_mhd = 6.94289
# 710 step done... : time_mhd = 4929.47400, dt_mhd = 6.94289
# 720 step done... : time_mhd = 4998.90292, dt_mhd = 6.94289
# 730 step done... : time_mhd = 5068.33185, dt_mhd = 6.94289
# 740 step done... : time_mhd = 5137.76078, dt_mhd = 6.94289
# 750 step done... : time_mhd = 5207.18972, dt_mhd = 6.94290
# 760 step done... : time_mhd = 5276.61867, dt_mhd = 6.94289
# 770 step done... : time_mhd = 5346.04763, dt_mhd = 6.94290
# 780 step done... : time_mhd = 5415.47660, dt_mhd = 6.94290
# 790 step done... : time_mhd = 5484.90559, dt_mhd = 6.94290
# 800 step done... : time_mhd = 5554.33458, dt_mhd = 6.94290
# 810 step done... : time_mhd = 5623.76358, dt_mhd = 6.94290
# 820 step done... : time_mhd = 5693.19259, dt_mhd = 6.94290
# 830 step done... : time_mhd = 5762.62161, dt_mhd = 6.94290
# 840 step done... : time_mhd = 5832.05063, dt_mhd = 6.94290
# 850 step done... : time_mhd = 5901.47967, dt_mhd = 6.94290
# 860 step done... : time_mhd = 5970.90871, dt_mhd = 6.94290
# 870 step done... : time_mhd = 6040.33775, dt_mhd = 6.94290
# 880 step done... : time_mhd = 6109.76679, dt_mhd = 6.94290
# 890 step done... : time_mhd = 6179.19584, dt_mhd = 6.94290
# 900 step done... : time_mhd = 6248.62487, dt_mhd = 6.94290
# 910 step done... : time_mhd = 6318.05390, dt_mhd = 6.94290
# 920 step done... : time_mhd = 6387.48292, dt_mhd = 6.94290
# 930 step done... : time_mhd = 6456.91193, dt_mhd = 6.94290
# 940 step done... : time_mhd = 6526.34091, dt_mhd = 6.94290
# 950 step done... : time_mhd = 6595.76989, dt_mhd = 6.94290
# 960 step done... : time_mhd = 6665.19883, dt_mhd = 6.94289
# 970 step done... : time_mhd = 6734.62775, dt_mhd = 6.94289
# 980 step done... : time_mhd = 6804.05664, dt_mhd = 6.94289
# 990 step done... : time_mhd = 6873.48550, dt_mhd = 6.94288
# 1000 step done... : time_mhd = 6942.91433, dt_mhd = 6.94288
# 1010 step done... : time_mhd = 7012.34313, dt_mhd = 6.94288
# 1020 step done... : time_mhd = 7081.77192, dt_mhd = 6.94288
# 1030 step done... : time_mhd = 7151.20068, dt_mhd = 6.94288
# 1040 step done... : time_mhd = 7220.62944, dt_mhd = 6.94288
# 1050 step done... : time_mhd = 7290.05819, dt_mhd = 6.94287
# 1060 step done... : time_mhd = 7359.48693, dt_mhd = 6.94287
# 1070 step done... : time_mhd = 7428.91567, dt_mhd = 6.94288
# 1080 step done... : time_mhd = 7498.34442, dt_mhd = 6.94287
# 1090 step done... : time_mhd = 7567.77317, dt_mhd = 6.94288
# 1100 step done... : time_mhd = 7637.20194, dt_mhd = 6.94288
# 1110 step done... : time_mhd = 7706.63072, dt_mhd = 6.94288
# 1120 step done... : time_mhd = 7776.05952, dt_mhd = 6.94288
# 1130 step done... : time_mhd = 7845.48834, dt_mhd = 6.94288
# 1140 step done... : time_mhd = 7914.91718, dt_mhd = 6.94288
# 1150 step done... : time_mhd = 7984.34603, dt_mhd = 6.94289
# 1160 step done... : time_mhd = 8053.77489, dt_mhd = 6.94289
# 1170 step done... : time_mhd = 8123.20377, dt_mhd = 6.94289
# 1180 step done... : time_mhd = 8192.63266, dt_mhd = 6.94289
# 1190 step done... : time_mhd = 8262.06156, dt_mhd = 6.94289
# 1200 step done... : time_mhd = 8331.49048, dt_mhd = 6.94289
# 1210 step done... : time_mhd = 8400.91939, dt_mhd = 6.94289
# 1220 step done... : time_mhd = 8470.34831, dt_mhd = 6.94289
# 1230 step done... : time_mhd = 8539.77724, dt_mhd = 6.94289
# 1240 step done... : time_mhd = 8609.20616, dt_mhd = 6.94289
# 1250 step done... : time_mhd = 8678.63508, dt_mhd = 6.94289
# 1260 step done... : time_mhd = 8748.06399, dt_mhd = 6.94289
# 1270 step done... : time_mhd = 8817.49288, dt_mhd = 6.94289
# 1280 step done... : time_mhd = 8886.92176, dt_mhd = 6.94289
# 1290 step done... : time_mhd = 8956.35062, dt_mhd = 6.94288
# 1300 step done... : time_mhd = 9025.77945, dt_mhd = 6.94288
# 1310 step done... : time_mhd = 9095.20824, dt_mhd = 6.94288
# 1320 step done... : time_mhd = 9164.63701, dt_mhd = 6.94288
# 1330 step done... : time_mhd = 9234.06575, dt_mhd = 6.94287
# 1340 step done... : time_mhd = 9303.49446, dt_mhd = 6.94287
# 1350 step done... : time_mhd = 9372.92315, dt_mhd = 6.94287
# 1360 step done... : time_mhd = 9442.35181, dt_mhd = 6.94287
# 1370 step done... : time_mhd = 9511.78046, dt_mhd = 6.94286
# 1380 step done... : time_mhd = 9581.20909, dt_mhd = 6.94286
# 1390 step done... : time_mhd = 9650.63771, dt_mhd = 6.94286
# 1400 step done... : time_mhd = 9720.06631, dt_mhd = 6.94286
# 1410 step done... : time_mhd = 9789.49491, dt_mhd = 6.94286
# 1420 step done... : time_mhd = 9858.92352, dt_mhd = 6.94286
# 1430 step done... : time_mhd = 9928.35212, dt_mhd = 6.94286
# 1440 step done... : time_mhd = 9997.78073, dt_mhd = 6.94286
# 1450 step done... : time_mhd = 10067.20935, dt_mhd = 6.94286
# 1460 step done... : time_mhd = 10136.63798, dt_mhd = 6.94286
# 1470 step done... : time_mhd = 10206.06664, dt_mhd = 6.94287
# 1480 step done... : time_mhd = 10275.49531, dt_mhd = 6.94287
# 1490 step done... : time_mhd = 10344.92401, dt_mhd = 6.94287
# 1500 step done... : time_mhd = 10414.35273, dt_mhd = 6.94287
# 1510 step done... : time_mhd = 10483.78146, dt_mhd = 6.94287
# 1520 step done... : time_mhd = 10553.21022, dt_mhd = 6.94288
# 1530 step done... : time_mhd = 10622.63899, dt_mhd = 6.94288
# 1540 step done... : time_mhd = 10692.06778, dt_mhd = 6.94288
# 1550 step done... : time_mhd = 10761.49658, dt_mhd = 6.94288
# 1560 step done... : time_mhd = 10830.92538, dt_mhd = 6.94288
# 1570 step done... : time_mhd = 10900.35419, dt_mhd = 6.94288
# 1580 step done... : time_mhd = 10969.78299, dt_mhd = 6.94288
# 1590 step done... : time_mhd = 11039.21179, dt_mhd = 6.94288
# 1600 step done... : time_mhd = 11108.64058, dt_mhd = 6.94288
# 1610 step done... : time_mhd = 11178.06936, dt_mhd = 6.94288
# 1620 step done... : time_mhd = 11247.49811, dt_mhd = 6.94287
# 1630 step done... : time_mhd = 11316.92684, dt_mhd = 6.94287
# 1640 step done... : time_mhd = 11386.35554, dt_mhd = 6.94287
# 1650 step done... : time_mhd = 11455.78422, dt_mhd = 6.94287
# 1660 step done... : time_mhd = 11525.21287, dt_mhd = 6.94286
# 1670 step done... : time_mhd = 11594.64150, dt_mhd = 6.94286
# 1680 step done... : time_mhd = 11664.07012, dt_mhd = 6.94286
# 1690 step done... : time_mhd = 11733.49871, dt_mhd = 6.94286
# 1700 step done... : time_mhd = 11802.92728, dt_mhd = 6.94286
# 1710 step done... : time_mhd = 11872.35584, dt_mhd = 6.94285
# 1720 step done... : time_mhd = 11941.78439, dt_mhd = 6.94285
# 1730 step done... : time_mhd = 12011.21292, dt_mhd = 6.94285
# 1740 step done... : time_mhd = 12080.64143, dt_mhd = 6.94285
# 1750 step done... : time_mhd = 12150.06994, dt_mhd = 6.94285
# 1760 step done... : time_mhd = 12219.49844, dt_mhd = 6.94285
# 1770 step done... : time_mhd = 12288.92695, dt_mhd = 6.94285
# 1780 step done... : time_mhd = 12358.35544, dt_mhd = 6.94285
# 1790 step done... : time_mhd = 12427.78395, dt_mhd = 6.94285
# 1800 step done... : time_mhd = 12497.21246, dt_mhd = 6.94285
# 1810 step done... : time_mhd = 12566.64098, dt_mhd = 6.94285
# 1820 step done... : time_mhd = 12636.06951, dt_mhd = 6.94285
# 1830 step done... : time_mhd = 12705.49807, dt_mhd = 6.94286
# 1840 step done... : time_mhd = 12774.92665, dt_mhd = 6.94286
# 1850 step done... : time_mhd = 12844.35524, dt_mhd = 6.94286
# 1860 step done... : time_mhd = 12913.78387, dt_mhd = 6.94286
# 1870 step done... : time_mhd = 12983.21250, dt_mhd = 6.94286
# 1880 step done... : time_mhd = 13052.64116, dt_mhd = 6.94287
# 1890 step done... : time_mhd = 13122.06982, dt_mhd = 6.94287
# 1900 step done... : time_mhd = 13191.49850, dt_mhd = 6.94287
# 1910 step done... : time_mhd = 13260.92717, dt_mhd = 6.94287
# 1920 step done... : time_mhd = 13330.35585, dt_mhd = 6.94287
# 1930 step done... : time_mhd = 13399.78452, dt_mhd = 6.94287
# 1940 step done... : time_mhd = 13469.21318, dt_mhd = 6.94286
# 1950 step done... : time_mhd = 13538.64183, dt_mhd = 6.94286
# 1960 step done... : time_mhd = 13608.07045, dt_mhd = 6.94286
# 1970 step done... : time_mhd = 13677.49906, dt_mhd = 6.94286
# 1980 step done... : time_mhd = 13746.92765, dt_mhd = 6.94286
# 1990 step done... : time_mhd = 13816.35622, dt_mhd = 6.94286
# 2000 step done... : time_mhd = 13885.78477, dt_mhd = 6.94285

# %% [markdown]
# プロット

# %%
k = 500

U = np.load(f"results_MHD_alfven/U1_{k}.npy")
rho_mhd = U[0, :]
u_mhd = U[1, :] / rho_mhd
v_mhd = U[2, :] / rho_mhd
w_mhd = U[3, :] / rho_mhd
Bx_mhd = U[4, :]
By_mhd = U[5, :]
Bz_mhd = U[6, :]
e_mhd = U[7, :]
p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
Ex_mhd = -(v_mhd * Bz_mhd - w_mhd * By_mhd)
Ey_mhd = -(w_mhd * Bx_mhd - u_mhd * Bz_mhd)
Ez_mhd = -(u_mhd * By_mhd - v_mhd * Bx_mhd)
current_x_mhd = np.zeros(Bx_mhd.shape)
current_y_mhd = -(np.roll(Bz_mhd, -1, axis=0) - np.roll(Bz_mhd, 1, axis=0)) / (2*dx_mhd)
current_z_mhd = (np.roll(By_mhd, -1, axis=0) - np.roll(By_mhd, 1, axis=0)) / (2*dx_mhd)
current_y_mhd[0] = current_y_mhd[1] 
current_y_mhd[-1] = current_y_mhd[-2] 
current_z_mhd[0] = current_z_mhd[1] 
current_z_mhd[-1] = current_z_mhd[-2]

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

rho = U[0, :]
u = U[1, :] / rho 
v = U[2, :] / rho 
w = U[3, :] / rho 
Bx = U[4, :]
By = U[5, :]
Bz = U[6, :]
e = U[7, :]
p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)

ax1.plot(x_coordinate_mhd, rho, marker='o', markersize=5)
ax2.plot(x_coordinate_mhd, p, marker='o', markersize=5)
ax3.plot(x_coordinate_mhd, u, marker='o', markersize=5)
ax4.plot(x_coordinate_mhd, v, marker='o', markersize=5)
ax5.plot(x_coordinate_mhd, By, marker='o', markersize=5)
ax6.plot(x_coordinate_mhd, Bz, marker='o', markersize=5)

ax1.set_ylim(0.9 * rho0_mhd, 1.1 * rho0_mhd)
ax2.set_ylim(0.9 * p0_mhd, 1.1 * p0_mhd)
ax3.set_ylim(-0.1 * VA_mhd, 0.1 * VA_mhd)
ax1.set_title(r"$\rho$", fontsize=24)
ax2.set_title(r"$p$", fontsize=24)
ax3.set_title(r"$u$", fontsize=24)
ax4.set_title(r"$v$", fontsize=24)
ax5.set_title(r"$B_y$", fontsize=24)
ax6.set_title(r"$B_z$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax5.tick_params(labelsize=16)
ax6.tick_params(labelsize=16)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

plt.suptitle(f"t = {k}", y=0.95, fontsize=32)

plt.show()

# %% [markdown]
# 動画作成

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

filename = "Alfven_MHD.mp4"

interval = 10
plot_steps = steps
for i in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()
    ax5.clear()
    ax6.clear()

    U = np.load(f"results_MHD_alfven/U1_{i}.npy")
    rho = U[0, :]
    u = U[1, :] / rho 
    v = U[2, :] / rho 
    w = U[3, :] / rho 
    Bx = U[4, :]
    By = U[5, :]
    Bz = U[6, :]
    e = U[7, :]
    p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)
    Ex = -(v * Bz - w * Bx)
    Ey = -(w * Bx - u * Bz)
    Ez = -(u * By - v * Bx)

    ax1.plot(x_coordinate_mhd, rho / rho0_mhd, marker='o', markersize=5)
    ax2.plot(x_coordinate_mhd, By / B0_mhd, marker='o', markersize=5)
    ax3.plot(x_coordinate_mhd, Bz / B0_mhd, marker='o', markersize=5)
    ax4.plot(x_coordinate_mhd, p / p0_mhd, marker='o', markersize=5)
    ax5.plot(x_coordinate_mhd, Ey, marker='o', markersize=5)
    ax6.plot(x_coordinate_mhd, Ez, marker='o', markersize=5)
    

    ax1.set_ylim(0.8, 1.2)
    ax2.set_ylim(-0.2, 0.2)
    ax3.set_ylim(-0.2, 0.2)
    ax4.set_ylim(0.8, 1.2)
    ax5.set_ylim(-0.2, 0.2)
    ax6.set_ylim(-0.2, 0.2)
    

    ax1.set_title(r"$\rho$", fontsize=24)
    ax2.set_title(r"$B_y$", fontsize=24)
    ax3.set_title(r"$B_z$", fontsize=24)
    ax4.set_title(r"$p$", fontsize=24)
    ax5.set_title(r"$E_y$", fontsize=24)
    ax6.set_title(r"$E_z$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax5.tick_params(labelsize=16)
    ax6.tick_params(labelsize=16)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()
    ax5.grid()
    ax6.grid()

    plt.suptitle(f"t = {i}", y=0.95, fontsize=32)

    fig.savefig(f'./pictures/{i}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for i in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{i}.png')
    video.write(img)
video.release()
