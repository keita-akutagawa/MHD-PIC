# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import cv2


import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))

from lib_MHDPIC1D.pic1d import *
from lib_MHDPIC1D.mhd1d import *
from lib_MHDPIC1D.interface import *
from lib_MHDPIC1D.remove_noise import *

# %%
def boundary_U1_and_U2(U1, U2):

    U1[:, -1] = U1[:, -2]
    U1[:, 0] = U2[:, -2] #注意。1グリッドずらす。
    
    U2[:, 0] = U2[:, 1]
    U2[:, -1] = U1[:, 1] #注意。1グリッドずらす。
    
    return U1, U2

# %% [markdown]
# Alfven波の伝搬

# %%
lambda_mhd = 5000.0
kx_mhd = 2.0 * np.pi / lambda_mhd

# %% [markdown]
# PIC初期化

# %%
c = 1.0
mu_0 = 1.0
epsilon0 = 1.0 / (mu_0 * c**2)
m_electron = 1.0
r_m = 1 / 100
m_ion = m_electron / r_m
t_r = 1.0
ne0_pic = 100 #ここは手動で調整すること
ni0_pic = ne0_pic
B0_pic = np.sqrt(ne0_pic) / 1.0
Te_pic = 0.5 * m_electron * (0.05*c)**2
Ti_pic = Te_pic / t_r
q_electron = -1 * np.sqrt(epsilon0 * Te_pic / ne0_pic)
q_ion = -1 * q_electron
debye_length = np.sqrt(epsilon0 * Te_pic / ne0_pic / q_electron**2)
omega_pe = np.sqrt(ne0_pic * q_electron**2 / m_electron / epsilon0)
omega_pi = np.sqrt(ni0_pic * q_ion**2 / m_ion / epsilon0)
omega_ce = q_electron * B0_pic / m_electron
omega_ci = q_ion * B0_pic / m_ion
VA_pic = B0_pic / np.sqrt(mu_0 * ni0_pic * m_ion)
gamma_pic = 5.0 / 3.0
rho_pic = ni0_pic * m_ion + ne0_pic * m_electron
p_pic = ni0_pic * Ti_pic + ne0_pic * Te_pic
CS_pic = np.sqrt(gamma_pic * p_pic / rho_pic)
v_thermal_electron = np.sqrt(2.0 * Te_pic / m_electron)
v_thermal_ion = np.sqrt(2.0 * Ti_pic / m_ion)
ion_inertial_length = c / omega_pi

dx_pic = debye_length
nx_pic = 1000
x_min_pic = 1e-10
x_max_pic = nx_pic * dx_pic - 1e-10
x_coordinate_pic = np.arange(0.0, x_max_pic, dx_pic)
dt_pic = 0.0
d_pic = 0.0

bulk_vx = np.zeros(x_coordinate_pic.shape[0])
bulk_vy = -0.1 * VA_pic * np.cos(kx_mhd * (x_coordinate_pic + 9500 * dx_pic))
bulk_vz = 0.1 * VA_pic * np.sin(kx_mhd * (x_coordinate_pic + 9500 * dx_pic))
E_pic = np.zeros([3, nx_pic])
B_pic = np.zeros([3, nx_pic])
current_pic = np.zeros([3, nx_pic])
rho_pic = np.zeros(nx_pic)
B_pic[0, :] = B0_pic
B_pic[1, :] = 0.1 * B0_pic * np.cos(kx_mhd * (x_coordinate_pic + 9500 * dx_pic))
B_pic[2, :] = -0.1 * B0_pic * np.sin(kx_mhd * (x_coordinate_pic + 9500 * dx_pic))
E_pic[0, :] = bulk_vy * B_pic[2, :] - bulk_vz * B_pic[1, :]
E_pic[1, :] = bulk_vz * B_pic[0, :] - bulk_vx * B_pic[2, :]
E_pic[2, :] = bulk_vx * B_pic[1, :] - bulk_vy * B_pic[0, :]
beta_pic = (ne0_pic * Te_pic + ni0_pic * Ti_pic) / (B0_pic**2 / 2 / mu_0)

n_ion = int(ni0_pic * nx_pic)
n_electron = int(n_ion * abs(q_ion / q_electron))
x_pic_ion = np.zeros([3, n_ion])
x_pic_electron = np.zeros([3, n_electron])
v_pic_ion = np.zeros([3, n_ion])
v_pic_electron = np.zeros([3, n_electron])

rs_ion = np.random.RandomState(10)
rs_electron = np.random.RandomState(20)
for i in range(nx_pic):
    x_pic_ion[0, i * ni0_pic : (i+1) * ni0_pic] = (rs_ion.rand(ni0_pic) + i) * dx_pic
    x_pic_electron[0, i * ne0_pic : (i+1) * ne0_pic] = (rs_electron.rand(ne0_pic) + i) * dx_pic
    
    v_pic_ion[0, i * ni0_pic : (i+1) * ni0_pic] = np.asarray(stats.norm.rvs(bulk_vx[i], v_thermal_ion, size=ni0_pic, random_state=30+(i+1)*nx_pic))
    v_pic_ion[1, i * ni0_pic : (i+1) * ni0_pic] = np.asarray(stats.norm.rvs(bulk_vy[i], v_thermal_ion, size=ni0_pic, random_state=40+(i+1)*nx_pic))
    v_pic_ion[2, i * ni0_pic : (i+1) * ni0_pic] = np.asarray(stats.norm.rvs(bulk_vz[i], v_thermal_ion, size=ni0_pic, random_state=50+(i+1)*nx_pic))
    v_pic_electron[0, i * ne0_pic : (i+1) * ne0_pic] = np.asarray(stats.norm.rvs(bulk_vx[i], v_thermal_electron, size=ne0_pic, random_state=60+(i+1)*nx_pic))
    v_pic_electron[1, i * ne0_pic : (i+1) * ne0_pic] = np.asarray(stats.norm.rvs(bulk_vy[i], v_thermal_electron, size=ne0_pic, random_state=70+(i+1)*nx_pic))
    v_pic_electron[2, i * ne0_pic : (i+1) * ne0_pic] = np.asarray(stats.norm.rvs(bulk_vz[i], v_thermal_electron, size=ne0_pic, random_state=80+(i+1)*nx_pic))

print(f"total number of particles is {n_ion + n_electron}.")
print(f"Box size is {nx_pic}")
print(f"ion inertial length is {ion_inertial_length:.1f}")
# Out:
# total number of particles is 200000.
# Box size is 1000
# ion inertial length is 282.8

# %% [markdown]
# MHD初期化

# %%
gamma_mhd = 5.0 / 3.0
B0_mhd = B0_pic
rho0_mhd = ne0_pic * m_electron + ni0_pic * m_ion
p0_mhd = ne0_pic * Te_pic + ni0_pic * Ti_pic
VA_mhd = B0_mhd / np.sqrt(rho0_mhd)
CS_mhd = np.sqrt(gamma_mhd * p0_mhd / rho0_mhd)
Cf_mhd = np.sqrt(VA_mhd**2 + CS_mhd**2)
dx_mhd = dx_pic

nx_mhd = 9550
x_min_mhd = 1e-10
x_max_mhd = nx_mhd * dx_mhd - 1e-10
dt_mhd = 0.0
CFL = 0.7
x_coordinate_mhd = np.arange(x_min_mhd, x_max_mhd, dx_mhd)

U1 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd
u_init = 0.0
v_init = -0.1 * VA_mhd * np.cos(kx_mhd * x_coordinate_mhd)
w_init = 0.1 * VA_mhd * np.sin(kx_mhd * x_coordinate_mhd)
Bx_init = B0_mhd
By_init = 0.1 * B0_mhd * np.cos(kx_mhd * x_coordinate_mhd)
Bz_init = -0.1 * B0_mhd * np.sin(kx_mhd * x_coordinate_mhd)
p_init = p0_mhd
U1[0, :] = rho_init
U1[1, :] = rho_init * u_init
U1[2, :] = rho_init * v_init
U1[3, :] = rho_init * w_init
U1[4, :] = Bx_init
U1[5, :] = By_init
U1[6, :] = Bz_init
U1[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

U2 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd
u_init = 0.0
v_init = -0.1 * VA_mhd * np.cos(kx_mhd * (x_coordinate_mhd + 10450 * dx_mhd))
w_init = 0.1 * VA_mhd * np.sin(kx_mhd * (x_coordinate_mhd + 10450 * dx_mhd))
Bx_init = B0_mhd
By_init = 0.1 * B0_mhd * np.cos(kx_mhd * (x_coordinate_mhd + 10450 * dx_mhd))
Bz_init = -0.1 * B0_mhd * np.sin(kx_mhd * (x_coordinate_mhd + 10450 * dx_mhd))
p_init = p0_mhd
U2[0, :] = rho_init
U2[1, :] = rho_init * u_init
U2[2, :] = rho_init * v_init
U2[3, :] = rho_init * w_init
U2[4, :] = Bx_init
U2[5, :] = By_init
U2[6, :] = Bz_init
U2[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

flux1 = np.zeros(U1.shape)
flux1_bar = np.zeros(flux1.shape)
flux2 = np.zeros(U2.shape)
flux2_bar = np.zeros(flux2.shape)

print(f"U1 size = {U1.shape}, U2 size = {U2.shape}")
# Out:
# U1 size = (8, 9550), U2 size = (8, 9550)

# %%
plt.plot(x_coordinate_mhd, U1[5, :])
plt.plot(x_coordinate_mhd + 10450, U2[5, :])
plt.plot(x_coordinate_pic + 9500, B_pic[1, :])

# %% [markdown]
# interface用の変数

# %%
window_size_convolution_pic = 10
window_size_smoothing_mhd = 5
interface_width = 50

index_interface_mhd_start_left = nx_mhd - interface_width
index_interface_mhd_end_left = nx_mhd
index_interface_mhd_start_right = 0
index_interface_mhd_end_right = interface_width
index_interface_pic_start_left = 0
index_interface_pic_end_left = interface_width
index_interface_pic_start_right = nx_pic - interface_width
index_interface_pic_end_right = nx_pic

x_interface_coordinate_left = np.arange(0, interface_width, 1)
x_interface_coordinate_half_left = np.arange(0.5, interface_width - 0.5, 1)
F_left = interlocking_function(x_interface_coordinate_left)
F_half_left = interlocking_function(x_interface_coordinate_half_left)
F_right = np.flip(F_left)
F_half_right = np.flip(F_half_left)

# %% [markdown]
# 時間発展

# %%
#STEP1:PICとMHDの時間を合わせる
#以下、t1からt2に時間発展させるとする
#ただし、t2 = t1 + dt_mhdとする
B_pic_time_ave = np.zeros(B_pic.shape)
zeroth_moment_ion_time_ave = np.zeros(nx_pic)
zeroth_moment_electron_time_ave = np.zeros(nx_pic)
first_moment_ion_time_ave = np.zeros([3, nx_pic])
first_moment_electron_time_ave = np.zeros([3, nx_pic])
second_moment_ion_time_ave = np.zeros([9, nx_pic])
second_moment_electron_time_ave = np.zeros([9, nx_pic])

total_substeps = 10

dirname = "results_MS_alfven"
steps = 2000
time_mhd = 0.0
time_pic = 0.0
for step in range(steps+1):

    # save
    if (step % 5 == 0):
        print(f"{step} step done... : time_mhd = {time_mhd:.5f}, time_pic = {time_pic:.5f}, dt_mhd = {dt_mhd:.5f}, dt_pic = {dt_pic:.5f}")

        #np.save(f'./{dirname}/x_ion_{step}.npy', x_pic_ion)
        #np.save(f'./{dirname}/x_electron_{step}.npy', x_pic_electron)
        #np.save(f'./{dirname}/v_ion_{step}.npy', v_pic_ion)
        #np.save(f'./{dirname}/v_electron_{step}.npy', v_pic_electron)
        np.save(f'./{dirname}/E_{step}.npy', E_pic)
        np.save(f'./{dirname}/B_{step}.npy', B_pic)
        np.save(f'./{dirname}/current_{step}.npy', current_pic)
        np.save(f"./{dirname}/U1_{step}.npy", U1)
        np.save(f"./{dirname}/U2_{step}.npy", U2)

        zeroth_moment_ion = np.zeros(nx_pic)
        zeroth_moment_electron = np.zeros(nx_pic)
        zeroth_moment_ion = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion)
        zeroth_moment_electron = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron)
        first_moment_ion = np.zeros([3, nx_pic])
        first_moment_electron = np.zeros([3, nx_pic])
        first_moment_ion = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion)
        first_moment_electron = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron)
        second_moment_ion = np.zeros([9, nx_pic])
        second_moment_electron = np.zeros([9, nx_pic])
        second_moment_ion = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion)
        second_moment_electron = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron)

        np.save(f'./{dirname}/zeroth_moment_ion_{step}.npy', zeroth_moment_ion)
        np.save(f'./{dirname}/zeroth_moment_electron_{step}.npy', zeroth_moment_electron)
        np.save(f'./{dirname}/first_moment_ion_{step}.npy', first_moment_ion)
        np.save(f'./{dirname}/first_moment_electron_{step}.npy', first_moment_electron)
        np.save(f'./{dirname}/second_moment_ion_{step}.npy', second_moment_ion)
        np.save(f'./{dirname}/second_moment_electron_{step}.npy', second_moment_electron)

        np.save(f'./{dirname}/B_time_ave_{step}.npy', B_pic_time_ave)
        np.save(f'./{dirname}/zeroth_moment_ion_time_ave_{step}.npy', zeroth_moment_ion_time_ave)
        np.save(f'./{dirname}/zeroth_moment_electron_time_ave_{step}.npy', zeroth_moment_electron_time_ave)
        np.save(f'./{dirname}/first_moment_ion_time_ave_{step}.npy', first_moment_ion_time_ave)
        np.save(f'./{dirname}/first_moment_electron_time_ave_{step}.npy', first_moment_electron_time_ave)
        np.save(f'./{dirname}/second_moment_ion_time_ave_{step}.npy', second_moment_ion_time_ave)
        np.save(f'./{dirname}/second_moment_electron_time_ave_{step}.npy', second_moment_electron_time_ave)

    #STEP1:MHD-Predictor
    U1_past = U1.copy()
    U2_past = U2.copy()
    #MHD
    #----------------------------------------------------------- 
    if True:
        U1_bar = U1.copy()
        U2_bar = U2.copy()

        dt_mhd_left = get_time_step(U1, gamma_mhd, dx_mhd, CFL)
        dt_mhd_right = get_time_step(U2, gamma_mhd, dx_mhd, CFL)
        dt_mhd = np.min([dt_mhd_left, dt_mhd_right])
        if np.isnan(dt_mhd):
            print(f"{step} steps (t = {time_mhd:.3f}) : Calculation is crashed!")
            break

        flux1 = get_flux_mhd(U1, gamma_mhd, flux1)
        flux2 = get_flux_mhd(U2, gamma_mhd, flux2)
        U1_bar += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2_bar += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1_bar, U2_bar = boundary_U1_and_U2(U1_bar, U2_bar)

        flux1_bar = get_flux_mhd(U1_bar, gamma_mhd, flux1_bar)
        flux2_bar = get_flux_mhd(U2_bar, gamma_mhd, flux2_bar)
        flux1 = 0.5 * (flux1 + flux1_bar)
        flux2 = 0.5 * (flux2 + flux2_bar)
        U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2 += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1, U2 = boundary_U1_and_U2(U1, U2)


    #STEP2:PIC
    B_pic_time_ave = np.zeros(B_pic.shape)
    zeroth_moment_ion_time_ave = np.zeros(zeroth_moment_ion_time_ave.shape)
    zeroth_moment_electron_time_ave = np.zeros(zeroth_moment_electron_time_ave.shape)
    first_moment_ion_time_ave = np.zeros(first_moment_ion_time_ave.shape)
    first_moment_electron_time_ave = np.zeros(first_moment_electron_time_ave.shape)
    second_moment_ion_time_ave = np.zeros(second_moment_ion_time_ave.shape)
    second_moment_electron_time_ave = np.zeros(second_moment_electron_time_ave.shape)
    
    dt_pic = dt_mhd / total_substeps
    for substep in range(total_substeps):

        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic) 
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U1 * (substep + 0.5) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, B_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U2 * (substep + 0.5) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, B_pic
        )
        
        v_pic_ion = time_evolution_v(c, E_pic, B_pic, x_pic_ion, q_ion, m_ion, nx_pic, dx_pic, dt_pic, v_pic_ion)
        v_pic_electron = time_evolution_v(c, E_pic, B_pic, x_pic_electron, q_electron, m_electron, nx_pic, dx_pic, dt_pic, v_pic_electron)
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)

        current_pic = np.zeros(current_pic.shape)
        current_pic = get_current_density(c, q_ion, v_pic_ion, x_pic_ion, nx_pic, dx_pic, current_pic)
        current_pic = get_current_density(c, q_electron, v_pic_electron, x_pic_electron, nx_pic, dx_pic, current_pic)
        current_pic[:, 0] = current_pic[:, 1]
        current_pic[:, -1] = current_pic[:, -2]
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U1 * (substep + 0.5) / total_substeps
        current_pic = send_MHD_to_PICinterface_current(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, dx_mhd, window_size_convolution_pic, current_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U2 * (substep + 0.5) / total_substeps
        current_pic = send_MHD_to_PICinterface_current(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, dx_mhd, window_size_convolution_pic, current_pic
        )
        
        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic)
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, B_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, B_pic
        )
        
        E_pic = time_evolution_E(B_pic, current_pic, c, epsilon0, dx_pic, dt_pic, E_pic)
        E_pic = boundary_E(E_pic)
        rho_pic = np.zeros(rho_pic.shape)
        rho_pic = get_rho(q_ion, x_pic_ion, nx_pic, dx_pic, rho_pic)
        rho_pic = get_rho(q_electron, x_pic_electron, nx_pic, dx_pic, rho_pic)
        rho_pic[0] = rho_pic[1]
        rho_pic[-1] = rho_pic[-2]
        E_pic = filter_E(rho_pic, dx_pic, dt_pic, d_pic, epsilon0, E_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        E_pic = send_MHD_to_PICinterface_E(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, F_half_left, 
            U1_send, window_size_convolution_pic, E_pic
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        E_pic = send_MHD_to_PICinterface_E(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, F_half_right, 
            U2_send, window_size_convolution_pic, E_pic
        )
        
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U1 * (substep + 1.0) / total_substeps
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
            index_interface_mhd_start_left, index_interface_mhd_end_left, 
            index_interface_pic_start_left, index_interface_pic_end_left, 
            F_left, x_min_pic,  
            U1_send, dx_mhd, gamma_mhd, q_electron, 
            m_electron, m_ion, nx_pic, c, window_size_convolution_pic, 
            v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        )
        U2_send = U2_past * (total_substeps - (substep + 1.0)) / total_substeps \
                + U2 * (substep + 1.0) / total_substeps
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
            index_interface_mhd_start_right, index_interface_mhd_end_right, 
            index_interface_pic_start_right, index_interface_pic_end_right, 
            F_right, x_min_pic,  
            U2_send, dx_mhd, gamma_mhd, q_electron, 
            m_electron, m_ion, nx_pic, c, window_size_convolution_pic, 
            v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        )

        time_pic += dt_pic


        # 時間平均のため
        if True:
            B_pic_time_ave += B_pic

            zeroth_moment_ion_tmp = np.zeros(zeroth_moment_ion_time_ave.shape)
            zeroth_moment_electron_tmp = np.zeros(zeroth_moment_electron_time_ave.shape)
            zeroth_moment_ion_tmp = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion_tmp)
            zeroth_moment_electron_tmp = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron_tmp)
            zeroth_moment_ion_time_ave += zeroth_moment_ion_tmp
            zeroth_moment_electron_time_ave += zeroth_moment_electron_tmp

            first_moment_ion_tmp = np.zeros(first_moment_ion_time_ave.shape)
            first_moment_electron_tmp = np.zeros(first_moment_electron_time_ave.shape)
            first_moment_ion_tmp = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion_tmp)
            first_moment_electron_tmp = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron_tmp)
            first_moment_ion_time_ave += first_moment_ion_tmp
            first_moment_electron_time_ave += first_moment_electron_tmp

            second_moment_ion_tmp = np.zeros(second_moment_ion_time_ave.shape)
            second_moment_electron_tmp = np.zeros(second_moment_electron_time_ave.shape)
            second_moment_ion_tmp = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion_tmp)
            second_moment_electron_tmp = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron_tmp)
            second_moment_ion_time_ave += second_moment_ion_tmp
            second_moment_electron_time_ave += second_moment_electron_tmp
            
    B_pic_time_ave /= total_substeps
    zeroth_moment_ion_time_ave /= total_substeps
    zeroth_moment_electron_time_ave /= total_substeps
    first_moment_ion_time_ave /= total_substeps
    first_moment_electron_time_ave /= total_substeps
    second_moment_ion_time_ave /= total_substeps
    second_moment_electron_time_ave /= total_substeps


    #STEP3:MHD-Correcter
    U1_PIC = np.zeros(U1.shape)
    U2_PIC = np.zeros(U2.shape)
    #n+1/2にする
    U1_PIC[:, :] = 0.5 * (U1_past[:, :] + U1[:, :])
    U2_PIC[:, :] = 0.5 * (U2_past[:, :] + U2[:, :])
    U1_PIC = send_PIC_to_MHDinterface(
        index_interface_mhd_start_left, index_interface_mhd_end_left, 
        index_interface_pic_start_left, index_interface_pic_end_left, 
        F_left, 
        gamma_mhd, m_electron, m_ion, nx_pic, B_pic_time_ave, 
        zeroth_moment_ion_time_ave, zeroth_moment_electron_time_ave, 
        first_moment_ion_time_ave, first_moment_electron_time_ave, 
        second_moment_ion_time_ave, second_moment_electron_time_ave, 
        window_size_convolution_pic, U1_PIC
    )
    U2_PIC = send_PIC_to_MHDinterface(
        index_interface_mhd_start_right, index_interface_mhd_end_right, 
        index_interface_pic_start_right, index_interface_pic_end_right, 
        F_right, 
        gamma_mhd, m_electron, m_ion, nx_pic, B_pic_time_ave, 
        zeroth_moment_ion_time_ave, zeroth_moment_electron_time_ave, 
        first_moment_ion_time_ave, first_moment_electron_time_ave, 
        second_moment_ion_time_ave, second_moment_electron_time_ave, 
        window_size_convolution_pic, U2_PIC
    )

    if True:
        U1 = U1_past.copy()
        U2 = U2_past.copy()
    
        flux1 = get_flux_mhd(U1_PIC, gamma_mhd, flux1)
        flux2 = get_flux_mhd(U2_PIC, gamma_mhd, flux2)
        U1 += -dt_mhd/dx_mhd * (flux1 - np.roll(flux1, 1, axis=1))
        U2 += -dt_mhd/dx_mhd * (flux2 - np.roll(flux2, 1, axis=1))
        U1, U2 = boundary_U1_and_U2(U1, U2)
        
        time_mhd += dt_mhd


    #interface領域のスムージング処理
    U1 = smoothing_U_left(
        U1, index_interface_mhd_start_left, index_interface_mhd_end_left, 
        window_size_smoothing_mhd
    )
    U2 = smoothing_U_right(
        U2, index_interface_mhd_start_right, index_interface_mhd_end_right, 
        window_size_smoothing_mhd
    )
# Out:
# 0 step done... : time_mhd = 0.00000, time_pic = 0.00000, dt_mhd = 0.00000, dt_pic = 0.00000
# 5 step done... : time_mhd = 34.89972, time_pic = 34.89972, dt_mhd = 6.97500, dt_pic = 0.69750
# 10 step done... : time_mhd = 69.74199, time_pic = 69.74199, dt_mhd = 6.96388, dt_pic = 0.69639
# 15 step done... : time_mhd = 104.54513, time_pic = 104.54513, dt_mhd = 6.96181, dt_pic = 0.69618
# 20 step done... : time_mhd = 139.36037, time_pic = 139.36037, dt_mhd = 6.96557, dt_pic = 0.69656
# 25 step done... : time_mhd = 174.20141, time_pic = 174.20141, dt_mhd = 6.96794, dt_pic = 0.69679
# 30 step done... : time_mhd = 209.01917, time_pic = 209.01917, dt_mhd = 6.95893, dt_pic = 0.69589
# 35 step done... : time_mhd = 243.77920, time_pic = 243.77920, dt_mhd = 6.94785, dt_pic = 0.69479
# 40 step done... : time_mhd = 278.50137, time_pic = 278.50137, dt_mhd = 6.94115, dt_pic = 0.69411
# 45 step done... : time_mhd = 313.15840, time_pic = 313.15840, dt_mhd = 6.92707, dt_pic = 0.69271
# 50 step done... : time_mhd = 347.79403, time_pic = 347.79403, dt_mhd = 6.93020, dt_pic = 0.69302
# 55 step done... : time_mhd = 382.44931, time_pic = 382.44931, dt_mhd = 6.93282, dt_pic = 0.69328
# 60 step done... : time_mhd = 417.13894, time_pic = 417.13894, dt_mhd = 6.93999, dt_pic = 0.69400
# 65 step done... : time_mhd = 451.84240, time_pic = 451.84240, dt_mhd = 6.94067, dt_pic = 0.69407
# 70 step done... : time_mhd = 486.53922, time_pic = 486.53922, dt_mhd = 6.93844, dt_pic = 0.69384
# 75 step done... : time_mhd = 521.23754, time_pic = 521.23754, dt_mhd = 6.94016, dt_pic = 0.69402
# 80 step done... : time_mhd = 555.94198, time_pic = 555.94198, dt_mhd = 6.94125, dt_pic = 0.69412
# 85 step done... : time_mhd = 590.64624, time_pic = 590.64624, dt_mhd = 6.94070, dt_pic = 0.69407
# 90 step done... : time_mhd = 625.34844, time_pic = 625.34844, dt_mhd = 6.94154, dt_pic = 0.69415
# 95 step done... : time_mhd = 660.05900, time_pic = 660.05900, dt_mhd = 6.94158, dt_pic = 0.69416
# 100 step done... : time_mhd = 694.76637, time_pic = 694.76637, dt_mhd = 6.94131, dt_pic = 0.69413
# 105 step done... : time_mhd = 729.47387, time_pic = 729.47387, dt_mhd = 6.94161, dt_pic = 0.69416
# 110 step done... : time_mhd = 764.17524, time_pic = 764.17524, dt_mhd = 6.94001, dt_pic = 0.69400
# 115 step done... : time_mhd = 798.86848, time_pic = 798.86848, dt_mhd = 6.93780, dt_pic = 0.69378
# 120 step done... : time_mhd = 833.55153, time_pic = 833.55153, dt_mhd = 6.93563, dt_pic = 0.69356
# 125 step done... : time_mhd = 868.22051, time_pic = 868.22051, dt_mhd = 6.93357, dt_pic = 0.69336
# 130 step done... : time_mhd = 902.88149, time_pic = 902.88149, dt_mhd = 6.93131, dt_pic = 0.69313
# 135 step done... : time_mhd = 937.53485, time_pic = 937.53485, dt_mhd = 6.93106, dt_pic = 0.69311
# 140 step done... : time_mhd = 972.19959, time_pic = 972.19959, dt_mhd = 6.93394, dt_pic = 0.69339
# 145 step done... : time_mhd = 1006.87644, time_pic = 1006.87644, dt_mhd = 6.93621, dt_pic = 0.69362
# 150 step done... : time_mhd = 1041.55369, time_pic = 1041.55369, dt_mhd = 6.93603, dt_pic = 0.69360
# 155 step done... : time_mhd = 1076.23764, time_pic = 1076.23764, dt_mhd = 6.93794, dt_pic = 0.69379
# 160 step done... : time_mhd = 1110.91876, time_pic = 1110.91876, dt_mhd = 6.93339, dt_pic = 0.69334
# 165 step done... : time_mhd = 1145.57055, time_pic = 1145.57055, dt_mhd = 6.92799, dt_pic = 0.69280
# 170 step done... : time_mhd = 1180.18973, time_pic = 1180.18973, dt_mhd = 6.92181, dt_pic = 0.69218
# 175 step done... : time_mhd = 1214.77874, time_pic = 1214.77874, dt_mhd = 6.91483, dt_pic = 0.69148
# 180 step done... : time_mhd = 1249.35233, time_pic = 1249.35233, dt_mhd = 6.91578, dt_pic = 0.69158
# 185 step done... : time_mhd = 1283.93860, time_pic = 1283.93860, dt_mhd = 6.91788, dt_pic = 0.69179
# 190 step done... : time_mhd = 1318.53781, time_pic = 1318.53781, dt_mhd = 6.92102, dt_pic = 0.69210
# 195 step done... : time_mhd = 1353.14724, time_pic = 1353.14724, dt_mhd = 6.92152, dt_pic = 0.69215
# 200 step done... : time_mhd = 1387.75487, time_pic = 1387.75487, dt_mhd = 6.92134, dt_pic = 0.69213
# 205 step done... : time_mhd = 1422.37834, time_pic = 1422.37834, dt_mhd = 6.92814, dt_pic = 0.69281
# 210 step done... : time_mhd = 1457.01789, time_pic = 1457.01789, dt_mhd = 6.92629, dt_pic = 0.69263
# 215 step done... : time_mhd = 1491.64132, time_pic = 1491.64132, dt_mhd = 6.92403, dt_pic = 0.69240
# 220 step done... : time_mhd = 1526.25923, time_pic = 1526.25923, dt_mhd = 6.92296, dt_pic = 0.69230
# 225 step done... : time_mhd = 1560.86729, time_pic = 1560.86729, dt_mhd = 6.92166, dt_pic = 0.69217
# 230 step done... : time_mhd = 1595.47281, time_pic = 1595.47281, dt_mhd = 6.92108, dt_pic = 0.69211
# 235 step done... : time_mhd = 1630.08270, time_pic = 1630.08270, dt_mhd = 6.92421, dt_pic = 0.69242
# 240 step done... : time_mhd = 1664.71172, time_pic = 1664.71172, dt_mhd = 6.92457, dt_pic = 0.69246
# 245 step done... : time_mhd = 1699.32975, time_pic = 1699.32975, dt_mhd = 6.92357, dt_pic = 0.69236
# 250 step done... : time_mhd = 1733.92601, time_pic = 1733.92601, dt_mhd = 6.91697, dt_pic = 0.69170
# 255 step done... : time_mhd = 1768.49689, time_pic = 1768.49689, dt_mhd = 6.91229, dt_pic = 0.69123
# 260 step done... : time_mhd = 1803.05399, time_pic = 1803.05399, dt_mhd = 6.91095, dt_pic = 0.69109
# 265 step done... : time_mhd = 1837.60914, time_pic = 1837.60914, dt_mhd = 6.91248, dt_pic = 0.69125
# 270 step done... : time_mhd = 1872.16557, time_pic = 1872.16557, dt_mhd = 6.90891, dt_pic = 0.69089
# 275 step done... : time_mhd = 1906.69284, time_pic = 1906.69284, dt_mhd = 6.90415, dt_pic = 0.69041
# 280 step done... : time_mhd = 1941.19775, time_pic = 1941.19775, dt_mhd = 6.89845, dt_pic = 0.68984
# 285 step done... : time_mhd = 1975.68724, time_pic = 1975.68724, dt_mhd = 6.89594, dt_pic = 0.68959
# 290 step done... : time_mhd = 2010.16382, time_pic = 2010.16382, dt_mhd = 6.89585, dt_pic = 0.68959
# 295 step done... : time_mhd = 2044.63745, time_pic = 2044.63745, dt_mhd = 6.89264, dt_pic = 0.68926
# 300 step done... : time_mhd = 2079.10323, time_pic = 2079.10323, dt_mhd = 6.89273, dt_pic = 0.68927
# 305 step done... : time_mhd = 2113.56767, time_pic = 2113.56767, dt_mhd = 6.89283, dt_pic = 0.68928
# 310 step done... : time_mhd = 2148.01869, time_pic = 2148.01869, dt_mhd = 6.88750, dt_pic = 0.68875
# 315 step done... : time_mhd = 2182.43676, time_pic = 2182.43676, dt_mhd = 6.88131, dt_pic = 0.68813
# 320 step done... : time_mhd = 2216.82582, time_pic = 2216.82582, dt_mhd = 6.87552, dt_pic = 0.68755
# 325 step done... : time_mhd = 2251.17990, time_pic = 2251.17990, dt_mhd = 6.86814, dt_pic = 0.68681
# 330 step done... : time_mhd = 2285.51080, time_pic = 2285.51080, dt_mhd = 6.86590, dt_pic = 0.68659
# 335 step done... : time_mhd = 2319.83425, time_pic = 2319.83425, dt_mhd = 6.86315, dt_pic = 0.68631
# 340 step done... : time_mhd = 2354.14699, time_pic = 2354.14699, dt_mhd = 6.86205, dt_pic = 0.68620
# 345 step done... : time_mhd = 2388.44412, time_pic = 2388.44412, dt_mhd = 6.85943, dt_pic = 0.68594
# 350 step done... : time_mhd = 2422.74726, time_pic = 2422.74726, dt_mhd = 6.86130, dt_pic = 0.68613
# 355 step done... : time_mhd = 2457.07603, time_pic = 2457.07603, dt_mhd = 6.86888, dt_pic = 0.68689
# 360 step done... : time_mhd = 2491.42944, time_pic = 2491.42944, dt_mhd = 6.87134, dt_pic = 0.68713
# 365 step done... : time_mhd = 2525.77197, time_pic = 2525.77197, dt_mhd = 6.86646, dt_pic = 0.68665
# 370 step done... : time_mhd = 2560.09328, time_pic = 2560.09328, dt_mhd = 6.86268, dt_pic = 0.68627
# 375 step done... : time_mhd = 2594.39911, time_pic = 2594.39911, dt_mhd = 6.86070, dt_pic = 0.68607
# 380 step done... : time_mhd = 2628.70495, time_pic = 2628.70495, dt_mhd = 6.86098, dt_pic = 0.68610
# 385 step done... : time_mhd = 2663.01973, time_pic = 2663.01973, dt_mhd = 6.86483, dt_pic = 0.68648
# 390 step done... : time_mhd = 2697.36073, time_pic = 2697.36073, dt_mhd = 6.87026, dt_pic = 0.68703
# 395 step done... : time_mhd = 2731.71879, time_pic = 2731.71879, dt_mhd = 6.87196, dt_pic = 0.68720
# 400 step done... : time_mhd = 2766.06187, time_pic = 2766.06187, dt_mhd = 6.86576, dt_pic = 0.68658
# 405 step done... : time_mhd = 2800.37616, time_pic = 2800.37616, dt_mhd = 6.86240, dt_pic = 0.68624
# 410 step done... : time_mhd = 2834.69027, time_pic = 2834.69027, dt_mhd = 6.86201, dt_pic = 0.68620
# 415 step done... : time_mhd = 2868.99869, time_pic = 2868.99869, dt_mhd = 6.86165, dt_pic = 0.68616
# 420 step done... : time_mhd = 2903.30344, time_pic = 2903.30344, dt_mhd = 6.86010, dt_pic = 0.68601
# 425 step done... : time_mhd = 2937.59986, time_pic = 2937.59986, dt_mhd = 6.85880, dt_pic = 0.68588
# 430 step done... : time_mhd = 2971.89662, time_pic = 2971.89662, dt_mhd = 6.85898, dt_pic = 0.68590
# 435 step done... : time_mhd = 3006.18810, time_pic = 3006.18810, dt_mhd = 6.85724, dt_pic = 0.68572
# 440 step done... : time_mhd = 3040.47858, time_pic = 3040.47858, dt_mhd = 6.85824, dt_pic = 0.68582
# 445 step done... : time_mhd = 3074.77360, time_pic = 3074.77360, dt_mhd = 6.85945, dt_pic = 0.68594
# 450 step done... : time_mhd = 3109.06398, time_pic = 3109.06398, dt_mhd = 6.85652, dt_pic = 0.68565
# 455 step done... : time_mhd = 3143.34304, time_pic = 3143.34304, dt_mhd = 6.85341, dt_pic = 0.68534
# 460 step done... : time_mhd = 3177.60556, time_pic = 3177.60556, dt_mhd = 6.85339, dt_pic = 0.68534
# 465 step done... : time_mhd = 3211.87086, time_pic = 3211.87086, dt_mhd = 6.85348, dt_pic = 0.68535
# 470 step done... : time_mhd = 3246.13418, time_pic = 3246.13418, dt_mhd = 6.85019, dt_pic = 0.68502
# 475 step done... : time_mhd = 3280.35996, time_pic = 3280.35996, dt_mhd = 6.84284, dt_pic = 0.68428
# 480 step done... : time_mhd = 3314.57668, time_pic = 3314.57668, dt_mhd = 6.84333, dt_pic = 0.68433
# 485 step done... : time_mhd = 3348.77587, time_pic = 3348.77587, dt_mhd = 6.83746, dt_pic = 0.68375
# 490 step done... : time_mhd = 3382.94484, time_pic = 3382.94484, dt_mhd = 6.83140, dt_pic = 0.68314
# 495 step done... : time_mhd = 3417.09384, time_pic = 3417.09384, dt_mhd = 6.82882, dt_pic = 0.68288
# 500 step done... : time_mhd = 3451.22101, time_pic = 3451.22101, dt_mhd = 6.82237, dt_pic = 0.68224
# 505 step done... : time_mhd = 3485.31190, time_pic = 3485.31190, dt_mhd = 6.81545, dt_pic = 0.68155
# 510 step done... : time_mhd = 3519.36835, time_pic = 3519.36835, dt_mhd = 6.81042, dt_pic = 0.68104
# 515 step done... : time_mhd = 3553.41250, time_pic = 3553.41250, dt_mhd = 6.80727, dt_pic = 0.68073
# 520 step done... : time_mhd = 3587.44279, time_pic = 3587.44279, dt_mhd = 6.80592, dt_pic = 0.68059
# 525 step done... : time_mhd = 3621.47734, time_pic = 3621.47734, dt_mhd = 6.80860, dt_pic = 0.68086
# 530 step done... : time_mhd = 3655.53148, time_pic = 3655.53148, dt_mhd = 6.81185, dt_pic = 0.68118
# 535 step done... : time_mhd = 3689.59397, time_pic = 3689.59397, dt_mhd = 6.81380, dt_pic = 0.68138
# 540 step done... : time_mhd = 3723.66458, time_pic = 3723.66458, dt_mhd = 6.81364, dt_pic = 0.68136
# 545 step done... : time_mhd = 3757.72861, time_pic = 3757.72861, dt_mhd = 6.81260, dt_pic = 0.68126
# 550 step done... : time_mhd = 3791.79134, time_pic = 3791.79134, dt_mhd = 6.81223, dt_pic = 0.68122
# 555 step done... : time_mhd = 3825.84525, time_pic = 3825.84525, dt_mhd = 6.81128, dt_pic = 0.68113
# 560 step done... : time_mhd = 3859.91254, time_pic = 3859.91254, dt_mhd = 6.81480, dt_pic = 0.68148
# 565 step done... : time_mhd = 3893.99371, time_pic = 3893.99371, dt_mhd = 6.81638, dt_pic = 0.68164
# 570 step done... : time_mhd = 3928.06351, time_pic = 3928.06351, dt_mhd = 6.81335, dt_pic = 0.68134
# 575 step done... : time_mhd = 3962.11935, time_pic = 3962.11935, dt_mhd = 6.81015, dt_pic = 0.68102
# 580 step done... : time_mhd = 3996.14836, time_pic = 3996.14836, dt_mhd = 6.80218, dt_pic = 0.68022
# 585 step done... : time_mhd = 4030.15817, time_pic = 4030.15817, dt_mhd = 6.80277, dt_pic = 0.68028
# 590 step done... : time_mhd = 4064.17942, time_pic = 4064.17942, dt_mhd = 6.80530, dt_pic = 0.68053
# 595 step done... : time_mhd = 4098.22849, time_pic = 4098.22849, dt_mhd = 6.81250, dt_pic = 0.68125
# 600 step done... : time_mhd = 4132.30420, time_pic = 4132.30420, dt_mhd = 6.81810, dt_pic = 0.68181
# 605 step done... : time_mhd = 4166.40368, time_pic = 4166.40368, dt_mhd = 6.81891, dt_pic = 0.68189
# 610 step done... : time_mhd = 4200.50585, time_pic = 4200.50585, dt_mhd = 6.82102, dt_pic = 0.68210
# 615 step done... : time_mhd = 4234.61309, time_pic = 4234.61309, dt_mhd = 6.82161, dt_pic = 0.68216
# 620 step done... : time_mhd = 4268.72190, time_pic = 4268.72190, dt_mhd = 6.82092, dt_pic = 0.68209
# 625 step done... : time_mhd = 4302.82663, time_pic = 4302.82663, dt_mhd = 6.82033, dt_pic = 0.68203
# 630 step done... : time_mhd = 4336.90931, time_pic = 4336.90931, dt_mhd = 6.81318, dt_pic = 0.68132
# 635 step done... : time_mhd = 4370.94800, time_pic = 4370.94800, dt_mhd = 6.80539, dt_pic = 0.68054
# 640 step done... : time_mhd = 4404.96015, time_pic = 4404.96015, dt_mhd = 6.80034, dt_pic = 0.68003
# 645 step done... : time_mhd = 4438.97121, time_pic = 4438.97121, dt_mhd = 6.80519, dt_pic = 0.68052
# 650 step done... : time_mhd = 4473.01979, time_pic = 4473.01979, dt_mhd = 6.81105, dt_pic = 0.68111
# 655 step done... : time_mhd = 4507.08153, time_pic = 4507.08153, dt_mhd = 6.81246, dt_pic = 0.68125
# 660 step done... : time_mhd = 4541.13113, time_pic = 4541.13113, dt_mhd = 6.80721, dt_pic = 0.68072
# 665 step done... : time_mhd = 4575.16066, time_pic = 4575.16066, dt_mhd = 6.80338, dt_pic = 0.68034
# 670 step done... : time_mhd = 4609.17573, time_pic = 4609.17573, dt_mhd = 6.80308, dt_pic = 0.68031
# 675 step done... : time_mhd = 4643.16165, time_pic = 4643.16165, dt_mhd = 6.79378, dt_pic = 0.67938
# 680 step done... : time_mhd = 4677.13279, time_pic = 4677.13279, dt_mhd = 6.79620, dt_pic = 0.67962
# 685 step done... : time_mhd = 4711.13450, time_pic = 4711.13450, dt_mhd = 6.80314, dt_pic = 0.68031
# 690 step done... : time_mhd = 4745.17104, time_pic = 4745.17104, dt_mhd = 6.80989, dt_pic = 0.68099
# 695 step done... : time_mhd = 4779.23316, time_pic = 4779.23316, dt_mhd = 6.81224, dt_pic = 0.68122
# 700 step done... : time_mhd = 4813.28445, time_pic = 4813.28445, dt_mhd = 6.80948, dt_pic = 0.68095
# 705 step done... : time_mhd = 4847.32642, time_pic = 4847.32642, dt_mhd = 6.80747, dt_pic = 0.68075
# 710 step done... : time_mhd = 4881.35930, time_pic = 4881.35930, dt_mhd = 6.80586, dt_pic = 0.68059
# 715 step done... : time_mhd = 4915.37431, time_pic = 4915.37431, dt_mhd = 6.80096, dt_pic = 0.68010
# 720 step done... : time_mhd = 4949.37594, time_pic = 4949.37594, dt_mhd = 6.80112, dt_pic = 0.68011
# 725 step done... : time_mhd = 4983.39895, time_pic = 4983.39895, dt_mhd = 6.80482, dt_pic = 0.68048
# 730 step done... : time_mhd = 5017.42240, time_pic = 5017.42240, dt_mhd = 6.80566, dt_pic = 0.68057
# 735 step done... : time_mhd = 5051.45821, time_pic = 5051.45821, dt_mhd = 6.80706, dt_pic = 0.68071
# 740 step done... : time_mhd = 5085.49469, time_pic = 5085.49469, dt_mhd = 6.80652, dt_pic = 0.68065
# 745 step done... : time_mhd = 5119.52901, time_pic = 5119.52901, dt_mhd = 6.80697, dt_pic = 0.68070
# 750 step done... : time_mhd = 5153.57102, time_pic = 5153.57102, dt_mhd = 6.81069, dt_pic = 0.68107
# 755 step done... : time_mhd = 5187.62351, time_pic = 5187.62351, dt_mhd = 6.81034, dt_pic = 0.68103
# 760 step done... : time_mhd = 5221.69032, time_pic = 5221.69032, dt_mhd = 6.81539, dt_pic = 0.68154
# 765 step done... : time_mhd = 5255.76885, time_pic = 5255.76885, dt_mhd = 6.81678, dt_pic = 0.68168
# 770 step done... : time_mhd = 5289.87095, time_pic = 5289.87095, dt_mhd = 6.82273, dt_pic = 0.68227
# 775 step done... : time_mhd = 5323.98877, time_pic = 5323.98877, dt_mhd = 6.82333, dt_pic = 0.68233
# 780 step done... : time_mhd = 5358.09632, time_pic = 5358.09632, dt_mhd = 6.82088, dt_pic = 0.68209
# 785 step done... : time_mhd = 5392.18775, time_pic = 5392.18775, dt_mhd = 6.81657, dt_pic = 0.68166
# 790 step done... : time_mhd = 5426.26865, time_pic = 5426.26865, dt_mhd = 6.81655, dt_pic = 0.68165
# 795 step done... : time_mhd = 5460.35686, time_pic = 5460.35686, dt_mhd = 6.81945, dt_pic = 0.68194
# 800 step done... : time_mhd = 5494.46129, time_pic = 5494.46129, dt_mhd = 6.82156, dt_pic = 0.68216
# 805 step done... : time_mhd = 5528.57153, time_pic = 5528.57153, dt_mhd = 6.82107, dt_pic = 0.68211
# 810 step done... : time_mhd = 5562.66992, time_pic = 5562.66992, dt_mhd = 6.81992, dt_pic = 0.68199
# 815 step done... : time_mhd = 5596.78704, time_pic = 5596.78704, dt_mhd = 6.82672, dt_pic = 0.68267
# 820 step done... : time_mhd = 5630.91320, time_pic = 5630.91320, dt_mhd = 6.82523, dt_pic = 0.68252
# 825 step done... : time_mhd = 5665.04541, time_pic = 5665.04541, dt_mhd = 6.82785, dt_pic = 0.68279
# 830 step done... : time_mhd = 5699.18108, time_pic = 5699.18108, dt_mhd = 6.82667, dt_pic = 0.68267
# 835 step done... : time_mhd = 5733.30900, time_pic = 5733.30900, dt_mhd = 6.82406, dt_pic = 0.68241
# 840 step done... : time_mhd = 5767.42142, time_pic = 5767.42142, dt_mhd = 6.82263, dt_pic = 0.68226
# 845 step done... : time_mhd = 5801.53066, time_pic = 5801.53066, dt_mhd = 6.82191, dt_pic = 0.68219
# 850 step done... : time_mhd = 5835.64169, time_pic = 5835.64169, dt_mhd = 6.82250, dt_pic = 0.68225
# 855 step done... : time_mhd = 5869.75518, time_pic = 5869.75518, dt_mhd = 6.82256, dt_pic = 0.68226
# 860 step done... : time_mhd = 5903.86691, time_pic = 5903.86691, dt_mhd = 6.82271, dt_pic = 0.68227
# 865 step done... : time_mhd = 5937.98228, time_pic = 5937.98228, dt_mhd = 6.82172, dt_pic = 0.68217
# 870 step done... : time_mhd = 5972.07665, time_pic = 5972.07665, dt_mhd = 6.81636, dt_pic = 0.68164
# 875 step done... : time_mhd = 6006.14773, time_pic = 6006.14773, dt_mhd = 6.81407, dt_pic = 0.68141
# 880 step done... : time_mhd = 6040.23363, time_pic = 6040.23363, dt_mhd = 6.81958, dt_pic = 0.68196
# 885 step done... : time_mhd = 6074.34431, time_pic = 6074.34431, dt_mhd = 6.82203, dt_pic = 0.68220
# 890 step done... : time_mhd = 6108.44247, time_pic = 6108.44247, dt_mhd = 6.81719, dt_pic = 0.68172
# 895 step done... : time_mhd = 6142.50958, time_pic = 6142.50958, dt_mhd = 6.81170, dt_pic = 0.68117
# 900 step done... : time_mhd = 6176.56987, time_pic = 6176.56987, dt_mhd = 6.81310, dt_pic = 0.68131
# 905 step done... : time_mhd = 6210.63214, time_pic = 6210.63214, dt_mhd = 6.81123, dt_pic = 0.68112
# 910 step done... : time_mhd = 6244.67030, time_pic = 6244.67030, dt_mhd = 6.80603, dt_pic = 0.68060
# 915 step done... : time_mhd = 6278.70540, time_pic = 6278.70540, dt_mhd = 6.80740, dt_pic = 0.68074
# 920 step done... : time_mhd = 6312.75351, time_pic = 6312.75351, dt_mhd = 6.81042, dt_pic = 0.68104
# 925 step done... : time_mhd = 6346.80114, time_pic = 6346.80114, dt_mhd = 6.80865, dt_pic = 0.68086
# 930 step done... : time_mhd = 6380.84864, time_pic = 6380.84864, dt_mhd = 6.81073, dt_pic = 0.68107
# 935 step done... : time_mhd = 6414.89587, time_pic = 6414.89587, dt_mhd = 6.80914, dt_pic = 0.68091
# 940 step done... : time_mhd = 6448.93579, time_pic = 6448.93579, dt_mhd = 6.80722, dt_pic = 0.68072
# 945 step done... : time_mhd = 6482.95934, time_pic = 6482.95934, dt_mhd = 6.80339, dt_pic = 0.68034
# 950 step done... : time_mhd = 6516.96978, time_pic = 6516.96978, dt_mhd = 6.80002, dt_pic = 0.68000
# 955 step done... : time_mhd = 6550.95980, time_pic = 6550.95980, dt_mhd = 6.79692, dt_pic = 0.67969
# 960 step done... : time_mhd = 6584.93922, time_pic = 6584.93922, dt_mhd = 6.79469, dt_pic = 0.67947
# 965 step done... : time_mhd = 6618.90525, time_pic = 6618.90525, dt_mhd = 6.79134, dt_pic = 0.67913
# 970 step done... : time_mhd = 6652.86091, time_pic = 6652.86091, dt_mhd = 6.79194, dt_pic = 0.67919
# 975 step done... : time_mhd = 6686.81782, time_pic = 6686.81782, dt_mhd = 6.79033, dt_pic = 0.67903
# 980 step done... : time_mhd = 6720.75343, time_pic = 6720.75343, dt_mhd = 6.78416, dt_pic = 0.67842
# 985 step done... : time_mhd = 6754.65040, time_pic = 6754.65040, dt_mhd = 6.77669, dt_pic = 0.67767
# 990 step done... : time_mhd = 6788.52988, time_pic = 6788.52988, dt_mhd = 6.77556, dt_pic = 0.67756
# 995 step done... : time_mhd = 6822.39977, time_pic = 6822.39977, dt_mhd = 6.77214, dt_pic = 0.67721
# 1000 step done... : time_mhd = 6856.25496, time_pic = 6856.25496, dt_mhd = 6.77138, dt_pic = 0.67714
# 1005 step done... : time_mhd = 6890.11738, time_pic = 6890.11738, dt_mhd = 6.77279, dt_pic = 0.67728
# 1010 step done... : time_mhd = 6923.96482, time_pic = 6923.96482, dt_mhd = 6.76538, dt_pic = 0.67654
# 1015 step done... : time_mhd = 6957.75288, time_pic = 6957.75288, dt_mhd = 6.75292, dt_pic = 0.67529
# 1020 step done... : time_mhd = 6991.49867, time_pic = 6991.49867, dt_mhd = 6.74702, dt_pic = 0.67470
# 1025 step done... : time_mhd = 7025.21903, time_pic = 7025.21903, dt_mhd = 6.74214, dt_pic = 0.67421
# 1030 step done... : time_mhd = 7058.92718, time_pic = 7058.92718, dt_mhd = 6.74179, dt_pic = 0.67418
# 1035 step done... : time_mhd = 7092.64392, time_pic = 7092.64392, dt_mhd = 6.74559, dt_pic = 0.67456
# 1040 step done... : time_mhd = 7126.38212, time_pic = 7126.38212, dt_mhd = 6.74934, dt_pic = 0.67493
# 1045 step done... : time_mhd = 7160.14310, time_pic = 7160.14310, dt_mhd = 6.75299, dt_pic = 0.67530
# 1050 step done... : time_mhd = 7193.93038, time_pic = 7193.93038, dt_mhd = 6.76057, dt_pic = 0.67606
# 1055 step done... : time_mhd = 7227.74962, time_pic = 7227.74962, dt_mhd = 6.76734, dt_pic = 0.67673
# 1060 step done... : time_mhd = 7261.60686, time_pic = 7261.60686, dt_mhd = 6.77354, dt_pic = 0.67735
# 1065 step done... : time_mhd = 7295.48186, time_pic = 7295.48186, dt_mhd = 6.77498, dt_pic = 0.67750
# 1070 step done... : time_mhd = 7329.35675, time_pic = 7329.35675, dt_mhd = 6.77541, dt_pic = 0.67754
# 1075 step done... : time_mhd = 7363.24961, time_pic = 7363.24961, dt_mhd = 6.78031, dt_pic = 0.67803
# 1080 step done... : time_mhd = 7397.15206, time_pic = 7397.15206, dt_mhd = 6.78139, dt_pic = 0.67814
# 1085 step done... : time_mhd = 7431.05638, time_pic = 7431.05638, dt_mhd = 6.78022, dt_pic = 0.67802
# 1090 step done... : time_mhd = 7464.96228, time_pic = 7464.96228, dt_mhd = 6.78205, dt_pic = 0.67821
# 1095 step done... : time_mhd = 7498.87295, time_pic = 7498.87295, dt_mhd = 6.78108, dt_pic = 0.67811
# 1100 step done... : time_mhd = 7532.76376, time_pic = 7532.76376, dt_mhd = 6.77652, dt_pic = 0.67765
# 1105 step done... : time_mhd = 7566.63746, time_pic = 7566.63746, dt_mhd = 6.77505, dt_pic = 0.67750
# 1110 step done... : time_mhd = 7600.52197, time_pic = 7600.52197, dt_mhd = 6.77747, dt_pic = 0.67775
# 1115 step done... : time_mhd = 7634.39837, time_pic = 7634.39837, dt_mhd = 6.77441, dt_pic = 0.67744
# 1120 step done... : time_mhd = 7668.26697, time_pic = 7668.26697, dt_mhd = 6.77271, dt_pic = 0.67727
# 1125 step done... : time_mhd = 7702.13070, time_pic = 7702.13070, dt_mhd = 6.77178, dt_pic = 0.67718
# 1130 step done... : time_mhd = 7735.99883, time_pic = 7735.99883, dt_mhd = 6.77471, dt_pic = 0.67747
# 1135 step done... : time_mhd = 7769.87093, time_pic = 7769.87093, dt_mhd = 6.77376, dt_pic = 0.67738
# 1140 step done... : time_mhd = 7803.72643, time_pic = 7803.72643, dt_mhd = 6.77002, dt_pic = 0.67700
# 1145 step done... : time_mhd = 7837.57357, time_pic = 7837.57357, dt_mhd = 6.76846, dt_pic = 0.67685
# 1150 step done... : time_mhd = 7871.41215, time_pic = 7871.41215, dt_mhd = 6.76670, dt_pic = 0.67667
# 1155 step done... : time_mhd = 7905.21842, time_pic = 7905.21842, dt_mhd = 6.75860, dt_pic = 0.67586
# 1160 step done... : time_mhd = 7939.00950, time_pic = 7939.00950, dt_mhd = 6.75855, dt_pic = 0.67586
# 1165 step done... : time_mhd = 7972.80996, time_pic = 7972.80996, dt_mhd = 6.76191, dt_pic = 0.67619
# 1170 step done... : time_mhd = 8006.63296, time_pic = 8006.63296, dt_mhd = 6.76603, dt_pic = 0.67660
# 1175 step done... : time_mhd = 8040.47745, time_pic = 8040.47745, dt_mhd = 6.77063, dt_pic = 0.67706
# 1180 step done... : time_mhd = 8074.32149, time_pic = 8074.32149, dt_mhd = 6.76728, dt_pic = 0.67673
# 1185 step done... : time_mhd = 8108.13609, time_pic = 8108.13609, dt_mhd = 6.75946, dt_pic = 0.67595
# 1190 step done... : time_mhd = 8141.92768, time_pic = 8141.92768, dt_mhd = 6.75754, dt_pic = 0.67575
# 1195 step done... : time_mhd = 8175.69865, time_pic = 8175.69865, dt_mhd = 6.75142, dt_pic = 0.67514
# 1200 step done... : time_mhd = 8209.43670, time_pic = 8209.43670, dt_mhd = 6.74843, dt_pic = 0.67484
# 1205 step done... : time_mhd = 8243.19271, time_pic = 8243.19271, dt_mhd = 6.75374, dt_pic = 0.67537
# 1210 step done... : time_mhd = 8276.98311, time_pic = 8276.98311, dt_mhd = 6.76008, dt_pic = 0.67601
# 1215 step done... : time_mhd = 8310.77981, time_pic = 8310.77981, dt_mhd = 6.75773, dt_pic = 0.67577
# 1220 step done... : time_mhd = 8344.55154, time_pic = 8344.55154, dt_mhd = 6.75279, dt_pic = 0.67528
# 1225 step done... : time_mhd = 8378.30494, time_pic = 8378.30494, dt_mhd = 6.75043, dt_pic = 0.67504
# 1230 step done... : time_mhd = 8412.07759, time_pic = 8412.07759, dt_mhd = 6.75814, dt_pic = 0.67581
# 1235 step done... : time_mhd = 8445.88213, time_pic = 8445.88213, dt_mhd = 6.76152, dt_pic = 0.67615
# 1240 step done... : time_mhd = 8479.68213, time_pic = 8479.68213, dt_mhd = 6.75703, dt_pic = 0.67570
# 1245 step done... : time_mhd = 8513.44736, time_pic = 8513.44736, dt_mhd = 6.75095, dt_pic = 0.67509
# 1250 step done... : time_mhd = 8547.19492, time_pic = 8547.19492, dt_mhd = 6.74800, dt_pic = 0.67480
# 1255 step done... : time_mhd = 8580.92900, time_pic = 8580.92900, dt_mhd = 6.74619, dt_pic = 0.67462
# 1260 step done... : time_mhd = 8614.68077, time_pic = 8614.68077, dt_mhd = 6.75265, dt_pic = 0.67526
# 1265 step done... : time_mhd = 8648.44331, time_pic = 8648.44331, dt_mhd = 6.75237, dt_pic = 0.67524
# 1270 step done... : time_mhd = 8682.19347, time_pic = 8682.19347, dt_mhd = 6.74916, dt_pic = 0.67492
# 1275 step done... : time_mhd = 8715.92790, time_pic = 8715.92790, dt_mhd = 6.74508, dt_pic = 0.67451
# 1280 step done... : time_mhd = 8749.63542, time_pic = 8749.63542, dt_mhd = 6.73977, dt_pic = 0.67398
# 1285 step done... : time_mhd = 8783.34076, time_pic = 8783.34076, dt_mhd = 6.74282, dt_pic = 0.67428
# 1290 step done... : time_mhd = 8817.05697, time_pic = 8817.05697, dt_mhd = 6.74322, dt_pic = 0.67432
# 1295 step done... : time_mhd = 8850.77132, time_pic = 8850.77132, dt_mhd = 6.74247, dt_pic = 0.67425
# 1300 step done... : time_mhd = 8884.47093, time_pic = 8884.47093, dt_mhd = 6.73865, dt_pic = 0.67387
# 1305 step done... : time_mhd = 8918.15989, time_pic = 8918.15989, dt_mhd = 6.73804, dt_pic = 0.67380
# 1310 step done... : time_mhd = 8951.86084, time_pic = 8951.86084, dt_mhd = 6.73994, dt_pic = 0.67399
# 1315 step done... : time_mhd = 8985.55757, time_pic = 8985.55757, dt_mhd = 6.74158, dt_pic = 0.67416
# 1320 step done... : time_mhd = 9019.27400, time_pic = 9019.27400, dt_mhd = 6.74372, dt_pic = 0.67437
# 1325 step done... : time_mhd = 9052.98855, time_pic = 9052.98855, dt_mhd = 6.74318, dt_pic = 0.67432
# 1330 step done... : time_mhd = 9086.71419, time_pic = 9086.71419, dt_mhd = 6.74649, dt_pic = 0.67465
# 1335 step done... : time_mhd = 9120.47049, time_pic = 9120.47049, dt_mhd = 6.75539, dt_pic = 0.67554
# 1340 step done... : time_mhd = 9154.27723, time_pic = 9154.27723, dt_mhd = 6.76480, dt_pic = 0.67648
# 1345 step done... : time_mhd = 9188.12230, time_pic = 9188.12230, dt_mhd = 6.77083, dt_pic = 0.67708
# 1350 step done... : time_mhd = 9222.00643, time_pic = 9222.00643, dt_mhd = 6.78125, dt_pic = 0.67812
# 1355 step done... : time_mhd = 9255.92922, time_pic = 9255.92922, dt_mhd = 6.78655, dt_pic = 0.67865
# 1360 step done... : time_mhd = 9289.88099, time_pic = 9289.88099, dt_mhd = 6.79192, dt_pic = 0.67919
# 1365 step done... : time_mhd = 9323.83998, time_pic = 9323.83998, dt_mhd = 6.79165, dt_pic = 0.67916
# 1370 step done... : time_mhd = 9357.80685, time_pic = 9357.80685, dt_mhd = 6.79371, dt_pic = 0.67937
# 1375 step done... : time_mhd = 9391.77944, time_pic = 9391.77944, dt_mhd = 6.79556, dt_pic = 0.67956
# 1380 step done... : time_mhd = 9425.75886, time_pic = 9425.75886, dt_mhd = 6.79557, dt_pic = 0.67956
# 1385 step done... : time_mhd = 9459.74377, time_pic = 9459.74377, dt_mhd = 6.79816, dt_pic = 0.67982
# 1390 step done... : time_mhd = 9493.74359, time_pic = 9493.74359, dt_mhd = 6.80160, dt_pic = 0.68016
# 1395 step done... : time_mhd = 9527.75277, time_pic = 9527.75277, dt_mhd = 6.80188, dt_pic = 0.68019
# 1400 step done... : time_mhd = 9561.75411, time_pic = 9561.75411, dt_mhd = 6.79938, dt_pic = 0.67994
# 1405 step done... : time_mhd = 9595.75770, time_pic = 9595.75770, dt_mhd = 6.80158, dt_pic = 0.68016
# 1410 step done... : time_mhd = 9629.76423, time_pic = 9629.76423, dt_mhd = 6.80083, dt_pic = 0.68008
# 1415 step done... : time_mhd = 9663.77124, time_pic = 9663.77124, dt_mhd = 6.80241, dt_pic = 0.68024
# 1420 step done... : time_mhd = 9697.77891, time_pic = 9697.77891, dt_mhd = 6.79979, dt_pic = 0.67998
# 1425 step done... : time_mhd = 9731.76623, time_pic = 9731.76623, dt_mhd = 6.79850, dt_pic = 0.67985
# 1430 step done... : time_mhd = 9765.76328, time_pic = 9765.76328, dt_mhd = 6.79880, dt_pic = 0.67988
# 1435 step done... : time_mhd = 9799.76231, time_pic = 9799.76231, dt_mhd = 6.80072, dt_pic = 0.68007
# 1440 step done... : time_mhd = 9833.76393, time_pic = 9833.76393, dt_mhd = 6.80037, dt_pic = 0.68004
# 1445 step done... : time_mhd = 9867.75371, time_pic = 9867.75371, dt_mhd = 6.79643, dt_pic = 0.67964
# 1450 step done... : time_mhd = 9901.73744, time_pic = 9901.73744, dt_mhd = 6.79710, dt_pic = 0.67971
# 1455 step done... : time_mhd = 9935.70987, time_pic = 9935.70987, dt_mhd = 6.79294, dt_pic = 0.67929
# 1460 step done... : time_mhd = 9969.67465, time_pic = 9969.67465, dt_mhd = 6.79188, dt_pic = 0.67919
# 1465 step done... : time_mhd = 10003.63065, time_pic = 10003.63065, dt_mhd = 6.79095, dt_pic = 0.67910
# 1470 step done... : time_mhd = 10037.56834, time_pic = 10037.56834, dt_mhd = 6.78550, dt_pic = 0.67855
# 1475 step done... : time_mhd = 10071.48814, time_pic = 10071.48814, dt_mhd = 6.78145, dt_pic = 0.67815
# 1480 step done... : time_mhd = 10105.37634, time_pic = 10105.37634, dt_mhd = 6.77613, dt_pic = 0.67761
# 1485 step done... : time_mhd = 10139.23885, time_pic = 10139.23885, dt_mhd = 6.76892, dt_pic = 0.67689
# 1490 step done... : time_mhd = 10173.05430, time_pic = 10173.05430, dt_mhd = 6.76026, dt_pic = 0.67603
# 1495 step done... : time_mhd = 10206.84553, time_pic = 10206.84553, dt_mhd = 6.75728, dt_pic = 0.67573
# 1500 step done... : time_mhd = 10240.62701, time_pic = 10240.62701, dt_mhd = 6.75640, dt_pic = 0.67564
# 1505 step done... : time_mhd = 10274.40828, time_pic = 10274.40828, dt_mhd = 6.75485, dt_pic = 0.67548
# 1510 step done... : time_mhd = 10308.16341, time_pic = 10308.16341, dt_mhd = 6.74980, dt_pic = 0.67498
# 1515 step done... : time_mhd = 10341.88679, time_pic = 10341.88679, dt_mhd = 6.74006, dt_pic = 0.67401
# 1520 step done... : time_mhd = 10375.55343, time_pic = 10375.55343, dt_mhd = 6.72919, dt_pic = 0.67292
# 1525 step done... : time_mhd = 10409.20101, time_pic = 10409.20101, dt_mhd = 6.73251, dt_pic = 0.67325
# 1530 step done... : time_mhd = 10442.86378, time_pic = 10442.86378, dt_mhd = 6.73176, dt_pic = 0.67318
# 1535 step done... : time_mhd = 10476.53464, time_pic = 10476.53464, dt_mhd = 6.73766, dt_pic = 0.67377
# 1540 step done... : time_mhd = 10510.23245, time_pic = 10510.23245, dt_mhd = 6.74044, dt_pic = 0.67404
# 1545 step done... : time_mhd = 10543.94045, time_pic = 10543.94045, dt_mhd = 6.73943, dt_pic = 0.67394
# 1550 step done... : time_mhd = 10577.62277, time_pic = 10577.62277, dt_mhd = 6.73464, dt_pic = 0.67346
# 1555 step done... : time_mhd = 10611.28289, time_pic = 10611.28289, dt_mhd = 6.73035, dt_pic = 0.67304
# 1560 step done... : time_mhd = 10644.91380, time_pic = 10644.91380, dt_mhd = 6.72509, dt_pic = 0.67251
# 1565 step done... : time_mhd = 10678.54558, time_pic = 10678.54558, dt_mhd = 6.72817, dt_pic = 0.67282
# 1570 step done... : time_mhd = 10712.20000, time_pic = 10712.20000, dt_mhd = 6.73080, dt_pic = 0.67308
# 1575 step done... : time_mhd = 10745.86521, time_pic = 10745.86521, dt_mhd = 6.73301, dt_pic = 0.67330
# 1580 step done... : time_mhd = 10779.52227, time_pic = 10779.52227, dt_mhd = 6.72877, dt_pic = 0.67288
# 1585 step done... : time_mhd = 10813.16343, time_pic = 10813.16343, dt_mhd = 6.72792, dt_pic = 0.67279
# 1590 step done... : time_mhd = 10846.83419, time_pic = 10846.83419, dt_mhd = 6.73738, dt_pic = 0.67374
# 1595 step done... : time_mhd = 10880.52456, time_pic = 10880.52456, dt_mhd = 6.73959, dt_pic = 0.67396
# 1600 step done... : time_mhd = 10914.22947, time_pic = 10914.22947, dt_mhd = 6.74036, dt_pic = 0.67404
# 1605 step done... : time_mhd = 10947.91023, time_pic = 10947.91023, dt_mhd = 6.73462, dt_pic = 0.67346
# 1610 step done... : time_mhd = 10981.57513, time_pic = 10981.57513, dt_mhd = 6.73278, dt_pic = 0.67328
# 1615 step done... : time_mhd = 11015.20869, time_pic = 11015.20869, dt_mhd = 6.72305, dt_pic = 0.67230
# 1620 step done... : time_mhd = 11048.81495, time_pic = 11048.81495, dt_mhd = 6.72095, dt_pic = 0.67209
# 1625 step done... : time_mhd = 11082.40995, time_pic = 11082.40995, dt_mhd = 6.71716, dt_pic = 0.67172
# 1630 step done... : time_mhd = 11115.98047, time_pic = 11115.98047, dt_mhd = 6.71301, dt_pic = 0.67130
# 1635 step done... : time_mhd = 11149.54510, time_pic = 11149.54510, dt_mhd = 6.71233, dt_pic = 0.67123
# 1640 step done... : time_mhd = 11183.09790, time_pic = 11183.09790, dt_mhd = 6.71030, dt_pic = 0.67103
# 1645 step done... : time_mhd = 11216.65162, time_pic = 11216.65162, dt_mhd = 6.71133, dt_pic = 0.67113
# 1650 step done... : time_mhd = 11250.21003, time_pic = 11250.21003, dt_mhd = 6.71203, dt_pic = 0.67120
# 1655 step done... : time_mhd = 11283.77302, time_pic = 11283.77302, dt_mhd = 6.71238, dt_pic = 0.67124
# 1660 step done... : time_mhd = 11317.31512, time_pic = 11317.31512, dt_mhd = 6.70545, dt_pic = 0.67054
# 1665 step done... : time_mhd = 11350.82173, time_pic = 11350.82173, dt_mhd = 6.69973, dt_pic = 0.66997
# 1670 step done... : time_mhd = 11384.32833, time_pic = 11384.32833, dt_mhd = 6.70306, dt_pic = 0.67031
# 1675 step done... : time_mhd = 11417.83732, time_pic = 11417.83732, dt_mhd = 6.70045, dt_pic = 0.67005
# 1680 step done... : time_mhd = 11451.32021, time_pic = 11451.32021, dt_mhd = 6.69388, dt_pic = 0.66939
# 1685 step done... : time_mhd = 11484.77132, time_pic = 11484.77132, dt_mhd = 6.68774, dt_pic = 0.66877
# 1690 step done... : time_mhd = 11518.19521, time_pic = 11518.19521, dt_mhd = 6.68317, dt_pic = 0.66832
# 1695 step done... : time_mhd = 11551.59783, time_pic = 11551.59783, dt_mhd = 6.67863, dt_pic = 0.66786
# 1700 step done... : time_mhd = 11584.99352, time_pic = 11584.99352, dt_mhd = 6.67930, dt_pic = 0.66793
# 1705 step done... : time_mhd = 11618.38062, time_pic = 11618.38062, dt_mhd = 6.67754, dt_pic = 0.66775
# 1710 step done... : time_mhd = 11651.76464, time_pic = 11651.76464, dt_mhd = 6.67525, dt_pic = 0.66753
# 1715 step done... : time_mhd = 11685.14487, time_pic = 11685.14487, dt_mhd = 6.67812, dt_pic = 0.66781
# 1720 step done... : time_mhd = 11718.55364, time_pic = 11718.55364, dt_mhd = 6.68342, dt_pic = 0.66834
# 1725 step done... : time_mhd = 11751.98027, time_pic = 11751.98027, dt_mhd = 6.68624, dt_pic = 0.66862
# 1730 step done... : time_mhd = 11785.39611, time_pic = 11785.39611, dt_mhd = 6.68094, dt_pic = 0.66809
# 1735 step done... : time_mhd = 11818.78097, time_pic = 11818.78097, dt_mhd = 6.67404, dt_pic = 0.66740
# 1740 step done... : time_mhd = 11852.14459, time_pic = 11852.14459, dt_mhd = 6.67134, dt_pic = 0.66713
# 1745 step done... : time_mhd = 11885.48788, time_pic = 11885.48788, dt_mhd = 6.66680, dt_pic = 0.66668
# 1750 step done... : time_mhd = 11918.80920, time_pic = 11918.80920, dt_mhd = 6.66236, dt_pic = 0.66624
# 1755 step done... : time_mhd = 11952.12290, time_pic = 11952.12290, dt_mhd = 6.66313, dt_pic = 0.66631
# 1760 step done... : time_mhd = 11985.45622, time_pic = 11985.45622, dt_mhd = 6.66937, dt_pic = 0.66694
# 1765 step done... : time_mhd = 12018.80289, time_pic = 12018.80289, dt_mhd = 6.66890, dt_pic = 0.66689
# 1770 step done... : time_mhd = 12052.15673, time_pic = 12052.15673, dt_mhd = 6.67289, dt_pic = 0.66729
# 1775 step done... : time_mhd = 12085.54713, time_pic = 12085.54713, dt_mhd = 6.68239, dt_pic = 0.66824
# 1780 step done... : time_mhd = 12118.97912, time_pic = 12118.97912, dt_mhd = 6.68760, dt_pic = 0.66876
# 1785 step done... : time_mhd = 12152.41673, time_pic = 12152.41673, dt_mhd = 6.68782, dt_pic = 0.66878
# 1790 step done... : time_mhd = 12185.84270, time_pic = 12185.84270, dt_mhd = 6.68303, dt_pic = 0.66830
# 1795 step done... : time_mhd = 12219.23171, time_pic = 12219.23171, dt_mhd = 6.67474, dt_pic = 0.66747
# 1800 step done... : time_mhd = 12252.58295, time_pic = 12252.58295, dt_mhd = 6.66734, dt_pic = 0.66673
# 1805 step done... : time_mhd = 12285.91402, time_pic = 12285.91402, dt_mhd = 6.66593, dt_pic = 0.66659
# 1810 step done... : time_mhd = 12319.25478, time_pic = 12319.25478, dt_mhd = 6.67080, dt_pic = 0.66708
# 1815 step done... : time_mhd = 12352.61738, time_pic = 12352.61738, dt_mhd = 6.67347, dt_pic = 0.66735
# 1820 step done... : time_mhd = 12385.98632, time_pic = 12385.98632, dt_mhd = 6.67424, dt_pic = 0.66742
# 1825 step done... : time_mhd = 12419.36268, time_pic = 12419.36268, dt_mhd = 6.67538, dt_pic = 0.66754
# 1830 step done... : time_mhd = 12452.73217, time_pic = 12452.73217, dt_mhd = 6.67443, dt_pic = 0.66744
# 1835 step done... : time_mhd = 12486.11792, time_pic = 12486.11792, dt_mhd = 6.67970, dt_pic = 0.66797
# 1840 step done... : time_mhd = 12519.53574, time_pic = 12519.53574, dt_mhd = 6.68658, dt_pic = 0.66866
# 1845 step done... : time_mhd = 12552.99064, time_pic = 12552.99064, dt_mhd = 6.69251, dt_pic = 0.66925
# 1850 step done... : time_mhd = 12586.45396, time_pic = 12586.45396, dt_mhd = 6.69448, dt_pic = 0.66945
# 1855 step done... : time_mhd = 12619.94054, time_pic = 12619.94054, dt_mhd = 6.69840, dt_pic = 0.66984
# 1860 step done... : time_mhd = 12653.43250, time_pic = 12653.43250, dt_mhd = 6.69776, dt_pic = 0.66978
# 1865 step done... : time_mhd = 12686.91942, time_pic = 12686.91942, dt_mhd = 6.69533, dt_pic = 0.66953
# 1870 step done... : time_mhd = 12720.36175, time_pic = 12720.36175, dt_mhd = 6.68482, dt_pic = 0.66848
# 1875 step done... : time_mhd = 12753.78413, time_pic = 12753.78413, dt_mhd = 6.68459, dt_pic = 0.66846
# 1880 step done... : time_mhd = 12787.21075, time_pic = 12787.21075, dt_mhd = 6.68585, dt_pic = 0.66858
# 1885 step done... : time_mhd = 12820.64060, time_pic = 12820.64060, dt_mhd = 6.68535, dt_pic = 0.66853
# 1890 step done... : time_mhd = 12854.05771, time_pic = 12854.05771, dt_mhd = 6.68215, dt_pic = 0.66822
# 1895 step done... : time_mhd = 12887.47104, time_pic = 12887.47104, dt_mhd = 6.68360, dt_pic = 0.66836
# 1900 step done... : time_mhd = 12920.89599, time_pic = 12920.89599, dt_mhd = 6.68515, dt_pic = 0.66851
# 1905 step done... : time_mhd = 12954.31216, time_pic = 12954.31216, dt_mhd = 6.68171, dt_pic = 0.66817
# 1910 step done... : time_mhd = 12987.73240, time_pic = 12987.73240, dt_mhd = 6.68681, dt_pic = 0.66868
# 1915 step done... : time_mhd = 13021.16741, time_pic = 13021.16741, dt_mhd = 6.68565, dt_pic = 0.66857
# 1920 step done... : time_mhd = 13054.58882, time_pic = 13054.58882, dt_mhd = 6.68307, dt_pic = 0.66831
# 1925 step done... : time_mhd = 13088.01046, time_pic = 13088.01046, dt_mhd = 6.68487, dt_pic = 0.66849
# 1930 step done... : time_mhd = 13121.44019, time_pic = 13121.44019, dt_mhd = 6.68710, dt_pic = 0.66871
# 1935 step done... : time_mhd = 13154.88008, time_pic = 13154.88008, dt_mhd = 6.68718, dt_pic = 0.66872
# 1940 step done... : time_mhd = 13188.31979, time_pic = 13188.31979, dt_mhd = 6.68864, dt_pic = 0.66886
# 1945 step done... : time_mhd = 13221.76570, time_pic = 13221.76570, dt_mhd = 6.68993, dt_pic = 0.66899
# 1950 step done... : time_mhd = 13255.21850, time_pic = 13255.21850, dt_mhd = 6.69048, dt_pic = 0.66905
# 1955 step done... : time_mhd = 13288.67050, time_pic = 13288.67050, dt_mhd = 6.69013, dt_pic = 0.66901
# 1960 step done... : time_mhd = 13322.14274, time_pic = 13322.14274, dt_mhd = 6.69932, dt_pic = 0.66993
# 1965 step done... : time_mhd = 13355.67425, time_pic = 13355.67425, dt_mhd = 6.70953, dt_pic = 0.67095
# 1970 step done... : time_mhd = 13389.20671, time_pic = 13389.20671, dt_mhd = 6.70565, dt_pic = 0.67057
# 1975 step done... : time_mhd = 13422.72825, time_pic = 13422.72825, dt_mhd = 6.70294, dt_pic = 0.67029
# 1980 step done... : time_mhd = 13456.23825, time_pic = 13456.23825, dt_mhd = 6.70084, dt_pic = 0.67008
# 1985 step done... : time_mhd = 13489.74749, time_pic = 13489.74749, dt_mhd = 6.70162, dt_pic = 0.67016
# 1990 step done... : time_mhd = 13523.25636, time_pic = 13523.25636, dt_mhd = 6.70175, dt_pic = 0.67018
# 1995 step done... : time_mhd = 13556.75856, time_pic = 13556.75856, dt_mhd = 6.69922, dt_pic = 0.66992
# 2000 step done... : time_mhd = 13590.25586, time_pic = 13590.25586, dt_mhd = 6.69936, dt_pic = 0.66994

# %% [markdown]
# プロット

# %%
dirname = "results_MS_alfven"
step = 300

B = np.load(f"{dirname}/B_{step}.npy")
E = np.load(f"{dirname}/E_{step}.npy")
current = np.load(f"{dirname}/current_{step}.npy")
zeroth_moment_ion = np.load(f"{dirname}/zeroth_moment_ion_{step}.npy")
zeroth_moment_electron = np.load(f"{dirname}/zeroth_moment_electron_{step}.npy")
first_moment_ion = np.load(f"{dirname}/first_moment_ion_{step}.npy")
first_moment_electron = np.load(f"{dirname}/first_moment_electron_{step}.npy")
second_moment_ion = np.load(f"{dirname}/second_moment_ion_{step}.npy")
second_moment_electron = np.load(f"{dirname}/second_moment_electron_{step}.npy")

B_time_ave = np.load(f"{dirname}/B_time_ave_{step}.npy")
zeroth_moment_ion_time_ave = np.load(f"{dirname}/zeroth_moment_ion_time_ave_{step}.npy")
zeroth_moment_electron_time_ave = np.load(f"{dirname}/zeroth_moment_electron_time_ave_{step}.npy")
first_moment_ion_time_ave = np.load(f"{dirname}/first_moment_ion_time_ave_{step}.npy")
first_moment_electron_time_ave = np.load(f"{dirname}/first_moment_electron_time_ave_{step}.npy")
second_moment_ion_time_ave = np.load(f"{dirname}/second_moment_ion_time_ave_{step}.npy")
second_moment_electron_time_ave = np.load(f"{dirname}/second_moment_electron_time_ave_{step}.npy")

U1 = np.load(f"{dirname}/U1_{step}.npy")
rho1_mhd = U1[0, :]
u1_mhd = U1[1, :] / rho1_mhd
v1_mhd = U1[2, :] / rho1_mhd
w1_mhd = U1[3, :] / rho1_mhd
Bx1_mhd = U1[4, :]
By1_mhd = U1[5, :]
Bz1_mhd = U1[6, :]
e1_mhd = U1[7, :]
p1_mhd = (gamma_mhd - 1.0) \
        * (e1_mhd - 0.5 * rho1_mhd * (u1_mhd**2+v1_mhd**2+w1_mhd**2)
            - 0.5 * (Bx1_mhd**2+By1_mhd**2+Bz1_mhd**2))
Ex1_mhd = -(v1_mhd * Bz1_mhd - w1_mhd * By1_mhd)
Ey1_mhd = -(w1_mhd * Bx1_mhd - u1_mhd * Bz1_mhd)
Ez1_mhd = -(u1_mhd * By1_mhd - v1_mhd * Bx1_mhd)
current1_x_mhd = np.zeros(Bx1_mhd.shape)
current1_y_mhd = -(np.roll(Bz1_mhd, -1, axis=0) - np.roll(Bz1_mhd, 1, axis=0)) / (2*dx_mhd)
current1_z_mhd = (np.roll(By1_mhd, -1, axis=0) - np.roll(By1_mhd, 1, axis=0)) / (2*dx_mhd)
current1_y_mhd[0] = current1_y_mhd[1] 
current1_y_mhd[-1] = current1_y_mhd[-2] 
current1_z_mhd[0] = current1_z_mhd[1] 
current1_z_mhd[-1] = current1_z_mhd[-2] 

U2 = np.load(f"{dirname}/U2_{step}.npy")
rho2_mhd = U2[0, :]
u2_mhd = U2[1, :] / rho2_mhd
v2_mhd = U2[2, :] / rho2_mhd
w2_mhd = U2[3, :] / rho2_mhd
Bx2_mhd = U2[4, :]
By2_mhd = U2[5, :]
Bz2_mhd = U2[6, :]
e2_mhd = U2[7, :]
p2_mhd = (gamma_mhd - 1.0) \
        * (e2_mhd - 0.5 * rho2_mhd * (u2_mhd**2+v2_mhd**2+w2_mhd**2)
            - 0.5 * (Bx2_mhd**2+By2_mhd**2+Bz2_mhd**2))
Ex2_mhd = -(v2_mhd * Bz2_mhd - w2_mhd * By2_mhd)
Ey2_mhd = -(w2_mhd * Bx2_mhd - u2_mhd * Bz2_mhd)
Ez2_mhd = -(u2_mhd * By2_mhd - v2_mhd * Bx2_mhd)
current2_x_mhd = np.zeros(Bx2_mhd.shape)
current2_y_mhd = -(np.roll(Bz2_mhd, -1, axis=0) - np.roll(Bz2_mhd, 1, axis=0)) / (2*dx_mhd)
current2_z_mhd = (np.roll(By2_mhd, -1, axis=0) - np.roll(By2_mhd, 1, axis=0)) / (2*dx_mhd)
current2_y_mhd[0] = current2_y_mhd[1] 
current2_y_mhd[-1] = current2_y_mhd[-2] 
current2_z_mhd[0] = current2_z_mhd[1] 
current2_z_mhd[-1] = current2_z_mhd[-2]

# %%
fig = plt.figure(figsize=(24, 16))
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412)
ax3 = fig.add_subplot(413)
ax4 = fig.add_subplot(414)

bulk_vy_pic = (first_moment_ion[1, :] + first_moment_electron[1, :]) / (zeroth_moment_ion + zeroth_moment_electron + 1e-10)
bulk_vz_pic = (first_moment_ion[2, :] + first_moment_electron[2, :]) / (zeroth_moment_ion + zeroth_moment_electron + 1e-10)

ax1.plot(x_coordinate_mhd, v1_mhd / VA_mhd, color='black', lw=3)
ax2.plot(x_coordinate_mhd, w1_mhd / VA_mhd, color='black', lw=3)
ax3.plot(x_coordinate_mhd, By1_mhd / B0_mhd, color='black', lw=3)
ax4.plot(x_coordinate_mhd, Bz1_mhd / B0_mhd, color='black', lw=3)
ax1.plot(x_coordinate_mhd + 10450, v2_mhd / VA_mhd, color='black', lw=3)
ax2.plot(x_coordinate_mhd + 10450, w2_mhd / VA_mhd, color='black', lw=3)
ax3.plot(x_coordinate_mhd + 10450, By2_mhd / B0_mhd, color='black', lw=3)
ax4.plot(x_coordinate_mhd + 10450, Bz2_mhd / B0_mhd, color='black', lw=3)
ax1.plot(x_coordinate_pic + 9500, bulk_vy_pic / VA_pic, color='green', lw=3)
ax2.plot(x_coordinate_pic + 9500, bulk_vz_pic / VA_pic, color='green', lw=3)
ax3.plot(x_coordinate_pic + 9500, B[1, :] / B0_pic, color='green', lw=3)
ax4.plot(x_coordinate_pic + 9500, B[2, :] / B0_pic, color='green', lw=3)

ax1.axvspan(0, 9550, color='blue', alpha=0.7)
ax2.axvspan(0, 9550, color='blue', alpha=0.7)
ax3.axvspan(0, 9550, color='blue', alpha=0.7)
ax4.axvspan(0, 9550, color='blue', alpha=0.7)
ax1.axvspan(10450, 20000, color='blue', alpha=0.7)
ax2.axvspan(10450, 20000, color='blue', alpha=0.7)
ax3.axvspan(10450, 20000, color='blue', alpha=0.7)
ax4.axvspan(10450, 20000, color='blue', alpha=0.7)
ax1.axvspan(9500, 10500, color='orange', alpha=0.7)
ax2.axvspan(9500, 10500, color='orange', alpha=0.7)
ax3.axvspan(9500, 10500, color='orange', alpha=0.7)
ax4.axvspan(9500, 10500, color='orange', alpha=0.7)

ax1.set_title(r"$v / V_A$", fontsize=24)
ax2.set_title(r"$w / V_A$", fontsize=24)
ax3.set_title(r"$B_y / B_0$", fontsize=24)
ax4.set_title(r"$B_z / B_0$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax1.set_xlim(0, 20000)
ax2.set_xlim(0, 20000)
ax3.set_xlim(0, 20000)
ax4.set_xlim(0, 20000)
ax1.set_ylim(-0.2, 0.2)
ax2.set_ylim(-0.2, 0.2)
ax3.set_ylim(-0.2, 0.2)
ax4.set_ylim(-0.2, 0.2)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()

plt.suptitle(f"t = {step}", y=0.95, fontsize=32)

plt.show()

# %% [markdown]
# 動画作成

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(411)
ax2 = fig.add_subplot(412)
ax3 = fig.add_subplot(413)
ax4 = fig.add_subplot(414)

dirname = "results_MS_alfven"
filename = "Alfven_MHD-PIC1.mp4"
log = np.loadtxt('log.txt', dtype=str)

interval = 10
plot_steps = 2000
for step in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()

    B = np.load(f"{dirname}/B_{step}.npy")
    zeroth_moment_ion = np.load(f"{dirname}/zeroth_moment_ion_{step}.npy")
    zeroth_moment_electron = np.load(f"{dirname}/zeroth_moment_electron_{step}.npy")
    first_moment_ion = np.load(f"{dirname}/first_moment_ion_{step}.npy")
    first_moment_electron = np.load(f"{dirname}/first_moment_electron_{step}.npy")

    U1 = np.load(f"{dirname}/U1_{step}.npy")
    rho1_mhd = U1[0, :]
    u1_mhd = U1[1, :] / rho1_mhd
    v1_mhd = U1[2, :] / rho1_mhd
    w1_mhd = U1[3, :] / rho1_mhd
    Bx1_mhd = U1[4, :]
    By1_mhd = U1[5, :]
    Bz1_mhd = U1[6, :]
    e1_mhd = U1[7, :]

    U2 = np.load(f"{dirname}/U2_{step}.npy")
    rho2_mhd = U2[0, :]
    u2_mhd = U2[1, :] / rho2_mhd
    v2_mhd = U2[2, :] / rho2_mhd
    w2_mhd = U2[3, :] / rho2_mhd
    Bx2_mhd = U2[4, :]
    By2_mhd = U2[5, :]
    Bz2_mhd = U2[6, :]
    e2_mhd = U2[7, :]

    bulk_vy_pic = (first_moment_ion[1, :] + first_moment_electron[1, :]) / (zeroth_moment_ion + zeroth_moment_electron + 1e-10)
    bulk_vz_pic = (first_moment_ion[2, :] + first_moment_electron[2, :]) / (zeroth_moment_ion + zeroth_moment_electron + 1e-10)

    ax1.plot(x_coordinate_mhd, v1_mhd / VA_mhd, color='black', lw=3)
    ax2.plot(x_coordinate_mhd, w1_mhd / VA_mhd, color='black', lw=3)
    ax3.plot(x_coordinate_mhd, By1_mhd / B0_mhd, color='black', lw=3)
    ax4.plot(x_coordinate_mhd, Bz1_mhd / B0_mhd, color='black', lw=3)
    ax1.plot(x_coordinate_mhd + 10450, v2_mhd / VA_mhd, color='black', lw=3)
    ax2.plot(x_coordinate_mhd + 10450, w2_mhd / VA_mhd, color='black', lw=3)
    ax3.plot(x_coordinate_mhd + 10450, By2_mhd / B0_mhd, color='black', lw=3)
    ax4.plot(x_coordinate_mhd + 10450, Bz2_mhd / B0_mhd, color='black', lw=3)
    ax1.plot(x_coordinate_pic + 9500, bulk_vy_pic / VA_pic, color='green', lw=3)
    ax2.plot(x_coordinate_pic + 9500, bulk_vz_pic / VA_pic, color='green', lw=3)
    ax3.plot(x_coordinate_pic + 9500, B[1, :] / B0_pic, color='green', lw=3)
    ax4.plot(x_coordinate_pic + 9500, B[2, :] / B0_pic, color='green', lw=3)

    ax1.axvspan(0, 9550, color='blue', alpha=0.7)
    ax2.axvspan(0, 9550, color='blue', alpha=0.7)
    ax3.axvspan(0, 9550, color='blue', alpha=0.7)
    ax4.axvspan(0, 9550, color='blue', alpha=0.7)
    ax1.axvspan(10450, 20000, color='blue', alpha=0.7)
    ax2.axvspan(10450, 20000, color='blue', alpha=0.7)
    ax3.axvspan(10450, 20000, color='blue', alpha=0.7)
    ax4.axvspan(10450, 20000, color='blue', alpha=0.7)
    ax1.axvspan(9500, 10500, color='orange', alpha=0.7)
    ax2.axvspan(9500, 10500, color='orange', alpha=0.7)
    ax3.axvspan(9500, 10500, color='orange', alpha=0.7)
    ax4.axvspan(9500, 10500, color='orange', alpha=0.7)

    ax4.set_xlabel(r"$x / \lambda_{De}$", fontsize=24)
    ax1.set_ylabel(r"$v / V_A$", fontsize=24)
    ax2.set_ylabel(r"$w / V_A$", fontsize=24)
    ax3.set_ylabel(r"$B_y / B_0$", fontsize=24)
    ax4.set_ylabel(r"$B_z / B_0$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax1.set_xlim(0, 20000)
    ax2.set_xlim(0, 20000)
    ax3.set_xlim(0, 20000)
    ax4.set_xlim(0, 20000)
    ax1.set_ylim(-0.2, 0.2)
    ax2.set_ylim(-0.2, 0.2)
    ax3.set_ylim(-0.2, 0.2)
    ax4.set_ylim(-0.2, 0.2)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()

    time = float(log[int(step/interval), 6].replace(',', ''))
    plt.suptitle(f"t = {time / (1.0 / omega_pe):.2f}" + r"$\omega_{pe}^{-1}$", y=0.95, fontsize=32)

    fig.savefig(f'./pictures/{step}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for step in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{step}.png')
    video.write(img)
video.release()

# %% [markdown]
# 分散関係

# %%
dirname = "results_MS_alfven"
 
Bz_total = np.zeros([400, 20000])
for step in range(0, 2000, 5):
    U1 = np.load(f"{dirname}/U1_{step}.npy")
    U2 = np.load(f"{dirname}/U2_{step}.npy")
    B = np.load(f"{dirname}/B_{step}.npy")

    Bz_total[int(step/5), :nx_mhd-interface_width] = U1[6, :nx_mhd-interface_width]
    Bz_total[int(step/5), nx_mhd-interface_width : nx_mhd-interface_width+nx_pic] = B[2, :]
    Bz_total[int(step/5), -nx_mhd+interface_width:] = U2[6, -nx_mhd+interface_width:]

# %%
Bz_FFT = np.fft.fft2(Bz_total)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

dt_tmp = 35.0
kx = np.fft.fftfreq(20000, d=dx_mhd)[:100]
omega = np.fft.fftfreq(400, d=dt_tmp)[:30]
X, Y = np.meshgrid(kx, omega)

contour = ax.pcolormesh(X, Y, np.log10(np.abs(Bz_FFT[:30, :100])**2), vmin=0, vmax=10.0, cmap='jet')
cbar = plt.colorbar(contour, ax=ax)
cbar.set_label(r"$\log_{10} |B_{z, k}|^2$", fontsize=16, labelpad=10)

ax.plot(kx, c * kx, lw=2, color='black', ls='dashed', label=r"$\omega = c k_x$")
#ax.vlines(kx[5], 0, 100, color='purple', lw=2, label=r"mode 5")
ax.plot(kx, VA_pic * kx, color='blue', lw=2, label=r"Alfven")
ax.plot(kx, -omega_ce/2 / (1.0 + omega_pe**2/kx**2/c**2) * ((1.0 + 4.0*omega_pi**2/kx**2/c**2)**0.5 + 1.0), color='white', lw=2, label=r"whistler")
ax.plot(kx, -omega_ce/2 / (1.0 + omega_pe**2/kx**2/c**2) * ((1.0 + 4.0*omega_pi**2/kx**2/c**2)**0.5 - 1.0), color='black', lw=2, label=r"ion cyclotron")
ax.set_xlabel(r"wave number $k_x$", fontsize=16)
ax.set_ylabel(r"wave frequency $\omega$", fontsize=16)
ax.set_xlim(0, kx[-1])
ax.set_ylim(0, omega[-1])
ax.legend(loc='upper right', fontsize=12)

fig.savefig("dispersion1.png", dpi=200)
# Out:
# C:\Users\keita\AppData\Local\Temp\ipykernel_19116\3693781112.py:18: RuntimeWarning: divide by zero encountered in divide
#   ax.plot(kx, -omega_ce/2 / (1.0 + omega_pe**2/kx**2/c**2) * ((1.0 + 4.0*omega_pi**2/kx**2/c**2)**0.5 + 1.0), color='white', lw=2, label=r"whistler")
# C:\Users\keita\AppData\Local\Temp\ipykernel_19116\3693781112.py:18: RuntimeWarning: invalid value encountered in multiply
#   ax.plot(kx, -omega_ce/2 / (1.0 + omega_pe**2/kx**2/c**2) * ((1.0 + 4.0*omega_pi**2/kx**2/c**2)**0.5 + 1.0), color='white', lw=2, label=r"whistler")
# C:\Users\keita\AppData\Local\Temp\ipykernel_19116\3693781112.py:19: RuntimeWarning: divide by zero encountered in divide
#   ax.plot(kx, -omega_ce/2 / (1.0 + omega_pe**2/kx**2/c**2) * ((1.0 + 4.0*omega_pi**2/kx**2/c**2)**0.5 - 1.0), color='black', lw=2, label=r"ion cyclotron")
# C:\Users\keita\AppData\Local\Temp\ipykernel_19116\3693781112.py:19: RuntimeWarning: invalid value encountered in multiply
#   ax.plot(kx, -omega_ce/2 / (1.0 + omega_pe**2/kx**2/c**2) * ((1.0 + 4.0*omega_pi**2/kx**2/c**2)**0.5 - 1.0), color='black', lw=2, label=r"ion cyclotron")
