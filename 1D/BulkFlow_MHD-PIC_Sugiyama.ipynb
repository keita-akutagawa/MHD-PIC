# %%
import numpy as np
from scipy import stats
#import cupy as cp
import matplotlib.pyplot as plt
import cv2

from lib_MHDPIC1D.pic1d import *
from lib_MHDPIC1D.mhd1d import *
from lib_MHDPIC1D.interface import *

# %% [markdown]
# Alfven波の伝搬

# %% [markdown]
# PIC初期化

# %%
c = 1.0
mu_0 = 1.0
epsilon0 = 1.0 / (mu_0 * c**2)
m_electron = 1.0
r_m = 1 / 25
m_ion = m_electron / r_m
t_r = 1.0
ne0_pic = 100 #ここは手動で調整すること
ni0_pic = ne0_pic
B0_pic = np.sqrt(ne0_pic) / 1.0
Te_pic = 0.5 * m_electron * (0.1*c)**2
Ti_pic = Te_pic / t_r
q_electron = -1 * np.sqrt(epsilon0 * Te_pic / ne0_pic)
q_ion = -1 * q_electron
debye_length = np.sqrt(epsilon0 * Te_pic / ne0_pic / q_electron**2)
omega_pe = np.sqrt(ne0_pic * q_electron**2 / m_electron / epsilon0)
omega_pi = np.sqrt(ni0_pic * q_ion**2 / m_ion / epsilon0)
omega_ce = q_electron * B0_pic / m_electron
omega_ci = q_ion * B0_pic / m_ion
VA_pic = B0_pic / np.sqrt(ni0_pic * m_ion + ni0_pic * m_electron)
gamma_pic = 5.0 / 3.0
rho_pic = ni0_pic * m_ion + ne0_pic * m_electron
p_pic = ni0_pic * Ti_pic + ne0_pic * Te_pic
CS_pic = np.sqrt(gamma_pic * p_pic / rho_pic)
v_ion = np.array([0.1 * c, 0.0, 0.0])
v_electron = np.array([0.1 * c, 0.0, 0.0])
v_thermal_electron = np.sqrt(2.0 * Te_pic / m_electron)
v_thermal_ion = np.sqrt(2.0 * Ti_pic / m_ion)
ion_inertial_length = c / omega_pi

dx_pic = debye_length
nx_pic = 200
x_min_pic = 1e-10
x_max_pic = nx_pic * dx_pic - 1e-10
x_coordinate_pic = np.arange(0.0, x_max_pic, dx_pic)
dt_pic = 0.0
d_pic = 0.0

E_pic = np.zeros([3, nx_pic])
B_pic = np.zeros([3, nx_pic])
current_pic = np.zeros([3, nx_pic])
rho_pic = np.zeros(nx_pic)
B_pic[0, :] = B0_pic
beta_pic = (ne0_pic * Te_pic + ni0_pic * Ti_pic) / (B0_pic**2 / 2 / mu_0)

n_ion = int(ni0_pic * nx_pic)
n_electron = int(n_ion * abs(q_ion / q_electron))
x_pic_ion = np.zeros([3, n_ion])
x_pic_electron = np.zeros([3, n_electron])
v_pic_ion = np.zeros([3, n_ion])
v_pic_electron = np.zeros([3, n_electron])

rs_ion = np.random.RandomState(10)
rs_electron = np.random.RandomState(20)
#x_start_ion = np.linspace(x_min_pic, x_max_pic, n_ion)
#x_start_electron = np.linspace(x_min_pic, x_max_pic, n_electron)
x_start_ion = rs_ion.rand(n_ion) * (x_max_pic - x_min_pic)
x_start_electron = rs_electron.rand(n_electron) * (x_max_pic - x_min_pic)

x_pic_ion[0, :] = x_start_ion
x_pic_electron[0, :] = x_start_electron
v_pic_ion[0, :] = np.asarray(stats.norm.rvs(v_ion[0], v_thermal_ion, size=n_ion, random_state=30))
v_pic_ion[1, :] = np.asarray(stats.norm.rvs(v_ion[1], v_thermal_ion, size=n_ion, random_state=40))
v_pic_ion[2, :] = np.asarray(stats.norm.rvs(v_ion[2], v_thermal_ion, size=n_ion, random_state=50))
v_pic_electron[0, :] = np.asarray(stats.norm.rvs(v_electron[0], v_thermal_electron, size=n_electron, random_state=60))
v_pic_electron[1, :] = np.asarray(stats.norm.rvs(v_electron[1], v_thermal_electron, size=n_electron, random_state=70))
v_pic_electron[2, :] = np.asarray(stats.norm.rvs(v_electron[2], v_thermal_electron, size=n_electron, random_state=80))

print(f"total number of particles is {n_ion + n_electron}.")
print(f"Box size is {nx_pic}")
print(f"ion inertial length is {ion_inertial_length:.1f}")
# Out:
# total number of particles is 40000.
# Box size is 200
# ion inertial length is 70.7

# %% [markdown]
# MHD初期化 \
# U1は上半分、U2は下半分のつもり

# %%
gamma_mhd = 5.0 / 3.0
B0_mhd = B0_pic
rho0_mhd = ne0_pic * m_electron + ni0_pic * m_ion
p0_mhd = ne0_pic * Te_pic + ni0_pic * Ti_pic
VA_mhd = B0_mhd / np.sqrt(rho0_mhd)
CS_mhd = np.sqrt(gamma_mhd * p0_mhd / rho0_mhd)
Cf_mhd = np.sqrt((B0_mhd**2 + 2.0 * p0_mhd) / rho0_mhd)
dx_mhd = dx_pic

nx_mhd = 200
x_min_mhd = 1e-10
x_max_mhd = nx_mhd * dx_mhd - 1e-10
dt_mhd = 0.0
CFL = 0.2
x_coordinate_mhd = np.arange(x_min_mhd, x_max_mhd, dx_mhd)

startpoint = 40
lambda_mhd = 100.0
kx_mhd = 2.0 * np.pi / lambda_mhd
x_coordinate_mhd_perturbation = np.arange(x_min_mhd, lambda_mhd * dx_mhd, dx_mhd)
perturbation_sin = np.zeros(x_coordinate_mhd.shape)
perturbation_sin[startpoint:startpoint+x_coordinate_mhd_perturbation.shape[0]] = -np.sin(kx_mhd * x_coordinate_mhd_perturbation)
U1 = np.zeros([8, nx_mhd])
rho_init = rho0_mhd
u_init = v_ion[0]
v_init = 0.0
w_init = 0.0
Bx_init = B0_mhd
By_init = 0.0
Bz_init = 0.0
p_init = p0_mhd
U1[0, :] = rho_init
U1[1, :] = rho_init * u_init
U1[2, :] = rho_init * v_init
U1[3, :] = rho_init * w_init
U1[4, :] = Bx_init
U1[5, :] = By_init
U1[6, :] = Bz_init
U1[7, :] = p_init / (gamma_mhd - 1) + rho_init * (u_init**2 + v_init**2 + w_init**2)/2 + (Bx_init**2 + By_init**2 + Bz_init**2)/2

F1 = np.zeros(U1.shape)
F1_bar = np.zeros(F1.shape)
G1 = np.zeros(U1.shape)
G1_bar = np.zeros(G1.shape)

U2 = U1.copy()
F2 = F1.copy()
F2_bar = F1_bar.copy()
G2 = G1.copy()
G2_bar2 = G1_bar.copy()

print(f"U size is {U1.shape}")
# Out:
# U size is (8, 200)

# %% [markdown]
# interface用の変数

# %%
index_interface_mhd_start = nx_mhd - 50
index_interface_mhd_end = nx_mhd
index_interface_pic_start = 0
index_interface_pic_end = 50

# %% [markdown]
# 時間発展

# %%
#STEP1:PICとMHDの時間を合わせる
#以下、t1からt2に時間発展させるとする
#ただし、t2 = t1 + dt_mhdとする
B_pic_time_ave = np.zeros(B_pic.shape)
zeroth_moment_ion_time_ave = np.zeros(nx_pic)
zeroth_moment_electron_time_ave = np.zeros(nx_pic)
first_moment_ion_time_ave = np.zeros([3, nx_pic])
first_moment_electron_time_ave = np.zeros([3, nx_pic])
second_moment_ion_time_ave = np.zeros([9, nx_pic])
second_moment_electron_time_ave = np.zeros([9, nx_pic])

total_substeps = 10

steps = 1000
time_mhd = 0.0
time_pic = 0.0
for step in range(steps+1):

    # save
    if (step % 5 == 0):
        print(f"{step} step done... : time_mhd = {time_mhd:.5f}, time_pic = {time_pic:.5f}, dt_mhd = {dt_mhd:.5f}, dt_pic = {dt_pic:.5f}")
        np.save(f'./results_MH_bulkflow/x_ion_{step}.npy', x_pic_ion)
        np.save(f'./results_MH_bulkflow/x_electron_{step}.npy', x_pic_electron)
        np.save(f'./results_MH_bulkflow/v_ion_{step}.npy', v_pic_ion)
        np.save(f'./results_MH_bulkflow/v_electron_{step}.npy', v_pic_electron)
        np.save(f'./results_MH_bulkflow/E_{step}.npy', E_pic)
        np.save(f'./results_MH_bulkflow/B_{step}.npy', B_pic)
        np.save(f'./results_MH_bulkflow/current_{step}.npy', current_pic)
        np.save(f"./results_MH_bulkflow/U1_{step}.npy", U1)

        zeroth_moment_ion = np.zeros(nx_pic)
        zeroth_moment_electron = np.zeros(nx_pic)
        zeroth_moment_ion = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion)
        zeroth_moment_electron = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron)
        first_moment_ion = np.zeros([3, nx_pic])
        first_moment_electron = np.zeros([3, nx_pic])
        first_moment_ion = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion)
        first_moment_electron = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron)
        second_moment_ion = np.zeros([9, nx_pic])
        second_moment_electron = np.zeros([9, nx_pic])
        second_moment_ion = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion)
        second_moment_electron = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron)

        np.save(f'./results_MH_bulkflow/zeroth_moment_ion_{step}.npy', zeroth_moment_ion)
        np.save(f'./results_MH_bulkflow/zeroth_moment_electron_{step}.npy', zeroth_moment_electron)
        np.save(f'./results_MH_bulkflow/first_moment_ion_{step}.npy', first_moment_ion)
        np.save(f'./results_MH_bulkflow/first_moment_electron_{step}.npy', first_moment_electron)
        np.save(f'./results_MH_bulkflow/second_moment_ion_{step}.npy', second_moment_ion)
        np.save(f'./results_MH_bulkflow/second_moment_electron_{step}.npy', second_moment_electron)

        np.save(f'./results_MH_bulkflow/B_time_ave_{step}.npy', B_pic_time_ave)
        np.save(f'./results_MH_bulkflow/zeroth_moment_ion_time_ave_{step}.npy', zeroth_moment_ion_time_ave)
        np.save(f'./results_MH_bulkflow/zeroth_moment_electron_time_ave_{step}.npy', zeroth_moment_electron_time_ave)
        np.save(f'./results_MH_bulkflow/first_moment_ion_time_ave_{step}.npy', first_moment_ion_time_ave)
        np.save(f'./results_MH_bulkflow/first_moment_electron_time_ave_{step}.npy', first_moment_electron_time_ave)
        np.save(f'./results_MH_bulkflow/second_moment_ion_time_ave_{step}.npy', second_moment_ion_time_ave)
        np.save(f'./results_MH_bulkflow/second_moment_electron_time_ave_{step}.npy', second_moment_electron_time_ave)

    #STEP1:MHD-Predictor
    U1_past = U1.copy()
    #MHD
    #----------------------------------------------------------- 
    
    if True:

        U1_bar = U1.copy()

        rho_mhd = U1[0, :].copy()
        u_mhd = U1[1, :].copy() / rho_mhd
        v_mhd = U1[2, :].copy() / rho_mhd
        w_mhd = U1[3, :].copy() / rho_mhd
        Bx_mhd = U1[4, :].copy()
        By_mhd = U1[5, :].copy()
        Bz_mhd = U1[6, :].copy()
        e_mhd = U1[7, :].copy()
        p_mhd = (gamma_mhd - 1.0) \
            * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
                - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
        F1 = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, F1, axis=0)

        cs_mhd = np.sqrt(gamma_mhd * p_mhd / rho_mhd)
        ca_mhd = np.sqrt((Bx_mhd**2 + By_mhd**2 + Bz_mhd**2) / rho_mhd)
        dt_mhd = CFL * np.min(1.0 / ((np.abs(u_mhd) + np.sqrt(cs_mhd**2 + ca_mhd**2)) / dx_mhd))
        if np.isnan(time_mhd):
            print(f"{step} steps (t = {time_mhd:.3f}) : Calculation is crashed!")
            break
        
        U1_bar += -dt_mhd/dx_mhd * (F1 - np.roll(F1, 1, axis=1))
        U1_bar = boundary_symmetric_x(U1_bar)
        
        rho_mhd = U1_bar[0, :].copy()
        u_mhd = U1_bar[1, :].copy() / rho_mhd
        v_mhd = U1_bar[2, :].copy() / rho_mhd
        w_mhd = U1_bar[3, :].copy() / rho_mhd
        Bx_mhd = U1_bar[4, :].copy()
        By_mhd = U1_bar[5, :].copy()
        Bz_mhd = U1_bar[6, :].copy()
        e_mhd = U1_bar[7, :].copy()
        p_mhd = (gamma_mhd - 1.0) \
            * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
                - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
        F1_bar = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, F1_bar, axis=0)
        F1 = 0.5 * (F1 + F1_bar)

        U1 += -dt_mhd/dx_mhd * (F1 - np.roll(F1, 1, axis=1))
        U1 = boundary_symmetric_x(U1)
        
        #time_mhd += dt_mhd

    #STEP2:PIC
    B_pic_time_ave = np.zeros(B_pic.shape)
    zeroth_moment_ion_time_ave = np.zeros(zeroth_moment_ion_time_ave.shape)
    zeroth_moment_electron_time_ave = np.zeros(zeroth_moment_electron_time_ave.shape)
    first_moment_ion_time_ave = np.zeros(first_moment_ion_time_ave.shape)
    first_moment_electron_time_ave = np.zeros(first_moment_electron_time_ave.shape)
    second_moment_ion_time_ave = np.zeros(second_moment_ion_time_ave.shape)
    second_moment_electron_time_ave = np.zeros(second_moment_electron_time_ave.shape)

    U1_send = U1_past
    B_pic = send_MHD_to_PICinterface_B(
        index_interface_mhd_start, index_interface_mhd_end, 
        index_interface_pic_start, index_interface_pic_end, 
        U1_send, B_pic
    )
    E_pic = send_MHD_to_PICinterface_E(
        index_interface_mhd_start, index_interface_mhd_end, 
        index_interface_pic_start, index_interface_pic_end, 
        U1_send, E_pic
    )
    current_pic = send_MHD_to_PICinterface_current(
        index_interface_mhd_start, index_interface_mhd_end, 
        index_interface_pic_start, index_interface_pic_end, 
        U1_send, dx_mhd, current_pic
    )
    v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
        index_interface_mhd_start, index_interface_mhd_end, 
        index_interface_pic_start, index_interface_pic_end, 
        U1_send, dx_mhd, gamma_mhd, q_electron, 
        m_electron, m_ion, nx_pic, c, 
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
    )
    
    dt_pic = dt_mhd / total_substeps
    for substep in range(total_substeps):

        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic) 
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                + U1 * (substep + 0.5) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start, index_interface_mhd_end, 
            index_interface_pic_start, index_interface_pic_end, 
            U1_send, B_pic
        )
        
        v_pic_ion = time_evolution_v(c, E_pic, B_pic, x_pic_ion, q_ion, m_ion, nx_pic, dx_pic, dt_pic, v_pic_ion)
        v_pic_electron = time_evolution_v(c, E_pic, B_pic, x_pic_electron, q_electron, m_electron, nx_pic, dx_pic, dt_pic, v_pic_electron)
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)
        #U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
        #                     + U1 * (substep + 0.5) / total_substeps
        #v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
        #    index_interface_mhd_start, index_interface_mhd_end, 
        #    index_interface_pic_start, index_interface_pic_end, 
        #    U1_send, dx_mhd, gamma_mhd, q_electron, 
        #    m_electron, m_ion, nx_pic, c, 
        #    v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        #)

        current_pic = np.zeros(current_pic.shape)
        current_pic = get_current_density(c, q_ion, v_pic_ion, x_pic_ion, nx_pic, dx_pic, current_pic)
        current_pic = get_current_density(c, q_electron, v_pic_electron, x_pic_electron, nx_pic, dx_pic, current_pic)
        current_pic[:, 0] = current_pic[:, 1]
        current_pic[:, -1] = current_pic[:, -2]
        U1_send = U1_past * (total_substeps - (substep + 0.5)) / total_substeps \
                             + U1 * (substep + 0.5) / total_substeps
        current_pic = send_MHD_to_PICinterface_current(
            index_interface_mhd_start, index_interface_mhd_end, 
            index_interface_pic_start, index_interface_pic_end, 
            U1_send, dx_mhd, current_pic
        )
        
        B_pic = time_evolution_B(E_pic, dx_pic, dt_pic/2, B_pic)
        B_pic = boundary_B(B_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                             + U1 * (substep + 1.0) / total_substeps
        B_pic = send_MHD_to_PICinterface_B(
            index_interface_mhd_start, index_interface_mhd_end, 
            index_interface_pic_start, index_interface_pic_end, 
            U1_send, B_pic
        )
        
        E_pic = time_evolution_E(B_pic, current_pic, c, epsilon0, dx_pic, dt_pic, E_pic)
        E_pic = boundary_E(E_pic)
        rho_pic = np.zeros(rho_pic.shape)
        rho_pic = get_rho(q_ion, x_pic_ion, nx_pic, dx_pic, rho_pic)
        rho_pic = get_rho(q_electron, x_pic_electron, nx_pic, dx_pic, rho_pic)
        rho_pic[0] = rho_pic[1]
        rho_pic[-1] = rho_pic[-2]
        E_pic = filter_E(rho_pic, dx_pic, dt_pic, d_pic, epsilon0, E_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                             + U1 * (substep + 1.0) / total_substeps
        E_pic = send_MHD_to_PICinterface_E(
            index_interface_mhd_start, index_interface_mhd_end, 
            index_interface_pic_start, index_interface_pic_end, 
            U1_send, E_pic
        )
        
        x_pic_ion = time_evolution_x(c, dt_pic/2, v_pic_ion, x_pic_ion)
        x_pic_electron = time_evolution_x(c, dt_pic/2, v_pic_electron, x_pic_electron)
        #とりあえず
        v_pic_ion, x_pic_ion = open_condition_x_left(v_pic_ion, x_pic_ion, x_min_pic)
        v_pic_ion, x_pic_ion = open_condition_x_right(v_pic_ion, x_pic_ion, x_max_pic)
        v_pic_electron, x_pic_electron = open_condition_x_left(v_pic_electron, x_pic_electron, x_min_pic)
        v_pic_electron, x_pic_electron = open_condition_x_right(v_pic_electron, x_pic_electron, x_max_pic)
        U1_send = U1_past * (total_substeps - (substep + 1.0)) / total_substeps \
                             + U1 * (substep + 1.0) / total_substeps
        v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron = send_MHD_to_PICinterface_particle(
            index_interface_mhd_start, index_interface_mhd_end, 
            index_interface_pic_start, index_interface_pic_end, 
            U1_send, dx_mhd, gamma_mhd, q_electron, 
            m_electron, m_ion, nx_pic, c, 
            v_pic_ion, v_pic_electron, x_pic_ion, x_pic_electron
        )

        time_pic += dt_pic

        if True:

            B_pic_time_ave += B_pic

            zeroth_moment_ion_tmp = np.zeros(zeroth_moment_ion_time_ave.shape)
            zeroth_moment_electron_tmp = np.zeros(zeroth_moment_electron_time_ave.shape)
            zeroth_moment_ion_tmp = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion_tmp)
            zeroth_moment_electron_tmp = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron_tmp)
            zeroth_moment_ion_time_ave += zeroth_moment_ion_tmp
            zeroth_moment_electron_time_ave += zeroth_moment_electron_tmp

            first_moment_ion_tmp = np.zeros(first_moment_ion_time_ave.shape)
            first_moment_electron_tmp = np.zeros(first_moment_electron_time_ave.shape)
            first_moment_ion_tmp = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion_tmp)
            first_moment_electron_tmp = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron_tmp)
            first_moment_ion_time_ave += first_moment_ion_tmp
            first_moment_electron_time_ave += first_moment_electron_tmp

            second_moment_ion_tmp = np.zeros(second_moment_ion_time_ave.shape)
            second_moment_electron_tmp = np.zeros(second_moment_electron_time_ave.shape)
            second_moment_ion_tmp = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion_tmp)
            second_moment_electron_tmp = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron_tmp)
            second_moment_ion_time_ave += second_moment_ion_tmp
            second_moment_electron_time_ave += second_moment_electron_tmp
            
    B_pic_time_ave /= total_substeps
    zeroth_moment_ion_time_ave /= total_substeps
    zeroth_moment_electron_time_ave /= total_substeps
    first_moment_ion_time_ave /= total_substeps
    first_moment_electron_time_ave /= total_substeps
    second_moment_ion_time_ave /= total_substeps
    second_moment_electron_time_ave /= total_substeps


    #STEP3:MHD-Correcter
    U1_PIC = np.zeros(U1.shape)
    #n+1/2にする
    U1_PIC[:, :] = 0.5 * (U1_past[:, :] + U1[:, :])
    U1_PIC = send_PIC_to_MHDinterface(
        index_interface_mhd_start, index_interface_mhd_end, 
        index_interface_pic_start, index_interface_pic_end, 
        gamma_mhd, m_electron, m_ion, nx_pic, B_pic_time_ave, 
        zeroth_moment_ion_time_ave, zeroth_moment_electron_time_ave, 
        first_moment_ion_time_ave, first_moment_electron_time_ave, 
        second_moment_ion_time_ave, second_moment_electron_time_ave, 
        U1_PIC
    )
    
    U1 = U1_past.copy()
    
    if True:

        rho_mhd = U1_PIC[0, :].copy()
        u_mhd = U1_PIC[1, :].copy() / rho_mhd
        v_mhd = U1_PIC[2, :].copy() / rho_mhd
        w_mhd = U1_PIC[3, :].copy() / rho_mhd
        Bx_mhd = U1_PIC[4, :].copy()
        By_mhd = U1_PIC[5, :].copy()
        Bz_mhd = U1_PIC[6, :].copy()
        e_mhd = U1_PIC[7, :].copy()
        p_mhd = (gamma_mhd - 1.0) \
            * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
                - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
        F1 = get_flux_HLLD(rho_mhd, u_mhd, v_mhd, w_mhd, Bx_mhd, By_mhd, Bz_mhd, e_mhd, gamma_mhd, F1, axis=0)

        U1 += -dt_mhd/dx_mhd * (F1 - np.roll(F1, 1, axis=1))
        U1 = boundary_symmetric_x(U1)
        
        time_mhd += dt_mhd
# Out:
# 0 step done... : time_mhd = 0.00000, time_pic = 0.00000, dt_mhd = 0.00000, dt_pic = 0.00000
# 5 step done... : time_mhd = 3.35644, time_pic = 3.35644, dt_mhd = 0.67083, dt_pic = 0.06708
# 10 step done... : time_mhd = 6.70693, time_pic = 6.70693, dt_mhd = 0.66963, dt_pic = 0.06696
# 15 step done... : time_mhd = 10.05284, time_pic = 10.05284, dt_mhd = 0.66901, dt_pic = 0.06690
# 20 step done... : time_mhd = 13.39748, time_pic = 13.39748, dt_mhd = 0.66890, dt_pic = 0.06689
# 25 step done... : time_mhd = 16.74116, time_pic = 16.74116, dt_mhd = 0.66841, dt_pic = 0.06684
# 30 step done... : time_mhd = 20.08100, time_pic = 20.08100, dt_mhd = 0.66777, dt_pic = 0.06678
# 35 step done... : time_mhd = 23.41911, time_pic = 23.41911, dt_mhd = 0.66755, dt_pic = 0.06675
# 40 step done... : time_mhd = 26.75634, time_pic = 26.75634, dt_mhd = 0.66737, dt_pic = 0.06674
# 45 step done... : time_mhd = 30.09194, time_pic = 30.09194, dt_mhd = 0.66688, dt_pic = 0.06669
# 50 step done... : time_mhd = 33.42398, time_pic = 33.42398, dt_mhd = 0.66607, dt_pic = 0.06661
# 55 step done... : time_mhd = 36.75167, time_pic = 36.75167, dt_mhd = 0.66519, dt_pic = 0.06652
# 60 step done... : time_mhd = 40.07573, time_pic = 40.07573, dt_mhd = 0.66465, dt_pic = 0.06646
# 65 step done... : time_mhd = 43.39888, time_pic = 43.39888, dt_mhd = 0.66467, dt_pic = 0.06647
# 70 step done... : time_mhd = 46.72303, time_pic = 46.72303, dt_mhd = 0.66495, dt_pic = 0.06649
# 75 step done... : time_mhd = 50.04821, time_pic = 50.04821, dt_mhd = 0.66497, dt_pic = 0.06650
# 80 step done... : time_mhd = 53.37235, time_pic = 53.37235, dt_mhd = 0.66479, dt_pic = 0.06648
# 85 step done... : time_mhd = 56.69594, time_pic = 56.69594, dt_mhd = 0.66462, dt_pic = 0.06646
# 90 step done... : time_mhd = 60.01846, time_pic = 60.01846, dt_mhd = 0.66444, dt_pic = 0.06644
# 95 step done... : time_mhd = 63.33951, time_pic = 63.33951, dt_mhd = 0.66412, dt_pic = 0.06641
# 100 step done... : time_mhd = 66.65928, time_pic = 66.65928, dt_mhd = 0.66376, dt_pic = 0.06638
# 105 step done... : time_mhd = 69.97699, time_pic = 69.97699, dt_mhd = 0.66345, dt_pic = 0.06634
# 110 step done... : time_mhd = 73.29400, time_pic = 73.29400, dt_mhd = 0.66331, dt_pic = 0.06633
# 115 step done... : time_mhd = 76.60876, time_pic = 76.60876, dt_mhd = 0.66272, dt_pic = 0.06627
# 120 step done... : time_mhd = 79.92135, time_pic = 79.92135, dt_mhd = 0.66243, dt_pic = 0.06624
# 125 step done... : time_mhd = 83.23284, time_pic = 83.23284, dt_mhd = 0.66221, dt_pic = 0.06622
# 130 step done... : time_mhd = 86.54341, time_pic = 86.54341, dt_mhd = 0.66205, dt_pic = 0.06621
# 135 step done... : time_mhd = 89.85312, time_pic = 89.85312, dt_mhd = 0.66185, dt_pic = 0.06618
# 140 step done... : time_mhd = 93.16143, time_pic = 93.16143, dt_mhd = 0.66151, dt_pic = 0.06615
# 145 step done... : time_mhd = 96.46746, time_pic = 96.46746, dt_mhd = 0.66102, dt_pic = 0.06610
# 150 step done... : time_mhd = 99.77174, time_pic = 99.77174, dt_mhd = 0.66083, dt_pic = 0.06608
# 155 step done... : time_mhd = 103.07646, time_pic = 103.07646, dt_mhd = 0.66104, dt_pic = 0.06610
# 160 step done... : time_mhd = 106.38075, time_pic = 106.38075, dt_mhd = 0.66058, dt_pic = 0.06606
# 165 step done... : time_mhd = 109.68182, time_pic = 109.68182, dt_mhd = 0.66004, dt_pic = 0.06600
# 170 step done... : time_mhd = 112.98188, time_pic = 112.98188, dt_mhd = 0.66005, dt_pic = 0.06601
# 175 step done... : time_mhd = 116.28306, time_pic = 116.28306, dt_mhd = 0.66039, dt_pic = 0.06604
# 180 step done... : time_mhd = 119.58473, time_pic = 119.58473, dt_mhd = 0.66002, dt_pic = 0.06600
# 185 step done... : time_mhd = 122.88364, time_pic = 122.88364, dt_mhd = 0.65973, dt_pic = 0.06597
# 190 step done... : time_mhd = 126.18266, time_pic = 126.18266, dt_mhd = 0.65989, dt_pic = 0.06599
# 195 step done... : time_mhd = 129.48282, time_pic = 129.48282, dt_mhd = 0.65998, dt_pic = 0.06600
# 200 step done... : time_mhd = 132.78030, time_pic = 132.78030, dt_mhd = 0.65930, dt_pic = 0.06593
# 205 step done... : time_mhd = 136.07663, time_pic = 136.07663, dt_mhd = 0.65930, dt_pic = 0.06593
# 210 step done... : time_mhd = 139.37370, time_pic = 139.37370, dt_mhd = 0.65951, dt_pic = 0.06595
# 215 step done... : time_mhd = 142.67184, time_pic = 142.67184, dt_mhd = 0.65956, dt_pic = 0.06596
# 220 step done... : time_mhd = 145.96847, time_pic = 145.96847, dt_mhd = 0.65925, dt_pic = 0.06593
# 225 step done... : time_mhd = 149.26502, time_pic = 149.26502, dt_mhd = 0.65937, dt_pic = 0.06594
# 230 step done... : time_mhd = 152.56245, time_pic = 152.56245, dt_mhd = 0.65956, dt_pic = 0.06596
# 235 step done... : time_mhd = 155.86044, time_pic = 155.86044, dt_mhd = 0.65961, dt_pic = 0.06596
# 240 step done... : time_mhd = 159.15860, time_pic = 159.15860, dt_mhd = 0.65964, dt_pic = 0.06596
# 245 step done... : time_mhd = 162.45610, time_pic = 162.45610, dt_mhd = 0.65941, dt_pic = 0.06594
# 250 step done... : time_mhd = 165.75256, time_pic = 165.75256, dt_mhd = 0.65924, dt_pic = 0.06592
# 255 step done... : time_mhd = 169.04878, time_pic = 169.04878, dt_mhd = 0.65928, dt_pic = 0.06593
# 260 step done... : time_mhd = 172.34571, time_pic = 172.34571, dt_mhd = 0.65947, dt_pic = 0.06595
# 265 step done... : time_mhd = 175.64262, time_pic = 175.64262, dt_mhd = 0.65922, dt_pic = 0.06592
# 270 step done... : time_mhd = 178.93841, time_pic = 178.93841, dt_mhd = 0.65917, dt_pic = 0.06592
# 275 step done... : time_mhd = 182.23473, time_pic = 182.23473, dt_mhd = 0.65935, dt_pic = 0.06594
# 280 step done... : time_mhd = 185.53298, time_pic = 185.53298, dt_mhd = 0.65989, dt_pic = 0.06599
# 285 step done... : time_mhd = 188.83298, time_pic = 188.83298, dt_mhd = 0.65974, dt_pic = 0.06597
# 290 step done... : time_mhd = 192.12967, time_pic = 192.12967, dt_mhd = 0.65914, dt_pic = 0.06591
# 295 step done... : time_mhd = 195.42371, time_pic = 195.42371, dt_mhd = 0.65838, dt_pic = 0.06584
# 300 step done... : time_mhd = 198.71147, time_pic = 198.71147, dt_mhd = 0.65706, dt_pic = 0.06571
# 305 step done... : time_mhd = 201.99472, time_pic = 201.99472, dt_mhd = 0.65650, dt_pic = 0.06565
# 310 step done... : time_mhd = 205.27707, time_pic = 205.27707, dt_mhd = 0.65647, dt_pic = 0.06565
# 315 step done... : time_mhd = 208.55873, time_pic = 208.55873, dt_mhd = 0.65593, dt_pic = 0.06559
# 320 step done... : time_mhd = 211.83481, time_pic = 211.83481, dt_mhd = 0.65485, dt_pic = 0.06548
# 325 step done... : time_mhd = 215.10825, time_pic = 215.10825, dt_mhd = 0.65466, dt_pic = 0.06547
# 330 step done... : time_mhd = 218.38165, time_pic = 218.38165, dt_mhd = 0.65471, dt_pic = 0.06547
# 335 step done... : time_mhd = 221.65571, time_pic = 221.65571, dt_mhd = 0.65490, dt_pic = 0.06549
# 340 step done... : time_mhd = 224.92965, time_pic = 224.92965, dt_mhd = 0.65461, dt_pic = 0.06546
# 345 step done... : time_mhd = 228.20212, time_pic = 228.20212, dt_mhd = 0.65445, dt_pic = 0.06545
# 350 step done... : time_mhd = 231.47415, time_pic = 231.47415, dt_mhd = 0.65436, dt_pic = 0.06544
# 355 step done... : time_mhd = 234.74588, time_pic = 234.74588, dt_mhd = 0.65437, dt_pic = 0.06544
# 360 step done... : time_mhd = 238.01815, time_pic = 238.01815, dt_mhd = 0.65453, dt_pic = 0.06545
# 365 step done... : time_mhd = 241.29150, time_pic = 241.29150, dt_mhd = 0.65479, dt_pic = 0.06548
# 370 step done... : time_mhd = 244.56663, time_pic = 244.56663, dt_mhd = 0.65520, dt_pic = 0.06552
# 375 step done... : time_mhd = 247.84368, time_pic = 247.84368, dt_mhd = 0.65540, dt_pic = 0.06554
# 380 step done... : time_mhd = 251.12035, time_pic = 251.12035, dt_mhd = 0.65532, dt_pic = 0.06553
# 385 step done... : time_mhd = 254.39691, time_pic = 254.39691, dt_mhd = 0.65533, dt_pic = 0.06553
# 390 step done... : time_mhd = 257.67220, time_pic = 257.67220, dt_mhd = 0.65489, dt_pic = 0.06549
# 395 step done... : time_mhd = 260.94565, time_pic = 260.94565, dt_mhd = 0.65457, dt_pic = 0.06546
# 400 step done... : time_mhd = 264.21783, time_pic = 264.21783, dt_mhd = 0.65419, dt_pic = 0.06542
# 405 step done... : time_mhd = 267.48466, time_pic = 267.48466, dt_mhd = 0.65279, dt_pic = 0.06528
# 410 step done... : time_mhd = 270.74428, time_pic = 270.74428, dt_mhd = 0.65137, dt_pic = 0.06514
# 415 step done... : time_mhd = 273.99744, time_pic = 273.99744, dt_mhd = 0.65016, dt_pic = 0.06502
# 420 step done... : time_mhd = 277.24502, time_pic = 277.24502, dt_mhd = 0.64897, dt_pic = 0.06490
# 425 step done... : time_mhd = 280.48444, time_pic = 280.48444, dt_mhd = 0.64715, dt_pic = 0.06471
# 430 step done... : time_mhd = 283.71512, time_pic = 283.71512, dt_mhd = 0.64552, dt_pic = 0.06455
# 435 step done... : time_mhd = 286.93934, time_pic = 286.93934, dt_mhd = 0.64450, dt_pic = 0.06445
# 440 step done... : time_mhd = 290.16095, time_pic = 290.16095, dt_mhd = 0.64429, dt_pic = 0.06443
# 445 step done... : time_mhd = 293.38059, time_pic = 293.38059, dt_mhd = 0.64326, dt_pic = 0.06433
# 450 step done... : time_mhd = 296.59191, time_pic = 296.59191, dt_mhd = 0.64172, dt_pic = 0.06417
# 455 step done... : time_mhd = 299.79858, time_pic = 299.79858, dt_mhd = 0.64121, dt_pic = 0.06412
# 460 step done... : time_mhd = 303.00476, time_pic = 303.00476, dt_mhd = 0.64133, dt_pic = 0.06413
# 465 step done... : time_mhd = 306.21262, time_pic = 306.21262, dt_mhd = 0.64175, dt_pic = 0.06417
# 470 step done... : time_mhd = 309.42210, time_pic = 309.42210, dt_mhd = 0.64188, dt_pic = 0.06419
# 475 step done... : time_mhd = 312.63033, time_pic = 312.63033, dt_mhd = 0.64157, dt_pic = 0.06416
# 480 step done... : time_mhd = 315.83825, time_pic = 315.83825, dt_mhd = 0.64157, dt_pic = 0.06416
# 485 step done... : time_mhd = 319.04358, time_pic = 319.04358, dt_mhd = 0.64067, dt_pic = 0.06407
# 490 step done... : time_mhd = 322.24289, time_pic = 322.24289, dt_mhd = 0.63927, dt_pic = 0.06393
# 495 step done... : time_mhd = 325.43507, time_pic = 325.43507, dt_mhd = 0.63795, dt_pic = 0.06380
# 500 step done... : time_mhd = 328.62258, time_pic = 328.62258, dt_mhd = 0.63728, dt_pic = 0.06373
# 505 step done... : time_mhd = 331.80792, time_pic = 331.80792, dt_mhd = 0.63694, dt_pic = 0.06369
# 510 step done... : time_mhd = 334.99132, time_pic = 334.99132, dt_mhd = 0.63647, dt_pic = 0.06365
# 515 step done... : time_mhd = 338.17170, time_pic = 338.17170, dt_mhd = 0.63575, dt_pic = 0.06358
# 520 step done... : time_mhd = 341.34721, time_pic = 341.34721, dt_mhd = 0.63461, dt_pic = 0.06346
# 525 step done... : time_mhd = 344.51602, time_pic = 344.51602, dt_mhd = 0.63320, dt_pic = 0.06332
# 530 step done... : time_mhd = 347.67851, time_pic = 347.67851, dt_mhd = 0.63211, dt_pic = 0.06321
# 535 step done... : time_mhd = 350.83628, time_pic = 350.83628, dt_mhd = 0.63094, dt_pic = 0.06309
# 540 step done... : time_mhd = 353.98532, time_pic = 353.98532, dt_mhd = 0.62911, dt_pic = 0.06291
# 545 step done... : time_mhd = 357.12643, time_pic = 357.12643, dt_mhd = 0.62767, dt_pic = 0.06277
# 550 step done... : time_mhd = 360.26154, time_pic = 360.26154, dt_mhd = 0.62666, dt_pic = 0.06267
# 555 step done... : time_mhd = 363.39346, time_pic = 363.39346, dt_mhd = 0.62628, dt_pic = 0.06263
# 560 step done... : time_mhd = 366.52473, time_pic = 366.52473, dt_mhd = 0.62626, dt_pic = 0.06263
# 565 step done... : time_mhd = 369.65626, time_pic = 369.65626, dt_mhd = 0.62635, dt_pic = 0.06263
# 570 step done... : time_mhd = 372.78724, time_pic = 372.78724, dt_mhd = 0.62589, dt_pic = 0.06259
# 575 step done... : time_mhd = 375.91420, time_pic = 375.91420, dt_mhd = 0.62509, dt_pic = 0.06251
# 580 step done... : time_mhd = 379.03799, time_pic = 379.03799, dt_mhd = 0.62458, dt_pic = 0.06246
# 585 step done... : time_mhd = 382.16003, time_pic = 382.16003, dt_mhd = 0.62430, dt_pic = 0.06243
# 590 step done... : time_mhd = 385.28131, time_pic = 385.28131, dt_mhd = 0.62428, dt_pic = 0.06243
# 595 step done... : time_mhd = 388.40362, time_pic = 388.40362, dt_mhd = 0.62466, dt_pic = 0.06247
# 600 step done... : time_mhd = 391.52964, time_pic = 391.52964, dt_mhd = 0.62564, dt_pic = 0.06256
# 605 step done... : time_mhd = 394.66144, time_pic = 394.66144, dt_mhd = 0.62681, dt_pic = 0.06268
# 610 step done... : time_mhd = 397.79794, time_pic = 397.79794, dt_mhd = 0.62751, dt_pic = 0.06275
# 615 step done... : time_mhd = 400.93547, time_pic = 400.93547, dt_mhd = 0.62744, dt_pic = 0.06274
# 620 step done... : time_mhd = 404.07171, time_pic = 404.07171, dt_mhd = 0.62714, dt_pic = 0.06271
# 625 step done... : time_mhd = 407.20726, time_pic = 407.20726, dt_mhd = 0.62714, dt_pic = 0.06271
# 630 step done... : time_mhd = 410.34371, time_pic = 410.34371, dt_mhd = 0.62740, dt_pic = 0.06274
# 635 step done... : time_mhd = 413.48133, time_pic = 413.48133, dt_mhd = 0.62759, dt_pic = 0.06276
# 640 step done... : time_mhd = 416.61926, time_pic = 416.61926, dt_mhd = 0.62754, dt_pic = 0.06275
# 645 step done... : time_mhd = 419.75612, time_pic = 419.75612, dt_mhd = 0.62721, dt_pic = 0.06272
# 650 step done... : time_mhd = 422.88937, time_pic = 422.88937, dt_mhd = 0.62617, dt_pic = 0.06262
# 655 step done... : time_mhd = 426.01590, time_pic = 426.01590, dt_mhd = 0.62471, dt_pic = 0.06247
# 660 step done... : time_mhd = 429.13569, time_pic = 429.13569, dt_mhd = 0.62350, dt_pic = 0.06235
# 665 step done... : time_mhd = 432.25026, time_pic = 432.25026, dt_mhd = 0.62257, dt_pic = 0.06226
# 670 step done... : time_mhd = 435.36119, time_pic = 435.36119, dt_mhd = 0.62196, dt_pic = 0.06220
# 675 step done... : time_mhd = 438.46986, time_pic = 438.46986, dt_mhd = 0.62163, dt_pic = 0.06216
# 680 step done... : time_mhd = 441.57808, time_pic = 441.57808, dt_mhd = 0.62168, dt_pic = 0.06217
# 685 step done... : time_mhd = 444.68306, time_pic = 444.68306, dt_mhd = 0.62027, dt_pic = 0.06203
# 690 step done... : time_mhd = 447.77994, time_pic = 447.77994, dt_mhd = 0.61885, dt_pic = 0.06189
# 695 step done... : time_mhd = 450.87082, time_pic = 450.87082, dt_mhd = 0.61775, dt_pic = 0.06178
# 700 step done... : time_mhd = 453.95669, time_pic = 453.95669, dt_mhd = 0.61681, dt_pic = 0.06168
# 705 step done... : time_mhd = 457.03791, time_pic = 457.03791, dt_mhd = 0.61583, dt_pic = 0.06158
# 710 step done... : time_mhd = 460.11405, time_pic = 460.11405, dt_mhd = 0.61488, dt_pic = 0.06149
# 715 step done... : time_mhd = 463.18757, time_pic = 463.18757, dt_mhd = 0.61472, dt_pic = 0.06147
# 720 step done... : time_mhd = 466.26222, time_pic = 466.26222, dt_mhd = 0.61509, dt_pic = 0.06151
# 725 step done... : time_mhd = 469.33882, time_pic = 469.33882, dt_mhd = 0.61545, dt_pic = 0.06155
# 730 step done... : time_mhd = 472.41631, time_pic = 472.41631, dt_mhd = 0.61546, dt_pic = 0.06155
# 735 step done... : time_mhd = 475.49169, time_pic = 475.49169, dt_mhd = 0.61476, dt_pic = 0.06148
# 740 step done... : time_mhd = 478.56254, time_pic = 478.56254, dt_mhd = 0.61373, dt_pic = 0.06137
# 745 step done... : time_mhd = 481.62752, time_pic = 481.62752, dt_mhd = 0.61250, dt_pic = 0.06125
# 750 step done... : time_mhd = 484.68722, time_pic = 484.68722, dt_mhd = 0.61167, dt_pic = 0.06117
# 755 step done... : time_mhd = 487.74464, time_pic = 487.74464, dt_mhd = 0.61142, dt_pic = 0.06114
# 760 step done... : time_mhd = 490.80128, time_pic = 490.80128, dt_mhd = 0.61122, dt_pic = 0.06112
# 765 step done... : time_mhd = 493.85592, time_pic = 493.85592, dt_mhd = 0.61070, dt_pic = 0.06107
# 770 step done... : time_mhd = 496.90767, time_pic = 496.90767, dt_mhd = 0.61017, dt_pic = 0.06102
# 775 step done... : time_mhd = 499.95867, time_pic = 499.95867, dt_mhd = 0.61010, dt_pic = 0.06101
# 780 step done... : time_mhd = 503.00344, time_pic = 503.00344, dt_mhd = 0.60816, dt_pic = 0.06082
# 785 step done... : time_mhd = 506.03807, time_pic = 506.03807, dt_mhd = 0.60616, dt_pic = 0.06062
# 790 step done... : time_mhd = 509.06522, time_pic = 509.06522, dt_mhd = 0.60514, dt_pic = 0.06051
# 795 step done... : time_mhd = 512.09122, time_pic = 512.09122, dt_mhd = 0.60532, dt_pic = 0.06053
# 800 step done... : time_mhd = 515.12000, time_pic = 515.12000, dt_mhd = 0.60614, dt_pic = 0.06061
# 805 step done... : time_mhd = 518.15416, time_pic = 518.15416, dt_mhd = 0.60731, dt_pic = 0.06073
# 810 step done... : time_mhd = 521.19375, time_pic = 521.19375, dt_mhd = 0.60825, dt_pic = 0.06082
# 815 step done... : time_mhd = 524.23708, time_pic = 524.23708, dt_mhd = 0.60893, dt_pic = 0.06089
# 820 step done... : time_mhd = 527.28370, time_pic = 527.28370, dt_mhd = 0.60960, dt_pic = 0.06096
# 825 step done... : time_mhd = 530.33412, time_pic = 530.33412, dt_mhd = 0.61041, dt_pic = 0.06104
# 830 step done... : time_mhd = 533.38797, time_pic = 533.38797, dt_mhd = 0.61094, dt_pic = 0.06109
# 835 step done... : time_mhd = 536.44296, time_pic = 536.44296, dt_mhd = 0.61100, dt_pic = 0.06110
# 840 step done... : time_mhd = 539.49765, time_pic = 539.49765, dt_mhd = 0.61087, dt_pic = 0.06109
# 845 step done... : time_mhd = 542.55147, time_pic = 542.55147, dt_mhd = 0.61071, dt_pic = 0.06107
# 850 step done... : time_mhd = 545.60479, time_pic = 545.60479, dt_mhd = 0.61064, dt_pic = 0.06106
# 855 step done... : time_mhd = 548.65809, time_pic = 548.65809, dt_mhd = 0.61070, dt_pic = 0.06107
# 860 step done... : time_mhd = 551.71230, time_pic = 551.71230, dt_mhd = 0.61094, dt_pic = 0.06109
# 865 step done... : time_mhd = 554.76782, time_pic = 554.76782, dt_mhd = 0.61122, dt_pic = 0.06112
# 870 step done... : time_mhd = 557.82486, time_pic = 557.82486, dt_mhd = 0.61153, dt_pic = 0.06115
# 875 step done... : time_mhd = 560.88320, time_pic = 560.88320, dt_mhd = 0.61174, dt_pic = 0.06117
# 880 step done... : time_mhd = 563.94238, time_pic = 563.94238, dt_mhd = 0.61190, dt_pic = 0.06119
# 885 step done... : time_mhd = 567.00244, time_pic = 567.00244, dt_mhd = 0.61209, dt_pic = 0.06121
# 890 step done... : time_mhd = 570.06347, time_pic = 570.06347, dt_mhd = 0.61228, dt_pic = 0.06123
# 895 step done... : time_mhd = 573.12528, time_pic = 573.12528, dt_mhd = 0.61242, dt_pic = 0.06124
# 900 step done... : time_mhd = 576.18797, time_pic = 576.18797, dt_mhd = 0.61262, dt_pic = 0.06126
# 905 step done... : time_mhd = 579.25021, time_pic = 579.25021, dt_mhd = 0.61206, dt_pic = 0.06121
# 910 step done... : time_mhd = 582.30651, time_pic = 582.30651, dt_mhd = 0.61070, dt_pic = 0.06107
# 915 step done... : time_mhd = 585.35625, time_pic = 585.35625, dt_mhd = 0.60948, dt_pic = 0.06095
# 920 step done... : time_mhd = 588.40058, time_pic = 588.40058, dt_mhd = 0.60853, dt_pic = 0.06085
# 925 step done... : time_mhd = 591.44262, time_pic = 591.44262, dt_mhd = 0.60842, dt_pic = 0.06084
# 930 step done... : time_mhd = 594.48553, time_pic = 594.48553, dt_mhd = 0.60869, dt_pic = 0.06087
# 935 step done... : time_mhd = 597.52939, time_pic = 597.52939, dt_mhd = 0.60881, dt_pic = 0.06088
# 940 step done... : time_mhd = 600.57338, time_pic = 600.57338, dt_mhd = 0.60876, dt_pic = 0.06088
# 945 step done... : time_mhd = 603.61625, time_pic = 603.61625, dt_mhd = 0.60845, dt_pic = 0.06084
# 950 step done... : time_mhd = 606.65777, time_pic = 606.65777, dt_mhd = 0.60825, dt_pic = 0.06083
# 955 step done... : time_mhd = 609.69883, time_pic = 609.69883, dt_mhd = 0.60819, dt_pic = 0.06082
# 960 step done... : time_mhd = 612.73989, time_pic = 612.73989, dt_mhd = 0.60825, dt_pic = 0.06082
# 965 step done... : time_mhd = 615.78159, time_pic = 615.78159, dt_mhd = 0.60841, dt_pic = 0.06084
# 970 step done... : time_mhd = 618.82438, time_pic = 618.82438, dt_mhd = 0.60868, dt_pic = 0.06087
# 975 step done... : time_mhd = 621.86895, time_pic = 621.86895, dt_mhd = 0.60907, dt_pic = 0.06091
# 980 step done... : time_mhd = 624.91544, time_pic = 624.91544, dt_mhd = 0.60944, dt_pic = 0.06094
# 985 step done... : time_mhd = 627.96367, time_pic = 627.96367, dt_mhd = 0.60976, dt_pic = 0.06098
# 990 step done... : time_mhd = 631.01337, time_pic = 631.01337, dt_mhd = 0.61006, dt_pic = 0.06101
# 995 step done... : time_mhd = 634.06447, time_pic = 634.06447, dt_mhd = 0.61032, dt_pic = 0.06103
# 1000 step done... : time_mhd = 637.11636, time_pic = 637.11636, dt_mhd = 0.61038, dt_pic = 0.06104

# %% [markdown]
# プロット

# %%
k = 130

B = np.load(f"results_MH_bulkflow/B_{k}.npy")
E = np.load(f"results_MH_bulkflow/E_{k}.npy")
current = np.load(f"results_MH_bulkflow/current_{k}.npy")
x_pic_ion = np.load(f"results_MH_bulkflow/x_ion_{k}.npy")
x_pic_electron = np.load(f"results_MH_bulkflow/x_electron_{k}.npy")
v_pic_ion = np.load(f"results_MH_bulkflow/v_ion_{k}.npy")
v_pic_electron = np.load(f"results_MH_bulkflow/v_electron_{k}.npy")
zeroth_moment_ion = np.load(f"results_MH_bulkflow/zeroth_moment_ion_{k}.npy")
zeroth_moment_electron = np.load(f"results_MH_bulkflow/zeroth_moment_electron_{k}.npy")
first_moment_ion = np.load(f"results_MH_bulkflow/first_moment_ion_{k}.npy")
first_moment_electron = np.load(f"results_MH_bulkflow/first_moment_electron_{k}.npy")
second_moment_ion = np.load(f"results_MH_bulkflow/second_moment_ion_{k}.npy")
second_moment_electron = np.load(f"results_MH_bulkflow/second_moment_electron_{k}.npy")

B_time_ave = np.load(f"results_MH_bulkflow/B_time_ave_{k}.npy")
zeroth_moment_ion_time_ave = np.load(f"results_MH_bulkflow/zeroth_moment_ion_time_ave_{k}.npy")
zeroth_moment_electron_time_ave = np.load(f"results_MH_bulkflow/zeroth_moment_electron_time_ave_{k}.npy")
first_moment_ion_time_ave = np.load(f"results_MH_bulkflow/first_moment_ion_time_ave_{k}.npy")
first_moment_electron_time_ave = np.load(f"results_MH_bulkflow/first_moment_electron_time_ave_{k}.npy")
second_moment_ion_time_ave = np.load(f"results_MH_bulkflow/second_moment_ion_time_ave_{k}.npy")
second_moment_electron_time_ave = np.load(f"results_MH_bulkflow/second_moment_electron_time_ave_{k}.npy")

U = np.load(f"results_MH_bulkflow/U1_{k}.npy")
rho_mhd = U[0, :]
u_mhd = U[1, :] / rho_mhd
v_mhd = U[2, :] / rho_mhd
w_mhd = U[3, :] / rho_mhd
Bx_mhd = U[4, :]
By_mhd = U[5, :]
Bz_mhd = U[6, :]
e_mhd = U[7, :]
p_mhd = (gamma_mhd - 1.0) \
        * (e_mhd - 0.5 * rho_mhd * (u_mhd**2+v_mhd**2+w_mhd**2)
            - 0.5 * (Bx_mhd**2+By_mhd**2+Bz_mhd**2))
Ex_mhd = -(v_mhd * Bz_mhd - w_mhd * By_mhd)
Ey_mhd = -(w_mhd * Bx_mhd - u_mhd * Bz_mhd)
Ez_mhd = -(u_mhd * By_mhd - v_mhd * Bx_mhd)
current_x_mhd = np.zeros(Bx_mhd.shape)
current_y_mhd = -(np.roll(Bz_mhd, -1, axis=0) - np.roll(Bz_mhd, 1, axis=0)) / (2*dx_mhd)
current_z_mhd = (np.roll(By_mhd, -1, axis=0) - np.roll(By_mhd, 1, axis=0)) / (2*dx_mhd)
current_y_mhd[0] = current_y_mhd[1] 
current_y_mhd[-1] = current_y_mhd[-2] 
current_z_mhd[0] = current_z_mhd[1] 
current_z_mhd[-1] = current_z_mhd[-2]

# %%
fig = plt.figure(figsize=(8, 4))
ax1 = fig.add_subplot(111)

plt.scatter(x_pic_ion[0, :], v_pic_ion[0, :] / v_thermal_ion, s=1, color='orange')
plt.scatter(x_pic_electron[0, :], v_pic_electron[0, :] / v_thermal_ion, s=1, color='blue')
#plt.ylim(-10, 10)
#plt.xlim(0, x_max_pic/4)
print(x_pic_ion.shape[1], x_pic_electron.shape[1])
# Out:
# 19958 19997

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

rho_mhd = U[0, :]
u_mhd = U[1, :] / rho_mhd 
v_mhd = U[2, :] / rho_mhd 
w_mhd = U[3, :] / rho_mhd 
Bx_mhd = U[4, :]
By_mhd = U[5, :]
Bz_mhd = U[6, :]
e_mhd = U[7, :]
p_mhd = (gamma_mhd-1) * (e_mhd - rho_mhd*(u_mhd**2+v_mhd**2+w_mhd**2)/2
                          - (Bx_mhd**2+By_mhd**2+Bz_mhd**2)/2)

ax1.plot(x_coordinate_mhd, rho_mhd, marker='o')
ax2.plot(x_coordinate_mhd, p_mhd, marker='o')
ax3.plot(x_coordinate_mhd, u_mhd, marker='o')
ax4.plot(x_coordinate_mhd, v_mhd, marker='o')
ax5.plot(x_coordinate_mhd, By_mhd, marker='o')
ax6.plot(x_coordinate_mhd, Bz_mhd, marker='o')

ax1.set_title(r"$\rho$", fontsize=24)
ax2.set_title(r"$p$", fontsize=24)
ax3.set_title(r"$u$", fontsize=24)
ax4.set_title(r"$v$", fontsize=24)
ax5.set_title(r"$B_y$", fontsize=24)
ax6.set_title(r"$B_z$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax5.tick_params(labelsize=16)
ax6.tick_params(labelsize=16)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

plt.suptitle(f"t = {k}", y=0.95, fontsize=32)

plt.show()

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

rho_pic = m_electron * zeroth_moment_electron + m_ion * zeroth_moment_ion
bulk_speed_ion_pic = first_moment_ion / (zeroth_moment_ion + 1e-10)
bulk_speed_electron_pic = first_moment_electron / (zeroth_moment_electron + 1e-10)
bulk_speed_pic = (m_electron * bulk_speed_electron_pic + m_ion * bulk_speed_ion_pic) / (m_electron + m_ion)
v_thi_squared_pic = ((second_moment_ion[0, :] + second_moment_ion[4, :] + second_moment_ion[8, :])
                      - zeroth_moment_ion * (bulk_speed_ion_pic[0, :]**2 + bulk_speed_ion_pic[1, :]**2 + bulk_speed_ion_pic[2, :]**2)) \
                      / 3.0 / (zeroth_moment_ion + 1e-10)
v_the_squared_pic = ((second_moment_electron[0, :] + second_moment_electron[4, :] + second_moment_electron[8, :])
                     - zeroth_moment_electron * (bulk_speed_electron_pic[0, :]**2 + bulk_speed_electron_pic[1, :]**2 + bulk_speed_electron_pic[2, :]**2)) \
                      / 3.0 / (zeroth_moment_electron + 1e-10)
p_pic = zeroth_moment_electron * m_electron * v_the_squared_pic / 2.0 + zeroth_moment_ion * m_ion * v_thi_squared_pic / 2.0
p_mhd = p_pic

ax1.plot(x_coordinate_pic, rho_pic, marker='o')
ax2.plot(x_coordinate_pic, B[1, :], marker='o')
ax3.plot(x_coordinate_pic, B[2, :], marker='o')
ax4.plot(x_coordinate_pic, p_mhd, marker='o')
ax5.plot(x_coordinate_pic, E[1, :], marker='o')
ax6.plot(x_coordinate_pic, E[2, :], marker='o')

ax1.set_title(r"$\rho$", fontsize=24)
ax2.set_title(r"$B_y$", fontsize=24)
ax3.set_title(r"$B_z$", fontsize=24)
ax4.set_title(r"$p_{MHD}$", fontsize=24)
ax5.set_title(r"$E_y$", fontsize=24)
ax6.set_title(r"$E_z$", fontsize=24)
ax1.tick_params(labelsize=16)
ax2.tick_params(labelsize=16)
ax3.tick_params(labelsize=16)
ax4.tick_params(labelsize=16)
ax5.tick_params(labelsize=16)
ax6.tick_params(labelsize=16)
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

plt.show()

# %% [markdown]
# 動画作成

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

filename = "bulkflow_MHD-PIC_MHD.mp4"

interval = 5
plot_steps = 1000
for i in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()
    ax5.clear()
    ax6.clear()

    U = np.load(f"results_MH_bulkflow/U1_{i}.npy")
    rho = U[0, :]
    u = U[1, :] / rho 
    v = U[2, :] / rho 
    w = U[3, :] / rho 
    Bx = U[4, :]
    By = U[5, :]
    Bz = U[6, :]
    e = U[7, :]
    p = (gamma_mhd-1) * (e - rho*(u**2+v**2+w**2)/2 - (Bx**2+By**2+Bz**2)/2)

    ax1.plot(x_coordinate_mhd, rho / rho0_mhd, marker='o')
    ax2.plot(x_coordinate_mhd, p / p0_mhd, marker='o')
    ax3.plot(x_coordinate_mhd, u / u_init, marker='o')
    ax4.plot(x_coordinate_mhd, v, marker='o')
    ax5.plot(x_coordinate_mhd, By / B0_mhd, marker='o')
    ax6.plot(x_coordinate_mhd, Bz / B0_mhd, marker='o')

    ax1.set_ylim(0.5, 1.5)
    ax2.set_ylim(0.5, 2.0)
    ax3.set_ylim(0.9, 1.1)
    ax4.set_ylim(-0.3, 0.3)
    ax5.set_ylim(-0.1, 0.1)
    ax6.set_ylim(-0.1, 0.1)

    ax1.set_title(r"$\rho$", fontsize=24)
    ax2.set_title(r"$p$", fontsize=24)
    ax3.set_title(r"$u$", fontsize=24)
    ax4.set_title(r"$v$", fontsize=24)
    ax5.set_title(r"$B_y$", fontsize=24)
    ax6.set_title(r"$B_z$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax5.tick_params(labelsize=16)
    ax6.tick_params(labelsize=16)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()
    ax5.grid()
    ax6.grid()

    plt.suptitle(f"t = {i}", y=0.95, fontsize=32)

    fig.savefig(f'./pictures/{i}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for i in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{i}.png')
    video.write(img)
video.release()

# %%
fig = plt.figure(figsize=(18, 12))
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
ax6 = fig.add_subplot(236)

filename = "bulkflow_MHD-PIC_PIC.mp4"

interval = 5
plot_steps = 1000
for i in range(0, plot_steps+1, interval):
    ax1.clear()
    ax2.clear()
    ax3.clear()
    ax4.clear()
    ax5.clear()
    ax6.clear()

    B = np.load(f"results_MH_bulkflow/B_{i}.npy")
    E = np.load(f"results_MH_bulkflow/E_{i}.npy")
    x_pic_ion = np.load(f"results_MH_bulkflow/x_ion_{i}.npy")
    x_pic_electron = np.load(f"results_MH_bulkflow/x_electron_{i}.npy")
    v_pic_ion = np.load(f"results_MH_bulkflow/v_ion_{i}.npy")
    v_pic_electron = np.load(f"results_MH_bulkflow/v_electron_{i}.npy")

    zeroth_moment_ion = np.zeros(nx_pic)
    zeroth_moment_electron = np.zeros(nx_pic)
    zeroth_moment_ion = get_zeroth_moment(x_pic_ion, nx_pic, dx_pic, zeroth_moment_ion)
    zeroth_moment_electron = get_zeroth_moment(x_pic_electron, nx_pic, dx_pic, zeroth_moment_electron)
    first_moment_ion = np.zeros([3, nx_pic])
    first_moment_electron = np.zeros([3, nx_pic])
    first_moment_ion = get_first_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, first_moment_ion)
    first_moment_electron = get_first_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, first_moment_electron)
    second_moment_ion = np.zeros([9, nx_pic])
    second_moment_electron = np.zeros([9, nx_pic])
    second_moment_ion = get_second_moment(c, v_pic_ion, x_pic_ion, nx_pic, dx_pic, second_moment_ion)
    second_moment_electron = get_second_moment(c, v_pic_electron, x_pic_electron, nx_pic, dx_pic, second_moment_electron)

    rho_pic = m_electron * zeroth_moment_electron + m_ion * zeroth_moment_ion
    bulk_speed_ion_pic = first_moment_ion / (zeroth_moment_ion + 1e-10)
    bulk_speed_electron_pic = first_moment_electron / (zeroth_moment_electron + 1e-10)
    bulk_speed_pic = (m_electron * bulk_speed_electron_pic + m_ion * bulk_speed_ion_pic) / (m_electron + m_ion)
    v_thi_squared_pic = ((second_moment_ion[0, :] + second_moment_ion[4, :] + second_moment_ion[8, :])
                      - zeroth_moment_ion * (bulk_speed_ion_pic[0, :]**2 + bulk_speed_ion_pic[1, :]**2 + bulk_speed_ion_pic[2, :]**2)) \
                      / 3.0 / (zeroth_moment_ion + 1e-10)
    v_the_squared_pic = ((second_moment_electron[0, :] + second_moment_electron[4, :] + second_moment_electron[8, :])
                      - zeroth_moment_electron * (bulk_speed_electron_pic[0, :]**2 + bulk_speed_electron_pic[1, :]**2 + bulk_speed_electron_pic[2, :]**2)) \
                      / 3.0 / (zeroth_moment_electron + 1e-10)

    p_pic = zeroth_moment_electron * m_electron * v_the_squared_pic / 2.0 + zeroth_moment_ion * m_ion * v_thi_squared_pic / 2.0
    p_mhd = p_pic

    ax1.plot(x_coordinate_pic, rho_pic / rho0_mhd, marker='o')
    ax2.plot(x_coordinate_pic, B[1, :] / B0_pic, marker='o')
    ax3.plot(x_coordinate_pic, B[2, :] / B0_pic, marker='o')
    ax4.plot(x_coordinate_pic, p_mhd / p0_mhd, marker='o')
    ax5.plot(x_coordinate_pic, E[1, :], marker='o')
    ax6.plot(x_coordinate_pic, E[2, :], marker='o')

    ax1.set_ylim(0.5, 1.5)
    ax2.set_ylim(-0.2, 0.2)
    ax3.set_ylim(-0.2, 0.2)
    ax4.set_ylim(0.5, 2.0)
    ax5.set_ylim(-0.2, 0.2)
    ax6.set_ylim(-0.2, 0.2)

    ax1.set_title(r"$\rho$", fontsize=24)
    ax2.set_title(r"$B_y$", fontsize=24)
    ax3.set_title(r"$B_z$", fontsize=24)
    ax4.set_title(r"$p_{MHD}$", fontsize=24)
    ax5.set_title(r"$E_y$", fontsize=24)
    ax6.set_title(r"$E_z$", fontsize=24)
    ax1.tick_params(labelsize=16)
    ax2.tick_params(labelsize=16)
    ax3.tick_params(labelsize=16)
    ax4.tick_params(labelsize=16)
    ax5.tick_params(labelsize=16)
    ax6.tick_params(labelsize=16)
    ax1.grid()
    ax2.grid()
    ax3.grid()
    ax4.grid()
    ax5.grid()
    ax6.grid()

    plt.suptitle(f"t = {i}", y=0.95, fontsize=32)

    fig.savefig(f'./pictures/{i}.png', dpi=200)


img = cv2.imread(f'./pictures/0.png')
framesize = (img.shape[1], img.shape[0])
fps = 5.0

fourcc = cv2.VideoWriter_fourcc('m','p','4','v')
video  = cv2.VideoWriter(filename=filename, fourcc=fourcc, fps=fps, frameSize=framesize)

for i in range(0, plot_steps+1, interval):
    img = cv2.imread(f'./pictures/{i}.png')
    video.write(img)
video.release()
